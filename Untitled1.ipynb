# %%
import pandas as pd

# %%
start = pd.read_csv("start_p2.csv")
final = pd.read_csv("final_p2.1.csv")

# %%
final
# Out:
#           Km      Vmax  activity   X  IR  pot2   ph  temp  dstr   lgCmin  ...  \
# 0        NaN       NaN       1.0 NaN NaN   NaN  6.2  25.0   NaN      NaN  ...
# 1        NaN       NaN       1.0 NaN NaN   NaN  5.8  35.0   NaN      NaN  ...
# 2        NaN       NaN       1.0 NaN NaN   NaN  5.8   4.0   NaN      NaN  ...
# 3        NaN       NaN       1.0 NaN NaN   NaN  5.8   4.0   NaN      NaN  ...
# 4     0.4913  0.004380       1.0 NaN NaN   NaN    4  35.0   3.0 -1.00000  ...
# ...      ...       ...       ...  ..  ..   ...  ...   ...   ...      ...  ...
# 9040  0.0350  0.060700       1.0 NaN NaN   NaN  7.0  22.5   NaN -2.39794  ...
# 9041  0.0360  0.058833       1.0 NaN NaN   NaN  7.0  22.5   NaN -2.39794  ...
# 9042  0.0330  0.053133       1.0 NaN NaN   NaN  7.0  22.5   NaN -2.39794  ...
# 9043  0.0310  0.049750       1.0 NaN NaN   NaN  7.0  22.5   NaN -2.39794  ...
# 9044     NaN       NaN       1.0 NaN NaN   NaN  7.5   4.0   NaN      NaN  ...
#
# ...

# %%
((final[["X", "IR", "pot2"]].isna().sum(axis=1) == 3) + start[["formula", "activity"]].isna().any(axis=1)).sum()
# Out:
# np.int64(5867)

# %%
# every (X, ir, pot2) formula property is nan or formula is nan or activity is nan
condition = ~((final[["X", "IR", "pot2"]].isna().sum(axis=1) == 3) +\
              start[["formula", "activity"]].isna().any(axis=1))

# %%
final[condition]
# Out:
#           Km          Vmax  activity         X        IR      pot2   ph  temp  \
# 7        NaN           NaN       1.0  2.215000       NaN -0.140000  NaN   NaN
# 11     0.020           NaN       1.0  2.750000  1.114286 -0.015429  5.0  55.0
# 14     0.010  1.000000e-03       1.0  2.675000       NaN -0.130000  3.5  50.0
# 15     0.010  1.000000e-03       1.0  2.675000       NaN -0.130000  3.5  50.0
# 19     0.150  3.800000e-05       2.0  2.200000       NaN  0.000000    4  25.0
# ...      ...           ...       ...       ...       ...       ...  ...   ...
# 9021   0.050  1.000000e-03       1.0  2.637907       NaN       NaN  3.5  25.0
# 9025  53.550  1.078000e-07       1.0  2.595556       NaN  0.000000  4.5  37.0
# 9026   0.213  5.477000e-08       1.0  2.595556       NaN  0.000000  4.5  37.0
# 9027     NaN           NaN       3.0  2.595556       NaN  0.000000  4.5  37.0
# 9036     NaN           NaN       1.0  2.750000  1.114286 -0.015429  5.5  25.0
#
# ...
