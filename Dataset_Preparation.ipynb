# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import unifyer as uf
from tqdm.notebook import tqdm
tqdm.pandas()

# %%
from importlib import reload
reload(uf);

# %%
df = pd.read_csv("data/LLM_unif.csv") # dataset generated by LLM with units

# %% [markdown]
# # Prepare LLM Dataset

# %% [markdown]
# ## Rename synonyms

# %% [markdown]
# For example:
# ```
# 'sheet-like': 'sheet',
# 'nanosheets': 'sheet',
# 'Nanosheets': 'sheet',
# ```

# %%
df["shape_unif"] = df["shape"].apply(uf.unify_shape)

# %%
df["activity_unif"] = df["activity"].apply(uf.unify_activity)

# %%
df["polymer_unif"] = df["polymer_used_in_synthesis"].apply(uf.unify_polymer)

# %%
df["surfactant_unif"] = df["surfactant"].apply(uf.unify_surfactant)

# %% [markdown]
# ## Rename dataset columns according to 'start_df.csv'

# %%
usefull_columns_and_rename = {
    'formula': 'formula',
    # no type
    'activity_unif': 'activity',
    # no Syngony
    'shape_unif': 'shape',
    'length_mean': 'length, nm',
    'width_mean': 'width, nm',
    'depth_mean': 'depth, nm',
    'size_mean': 'size, nm', # only in my dataset
    # no Sufrace
    # no surface
    'polymer_unif': 'pol',
    'surfactant_unif': 'surf',
    # no Mw(coat), g/mol
    'km_unif': 'Km, mM',
    'vmax_unif': 'Vmax, mM/s',
    'reaction_type': 'ReactionType',
    # no Subtype
    'c_min_unif': 'C min, mM',
    # no Vsub_min(mL)
    'c_max_unif': 'C max, mM',
    # no Vsub_max(mL)
    'concentration_of_co_substrate_unif': 'C(const), mM',  #  C(const)
    # no Vsub_const(mL)
    'concentration_of_nanoparticles_unif': 'Ccat(mg/mL)', #  C(cat)
    # no Vcat(mL)
    # no Ccat(mkM)
    'p_h': 'ph',
    'temperature': 'temp, °C',
    # no 'Vbuffer(mL)', 'Dstr', 'mX', 'mROx', 'mCD', 'volume', 'Mr, g/mol'
    'zeta_potential_unif': 'Zpotential',
    'surface_area_unif': 'SurfaceArea, m^2/g',
}

# %%
df = df[list(usefull_columns_and_rename.keys())].rename(columns=usefull_columns_and_rename)

# %% [markdown]
# ## Fill length, width, depth with sizse if Nan

# %%
cols_to_fill = ['length, nm', 'width, nm', 'depth, nm']
for col in cols_to_fill:
    df[col] = df[col].fillna(df['size, nm'])

# %% [markdown]
# ## Remove temperature units

# %%
import re
def convert_temp(temp_str):
    
    if uf.check_nan(temp_str):
        return np.nan
    temp_str = temp_str.replace("~", "").lower().replace("_", " ")
    
    match = re.match(r"(\d+(?:\.\d+)?)\s*\-\s*(\d+(?:\.\d+)?)\s*(?:°c|degrees celsius|c|degree celsius)", temp_str)
    if match:
        mn, mx = match.groups()
        return (float(mn)+float(mx))/2

    match = re.match(r"(\d+(?:\.\d+)?)\s*(?:°c|degrees celsius|c|degree celsius)", temp_str)
    if match:
        return float(match.groups()[0])

    match = re.match(r"(\d+(?:\.\d+)?)\s*±\s*(\d+(?:\.\d+)?)\s*(?:°c|degrees celsius|c|degree celsius)", temp_str)
    if match:
        return float(match.groups()[0])

    print(temp_str)
    return np.nan
df["temp, °C"] = df["temp, °C"].apply(convert_temp)
# Out:
# 298 k
# 298 k
# 298 k
# 298 k
# 298 k
# 298 k
# 298 k
# 298 k
# 298.15 k
# 298.1 k
# 298.1 k
# 298.1 k
# 298.1 k
# 298.1 k
# 298.1 k
# 298.1 k
# 300 k
# 300 k
# 300 k
# 300 k
# 298.15 k
# 293 k
# 293 k
# 293 k
# 293 k
# 295 k
# 295 k
# 293 k
# 293 k
# 293 k
# 293 k
# 293 k
# 5 min
# 5 min
# 298 k
# 298 k
# 303.1 k
# 303.1 k
# ambient
# 303 k
# 303 k
# ambient
# 298 k
# 278-328 k
# 310.00 k
# 310.00 k
# 20 - -30 °c
# 20 - -30 °c
# 25 degree c
# 25 degree c
# 298 k
# 298 k
# 298 k
# 298 k
# 310 k
# 4 degrees centigrade
# 4 degrees centigrade
# 8 k
# 8 k
# ambient
# 295 k
# 300 k
# 300 k
# 300 k
# 298 k
# 298 k
# 298 k
# 298 k
# 298 k
# 298 k
# 25 degrees c
# 25 degrees c
# 307 k
# 298 k
# 298 k
# 298 k
# 50 # einsteins/m2/s
# 365 millidegree
# 83-88 f
# 85-88 f
# 79-90 f
# 85-88 f
# 79-90 f
# 79-90 f
# 363 k
# 298 k
# 298 k
# 303 k
# 303 k
# 303 k
# 310 k
# 298 k
# 310 k
# 310 k
# 310 k
# 298 k
# 298 k
# 298 k
# 343 k
# 305 k
# 293 k
# 293 k
# 293 k
# 293 k
# 293 k
# 293 k
# 293 k
# 293 k
# 293 k
# 293 k
# room temperature
# room temperature
# room temperature
# room temperature
# 300 k
# 300 k
# 298.15 k
# 298.15 k
# 298.15 k
# 298 k
# 298 k
# 298 k
# 298 k
# 140 f

# %% [markdown]
# # Make descriptors

# %%
import functions.functions_a as fu

# %%
reload(fu);

# %%
res_df = pd.DataFrame()

# %% [markdown]
# ## X

# %%
def createX(formula):
    if uf.check_nan(formula):
        return np.nan
    try:
        composition = fu.Composition(formula)
    except:
        print(f"ERR creating composition {formula}")
        return np.nan

    X = composition.average_electroneg
    return X

# %%
res_df["X"] = df["formula"].apply(createX)
# Out:
# ERR creating composition N-CQDs
# ERR creating composition N-CQDs
# ERR creating composition u-cytc550
# ERR creating composition u-cytc550
# ERR creating composition u-cytc550
# ERR creating composition u-cytc550
# ERR creating composition BSA-PtAu@CNS
# ERR creating composition BSA-PtAu@CNS
# ERR creating composition Cys-AuNCs
# ERR creating composition CaO2/DOX
# ERR creating composition CaO2/DOX@SiO2/DOX
# ERR creating composition CaO2/DOX@SiO2/DOX-MnO2
# ERR creating composition CaO2/DOX@SiO2/DOX-MnO2
# ERR creating composition CaO2/DOX@SiO2/DOX-MnO2
# ERR creating composition Fe3O4/Pβ-CD
# ERR creating composition Fe3O4/Pβ-CD
# ERR creating composition SeO32-
# ERR creating composition (CyaSe)2
# ERR creating composition 3-amino-9-ethylcarbazole
# ERR creating composition o-tolidine
# ERR creating composition FeIII–TMPyP
# ERR creating composition AuNPs/MCA
# ERR creating composition AuNPs/MCA
# ERR creating composition Mn3O4/Pd@Pt
# ERR creating composition Mn3O4/Pd@Pt
# ERR creating composition P@Pt@P-Au
# ERR creating composition P@Pt@P-Au
# ERR creating composition P@Pt@P-Au
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition AuNPs
# ERR creating composition AuNPs
# ERR creating composition cyt c
# ERR creating composition cyt c
# ERR creating composition PRT-AuNCs
# ERR creating composition PRT-AuNCs
# ERR creating composition 3(cid:11)-H9
# ERR creating composition 3(cid:11)-H12
# ERR creating composition Ag-Fe3O4
# ERR creating composition Ag-Fe3O4
# ERR creating composition Dex-IONP-GOx
# ERR creating composition Dex-IONP-GOx
# ERR creating composition C-dot/NiAl-LDH
# ERR creating composition C-dot/NiAl-LDH
# ERR creating composition Au-Ag
# ERR creating composition Au-Ag
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Fe3O4/Au
# ERR creating composition Fe3O4/Au
# ERR creating composition Fe3O4/Au
# ERR creating composition Fe3O4/Au
# ERR creating composition Cu 1.8S–cgmc
# ERR creating composition Cu 1.8S–cgmc
# ERR creating composition ZIF-8@BHb
# ERR creating composition ZIF-8@BHb
# ERR creating composition ZIF-8@BHb
# ERR creating composition G3.0-He
# ERR creating composition G3.0-He
# ERR creating composition HRP^SP
# ERR creating composition 3 MgCO3·9 Mg(OH)2·3 H2O
# ERR creating composition CH3Se-
# ERR creating composition c-cyts
# ERR creating composition HRP-OX
# ERR creating composition YcYfetus
# ERR creating composition Fe3+
# ERR creating composition Fe3+
# ERR creating composition 4c15
# ERR creating composition 4c15A4
# ERR creating composition 4c15A12
# ERR creating composition 4c15A20
# ERR creating composition Cu2+
# ERR creating composition Cu2+
# ERR creating composition Cu2+
# ERR creating composition Cu2+
# ERR creating composition Cu2+
# ERR creating composition Cu2+
# ERR creating composition Cu2+
# ERR creating composition Pt-WO3-r-GO
# ERR creating composition Fe-N-C
# ERR creating composition Fe-N-C
# ERR creating composition cyt c
# ERR creating composition cyt c
# ERR creating composition Sm-CeO2
# ERR creating composition GO-CTAB-AuNP-hemin
# ERR creating composition GO-CTAB-AuNP-hemin
# ERR creating composition GO-CTAB-AuNP-hemin
# ERR creating composition GO-CTAB-AuNP-hemin
# ERR creating composition AuPd-NH2-fMnO2
# ERR creating composition AuPd-NH2-fMnO2
# ERR creating composition TfuCat
# ERR creating composition TfuCat
# ERR creating composition Au-Hg/rGO
# ERR creating composition Au-Hg/rGO
# ERR creating composition Prostaglandin H Synthase
# ERR creating composition Prostaglandin H Synthase
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition SYI-2074
# ERR creating composition Cu(Nc)22+
# ERR creating composition Cu(Nc)22+
# ERR creating composition Cu2-xSe
# ERR creating composition Cu2-xSe
# ERR creating composition Cu2-xSe
# ERR creating composition Cu2-xSe
# ERR creating composition BLG-Heme
# ERR creating composition BLG-T-Heme
# ERR creating composition BLG-C-Heme
# ERR creating composition BLG-K-Heme
# ERR creating composition Crystallin-Heme
# ERR creating composition CD44 MMSN/AuNPs
# ERR creating composition CD44 MMSN/AuNPs
# ERR creating composition Au-Pt/SiO2
# ERR creating composition Au-Pt/SiO2
# ERR creating composition cSelS
# ERR creating composition cSelS
# ERR creating composition cSelS C174S
# ERR creating composition AuNWs
# ERR creating composition PBNPs@AuNWs
# ERR creating composition Pt-GNRs
# ERR creating composition Pt-GNRs
# ERR creating composition TiO2@CeOx
# ERR creating composition TiO2@CeOx
# ERR creating composition TiO2@CeOx
# ERR creating composition TiO2@CeOx
# ERR creating composition ficin-TN
# ERR creating composition ficin-TN
# ERR creating composition cit-PHGPx
# ERR creating composition ST1Cys
# ERR creating composition ST2Cys
# ERR creating composition ST1Sec
# ERR creating composition ST2Sec
# ERR creating composition GSH-Px
# ERR creating composition Cyt c
# ERR creating composition PPAuMns
# ERR creating composition PPAuMns
# ERR creating composition PPAuMns
# ERR creating composition PPAuMns
# ERR creating composition PPAuMns
# ERR creating composition PPAuMns
# ERR creating composition PPAuMns
# ERR creating composition PPAuMns
# ERR creating composition PPAuMns
# ERR creating composition Co/CuS-MMT
# ERR creating composition Co/CuS-MMT
# ERR creating composition g-C3N4-PdNPs
# ERR creating composition g-C3N4-PdNPs
# ERR creating composition MnCcP.1
# ERR creating composition Tyr36Phe-MnCcP.1
# ERR creating composition Lys179Arg-MnCcP.1
# ERR creating composition Ile40Gly-MnCcP.1
# ERR creating composition Tyr36Phe/Lys179Arg-MnCcP.1
# ERR creating composition Ile40Gly/Lys179Arg-MnCcP.1
# ERR creating composition Tyr36Phe/Ile40Gly-MnCcP.1
# ERR creating composition Tyr36Phe/Ile40Gly/Lys179Arg-MnCcP.1
# ERR creating composition Mn-TCPP
# ERR creating composition Fe-TCPP
# ERR creating composition Mn-TCPP
# ERR creating composition Mn-TCPP
# ERR creating composition h-Fe3O4@ppy
# ERR creating composition h-Fe3O4@ppy
# ERR creating composition ZnPc-GQDs-MnO2@PtNPs
# ERR creating composition CP 600−6
# ERR creating composition CP 600−6
# ERR creating composition HRP-avidin
# ERR creating composition HRP-avidin
# ERR creating composition HRP-avidin
# ERR creating composition HRP-avidin
# ERR creating composition HRP-avidin
# ERR creating composition HRP-avidin
# ERR creating composition Fe3O4@Cu/GMP
# ERR creating composition PB-Ft
# ERR creating composition PB-Ft
# ERR creating composition PB-Ft
# ERR creating composition PB-Ft
# ERR creating composition Selenium-enriched yeast
# ERR creating composition Selenium-enriched alga Chlorella
# ERR creating composition L4.6k-dG4
# ERR creating composition L4.6k-dG4
# ERR creating composition AuNPs@g-C3N4
# ERR creating composition AuNPs@g-C3N4
# ERR creating composition g-C3N4
# ERR creating composition g-C3N4
# ERR creating composition Prussian Blue
# ERR creating composition Co/PMCS
# ERR creating composition Cu−N−C
# ERR creating composition Zn−N−C
# ERR creating composition Co−N−C
# ERR creating composition Fe−N−C
# ERR creating composition Cu−N−C
# ERR creating composition Hemin-T 10-EAD2
# ERR creating composition Hemin-T 10-EAD2
# ERR creating composition Hemin-T 10-EAD2
# ERR creating composition Hemin-T 10-EAD2
# ERR creating composition La3+
# ERR creating composition La3+
# ERR creating composition DNA50/hemin
# ERR creating composition Control1
# ERR creating composition Control1/hemin
# ERR creating composition Control2
# ERR creating composition Control2/hemin
# ERR creating composition Control3
# ERR creating composition Control3/hemin
# ERR creating composition G-PhB
# ERR creating composition G-PhB
# ERR creating composition Fe3O4@PDA@Pd/Pt
# ERR creating composition Fe3O4@PDA@Pd/Pt
# ERR creating composition PhSe2
# ERR creating composition Ficin
# ERR creating composition Ficin
# ERR creating composition MoS2-Au@Pt
# ERR creating composition MoS2-Au@Pt
# ERR creating composition FeIII–mimochrome VI
# ERR creating composition FeIII–mimochrome VI
# ERR creating composition FeIII–mimochrome VI
# ERR creating composition FeIII–mimochrome VI
# ERR creating composition Se-scFv-B3
# ERR creating composition H170A hHRP
# ERR creating composition H170A hHRP
# ERR creating composition 5Fe2O3•9H2O
# ERR creating composition Cu2+
# ERR creating composition Cu2+
# ERR creating composition NH2-MIL-88B(Fe)
# ERR creating composition NH2-MIL-88B(Fe)
# ERR creating composition NMC Tp-TTA
# ERR creating composition NMC Tp-TTA
# ERR creating composition AuNPs@POMD-8pep
# ERR creating composition AuNPs@POMD-8pep
# ERR creating composition VOx
# ERR creating composition VOx
# ERR creating composition Cu-N-C
# ERR creating composition Cu-N-C
# ERR creating composition cationic Au NCs
# ERR creating composition cationic Au NCs
# ERR creating composition cationic Au NCs
# ERR creating composition cationic Au NCs
# ERR creating composition Fc
# ERR creating composition Fc
# ERR creating composition PDI/Si-CeO2
# ERR creating composition PDI/Si-CeO2
# ERR creating composition Co-MOF
# ERR creating composition Fe/Al-GNE
# ERR creating composition Fe/Al-GNE
# ERR creating composition Fe/Al-GNE
# ERR creating composition Fe/Al-GNE
# ERR creating composition SWNT-NH2@hemin
# ERR creating composition SWNT-NH2@hemin
# ERR creating composition SWNT@hemin
# ERR creating composition SWNT@hemin
# ERR creating composition SWNT-COOH@hemin
# ERR creating composition SWNT-COOH@hemin
# ERR creating composition Sepp1UF
# ERR creating composition Sepp1UF
# ERR creating composition Sepp1UF
# ERR creating composition Sepp1UF
# ERR creating composition NBD-CL
# ERR creating composition NBD-CL
# ERR creating composition Pd-WO3-SiO2
# ERR creating composition Pd-WO3-SiO2-PB
# ERR creating composition Pd-WO3-SiO2-PB
# ERR creating composition Pd-WO3-SiO2
# ERR creating composition Pd-WO3-SiO2-PB
# ERR creating composition Fe3O4/SiO2/Gr
# ERR creating composition Fe3O4/SiO2/Gr
# ERR creating composition Fe3O4/SiO2/Gr
# ERR creating composition Fe3O4/SiO2/Gr
# ERR creating composition Co(II) complex 1
# ERR creating composition Co(II) complex 2
# ERR creating composition Catalase
# ERR creating composition Hemoglobin
# ERR creating composition Cu–hemin
# ERR creating composition Cu–hemin
# ERR creating composition Fe-SAs/NC
# ERR creating composition Fe-SAs/NC
# ERR creating composition Cu2O/Au
# ERR creating composition Cu2O/Au
# ERR creating composition Ni-CuAu
# ERR creating composition Ni-CuAu
# ERR creating composition β-CD-hemin
# ERR creating composition β-CD-hemin
# ERR creating composition Fe3O4/g-C3N4
# ERR creating composition Fe3O4/g-C3N4
# ERR creating composition Fe3O4/g-C3N4
# ERR creating composition Fe3O4/g-C3N4
# ERR creating composition Cu,Zn-SOD
# ERR creating composition Cu,Zn-SOD
# ERR creating composition [MnIIIMnII(Ldtb)((cid:2)-OAc)2]BPh4
# ERR creating composition 4c15-s
# ERR creating composition 4c15
# ERR creating composition DPPC-PI
# ERR creating composition DPPC-PI
# ERR creating composition DPPC-PI
# ERR creating composition DPPC-PI
# ERR creating composition DPPC-PI
# ERR creating composition DPPC-PI
# ERR creating composition VHb
# ERR creating composition VHb
# ERR creating composition VHb
# ERR creating composition CcpA
# ERR creating composition FeIII-MC6*
# ERR creating composition FeIII-MC6*
# ERR creating composition FeIII-MC6*a
# ERR creating composition FeIII-MC6*a
# ERR creating composition T-DMSNs@Au
# ERR creating composition T-DMSNs@Au
# ERR creating composition SWNT/Mb
# ERR creating composition SWNT/HRP
# ERR creating composition Fe(TpCPP)
# ERR creating composition Fe(TpCPP)
# ERR creating composition Fe(TpCPP)-Xln10A
# ERR creating composition Fe(TpCPP)-Xln10A
# ERR creating composition N-doped Fe3C
# ERR creating composition MWCNT@rGONR
# ERR creating composition MWCNT@rGONR
# ERR creating composition MoS2-Au
# ERR creating composition MoS2-Au
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Fe(III)Hb
# ERR creating composition Fe(III)Hb
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Prx1
# ERR creating composition Prx1
# ERR creating composition Mn-TPPS
# ERR creating composition GO-UO22+
# ERR creating composition CS-MoSe2
# ERR creating composition CS-MoSe2
# ERR creating composition CS-MoSe2
# ERR creating composition CS-MoSe2
# ERR creating composition 2-(benzylselanyl)phenyl)methanamine
# ERR creating composition Cytc
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition CatG4
# ERR creating composition Fe@Fe3O4@Cu2-xS
# ERR creating composition Fe@Fe3O4@Cu2-xS
# ERR creating composition Au-Cu(II)
# ERR creating composition Au-Cu(II)
# ERR creating composition CH3-C(CH3)2CH2C(CH3)2-C6H4-O(C2H4O)9_I0-H
# ERR creating composition C12H25N(COC(CH3)=CH2)-(C2H40)Is-H
# ERR creating composition C18H37NH(C2H40)10-H
# ERR creating composition C18H37NH(C2H40)15-H
# ERR creating composition ethanol
# ERR creating composition propanol-2
# ERR creating composition butanol
# ERR creating composition CuO-Au
# ERR creating composition CuO-Au
# ERR creating composition Ag-Au
# ERR creating composition Ag-Au
# ERR creating composition Ag-Au
# ERR creating composition Ag-Au
# ERR creating composition metMb
# ERR creating composition N-(2-nitrophenyl) benzenesulfonamide
# ERR creating composition NPY–heme
# ERR creating composition NPY–heme
# ERR creating composition guaiacol
# ERR creating composition guaiacol
# ERR creating composition Kaol-ycc
# ERR creating composition Kaol-E20-ycc
# ERR creating composition Kaol-ycc
# ERR creating composition Kaol-E40-ycc
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Phe68azoAla
# ERR creating composition Phe179azoAla
# ERR creating composition PC-OOH
# ERR creating composition PC-OOH
# ERR creating composition H2O2 + TMB
# ERR creating composition H2O2 + OPD
# ERR creating composition Fe-CNNPs
# ERR creating composition Fe-CNNPs
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Hemoglobin
# ERR creating composition Hemoglobin
# ERR creating composition Horseradish peroxidase
# ERR creating composition Horseradish peroxidase
# ERR creating composition AuNPs–SWNTs
# ERR creating composition AuNPs–SWNTs
# ERR creating composition ficin
# ERR creating composition Au−Ag/L-Cys-rGO
# ERR creating composition Au−Ag/L-Cys-rGO
# ERR creating composition Au/L-Cys-rGO
# ERR creating composition Au/L-Cys-rGO
# ERR creating composition Ag/L-Cys-rGO
# ERR creating composition Ag/L-Cys-rGO
# ERR creating composition Cu-Pt
# ERR creating composition POM-Calix hybrid
# ERR creating composition POM-Calix hybrid
# ERR creating composition Mn-HPyP
# ERR creating composition Mn-HPyP
# ERR creating composition Mn-HPyP
# ERR creating composition AuNPs@MoS2-QDs
# ERR creating composition AuNPs@MoS2-QDs
# ERR creating composition 15SeP 1
# ERR creating composition 15SeP 1
# ERR creating composition 15SeP
# ERR creating composition 15SeP
# ERR creating composition IgG
# ERR creating composition Gd-MPO
# ERR creating composition Ni3(OH)2(C8H4O4)2(H2O)4·2H2O
# ERR creating composition Ni3(OH)2(C8H4O4)2(H2O)4·2H2O
# ERR creating composition Au NC micelles
# ERR creating composition NEQC-340
# ERR creating composition oPGHS-1
# ERR creating composition Por-CeO2
# ERR creating composition Por-CeO2
# ERR creating composition ycc
# ERR creating composition MP-8
# ERR creating composition MP-8
# ERR creating composition Ceruloplasmin
# ERR creating composition PNIPAM-CD-g-Te
# ERR creating composition PNIPAM-CD-g-Te
# ERR creating composition PNIPAM-CD-g-Te
# ERR creating composition PNIPAM-CD-g-Te
# ERR creating composition (25R)-5a-spirostane-2a,3b,5a-triol 3-O-(O-a-L-rhamnopyranosyl-(1 ? 2)-O-(b-D-galactopyranosyl-(1 ? 3))-b-D-glucopyranoside)
# ERR creating composition Fe3(PO4)2·8H2O
# ERR creating composition Fe3(PO4)2·8H2O
# ERR creating composition crystallin aggregate-heme
# ERR creating composition crystallin aggregate-heme
# ERR creating composition crystallin aggregate-heme
# ERR creating composition crystallin aggregate-heme
# ERR creating composition [SVW11O40]3-
# ERR creating composition [SVW11O40]3-
# ERR creating composition [SV2W10O40]4-
# ERR creating composition [SV2W10O40]4-
# ERR creating composition Fe-N-C
# ERR creating composition Au/Pt
# ERR creating composition Au/Pt
# ERR creating composition Au/Fe3O4/GO
# ERR creating composition Au/Fe3O4/GO
# ERR creating composition Hb
# ERR creating composition FTN_1133
# ERR creating composition FTN_1133
# ERR creating composition MoS2-COOH-MWCNT
# ERR creating composition Fe(por)
# ERR creating composition Fe(por)
# ERR creating composition ficin
# ERR creating composition ficin
# ERR creating composition Tg-HbI
# ERR creating composition Tg-HbII
# ERR creating composition Ti3C2Tx
# ERR creating composition Ti3C2Tx
# ERR creating composition Ti3C2Tx
# ERR creating composition DNA–Pt
# ERR creating composition DNA–Pt
# ERR creating composition g-CN@CuMOF
# ERR creating composition g-CN@CuMOF
# ERR creating composition Fe3C-NC
# ERR creating composition Fe5HO8·4H2O
# ERR creating composition Fe5HO8·4H2O
# ERR creating composition Fe3O4NP@pSiO2
# ERR creating composition Fe3O4NP@pSiO2
# ERR creating composition Fe3O4NP@pSiO2
# ERR creating composition Fe3O4NP@pSiO2
# ERR creating composition HRP/GO-GQDs
# ERR creating composition HRP/GO-GQDs
# ERR creating composition CeO2-Gd
# ERR creating composition CeO2-Gd
# ERR creating composition Co-MGNCs
# ERR creating composition Co-MGNCs
# ERR creating composition TA-Hb
# ERR creating composition TA-Hb
# ERR creating composition Cmcytc
# ERR creating composition Cmcytc
# ERR creating composition Cu,Zn-SOD
# ERR creating composition Cu,Zn-SOD
# ERR creating composition Ce-Fe3O4
# ERR creating composition Ce-Fe3O4
# ERR creating composition MoS2/N-rGO
# ERR creating composition MoS2/N-rGO
# ERR creating composition MoS2/N-rGO
# ERR creating composition MoS2/N-rGO
# ERR creating composition MoS2/N-rGO
# ERR creating composition 2-phenyl-1,2-benzisoselenazol-3(2H)-one
# ERR creating composition Cyt c
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Co-TCPP(Fe)
# ERR creating composition Cu-TCPP(Fe)
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Cu,Zn-SOD1
# ERR creating composition Cu,Zn-SOD1
# ERR creating composition CoMo hybrids
# ERR creating composition CoMo hybrids
# ERR creating composition CoMo hybrids
# ERR creating composition Tb-OBBA-Hemin
# ERR creating composition Tb-OBBA-Hemin
# ERR creating composition PS-[VVO(OMe)(hap-iah)]
# ERR creating composition Fe-iCOF
# ERR creating composition S-rGO
# ERR creating composition S-rGO
# ERR creating composition FeP-pSC4-AuNPs
# ERR creating composition FeP-pSC4-AuNPs
# ERR creating composition Ce0.94Fe0.06O2-δ
# ERR creating composition Ce0.94Fe0.06O2-δ
# ERR creating composition Fe3O4@MIL-100(Fe)
# ERR creating composition Fe3O4@MIL-100(Fe)
# ERR creating composition SDS-Hemin-Imidazole
# ERR creating composition AuNPs
# ERR creating composition AuNPs
# ERR creating composition CNT/FeNC
# ERR creating composition CNT/FeNC
# ERR creating composition Au@CD + CeO2
# ERR creating composition Au@CD + CeO2
# ERR creating composition Prx4
# ERR creating composition AgNPs@Fe3O4
# ERR creating composition AgNPs@Fe3O4
# ERR creating composition g-C3N4
# ERR creating composition g-C3N4
# ERR creating composition Fe-g-C3N4
# ERR creating composition Fe-g-C3N4
# ERR creating composition C44.0%H12.2%O23.3%N16.5%S4.01%
# ERR creating composition C44.0%H12.2%O23.3%N16.5%S4.01%
# ERR creating composition Fe(III)-protoporphyrin IX
# ERR creating composition Fe(III)-protoporphyrin IX
# ERR creating composition Prx2
# ERR creating composition Prx2
# ERR creating composition Prx2
# ERR creating composition Fe(III) protoporphyrin IX chloride
# ERR creating composition FeCu-DA/NC
# ERR creating composition FeCu-DA/NC
# ERR creating composition FeCu-DA/NC
# ERR creating composition ZnFe2O4/ZnO
# ERR creating composition Se-enriched yeast
# ERR creating composition MWNT-SP
# ERR creating composition MWNT-MC
# ERR creating composition CeO2/CoO
# ERR creating composition CeO2/CoO
# ERR creating composition AuPd@UiO-67
# ERR creating composition Co@C-dots
# ERR creating composition Co@C-dots
# ERR creating composition CAANSs
# ERR creating composition Fe-PorCOF
# ERR creating composition Fe-PorCOF
# ERR creating composition pTBCB-PEG
# ERR creating composition pTBCB-PEG
# ERR creating composition pTBCB-PEG
# ERR creating composition pTBCB-PEG
# ERR creating composition pTBCB-PEG
# ERR creating composition pTBCB-PEG
# ERR creating composition Fe3O4/MWCNTs
# ERR creating composition Fe3O4/MWCNTs
# ERR creating composition NAD+
# ERR creating composition NAD+
# ERR creating composition HbA0
# ERR creating composition HbA1c
# ERR creating composition Fe3O4@Cu/GMP
# ERR creating composition Fe3O4@Cu/GMP
# ERR creating composition Fe3O4@Cu/GMP-GOx
# ERR creating composition Fe3O4@Cu/GMP-GOx
# ERR creating composition Fe3O4@Cu/GMP-GOx
# ERR creating composition EbBz
# ERR creating composition Pt/Fe3O4-DIB-DETA-CNS
# ERR creating composition Pt/Fe3O4-DIB-DETA-CNS
# ERR creating composition Tf-trHb
# ERR creating composition Tf-trHb
# ERR creating composition Cu2-xSe
# ERR creating composition Cu2-xSe
# ERR creating composition Cu2-xSe
# ERR creating composition Cu2-xSe
# ERR creating composition Cu2-xSe
# ERR creating composition PtNPs@MnO2
# ERR creating composition Fe3O4-Sch
# ERR creating composition Fe3O4-Sch
# ERR creating composition Pt NC/3D GF
# ERR creating composition Pt NC/3D GF
# ERR creating composition Pt NC/3D GF
# ERR creating composition Pt NC/3D GF
# ERR creating composition ZIF-8/GO
# ERR creating composition ZIF-8/GO
# ERR creating composition ZIF-8/GO
# ERR creating composition ZIF-8/GO
# ERR creating composition ZnFe2O4/rGO
# ERR creating composition ZnFe2O4/rGO
# ERR creating composition Fe-N-C
# ERR creating composition PDA/PB
# ERR creating composition PDA/PB
# ERR creating composition Ac-PAL-AMC
# ERR creating composition Cu-MOFs
# ERR creating composition Cu-MOFs
# ERR creating composition Cu3(PO4)2⋅3H2O
# ERR creating composition Cu3(PO4)2⋅3H2O
# ERR creating composition Fe(III) protoporphyrin IX chloride
# ERR creating composition Fe(III) protoporphyrin IX chloride
# ERR creating composition Fe(III) protoporphyrin IX chloride
# ERR creating composition Fe(III) protoporphyrin IX chloride
# ERR creating composition Pt@PCN222-Mn
# ERR creating composition Pt@PCN222-Mn
# ERR creating composition β-CD@AuNPs
# ERR creating composition β-CD@AuNPs
# ERR creating composition β-CD@AuNPs
# ERR creating composition Ohr
# ERR creating composition Ohr
# ERR creating composition Ohr
# ERR creating composition Ohr
# ERR creating composition Ohr
# ERR creating composition c-di-GMP-proflavine-hemin
# ERR creating composition c-di-GMP-proflavine-hemin
# ERR creating composition c-di-GMP-proflavine-hemin
# ERR creating composition c-di-GMP-proflavine-hemin
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Au@meso-SiO2
# ERR creating composition CuS-MoS2
# ERR creating composition CuS-MoS2
# ERR creating composition Cyt-c
# ERR creating composition Cyt-c
# ERR creating composition Zn-N-C
# ERR creating composition Zn-N-C
# ERR creating composition C60(OH)nOm
# ERR creating composition C60(OH)nOm
# ERR creating composition C60(OH)nOm
# ERR creating composition GO/Au
# ERR creating composition GO/Au
# ERR creating composition Hemin + G-quadruplex
# ERR creating composition Hemin + G-quadruplex
# ERR creating composition H2O2+TMB
# ERR creating composition H2O2+TMB
# ERR creating composition Co3O4-CeO2
# ERR creating composition Co3O4-CeO2
# ERR creating composition GST A1-1
# ERR creating composition GST A1-1
# ERR creating composition Au-Pt
# ERR creating composition Au-Pt
# ERR creating composition CBP–Con A complex
# ERR creating composition Prx1p
# ERR creating composition Prx1p
# ERR creating composition Prx1p
# ERR creating composition Ser38-m-Prx1p
# ERR creating composition Ser38-m-Prx1p
# ERR creating composition Ser38-m-Prx1p
# ERR creating composition PG endoperoxide synthetase
# ERR creating composition Au@Co-Fe
# ERR creating composition Au@Co-Fe
# ERR creating composition Au@Co-Fe
# ERR creating composition Au@Co-Fe
# ERR creating composition Hb-Hp I-I intermediate complex
# ERR creating composition Hb-Hp I-I intermediate complex
# ERR creating composition Hb-Hp I-I saturated complex
# ERR creating composition Hb-Hp I-I saturated complex
# ERR creating composition Cu-mb
# ERR creating composition PAMTegel
# ERR creating composition PAMTegel
# ERR creating composition PAMTegel
# ERR creating composition PAMTegel
# ERR creating composition d(TTAGGG)4
# ERR creating composition d(TTAGGG)12
# ERR creating composition c-Myc promoter
# ERR creating composition Limlin
# ERR creating composition Ch-Ag
# ERR creating composition Ch-Ag
# ERR creating composition Au-Ft
# ERR creating composition Ag-Au/AgCl
# ERR creating composition Ag-Au/AgCl
# ERR creating composition Fe-SAs/NC
# ERR creating composition HRP-C
# ERR creating composition HRP-C
# ERR creating composition Hb(AcTPOH)12
# ERR creating composition Hb(AcTPOH)12
# ERR creating composition Hb(AcTPOH)12
# ERR creating composition Co xFe 3(cid:2)xO 4
# ERR creating composition Co xFe 3(cid:2)xO 4
# ERR creating composition UiO-66-NH2
# ERR creating composition UiO-66-NH2
# ERR creating composition Fe(ToCPP)
# ERR creating composition Fe(ToCPP)
# ERR creating composition Fe(ToCPP)
# ERR creating composition FePPOPs-SO3H
# ERR creating composition FePPOPs-SO3H
# ERR creating composition D-Trp-OMe@AuNCs
# ERR creating composition D-Trp-OMe@AuNCs
# ERR creating composition D-Trp-OMe@AuNCs-TC
# ERR creating composition D-Trp-OMe@AuNCs-TC
# ERR creating composition FTn-Pt
# ERR creating composition FTn-Rh
# ERR creating composition FTn-Au
# ERR creating composition FTn-Ir
# ERR creating composition FTn-Mn
# ERR creating composition MIL-101(Fe)
# ERR creating composition MIL-101(Fe)
# ERR creating composition Fe{1,2-X2C6H2-4,5-(NCOCMe2NCO)2CR2}(OH2)-
# ERR creating composition Fe{1,2-X2C6H2-4,5-(NCOCMe2NCO)2CR2}(OH2)-
# ERR creating composition ficin
# ERR creating composition Prx6
# ERR creating composition Prx6
# ERR creating composition Pt/ZnCo2O4
# ERR creating composition Pt/ZnCo2O4
# ERR creating composition Fe3+
# ERR creating composition Fe3+
# ERR creating composition N-CDs
# ERR creating composition N-CDs
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition H42A hHRP
# ERR creating composition H42A hHRP
# ERR creating composition H42A hHRP
# ERR creating composition H42A hHRP
# ERR creating composition hemin-SWCNT
# ERR creating composition hemin-SWCNT
# ERR creating composition AuNPs/MOGs (Fe)
# ERR creating composition AuNPs/MOGs (Fe)
# ERR creating composition Ag/ZnMOF
# ERR creating composition Hemin/ZIF-8
# ERR creating composition V-substituted tungstosulfate polyoxometalate
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition FeCo-LDH
# ERR creating composition FeCo-LDH
# ERR creating composition FeeHCleNH2-UiO-66
# ERR creating composition FeeHCleNH2-UiO-66
# ERR creating composition FeeHCleNH2-UiO-66
# ERR creating composition FeeHCleNH2-UiO-66
# ERR creating composition H2TCPP-ZnS
# ERR creating composition H2TCPP-ZnS
# ERR creating composition VMPxC1
# ERR creating composition VMPxC2
# ERR creating composition Heme-ficin
# ERR creating composition Heme-ficin
# ERR creating composition H2TCPP-Fe3O4
# ERR creating composition H2TCPP-Fe3O4
# ERR creating composition IrOx
# ERR creating composition IrOx
# ERR creating composition Cu2+/GMP
# ERR creating composition Ag3Cit
# ERR creating composition Fe(III) mesoporphyrin
# ERR creating composition Fe(III) mesoporphyrin
# ERR creating composition Fe(III) mesoporphyrin
# ERR creating composition Fe(III) mesoporphyrin
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Cu-CDs
# ERR creating composition CDs@γ-/α-Fe2O3
# ERR creating composition CDs@γ-/α-Fe2O3
# ERR creating composition α-Fe2O3
# ERR creating composition α-Fe2O3
# ERR creating composition TMB + H2O2
# ERR creating composition TMB + H2O2
# ERR creating composition Ag/Pt
# ERR creating composition Ag/Pt
# ERR creating composition hematin
# ERR creating composition hematin-methanol complex
# ERR creating composition hematin-pyridine complex
# ERR creating composition hematin-guanidine complex
# ERR creating composition hematin-formamide complex
# ERR creating composition hematin-acetate complex
# ERR creating composition hematin-histidine complex
# ERR creating composition hematin-arginine complex
# ERR creating composition SM-Te
# ERR creating composition SM-Te
# ERR creating composition SM-Te
# ERR creating composition SM-Te
# ERR creating composition YhjA
# ERR creating composition YhjA
# ERR creating composition YhjA
# ERR creating composition g-C3N4
# ERR creating composition MIP-g-C3N4
# ERR creating composition N-SCSs
# ERR creating composition N-SCSs
# ERR creating composition N-SCSs
# ERR creating composition N-SCSs
# ERR creating composition Mn x(PO 4) y
# ERR creating composition Fe-TCPP
# ERR creating composition Mn-TCPP
# ERR creating composition Fe-TCPP
# ERR creating composition Mn-TCPP
# ERR creating composition Fe-TCPP
# ERR creating composition Mn-TCPP
# ERR creating composition Fe-TCPP
# ERR creating composition Mn-TCPP
# ERR creating composition di-2-(N-cyclohexyl,N-(methylamino)-methyl)phenyl diselenide
# ERR creating composition di-2-(N-cyclohexyl,N-(methylamino)-methyl)phenyl diselenide
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Fe(III)-protoporphyrin IX
# ERR creating composition Fe(III)-protoporphyrin IX
# ERR creating composition Carbon shell
# ERR creating composition Carbon shell
# ERR creating composition Carbon
# ERR creating composition Hb
# ERR creating composition γ-MnOOH
# ERR creating composition Cu,Zn-SOD
# ERR creating composition Cu,Zn-SOD
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Co–Fe@hemin
# ERR creating composition Co–Fe@hemin
# ERR creating composition TPhPFe3+OH/Al2O3
# ERR creating composition TPhPFe3+OH/Al2O3
# ERR creating composition TPhPFe3+OH/Al2O3
# ERR creating composition perFTPhPFe3+OH/Al2O3
# ERR creating composition perFTPhPFe3+OH/Al2O3
# ERR creating composition PB-Fe2O3
# ERR creating composition PB-Fe2O3
# ERR creating composition C-dots
# ERR creating composition dSCS-Au NPs
# ERR creating composition GSH-Au NCs
# ERR creating composition dSCS-Au NPs
# ERR creating composition dSCS-Au NPs
# ERR creating composition (Z)-N-(4-methylbenzylidene)-1-(2-((2-(1-((E)-4-methylbenzylideneamino)ethyl)phenyl)diselanyl)phenyl)ethanamine ethyl)phenyl) diselanyl) phenyl) ethylimino) methyl)phenol
# ERR creating composition (PhSe)2
# ERR creating composition (Z)-N-(4-methylbenzylidene)-1-(2-((2-(1-((E)-4-methylbenzylideneamino)ethyl)phenyl)diselanyl)phenyl)ethanamine ethyl)phenyl) diselanyl) phenyl) ethylimino) methyl)phenol
# ERR creating composition (PhSe)2
# ERR creating composition (Z)-N-(4-methylbenzylidene)-1-(2-((2-(1-((E)-4-methylbenzylideneamino)ethyl)phenyl)diselanyl)phenyl)ethanamine ethyl)phenyl) diselanyl) phenyl) ethylimino) methyl)phenol
# ERR creating composition (PhSe)2
# ERR creating composition hSOD1
# ERR creating composition hSOD1
# ERR creating composition Au-Pt
# ERR creating composition G20-Cu(II)
# ERR creating composition G20-Cu(II)
# ERR creating composition Ovoperoxidase
# ERR creating composition Ovoperoxidase
# ERR creating composition AF-SiO2-TiO2NC
# ERR creating composition Cu-FeHCF
# ERR creating composition Cu-FeHCF
# ERR creating composition Mn-FeHCF
# ERR creating composition Mn-FeHCF
# ERR creating composition Ni-FeHCF
# ERR creating composition Ni-FeHCF
# ERR creating composition cyt c
# ERR creating composition cyt c
# ERR creating composition cyt c
# ERR creating composition cyt c
# ERR creating composition cyt c
# ERR creating composition cyt c
# ERR creating composition AldO-MP
# ERR creating composition AldO-MP
# ERR creating composition AldO-HB1
# ERR creating composition AldO-HB1
# ERR creating composition 15SeP
# ERR creating composition 15SeP
# ERR creating composition MoS2/MWCNTs
# ERR creating composition Hb
# ERR creating composition Met Hb
# ERR creating composition TA@VOx
# ERR creating composition Co\Fe\TiO2
# ERR creating composition Co\Fe\TiO2
# ERR creating composition KatA
# ERR creating composition KatA
# ERR creating composition KatB
# ERR creating composition KatB
# ERR creating composition Cyt b5
# ERR creating composition Cyt b5
# ERR creating composition Ss-HbI
# ERR creating composition Ss-HbI
# ERR creating composition Ss-HbII
# ERR creating composition Ss-HbII
# ERR creating composition ABTS + H2O2
# ERR creating composition ABTS + H2O2
# ERR creating composition hPrx1
# ERR creating composition Ab 9A5 + mesohemin
# ERR creating composition Ab 11D1 + mesohemin
# ERR creating composition Fe-Co-Ni oxide
# ERR creating composition Fe-Co-Ni oxide
# ERR creating composition Fe(OH)(O2C(C6H4)CO2)·H2O
# ERR creating composition Fe(OH)(O2C(C6H4)CO2)·H2O
# ERR creating composition Se-scFv-WCD1-lessACA
# ERR creating composition Se-scFv-WCD1-lessACA
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition CuO-g-C3N4
# ERR creating composition CuO-g-C3N4
# ERR creating composition Mb-Cu
# ERR creating composition Mb2-Cu
# ERR creating composition Mb4-Cu
# ERR creating composition Mb2-Cu
# ERR creating composition Mb2-Cu
# ERR creating composition PMIDA-Mn0.5Fe0.5Fe2O4
# ERR creating composition PMIDA-Mn0.5Fe0.5Fe2O4
# ERR creating composition SV-IV
# ERR creating composition SV-IV
# ERR creating composition NH2-MIL-88B(Fe)
# ERR creating composition NH2-MIL-88B(Fe)
# ERR creating composition NMC Tp-TTA
# ERR creating composition NMC Tp-TTA
# ERR creating composition Mn(II)/CeO2
# ERR creating composition Mn(II)/CeO2
# ERR creating composition Fe(III)/CeO2
# ERR creating composition Fe(III)/CeO2
# ERR creating composition Co(II)/CeO2
# ERR creating composition Co(II)/CeO2
# ERR creating composition Pd NPs/CeO2 NTs
# ERR creating composition Pd NPs/CeO2 NTs
# ERR creating composition Pd NPs
# ERR creating composition Pd NPs
# ERR creating composition Cu(II)–cysteine/SDS/DTAB
# ERR creating composition Cu(II)–cysteine/SDS/DTAB
# ERR creating composition Cu(II)–cysteine/SDS/DTAB
# ERR creating composition nGO
# ERR creating composition nGO
# ERR creating composition Fe-MoS2
# ERR creating composition Fe-MoS2
# ERR creating composition PS2.M–hemin
# ERR creating composition PS2.M–hemin
# ERR creating composition rPS2.M–hemin
# ERR creating composition rPS2.M–hemin
# ERR creating composition OXY4–hemin
# ERR creating composition OXY4–hemin
# ERR creating composition C-dots
# ERR creating composition C-dots
# ERR creating composition C-dots
# ERR creating composition C-dots
# ERR creating composition C-dots
# ERR creating composition C-dots
# ERR creating composition C-dots
# ERR creating composition C-dots
# ERR creating composition Fe(III)-Mn(II)
# ERR creating composition CM-HSA
# ERR creating composition se-scFv-B3
# ERR creating composition CeO2-CDs
# ERR creating composition CeO2-CDs
# ERR creating composition HbFe3+
# ERR creating composition HbFe3+
# ERR creating composition TClPP-CuFe2O4/SiO2
# ERR creating composition TClPP-CuFe2O4/SiO2
# ERR creating composition Fe3O4@NH2-MIL-101(Fe)
# ERR creating composition Fe3O4@NH2-MIL-101(Fe)
# ERR creating composition HRP-GCS
# ERR creating composition 2-TeCD
# ERR creating composition 2-TeCD
# ERR creating composition 2-TeCD
# ERR creating composition Au/CDs
# ERR creating composition Au/CDs
# ERR creating composition H2O2 + TMB
# ERR creating composition H2O2 + TMB
# ERR creating composition Co2(OH)2CO3-CeO2
# ERR creating composition Co2(OH)2CO3-CeO2
# ERR creating composition Se-g-C3N4
# ERR creating composition Se-g-C3N4
# ERR creating composition Pt/C
# ERR creating composition Pt/C
# ERR creating composition Pt/C
# ERR creating composition Pt/C
# ERR creating composition PtCNPs
# ERR creating composition PtCNPs
# ERR creating composition CuCNPs
# ERR creating composition CuCNPs
# ERR creating composition NiCNPs
# ERR creating composition NiCNPs
# ERR creating composition PdCNPs
# ERR creating composition PdCNPs
# ERR creating composition T67R/S92D Mb
# ERR creating composition T67R/S92D Mb-H
# ERR creating composition P-450cam
# ERR creating composition P-450cam
# ERR creating composition PB-Ft
# ERR creating composition PB-Ft
# ERR creating composition PB-Ft
# ERR creating composition PB-Ft
# ERR creating composition CuO/WO3
# ERR creating composition CuO/WO3
# ERR creating composition Co3O4@Co-Fe oxide
# ERR creating composition Co3O4@Co-Fe oxide
# ERR creating composition ZnO-Pd
# ERR creating composition ZnO-Pd
# ERR creating composition Cytochrome c
# ERR creating composition Cytochrome c
# ERR creating composition Cu-SBA-15
# ERR creating composition Cu-SBA-15
# ERR creating composition Fe-MIL-88NH2
# ERR creating composition Fe-MIL-88NH2
# ERR creating composition Cu,Zn-SOD
# ERR creating composition Cu,Zn-SOD
# ERR creating composition Au/CeO2
# ERR creating composition Au/CeO2
# ERR creating composition TaAPX-6B
# ERR creating composition Mn-TSPP
# ERR creating composition Fe-TSPP
# ERR creating composition Mn-TSPP
# ERR creating composition Cu2OeAu
# ERR creating composition Cu2OeAu
# ERR creating composition ZmANN33/35
# ERR creating composition Fe-BTC
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition hemin-Fib
# ERR creating composition MA-Hem/AueAg
# ERR creating composition MA-Hem/AueAg
# ERR creating composition C-dots
# ERR creating composition C-dots
# ERR creating composition C-dots
# ERR creating composition C-dots
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Se-enriched yeast
# ERR creating composition Se-enriched yeast
# ERR creating composition Se-enriched yeast
# ERR creating composition MoS2@TA/Fe
# ERR creating composition MoS2@TA/Fe
# ERR creating composition MoS2@TA/Fe
# ERR creating composition Cu3(PO4)2·3H2O
# ERR creating composition Cu3(PO4)2·3H2O
# ERR creating composition Cu3(PO4)2·3H2O
# ERR creating composition Cu3(PO4)2·3H2O
# ERR creating composition Cu3(PO4)2·3H2O
# ERR creating composition Cu3(PO4)2·3H2O
# ERR creating composition Cu3(PO4)2·3H2O
# ERR creating composition Cu3(PO4)2·3H2O
# ERR creating composition MoS2-MIL-101(Fe)
# ERR creating composition MoS2-MIL-101(Fe)
# ERR creating composition AuNS@Ag-5-H-rGO
# ERR creating composition AuNS@Ag-5-H-rGO
# ERR creating composition AuNP@Ag-5-H-rGO
# ERR creating composition AuNP@Ag-5-H-rGO
# ERR creating composition Zn-N-C
# ERR creating composition Zn-N-C
# ERR creating composition Fe3+-TCAS
# ERR creating composition Fe3+-TCAS
# ERR creating composition Co-Al ELDH
# ERR creating composition Co-Al ELDH
# ERR creating composition Cytochrome bd
# ERR creating composition Cytochrome bd
# ERR creating composition GHK/K8[α-SiW11O39]/Co2+
# ERR creating composition cyt c
# ERR creating composition cyt c
# ERR creating composition Na_xH_(2-x)Ti_3O_7
# ERR creating composition 2,2′-diamino-diphenyldiselenide
# ERR creating composition 2,2′-diselenopyridin
# ERR creating composition 2-phenyl-1,2-benzoisoselenazol-3(2H)-one
# ERR creating composition ethyl-benzo-1,2-selenazine-4-one-3-carboxylate
# ERR creating composition 2-methylselenobenzoylcyanide
# ERR creating composition cyt c-SNPs
# ERR creating composition cyt c-SNPs
# ERR creating composition iron protoporphyrin IX diglutathione
# ERR creating composition iron protoporphyrin IX diglutathione
# ERR creating composition Cyt-c
# ERR creating composition iron(III)-5-(4-carboxyphenyl)-10,15,20-tritolylporphyrin
# ERR creating composition iron(III)-5-(4-carboxyphenyl)-10,15,20-tritolylporphyrin
# ERR creating composition iron(III)-5-(4-carboxyphenyl)-10,15,20-tritolylporphyrin
# ERR creating composition Au@Ag-Pt
# ERR creating composition Au@Ag-Pt
# ERR creating composition GOx@Au@MagSiO2
# ERR creating composition GOx@Au@MagSiO2
# ERR creating composition Cu2+-rGO
# ERR creating composition PEG-GO-Hemin
# ERR creating composition PEG-GO-Hemin
# ERR creating composition PEG-GO-Hemin
# ERR creating composition PEG-GO-Hemin
# ERR creating composition Au@Pt@mesoporous SiO2
# ERR creating composition Au@Pt@mesoporous SiO2
# ERR creating composition FePt-Au
# ERR creating composition FePt-Au
# ERR creating composition Fe-MIL-101
# ERR creating composition Fe-MIL-101
# ERR creating composition Fe-MIL-101
# ERR creating composition Fe-MIL-101
# ERR creating composition Fe-MIL-101-FA
# ERR creating composition Fe-MIL-101-FA
# ERR creating composition Fe-MIL-101-FA
# ERR creating composition Fe-MIL-101-FA
# ERR creating composition PtNPs/GO
# ERR creating composition PtNPs/GO
# ERR creating composition His-AuNCs
# ERR creating composition His-AuNCs
# ERR creating composition PtPB-1
# ERR creating composition PtPB-2
# ERR creating composition PtPB-3
# ERR creating composition PtPB-4
# ERR creating composition IIB-III
# ERR creating composition IIB-III
# ERR creating composition Fe@PCN-224
# ERR creating composition Fe@PCN-224
# ERR creating composition Fe@PCN-224
# ERR creating composition PDI-CuO
# ERR creating composition PDI-CuO
# ERR creating composition Fe3O4@ZIF-8
# ERR creating composition Fe3O4@ZIF-8
# ERR creating composition AuNFs/Fe3O4@ZIF-8-MoS2
# ERR creating composition AuNFs/Fe3O4@ZIF-8-MoS2
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition NaYF4:Yb,Er
# ERR creating composition NaYF4:Yb,Er
# ERR creating composition Pt@mSiO2
# ERR creating composition Pt@mSiO2
# ERR creating composition Hb
# ERR creating composition Cytochrome c
# ERR creating composition Cytochrome c
# ERR creating composition Heme-ZrMOF
# ERR creating composition Heme-ZrMOF
# ERR creating composition Heme-ZrMOF
# ERR creating composition Ca2+-MMT
# ERR creating composition Ca2+-MMT
# ERR creating composition MoS2/rGO
# ERR creating composition MoS2/rGO
# ERR creating composition MoS2/rGO
# ERR creating composition MoS2/rGO
# ERR creating composition NGr-FeTPyP
# ERR creating composition FeTPyP-NGr
# ERR creating composition Tellurosubtilisin
# ERR creating composition Tellurosubtilisin
# ERR creating composition CYP BM3 21B3
# ERR creating composition W96A/F405L
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cu2+
# ERR creating composition Cu2+
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Au-MoS2
# ERR creating composition Au-MoS2
# ERR creating composition MnL1(OH2)2⋅H2O
# ERR creating composition Fe3+
# ERR creating composition Fe3+
# ERR creating composition Fe3+
# ERR creating composition Fe3+
# ERR creating composition Fe3+
# ERR creating composition Fe3+
# ERR creating composition Dz 1Dz 2NPs
# ERR creating composition Dz 1Dz 2NPs
# ERR creating composition Dz 1Dz 2NPs
# ERR creating composition Dz 1Dz 2NPs
# ERR creating composition Dz 1Dz 2NPs
# ERR creating composition Dz 1Dz 2NPs
# ERR creating composition Dz 1Dz 2NPs
# ERR creating composition Dz 1Dz 2NPs
# ERR creating composition Mn-TPPS4
# ERR creating composition Mn-TPPS4
# ERR creating composition Mn-TPPS4
# ERR creating composition Cu(II)-coordinated GpG-duplex DNA
# ERR creating composition Cu(II)-coordinated GpG-duplex DNA
# ERR creating composition Z-His-NHNH2/Zn2+
# ERR creating composition FeCPNPs
# ERR creating composition FeCPNPs
# ERR creating composition Co/Fe-MOFs-iodide
# ERR creating composition Co/Fe-MOFs-iodide
# ERR creating composition Au-C/SiO2
# ERR creating composition Au-C/SiO2
# ERR creating composition DAFS-25
# ERR creating composition DAFS-25
# ERR creating composition DAFS-25
# ERR creating composition DAFS-25
# ERR creating composition Fe3O4@C/Ni
# ERR creating composition Fe3O4@C/Ni
# ERR creating composition PNC2-WT
# ERR creating composition PNC2-WT
# ERR creating composition PNC2-M
# ERR creating composition PNC2-M
# ERR creating composition PtGNs
# ERR creating composition PtGNs
# ERR creating composition DypB
# ERR creating composition D153A/N246A
# ERR creating composition HAP@MIL-100(Fe)
# ERR creating composition Cu2+
# ERR creating composition PhSeZnCl
# ERR creating composition CuS-BSA-Cu3(PO4)2
# ERR creating composition CuS-BSA-Cu3(PO4)2
# ERR creating composition N-GQDs
# ERR creating composition N-GQDs
# ERR creating composition N57C/S71C Cyt b5
# ERR creating composition N57C/S71C Cyt b5
# ERR creating composition WT Cyt b5
# ERR creating composition WT Cyt b5
# ERR creating composition hemin
# ERR creating composition hemin
# ERR creating composition HRP-4C
# ERR creating composition Cu,Zn SOD
# ERR creating composition Cu,Zn SOD
# ERR creating composition Cu,Zn SOD
# ERR creating composition Cu,Zn SOD
# ERR creating composition CDN1/Au2
# ERR creating composition CDN1/Au2
# ERR creating composition CDN/Au1
# ERR creating composition CDN/Au1
# ERR creating composition Cu5(pz)6Cl[SiW12O40]
# ERR creating composition Cu5(pz)6Cl[SiW12O40]
# ERR creating composition Cu5(pz)6Cl[SiW12O40]
# ERR creating composition Cu5(pz)6Cl[SiW12O40]
# ERR creating composition Cu5(pz)6Cl[SiW12O40]
# ERR creating composition Cu5(pz)6Cl[SiW12O40]
# ERR creating composition Cu/CuO-rGO
# ERR creating composition Cu/CuO-rGO
# ERR creating composition peptide-hGQ
# ERR creating composition Co3O4 + CoAl2O4 + CeO2
# ERR creating composition Co3O4 + CoAl2O4 + CeO2
# ERR creating composition GPx
# ERR creating composition GPx
# ERR creating composition C-dots
# ERR creating composition C-dots
# ERR creating composition 1a
# ERR creating composition 1a
# ERR creating composition Fe-BDC-NH2
# ERR creating composition Fe-BDC-NH2
# ERR creating composition GO-Se
# ERR creating composition GO-Se
# ERR creating composition Pd/Fe3O4-PEI-RGO
# ERR creating composition Cu3(PO4)2·3H2O
# ERR creating composition Cu3(PO4)2·3H2O
# ERR creating composition PLPC-OOH
# ERR creating composition AD-100
# ERR creating composition Cu,ZnSOD
# ERR creating composition CeO2/NiO
# ERR creating composition CeO2/NiO
# ERR creating composition ferritin–heme
# ERR creating composition ferritin–heme
# ERR creating composition ferritin–heme
# ERR creating composition ferritin–heme
# ERR creating composition ferritin–heme
# ERR creating composition ferritin–heme
# ERR creating composition ferritin–heme
# ERR creating composition ferritin–heme
# ERR creating composition N, Fe-CDs
# ERR creating composition N, Fe-CDs
# ERR creating composition Fe3O4-Au
# ERR creating composition Fe3O4-Au
# ERR creating composition Co-N-C
# ERR creating composition Co-N-C
# ERR creating composition Fe-Ni LDH-hemin
# ERR creating composition Fe-Ni LDH-hemin
# ERR creating composition ATXII-microperoxidase
# ERR creating composition MoS2/GO
# ERR creating composition MoS2/GO
# ERR creating composition Zr-MOF-PVP
# ERR creating composition Zr-MOF-PVP
# ERR creating composition SA-PtNPs
# ERR creating composition Cu/Ag
# ERR creating composition Cu/Ag
# ERR creating composition VVO(ap-fah)(OMe)(MeOH)
# ERR creating composition VVO(ap-bhz)(OMe)(MeOH)
# ERR creating composition VVO(ap-nah)(OMe)(MeOH)
# ERR creating composition VVO(ap-inh)(OMe)(MeOH)
# ERR creating composition H-GNs
# ERR creating composition H-GNs
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition seleno-hGPx1-C2/78/115/156/202S
# ERR creating composition seleno-hGPx1-C2/78/115/156/202S
# ERR creating composition seleno-hGPx1-C2/78/115/156/202S
# ERR creating composition seleno-hGPx1-C2/78/115/156/202S
# ERR creating composition seleno-hGPx1-C2/78/115/156/202S
# ERR creating composition seleno-hGPx1-C2/78/115/156/202S
# ERR creating composition seleno-hGPx1-C2/78/115/156/202S
# ERR creating composition seleno-hGPx1-C2/78/115/156/202S
# ERR creating composition FeTSPc
# ERR creating composition FeTSPc
# ERR creating composition CxOyBrz
# ERR creating composition CxOyBrz
# ERR creating composition TPyP-CuS
# ERR creating composition TPyP-CuS
# ERR creating composition MIL-101(Cr)
# ERR creating composition MIL-101(Cr)
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Hemoglobin-Haptoglobin Complex
# ERR creating composition Hemoglobin-Haptoglobin Complex
# ERR creating composition Hemoglobin-Haptoglobin Complex
# ERR creating composition Hemoglobin-Haptoglobin Complex
# ERR creating composition Hemoglobin-Haptoglobin Complex
# ERR creating composition PtNP/GO
# ERR creating composition PtNP/GO
# ERR creating composition CeO2/TiO2
# ERR creating composition CeO2/TiO2
# ERR creating composition OgCytAPX1
# ERR creating composition OgCytAPX1
# ERR creating composition MoS2@CNNS(30)
# ERR creating composition MoS2@CNNS(30)
# ERR creating composition T67R/S92D Mb
# ERR creating composition T67R/S92D Mb
# ERR creating composition T67R/S92D Mb
# ERR creating composition T67R/S92D Mb-H
# ERR creating composition T67R/S92D Mb-H
# ERR creating composition T67R/S92D Mb-H
# ...
# ERR creating composition MOF-Au-Ce
# ERR creating composition MOF-2.5Au
# ERR creating composition PGP–Con A
# ERR creating composition DvNgr
# ERR creating composition Co@NCNTs/NC
# ERR creating composition DL-selenomethionine
# ERR creating composition 6A,6B-diseleninic acid-6A*,6B*-selenium bridged b-cyclodextrin
# ERR creating composition 6A,6B-diseleninic acid-6A*,6B*-selenium bridged b-cyclodextrin
# ERR creating composition Cyt c-550
# ERR creating composition Cyt c-550
# ERR creating composition Fe-MIL-88B-NH2
# ERR creating composition Fe-MIL-88B-NH2
# ERR creating composition Sm-TCPP-Pt
# ERR creating composition Sm-TCPP-Pt
# ERR creating composition Fe3+P
# ERR creating composition Fe3+P
# ERR creating composition Fe3+P
# ERR creating composition Fe3+P
# ERR creating composition Fe3+P
# ERR creating composition Fe3+P
# ERR creating composition Fe3+P
# ERR creating composition cytc550
# ERR creating composition cytc550
# ERR creating composition cytc550
# ERR creating composition cytc550
# ERR creating composition cytc550
# ERR creating composition cytc550
# ERR creating composition cytc550
# ERR creating composition cytc550
# ERR creating composition H39Q Cyt b5
# ERR creating composition H39S Cyt b5
# ERR creating composition Fe-MOF
# ERR creating composition MLT-7
# ERR creating composition Fe(III) 5,10,15-tris(4-N-methylpyridiniumyl)-20-(4-phenyl(3-O-amidoxymethylestradiol)) porphyrin
# ERR creating composition Fe(III) 5,10,15-tris(4-N-methylpyridiniumyl)-20-(4-phenyl(3-O-amidoxymethylestradiol)) porphyrin
# ERR creating composition Fe(III) 5,10,15-tris(4-N-methylpyridiniumyl)-20-(4-phenyl(3-O-amidoxymethylestradiol)) porphyrin
# ERR creating composition Fe(III) 5,10,15-tris(4-N-methylpyridiniumyl)-20-(4-phenyl(3-O-amidoxymethylestradiol)) porphyrin
# ERR creating composition Hb
# ERR creating composition H2TCPP-CdS
# ERR creating composition H2TCPP-CdS
# ERR creating composition Fe-N-C
# ERR creating composition Fe/NC-SAs
# ERR creating composition Fe/NC-SAs
# ERR creating composition F-Fe3O4-1
# ERR creating composition F-Fe3O4-1
# ERR creating composition F-Fe3O4-1
# ERR creating composition F-Fe3O4-1
# ERR creating composition Fe3O4-blank
# ERR creating composition Fe3O4-blank
# ERR creating composition Fe3O4-blank
# ERR creating composition MoOx
# ERR creating composition Cytochrome b562 (F61I/F65Y/R106L)
# ERR creating composition Cytochrome b562 (F61A)
# ERR creating composition Cytochrome b562 (Wild type)
# ERR creating composition Cytochrome b562 (F61I/F65Y/R106L)
# ERR creating composition Cytochrome b562 (F61A)
# ERR creating composition Cytochrome b562 (Wild type)
# ERR creating composition Cu2-xS
# ERR creating composition Cu2-xS
# ERR creating composition Bleomycin-Fe3+
# ERR creating composition Bleomycin-Fe3+
# ERR creating composition Bleomycin-Fe3+
# ERR creating composition Bleomycin-Fe3+
# ERR creating composition NB-GNRs
# ERR creating composition NB-GNRs
# ERR creating composition FeeNeC
# ERR creating composition FeeNeC
# ERR creating composition A15/FeeNeC
# ERR creating composition A15/FeeNeC
# ERR creating composition 2,2P-diseleno-bis-L-cyclodextrin
# ERR creating composition 2,2P-diseleno-bis-L-cyclodextrin
# ERR creating composition Mn3+-octabromo-tetrakis(4-sulfophenyl)porphine
# ERR creating composition Cu-Ag/g-C3N4/ZIF
# ERR creating composition Cu-Ag/g-C3N4/ZIF
# ERR creating composition rHRP(1)
# ERR creating composition rHRP(2)
# ERR creating composition rHRP(3)
# ERR creating composition hemin-EAD2
# ERR creating composition hemin-EAD2
# ERR creating composition Tb–HRP
# ERR creating composition Tb–HRP
# ERR creating composition Tb–HRP
# ERR creating composition Mn-TPPS
# ERR creating composition Mn-TPPS
# ERR creating composition Fe-TMPyP
# ERR creating composition Fe-TMPyP
# ERR creating composition Zn3(MoO4)2(trz)2(H2O)2
# ERR creating composition Zn3(MoO4)2(trz)2(H2O)2
# ERR creating composition cyt-c
# ERR creating composition cyt-c
# ERR creating composition cyt-c
# ERR creating composition rG4 + hemin
# ERR creating composition rG4 + hemin
# ERR creating composition 13,16-dicarboxyethyl-2,7-diethyl-3,6,12,17-tetramethylporphycenatoiron(III)
# ERR creating composition 13,16-dicarboxyethyl-2,7-diethyl-3,6,12,17-tetramethylporphycenatoiron(III)
# ERR creating composition 13,16-dicarboxyethyl-2,7-diethyl-3,6,12,17-tetramethylporphycenatoiron(III)
# ERR creating composition 13,16-dicarboxyethyl-2,7-diethyl-3,6,12,17-tetramethylporphycenatoiron(III)
# ERR creating composition CH-Cu
# ERR creating composition CH-Cu
# ERR creating composition L29H/F43H Mb
# ERR creating composition Cu(II)-L29H/F43H Mb
# ERR creating composition Zn(II)-L29H/F43H Mb
# ERR creating composition L29H/F43H Mb
# ERR creating composition Cu(II)-L29H/F43H Mb
# ERR creating composition Zn(II)-L29H/F43H Mb
# ERR creating composition L29H/F43H Mb
# ERR creating composition Cu(II)-L29H/F43H Mb
# ERR creating composition Zn(II)-L29H/F43H Mb
# ERR creating composition DhHP-6
# ERR creating composition DhHP-6
# ERR creating composition DhHP-6
# ERR creating composition DhHP-6
# ERR creating composition DhHP-6
# ERR creating composition DhHP-6
# ERR creating composition DhHP-6
# ERR creating composition Fe3+/AMP
# ERR creating composition PLPC-OOH
# ERR creating composition Mn-T(4-TAP)P
# ERR creating composition Fe(III)-MC6
# ERR creating composition Fe(III)-MC6
# ERR creating composition AuNP/Ag-bipyridine
# ERR creating composition AuNP/Ag-bipyridine
# ERR creating composition Fe-N-CDs
# ERR creating composition Fe-N-CDs
# ERR creating composition Ni(C33H37N4O4S2)·DMF
# ERR creating composition unknown
# ERR creating composition MPS-PPV
# ERR creating composition MPS-PPV
# ERR creating composition Au@Pt 0.25%
# ERR creating composition Au@Pt 2.5%
# ERR creating composition Au@Pt 25%
# ERR creating composition Au@Pt 2.5%
# ERR creating composition Fe3O4-TiO2/rGO
# ERR creating composition Fe3O4-TiO2/rGO
# ERR creating composition DhHP-6-c-ZrMOF
# ERR creating composition DhHP-6-c-ZrMOF
# ERR creating composition DhHP-6
# ERR creating composition DhHP-6
# ERR creating composition Cu/Au
# ERR creating composition Cu/Au
# ERR creating composition CH3CONH2 + HOOC(CH2)3COOH
# ERR creating composition CH3CONH2 + HOOC(CH2)3COOH
# ERR creating composition g-C3N4
# ERR creating composition g-C3N4
# ERR creating composition N-CNTs@Co
# ERR creating composition PRGI/Pt
# ERR creating composition PRGI/Pt
# ERR creating composition V2O5@pDA@MnO2
# ERR creating composition V2O5@pDA@MnO2
# ERR creating composition PEIeAuNPseMnIIIPPIX
# ERR creating composition Au-Ag-AFT
# ERR creating composition Au-Ag-AFT
# ERR creating composition Au-Ag-AFT
# ERR creating composition Se-DL-Cysteine
# ERR creating composition Se-DL-Cysteine
# ERR creating composition Apt–Au NPs/BiOCl
# ERR creating composition Apt–Au NPs/BiOCl
# ERR creating composition Apt–Au NPs/BiOCl
# ERR creating composition Apt–Au NPs/BiOCl
# ERR creating composition Fe3O4@MoS2-1%Ag
# ERR creating composition Fe3O4@MoS2-1%Ag
# ERR creating composition ADM-Fe3+
# ERR creating composition ADM-Fe3+
# ERR creating composition ADM-Fe3+
# ERR creating composition Cu xO
# ERR creating composition Cu xO
# ERR creating composition Cu xO
# ERR creating composition seleno-LuGST1-1
# ERR creating composition seleno-LuGST1-1
# ERR creating composition seleno-LuGST1-1
# ERR creating composition seleno-LuGST1-1
# ERR creating composition seleno-LuGST1-1
# ERR creating composition seleno-LuGST1-1
# ERR creating composition Cytc
# ERR creating composition 3,8-DMD(Fe3+)-6-mer/T
# ERR creating composition 3,8-DMD(Fe3+)-6-mer/A
# ERR creating composition 2,8-DPF(Fe3+)-6-mer/T
# ERR creating composition 2,8-DPF(Fe3+)-6-mer/A
# ERR creating composition FeT(4-TAP)P
# ERR creating composition FeT(4-TAP)P
# ERR creating composition MnT(4-TAP)P
# ERR creating composition MnT(4-TAP)P
# ERR creating composition G4-hpDNA
# ERR creating composition BSA-Au
# ERR creating composition hSOD1
# ERR creating composition hSOD1
# ERR creating composition Nak-YCC3.5
# ERR creating composition Nak-YCC3.5
# ERR creating composition Nak-YCC3.5
# ERR creating composition Nak-YCC3.5
# ERR creating composition Nak-YCC3.5
# ERR creating composition Nak-YCC3.5
# ERR creating composition Nak-TMut3.5
# ERR creating composition Nak-TMut3.5
# ERR creating composition FeOxH–rGO
# ERR creating composition FeOxH–rGO
# ERR creating composition I-
# ERR creating composition I-
# ERR creating composition CeO2@MMT(2:8)
# ERR creating composition CeO2@MMT(2:8)
# ERR creating composition CeO2@MMT(2:8)
# ERR creating composition CeO2@MMT(1:9)
# ERR creating composition CeO2@MMT(1:9)
# ERR creating composition CeO2@MMT(1:9)
# ERR creating composition N-CNTs
# ERR creating composition N-CNTs
# ERR creating composition Au-Pt
# ERR creating composition Au-Pt
# ERR creating composition AuNC/GNR
# ERR creating composition AuNC/GNR
# ERR creating composition 1
# ERR creating composition 1
# ERR creating composition 1
# ERR creating composition HRP-PEG 5000
# ERR creating composition HRP-PEG 20000
# ERR creating composition HRP-PEG 40000
# ERR creating composition HRP-PEG 5000, co-lyophilized
# ERR creating composition HRP-PEG 20000, co-lyophilized
# ERR creating composition HRP-PEG 40000, co-lyophilized
# ERR creating composition Arg51Gln
# ERR creating composition Arg51Asn
# ERR creating composition Arg51Leu
# ERR creating composition Arg51Lys
# ERR creating composition TMBDA-MIL-100(Fe)
# ERR creating composition TMBDA-MIL-100(Fe)
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition metHb
# ERR creating composition metHb
# ERR creating composition myoglobin
# ERR creating composition myoglobin
# ERR creating composition Pt-on-Pd/RGO
# ERR creating composition Pt-on-Pd/RGO
# ERR creating composition NH2-MIL-101(Fe)
# ERR creating composition NH2-MIL-101(Fe)
# ERR creating composition NADPH oxidase
# ERR creating composition NADPH oxidase
# ERR creating composition MoS2/g-C3N4
# ERR creating composition MoS2/g-C3N4
# ERR creating composition [Co(L)(H2O)2]n
# ERR creating composition [Co(L)(H2O)2]n
# ERR creating composition Mo SA–N 3–C
# ERR creating composition Mo SA–N 3–C
# ERR creating composition Fe-N-C
# ERR creating composition Fe-N-C
# ERR creating composition 2-SeCD
# ERR creating composition Pc(OH)8/CoSn(OH)6
# ERR creating composition Pc(OH)8/CoSn(OH)6
# ERR creating composition catalase
# ERR creating composition Cu(NO3)2·3H2O
# ERR creating composition Cu(NO3)2·3H2O
# ERR creating composition G-quadruplex-Cu2+
# ERR creating composition G-quadruplex-Cu2+
# ERR creating composition HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating composition HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating composition HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating composition HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating composition HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating composition HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating composition HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating composition SrTiO3/DHB
# ERR creating composition AuPd-PDA
# ERR creating composition AuPd-PDA
# ERR creating composition GSH-Px
# ERR creating composition GSH-Px
# ERR creating composition Fe-Ag2S
# ERR creating composition Fe-Ag2S
# ERR creating composition MbFe(IV)dO
# ERR creating composition MbFe(IV)dO
# ERR creating composition MbFe(IV)dO
# ERR creating composition MbFe(IV)dO
# ERR creating composition GO-Cyt c_1 min
# ERR creating composition GO-Cyt c_1 min
# ERR creating composition GO-Cyt c_5 h
# ERR creating composition GO-Cyt c_5 h
# ERR creating composition metMb
# ERR creating composition metMb
# ERR creating composition Fe3O4-chitosan-tripolyphosphate-calcium
# ERR creating composition Fe3O4-chitosan-tripolyphosphate-calcium-glucose oxidase-concanavalin A
# ERR creating composition Fe3O4-chitosan-tripolyphosphate-calcium-glucose oxidase-concanavalin A
# ERR creating composition Fe3O4-chitosan-tripolyphosphate-calcium-glucose oxidase-concanavalin A
# ERR creating composition Fe3O4-chitosan-tripolyphosphate-calcium-glucose oxidase-concanavalin A
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition His-Ti3C2
# ERR creating composition His-Ti3C2
# ERR creating composition Ala-Ti3C2
# ERR creating composition Ala-Ti3C2
# ERR creating composition HRP/CHIT/CMS
# ERR creating composition ZnO–g-C3N4/MoS2
# ERR creating composition ZnO–g-C3N4/MoS2
# ERR creating composition 6,60-telluro-bis (6-deoxy-b-cyclodextrin)
# ERR creating composition 6,60-telluro-bis (6-deoxy-b-cyclodextrin)
# ERR creating composition 6,60-ditelluro-bis (6-deoxy-b-cyclodextrin)
# ERR creating composition 6,60-ditelluro-bis (6-deoxy-b-cyclodextrin)
# ERR creating composition Fe(III)-porphyrin
# ERR creating composition Fe(III)-porphyrin
# ERR creating composition Se-SP-1
# ERR creating composition Se-SP-2
# ERR creating composition Fv
# ERR creating composition CoPc-MWCNT
# ERR creating composition CoPc-MWCNT
# ERR creating composition SWNT-3
# ERR creating composition SWNT-3
# ERR creating composition SWNT-4
# ERR creating composition SWNT-4
# ERR creating composition FeTSPc
# ERR creating composition MAP_2744c
# ERR creating composition MAP_2744c
# ERR creating composition MAP_2744c
# ERR creating composition MAP_2744c
# ERR creating composition Fe/C NS
# ERR creating composition Fe/C NS
# ERR creating composition PNPG-PEG
# ERR creating composition PNPG-PEG
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Prdx6
# ERR creating composition Prdx6
# ERR creating composition PPAM–N–CD–Te
# ERR creating composition Co-N-C
# ERR creating composition Co-N-C
# ERR creating composition CysSeSeCys
# ERR creating composition CysSeSeCys
# ERR creating composition CysSeSeCys
# ERR creating composition CysSeSeCys
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition BP-IL-SWCNH
# ERR creating composition Hb
# ERR creating composition Fe3O4-Au
# ERR creating composition Fe3O4-Au
# ERR creating composition Cu3V2O7(OH)2·2H2O
# ERR creating composition Cu3V2O7(OH)2·2H2O
# ERR creating composition Cu3V2O7(OH)2·2H2O
# ERR creating composition Cu3V2O7(OH)2·2H2O
# ERR creating composition Fe(III)MP-8
# ERR creating composition Fe(III)MP-8
# ERR creating composition Fe(III)MP-8
# ERR creating composition Fe(III)MP-8
# ERR creating composition GMP-Cu
# ERR creating composition GMP-Cu
# ERR creating composition OPD-MoS2
# ERR creating composition OPD-MoS2
# ERR creating composition OPD-MoS2
# ERR creating composition OPD-MoS2
# ERR creating composition H2O2 + o-phenylenediamine
# ERR creating composition ficin
# ERR creating composition H&rGO
# ERR creating composition hemin
# ERR creating composition hemin
# /home/oleg/Programs/.venv/lib/python3.12/site-packages/pymatgen/core/composition.py:328: UserWarning: No Pauling electronegativity for Ds. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   return sum((el.X * abs(amt) for el, amt in self.items())) / self.num_atoms
# /home/oleg/Programs/.venv/lib/python3.12/site-packages/pymatgen/core/composition.py:328: UserWarning: No Pauling electronegativity for Ts. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   return sum((el.X * abs(amt) for el, amt in self.items())) / self.num_atoms
# /home/oleg/Programs/.venv/lib/python3.12/site-packages/pymatgen/core/composition.py:328: UserWarning: No Pauling electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   return sum((el.X * abs(amt) for el, amt in self.items())) / self.num_atoms
# ERR creating composition Pu39WT-hemin
# ERR creating composition HDP-ELP
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Hb(cid:1)Hp
# ERR creating composition Hb(cid:1)Hp
# ERR creating composition (Et3NH)[Fe(bpb)Cl2]
# ERR creating composition (Et3NH)[Fe(bpb)Cl2]
# ERR creating composition NADH peroxidase
# ERR creating composition Cyt c
# ERR creating composition Fe2O3/Pt/CNTs
# ERR creating composition Fe2O3/Pt/CNTs
# ERR creating composition Fe2O3/Pt/CNTs
# ERR creating composition HSA + uric acid + Cu
# ERR creating composition HSA + uric acid + Cu
# ERR creating composition CDs@NC-3
# ERR creating composition CDs@NC-3
# ERR creating composition HPtNPs-Fe3O4
# ERR creating composition HbGp
# ERR creating composition HbGp
# ERR creating composition HbGp
# ERR creating composition HbGp
# ERR creating composition HbGp
# ERR creating composition HbGp

# %% [markdown]
# ## IR

# %%
banned_oxi = ['HRP', 'H10Q', 'H10A', 'GSH', 'GrdB', 'Cu 1.8S', 'K12[Ga4L6]', 'C14H24N2O2Se',
              'C30H24N2O2Se', 'C30H48N2O2Se', 'C16H24N2O2Se', 'FeMP', 'C15H21NOSe',
              'C16H21NOSe', 'C24H32N2O2Se2', 'C20H20N2O2Se2', 'K0.8Fe0.8Ti1.2O4', 'PTEBS',
              'C22H24N2O2Se2', '[Gly64]Mb', 'PS2.MA4', 'PS2.MA20', 'RBCm@Ru@MnO2', 'GNRs',
              'BSA', 'OsAPX', 'MPO', 'PANI', 'COX', 'Fe4[Fe(CN)6]3', 'POX 1B', 'C96H160O66N2Se2',
              'DNA50', 'C22H22Br2N2O10Se2', 'C22H24N2O6Se2', 'C18H22N2O6Se', 'C20H26N2O6Se', 'C20H20N2O6Se2',
              'PZ51', 'GAPDH', 'GQDs', 'C14H11NO3Se', 'C18H14OSe', 'C15H14O2Se', 'C3N4@NMF', 'C20H24N2O6Se2',
              'C34H28Fe2N2O2Se2', 'C30H36Fe2N2O2Se2', 'C38H38Fe2N2O2Se2', 'C26H28N2Se2', 'C12H6N4O8Se2',
              'P450CLA', 'C23H34N4O8SSe', 'Fe(III)Mb', 'G34C', 'A50C', 'DAB', 'GNR', 'STAP', 'C15H10O2',
              'C14H11NO2Se', 'PRDX1', 'K79A', 'K73A', 'K72AK73A', 'K72AK73AK79A', 'C13H9NOSe', 'PRX1',
              'Fe0.5Co0.5', 'TMB', 'TcGPXI', 'GFeF', 'CQDs', 'GO', 'C28H22O8', 'C29H24O8', 'C30H24O9',
              'C32H26O10', 'C19H24N3O3Se', 'C21H21N2O2Se', 'C20H31N4O', 'C16H19N2O2Se', 'C14H19N2O',
              'C27H33N4O2Se', 'C18H23N2O4Se', 'C16H21N2O2Se', 'EbMe', 'EbTe2', 'Ag2S@GO', 'GDYO', 'NADPH',
              'NADH', 'C12H14N4', 'Au140RS60', 'APX1', 'GGGTGGGAnGGGTGGG', 'GGGTGGGTGGGTGGG',
              'GGGTGGGTGGGTGGGAnGGGTGGGTGGG', 'GGGTGGGTGGGTGGGA7GGGTGGGTGGG', 'GST M208A', 'GST R15K',
              'C34H32N4O4FeCl', 'C15H10O7', 'C20H28N2O2Se2', 'PS2.M', 'Fe SAzyme', 'Zn SAzyme', 'C20H14N2O3Se',
              'HRP 5000', 'FeAC', 'Au 9.8Pd 90.2', 'CuI 4L 4', 'Ce0.5Zr0.5O2', 'CeGONRs', 'Fe3[Fe(CN)6]2', 'RNP',
              '[H2N(CH2)3]8Si8Co6O12(OH)4', 'HSA', 'MnP S168W', 'DMOP', 'CAPOA1', 'CAPOT1', 'CAPO1', 'C19H14BrN3O2Se',
              'C18H19BrN2O2Se', 'C17H17BrN2O2Se', 'C12H13O2.50Se', 'L29H Mb', 'Mn0.15Fe0.85Fe2O4', 'Mn0.5Fe0.5Fe2O4',
              'GHZ', 'CYP25', 'CuNiAl LDH', 'SAA', 'C20H29NO2SSe', 'PtCo@G', 'ATP A2', 'HRP A2', 'BiSA@Au', 'T67R Mb',
              'T67K Mb', 'BSA@AuNCs', 'PZ 51', 'TMPD', 'LPO', 'LspPOX', 'Fe(III)HRP', 'Mn(III)HRP', 'FeTBAP', 'C9H11NOSe',
              'C11H16NOSe', 'SAG', 'C8H18O2Se2', 'AF', 'W96A', 'F405L', 'F393A', 'M237V',
              'KFe(III)[Fe(CN) 6]Fe 2(III)(OH)(DMF)O(BDC) 3', 'C12H10O2Se2', 'C12H10O3Se2', 'D153A', 'N246A',
              'C13H8Cl2N2O2Se', 'C13H8Br2N2O2Se', 'C13H9Br3N2O2Se', 'C14H14O3Se', 'C18H12N2O2', 'FCG', 'AtGLB1',
              'AtGLB2', 'AtGLB3', 'TSA', 'AhpC', 'LmPP', 'V90H', 'Cu 0.3Co 2.7O 4', 'C1H0.677O0.586N0.015Na0.069',
              'C34H32ClFeN4O4', 'ESeSAr', 'C26H20N2O2Se', 'C26H20N2O2Te', 'C27H20Cl2N2O2Se', 'C28H18N2O2.5Te',
              'C26H18N2O2Te', 'BAFA', 'MbFeIII', 'C14H18N2Se2', 'C22H26N2Se2', 'C14H17NSe', 'C18H21NSe', 'ETP',
              'WT Mb', 'Fe 1.44O 0.32 (OH) 3.86', 'C34H32FeN4O4', 'ABTS', 'PdCu@HRP', 'C62(COOH)4', 'AnnAt1',
              'C60[C(COOH)2]2', 'Y103F Mb', 'VO(DAC)2', 'D138V', 'C16H18O4Se', 'C18H22O6Se', 'C20H26O8Se', 'CAT',
              'CNA', 'FePPIX', 'C26H40N2Se2', 'C16H20N2Se2', 'C18H24N2Se2', 'C20H28N2Se2', 'H39Q', 'GSeSeG',
              'C18H15N2O11Se2', 'C18H16N2O8Se', 'C18H15N2O8Se2', 'DOPA', 'C44H81O10NP', 'CYP119A1', 'BMP',
              'CYP152A1', 'CYP101A1', 'Cu 3.2(PO 4) 2@GOD', 'Cu 0.89Zn 0.11O', 'EPO', 'CPZ', 'CCP(M1)', 'W51F',
              'W191F', 'HRPC', 'Fe3O4@MOF', 'GIM', 'DMP', 'C15H10O5', 'C15H10O6', 'FeCPNGs', 'BSA@Au', 'Pd@PEDOT',
              'H404A', 'D292A', 'H496A', 'R490A', 'R360A', 'K353A', 'Au127SR51', 'Au127SR65', 'OsGrx', 'B(C6F5)3',
              'C25H14O7', '(T 3G 2) 4', 'T 2G 3', 'H48Q', 'Ce61Zr39O4(OH)4(BDC)6', 'Ce28Zr72O4(OH)4(BDC)6',
              'Ce43Zr57O4(OH)4(BDC)6', 'Ce87Zr13O4(OH)4(BDC)6', 'MMb', 'C282H432N80O80S4Fe', 'C4H10N130Te', 'C5H12N130Te',
              'CuC19H14N4O2', 'PGP', 'PMNT', 'MnTBAP', 'AuMS', 'C100H180N20O24', 'DMSN@AuPtCo', 'CYP119', 'GCDSA', 'MTP',
              'C20H10F2O5', 'Ni(C30H28N4O4S2)', 'Ni(C31H30N4O4S2)', 'AuAMP', 'C18H20N2O2Se2', 'C22H28N2O2Se2', 'C26H36N2O2Se2',
              'C26H40N2O2Se2', 'PMGO', 'CYP175A1', 'L80H', 'L80Q', 'Cu2Ag0.53Fe0.465(CN)6', 'Pd12L6', 'BM3', 'HRPR', 'GFH',
              'GPX1', 'WPTP E254G', 'BPQDs', 'Co1.5Mn1.5O4', 'Ru@G', 'PEDOT', 'ZPOA', 'HRPA', 'DMA', 'DNAzyme']

# %%
def createIR(formula):
    global banned_oxi
    if uf.check_nan(formula) or formula in banned_oxi:
        return np.nan

    try:
        composition = fu.Composition(formula)
    except:
        print(f"ERR creating composition {formula}")
        return np.nan

    element_counts = fu.elfromcomp(composition)
    sum_atoms = 0
    res = []

    try:
        oxi_state = fu.OS(formula)
    except:
        banned_oxi += [formula]
        print(f"ERR creating OS {formula}")
        return np.nan

    for atom, _ in composition.items():
        try:
            ir = atom.ionic_radii[int(oxi_state[str(atom)])]
            # print(atom, oxi_state[str(atom)], ir, element_counts[str(atom)])
        except:
            print(f"ERR getting ionic radii {formula}; {atom};")#{atom.ionic_radii}; {oxi_state[str(atom)]};")
            return np.nan
        sum_atoms += element_counts[str(atom)]
        res.append(element_counts[str(atom)] * ir)
        
    IR = sum(res)/sum_atoms
    return IR

# %%
res_df["IR"] = df["formula"].apply(createIR)
# Out:
# ERR creating composition N-CQDs
# ERR creating composition N-CQDs
# ERR getting ionic radii Co@C; C;
# ERR getting ionic radii NiO; Ni;
# ERR getting ionic radii NiO; Ni;
# ERR getting ionic radii Pd; Pd;
# ERR creating composition u-cytc550
# ERR creating composition u-cytc550
# ERR creating composition u-cytc550
# ERR creating composition u-cytc550
# ERR creating composition BSA-PtAu@CNS
# ERR creating composition BSA-PtAu@CNS
# ERR creating composition Cys-AuNCs
# ERR getting ionic radii CaO2; Ca;
# ERR creating composition CaO2/DOX
# ERR creating composition CaO2/DOX@SiO2/DOX
# ERR creating composition CaO2/DOX@SiO2/DOX-MnO2
# ERR creating composition CaO2/DOX@SiO2/DOX-MnO2
# ERR creating composition CaO2/DOX@SiO2/DOX-MnO2
# ERR getting ionic radii CDs; C;
# ERR getting ionic radii CDs; C;
# /home/oleg/Programs/.venv/lib/python3.12/site-packages/pymatgen/core/composition.py:372: UserWarning: No Pauling electronegativity for Ds. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   syms = sorted(sym_amt, key=lambda sym: get_el_sp(sym).X)
# ERR getting ionic radii C10H11NO6Se; C;
# ERR getting ionic radii C13H19NO4Se; C;
# ERR getting ionic radii C14H21NO4Se; C;
# ERR getting ionic radii C13H17NO4Se; C;
# ERR getting ionic radii TPO; H;
# ERR creating composition Fe3O4/Pβ-CD
# ERR creating composition Fe3O4/Pβ-CD
# ERR getting ionic radii C; C;
# ERR getting ionic radii C; C;
# ERR getting ionic radii Pd; Pd;
# ERR getting ionic radii Pd; Pd;
# ERR getting ionic radii Pd; Pd;
# ERR getting ionic radii Pd; Pd;
# ERR getting ionic radii Pd; Pd;
# ERR getting ionic radii Pd; Pd;
# ERR creating composition SeO32-
# ERR creating composition (CyaSe)2
# ERR creating composition 3-amino-9-ethylcarbazole
# ERR creating composition o-tolidine
# ERR creating composition FeIII–TMPyP
# ERR creating composition AuNPs/MCA
# ERR creating composition AuNPs/MCA
# ERR getting ionic radii Pd@Pt; Pd;
# ERR creating composition Mn3O4/Pd@Pt
# ERR creating composition Mn3O4/Pd@Pt
# ERR getting ionic radii Pd@Pt; Pd;
# ERR getting ionic radii Mn3[Co(CN)6]2; C;
# ERR getting ionic radii Mn3[Co(CN)6]2; C;
# ERR getting ionic radii Mn3[Co(CN)6]2; C;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii P@Pt@P; P;
# ERR getting ionic radii P@Pt@P; P;
# ERR creating composition P@Pt@P-Au
# ERR creating composition P@Pt@P-Au
# ERR creating composition P@Pt@P-Au
# ERR creating composition Hb
# ERR getting ionic radii MnO2; Mn;
# ERR getting ionic radii MnO2; Mn;
# ERR getting ionic radii C; C;
# ERR getting ionic radii C; C;
# ERR getting ionic radii C; C;
# ERR getting ionic radii C; C;
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition AuNPs
# ERR creating composition AuNPs
# ERR getting ionic radii H2O2; H;
# ERR getting ionic radii H2O2; H;
# ERR getting ionic radii C6H8N2O2Se; C;
# ERR getting ionic radii C8H12N2O2Se; C;
# ERR getting ionic radii C18H16N2O2Se; C;
# ERR getting ionic radii C10H16N2O2Se; C;
# ERR getting ionic radii C14H20N2O4Se; C;
# ERR creating composition cyt c
# ERR creating composition cyt c
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition PRT-AuNCs
# ERR creating composition PRT-AuNCs
# ERR creating composition 3(cid:11)-H9
# ERR creating composition 3(cid:11)-H12
# ERR creating composition Ag-Fe3O4
# ERR creating composition Ag-Fe3O4
# ERR creating composition Dex-IONP-GOx
# ERR creating composition Dex-IONP-GOx
# ERR creating composition C-dot/NiAl-LDH
# ERR creating composition C-dot/NiAl-LDH
# ERR getting ionic radii Pd; Pd;
# ERR getting ionic radii Pd; Pd;
# ERR getting ionic radii Cu(OH)2; H;
# ERR getting ionic radii Cu(OH)2; H;
# ERR creating composition Au-Ag
# ERR creating composition Au-Ag
# ERR getting ionic radii C10H9NOSe; C;
# ERR getting ionic radii C11H13NOSe; C;
# ERR getting ionic radii C14H19NOSe; C;
# ERR getting ionic radii MnO2; Mn;
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Fe3O4/Au
# ERR creating composition Fe3O4/Au
# ERR creating composition Fe3O4/Au
# ERR creating composition Fe3O4/Au
# ERR creating composition Cu 1.8S–cgmc
# ERR creating composition Cu 1.8S–cgmc
# ERR creating composition ZIF-8@BHb
# ERR creating composition ZIF-8@BHb
# ERR creating composition ZIF-8@BHb
# ERR creating composition G3.0-He
# ERR creating composition G3.0-He
# ERR creating composition HRP^SP
# ERR getting ionic radii Co9S8; Co;
# ERR getting ionic radii Co9S8; Co;
# ERR creating composition 3 MgCO3·9 Mg(OH)2·3 H2O
# ERR creating composition CH3Se-
# ERR getting ionic radii C; C;
# ERR getting ionic radii C; C;
# ERR getting ionic radii C; C;
# ERR getting ionic radii C; C;
# ERR getting ionic radii Mb; Mb0+;
# ERR getting ionic radii Au; Au;
# ERR creating composition c-cyts
# ERR creating composition HRP-OX
# ERR creating composition YcYfetus
# ERR getting ionic radii HCNTs; H;
# ERR getting ionic radii HCNTs; H;
# ERR creating composition Fe3+
# ERR creating composition Fe3+
# ERR creating composition 4c15
# ERR creating composition 4c15A4
# ERR creating composition 4c15A12
# ERR creating composition 4c15A20
# ERR creating composition Cu2+
# ERR creating composition Cu2+
# ERR creating composition Cu2+
# ERR creating composition Cu2+
# ERR creating composition Cu2+
# ERR creating composition Cu2+
# ERR creating composition Cu2+
# ERR creating composition Pt-WO3-r-GO
# ERR creating composition Fe-N-C
# ERR creating composition Fe-N-C
# ERR creating composition cyt c
# ERR creating composition cyt c
# ERR creating composition Sm-CeO2
# ERR getting ionic radii C; C;
# ERR getting ionic radii C; C;
# ERR getting ionic radii C; C;
# ERR creating composition GO-CTAB-AuNP-hemin
# ERR creating composition GO-CTAB-AuNP-hemin
# ERR creating composition GO-CTAB-AuNP-hemin
# ERR creating composition GO-CTAB-AuNP-hemin
# ERR getting ionic radii AuPd; Au;
# ERR getting ionic radii AuPd; Au;
# ERR creating composition AuPd-NH2-fMnO2
# ERR creating composition AuPd-NH2-fMnO2
# ERR creating composition TfuCat
# ERR creating composition TfuCat
# /home/oleg/Programs/.venv/lib/python3.12/site-packages/pymatgen/core/composition.py:372: UserWarning: No Pauling electronegativity for Ts. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   syms = sorted(sym_amt, key=lambda sym: get_el_sp(sym).X)
# ERR getting ionic radii C10H18O2Se; C;
# ERR getting ionic radii C10H18O2Se; C;
# ERR getting ionic radii C10H18O2Se; C;
# ERR getting ionic radii C10H18O2Se; C;
# ERR getting ionic radii C10H18O2Se; C;
# ERR getting ionic radii C10H18O2Se; C;
# ERR creating composition Au-Hg/rGO
# ERR creating composition Au-Hg/rGO
# ERR creating composition Prostaglandin H Synthase
# ERR creating composition Prostaglandin H Synthase
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition SYI-2074
# ERR getting ionic radii Au@Pt; Au;
# ERR getting ionic radii Au@Pt; Au;
# ERR creating composition Cu(Nc)22+
# ERR creating composition Cu(Nc)22+
# ERR creating composition Cu2-xSe
# ERR creating composition Cu2-xSe
# ERR creating composition Cu2-xSe
# ERR creating composition Cu2-xSe
# ERR creating composition BLG-Heme
# ERR creating composition BLG-T-Heme
# ERR creating composition BLG-C-Heme
# ERR creating composition BLG-K-Heme
# ERR creating composition Crystallin-Heme
# ERR getting ionic radii Ru@MnO2; Ru;
# ERR getting ionic radii Ru@MnO2; Ru;
# ERR creating composition CD44 MMSN/AuNPs
# ERR creating composition CD44 MMSN/AuNPs
# ERR creating composition Au-Pt/SiO2
# ERR creating composition Au-Pt/SiO2
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition cSelS
# ERR creating composition cSelS
# ERR creating composition cSelS C174S
# ERR creating composition AuNWs
# ERR creating composition PBNPs@AuNWs
# ERR creating composition Pt-GNRs
# ERR creating composition Pt-GNRs
# ERR creating composition TiO2@CeOx
# ERR creating composition TiO2@CeOx
# ERR creating composition TiO2@CeOx
# ERR creating composition TiO2@CeOx
# ERR getting ionic radii MnO2; Mn;
# ERR getting ionic radii MnO2; Mn;
# ERR getting ionic radii MnO2; Mn;
# ERR getting ionic radii MnO2; Mn;
# ERR getting ionic radii MnO2; Mn;
# ERR creating composition ficin-TN
# ERR creating composition ficin-TN
# ERR getting ionic radii Co3O4@NiO; Ni;
# ERR getting ionic radii Co3O4@NiO; Ni;
# ERR creating composition cit-PHGPx
# ERR creating composition ST1Cys
# ERR creating composition ST2Cys
# ERR creating composition ST1Sec
# ERR creating composition ST2Sec
# ERR creating composition GSH-Px
# ERR creating composition Cyt c
# ERR creating composition PPAuMns
# ERR creating composition PPAuMns
# ERR creating composition PPAuMns
# ERR creating composition PPAuMns
# ERR creating composition PPAuMns
# ERR creating composition PPAuMns
# ERR creating composition PPAuMns
# ERR creating composition PPAuMns
# ERR creating composition PPAuMns
# ERR getting ionic radii NiCo2O4; Ni;
# ERR getting ionic radii NiCo2O4; Ni;
# ERR creating composition Co/CuS-MMT
# ERR creating composition Co/CuS-MMT
# ERR getting ionic radii Se; Se;
# ERR getting ionic radii HPO; H;
# ERR getting ionic radii HPO; H;
# ERR creating composition g-C3N4-PdNPs
# ERR creating composition g-C3N4-PdNPs
# ERR creating composition MnCcP.1
# ERR creating composition Tyr36Phe-MnCcP.1
# ERR creating composition Lys179Arg-MnCcP.1
# ERR creating composition Ile40Gly-MnCcP.1
# ERR creating composition Tyr36Phe/Lys179Arg-MnCcP.1
# ERR creating composition Ile40Gly/Lys179Arg-MnCcP.1
# ERR creating composition Tyr36Phe/Ile40Gly-MnCcP.1
# ERR creating composition Tyr36Phe/Ile40Gly/Lys179Arg-MnCcP.1
# ERR creating composition Mn-TCPP
# ERR creating composition Fe-TCPP
# ERR creating composition Mn-TCPP
# ERR creating composition Mn-TCPP
# ERR creating composition h-Fe3O4@ppy
# ERR creating composition h-Fe3O4@ppy
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii FeTSPC; H;
# ERR getting ionic radii FeTSPC; H;
# ERR getting ionic radii Au; Au;
# ERR creating composition ZnPc-GQDs-MnO2@PtNPs
# ERR getting ionic radii H2O2; H;
# ERR getting ionic radii H2O2; H;
# ERR creating composition CP 600−6
# ERR creating composition CP 600−6
# ERR getting ionic radii CeCu; Ce;
# ERR getting ionic radii CeCu; Ce;
# ERR getting ionic radii NiPtPd; Ni;
# ERR getting ionic radii NiPtPd; Ni;
# ERR getting ionic radii CuHCF; H;
# ERR getting ionic radii CuHCF; H;
# ERR getting ionic radii C; C;
# ERR getting ionic radii C; C;
# ERR getting ionic radii C; C;
# ERR getting ionic radii C; C;
# ERR creating composition HRP-avidin
# ERR creating composition HRP-avidin
# ERR creating composition HRP-avidin
# ERR creating composition HRP-avidin
# ERR creating composition HRP-avidin
# ERR creating composition HRP-avidin
# ERR creating composition Fe3O4@Cu/GMP
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR creating composition PB-Ft
# ERR creating composition PB-Ft
# ERR creating composition PB-Ft
# ERR creating composition PB-Ft
# ERR creating composition Selenium-enriched yeast
# ERR creating composition Selenium-enriched alga Chlorella
# ERR getting ionic radii AuVCs; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition L4.6k-dG4
# ERR creating composition L4.6k-dG4
# ERR creating composition AuNPs@g-C3N4
# ERR creating composition AuNPs@g-C3N4
# ERR creating composition g-C3N4
# ERR creating composition g-C3N4
# ERR creating composition Prussian Blue
# ERR getting ionic radii FeN5; N;
# ERR creating composition Co/PMCS
# ERR creating composition Cu−N−C
# ERR getting ionic radii FeN5; N;
# ERR creating composition Zn−N−C
# ERR creating composition Co−N−C
# ERR creating composition Fe−N−C
# ERR creating composition Cu−N−C
# ERR creating composition Hemin-T 10-EAD2
# ERR creating composition Hemin-T 10-EAD2
# ERR creating composition Hemin-T 10-EAD2
# ERR creating composition Hemin-T 10-EAD2
# ERR creating composition La3+
# ERR creating composition La3+
# ERR creating composition DNA50/hemin
# ERR creating composition Control1
# ERR creating composition Control1/hemin
# ERR creating composition Control2
# ERR creating composition Control2/hemin
# ERR creating composition Control3
# ERR creating composition Control3/hemin
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii C; C;
# ERR getting ionic radii C; C;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition G-PhB
# ERR creating composition G-PhB
# ERR getting ionic radii Au@Pt; Au;
# ERR creating composition Fe3O4@PDA@Pd/Pt
# ERR creating composition Fe3O4@PDA@Pd/Pt
# ERR creating composition PhSe2
# ERR getting ionic radii CuZnFeS; Cu;
# ERR getting ionic radii CuZnFeS; Cu;
# ERR creating composition Ficin
# ERR creating composition Ficin
# ERR creating composition MoS2-Au@Pt
# ERR creating composition MoS2-Au@Pt
# ERR creating composition FeIII–mimochrome VI
# ERR creating composition FeIII–mimochrome VI
# ERR creating composition FeIII–mimochrome VI
# ERR creating composition FeIII–mimochrome VI
# ERR creating composition Se-scFv-B3
# ERR creating composition H170A hHRP
# ERR creating composition H170A hHRP
# ERR getting ionic radii Co4N; Co;
# ERR getting ionic radii Co4N; Co;
# ERR getting ionic radii TCDD; H;
# ERR getting ionic radii TCDD; H;
# ERR creating composition 5Fe2O3•9H2O
# ERR getting ionic radii Se; Se;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition Cu2+
# ERR creating composition Cu2+
# ERR creating composition NH2-MIL-88B(Fe)
# ERR creating composition NH2-MIL-88B(Fe)
# ERR creating composition NMC Tp-TTA
# ERR creating composition NMC Tp-TTA
# ERR getting ionic radii C12H10OSSe; C;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR creating composition AuNPs@POMD-8pep
# ERR creating composition AuNPs@POMD-8pep
# ERR creating composition VOx
# ERR creating composition VOx
# ERR creating composition Cu-N-C
# ERR creating composition Cu-N-C
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Au NCs; Au;
# ERR creating composition cationic Au NCs
# ERR creating composition cationic Au NCs
# ERR creating composition cationic Au NCs
# ERR creating composition cationic Au NCs
# ERR creating composition Fc
# ERR creating composition Fc
# ERR getting ionic radii Se; Se;
# ERR creating composition PDI/Si-CeO2
# ERR creating composition PDI/Si-CeO2
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition Co-MOF
# ERR getting ionic radii Pd; Pd;
# ERR getting ionic radii Pd; Pd;
# ERR getting ionic radii Pd@Pt; Pd;
# ERR getting ionic radii Pd@Pt; Pd;
# ERR getting ionic radii MoS2@Au; Mo;
# ERR getting ionic radii MoS2@Au; Mo;
# ERR creating composition Fe/Al-GNE
# ERR creating composition Fe/Al-GNE
# ERR creating composition Fe/Al-GNE
# ERR creating composition Fe/Al-GNE
# ERR creating composition SWNT-NH2@hemin
# ERR creating composition SWNT-NH2@hemin
# ERR creating composition SWNT@hemin
# ERR creating composition SWNT@hemin
# ERR creating composition SWNT-COOH@hemin
# ERR creating composition SWNT-COOH@hemin
# ERR getting ionic radii Fe3(BDC)3; B;
# ERR getting ionic radii Fe3(BDC)3; B;
# ERR getting ionic radii C7H9NO3Se; C;
# ERR getting ionic radii C7H9NO3Se; C;
# ERR getting ionic radii Se; Se;
# ERR getting ionic radii Se; Se;
# ERR creating composition Sepp1UF
# ERR creating composition Sepp1UF
# ERR creating composition Sepp1UF
# ERR creating composition Sepp1UF
# ERR creating composition NBD-CL
# ERR creating composition NBD-CL
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR creating composition Pd-WO3-SiO2
# ERR creating composition Pd-WO3-SiO2-PB
# ERR creating composition Pd-WO3-SiO2-PB
# ERR creating composition Pd-WO3-SiO2
# ERR creating composition Pd-WO3-SiO2-PB
# ERR getting ionic radii NH4F; H;
# ERR getting ionic radii SnF2; Sn;
# ERR creating composition Fe3O4/SiO2/Gr
# ERR creating composition Fe3O4/SiO2/Gr
# ERR creating composition Fe3O4/SiO2/Gr
# ERR creating composition Fe3O4/SiO2/Gr
# ERR creating composition Co(II) complex 1
# ERR creating composition Co(II) complex 2
# ERR creating composition Catalase
# ERR creating composition Hemoglobin
# ERR getting ionic radii Fe; Fe;
# ERR getting ionic radii Fe; Fe;
# ERR creating composition Cu–hemin
# ERR creating composition Cu–hemin
# ERR creating composition Fe-SAs/NC
# ERR creating composition Fe-SAs/NC
# ERR creating composition Cu2O/Au
# ERR creating composition Cu2O/Au
# ERR creating composition Ni-CuAu
# ERR creating composition Ni-CuAu
# ERR creating composition β-CD-hemin
# ERR creating composition β-CD-hemin
# ERR creating composition Fe3O4/g-C3N4
# ERR creating composition Fe3O4/g-C3N4
# ERR creating composition Fe3O4/g-C3N4
# ERR creating composition Fe3O4/g-C3N4
# ERR creating composition Cu,Zn-SOD
# ERR creating composition Cu,Zn-SOD
# ERR creating composition [MnIIIMnII(Ldtb)((cid:2)-OAc)2]BPh4
# ERR creating composition 4c15-s
# ERR creating composition 4c15
# ERR creating composition DPPC-PI
# ERR creating composition DPPC-PI
# ERR creating composition DPPC-PI
# ERR creating composition DPPC-PI
# ERR creating composition DPPC-PI
# ERR creating composition DPPC-PI
# ERR creating composition VHb
# ERR creating composition VHb
# ERR creating composition VHb
# ERR getting ionic radii TPO; H;
# ERR creating composition CcpA
# ERR getting ionic radii Au@TiO2; Au;
# ERR getting ionic radii Au@TiO2; Au;
# ERR getting ionic radii TCPP Fe(III); H;
# ERR getting ionic radii TCPP Fe(III); H;
# ERR creating composition FeIII-MC6*
# ERR creating composition FeIII-MC6*
# ERR creating composition FeIII-MC6*a
# ERR creating composition FeIII-MC6*a
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition T-DMSNs@Au
# ERR creating composition T-DMSNs@Au
# ERR creating composition SWNT/Mb
# ERR creating composition SWNT/HRP
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition Fe(TpCPP)
# ERR creating composition Fe(TpCPP)
# ERR creating composition Fe(TpCPP)-Xln10A
# ERR creating composition Fe(TpCPP)-Xln10A
# ERR creating composition N-doped Fe3C
# ERR creating composition MWCNT@rGONR
# ERR creating composition MWCNT@rGONR
# ERR creating composition MoS2-Au
# ERR creating composition MoS2-Au
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Fe(III)Hb
# ERR creating composition Fe(III)Hb
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Prx1
# ERR creating composition Prx1
# ERR getting ionic radii AuNCs; Au;
# ERR getting ionic radii AuNCs; Au;
# ERR creating composition Mn-TPPS
# ERR creating composition GO-UO22+
# ERR creating composition CS-MoSe2
# ERR creating composition CS-MoSe2
# ERR creating composition CS-MoSe2
# ERR creating composition CS-MoSe2
# ERR creating composition 2-(benzylselanyl)phenyl)methanamine
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition Cytc
# ERR getting ionic radii T28C; H;
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition CatG4
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition Fe@Fe3O4@Cu2-xS
# ERR creating composition Fe@Fe3O4@Cu2-xS
# ERR getting ionic radii H2O2; H;
# ERR getting ionic radii TCPP Fe(III); H;
# ERR getting ionic radii TCPP Fe(III); H;
# ERR creating composition Au-Cu(II)
# ERR creating composition Au-Cu(II)
# ERR creating composition CH3-C(CH3)2CH2C(CH3)2-C6H4-O(C2H4O)9_I0-H
# ERR creating composition C12H25N(COC(CH3)=CH2)-(C2H40)Is-H
# ERR creating composition C18H37NH(C2H40)10-H
# ERR creating composition C18H37NH(C2H40)15-H
# ERR creating composition ethanol
# ERR creating composition propanol-2
# ERR creating composition butanol
# ERR creating composition CuO-Au
# ERR creating composition CuO-Au
# ERR creating composition Ag-Au
# ERR creating composition Ag-Au
# ERR creating composition Ag-Au
# ERR creating composition Ag-Au
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition metMb
# ERR getting ionic radii Fe; Fe;
# ERR getting ionic radii Fe; Fe;
# ERR creating composition N-(2-nitrophenyl) benzenesulfonamide
# ERR creating composition NPY–heme
# ERR creating composition NPY–heme
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Cu@PB; Cu;
# ERR getting ionic radii Cu@PB; Cu;
# ERR creating composition guaiacol
# ERR creating composition guaiacol
# ERR creating composition Kaol-ycc
# ERR creating composition Kaol-E20-ycc
# ERR creating composition Kaol-ycc
# ERR creating composition Kaol-E40-ycc
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Phe68azoAla
# ERR creating composition Phe179azoAla
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition PC-OOH
# ERR creating composition PC-OOH
# ERR creating composition H2O2 + TMB
# ERR creating composition H2O2 + OPD
# ERR creating composition Fe-CNNPs
# ERR creating composition Fe-CNNPs
# ERR getting ionic radii K4[Fe(CN)6]; C;
# ERR getting ionic radii K4[Fe(CN)6]; C;
# ERR getting ionic radii NiCo2S4; Ni;
# ERR getting ionic radii NiCo2S4; Ni;
# ERR getting ionic radii K4[Fe(CN)6]; C;
# ERR getting ionic radii K4[Fe(CN)6]; C;
# ERR getting ionic radii K4[Fe(CN)6]; C;
# ERR getting ionic radii K4[Fe(CN)6]; C;
# ERR getting ionic radii K4[Fe(CN)6]; C;
# ERR getting ionic radii K4[Fe(CN)6]; C;
# ERR getting ionic radii K4[Fe(CN)6]; C;
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Zn-TCPP(Fe)
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR creating composition Hemoglobin
# ERR creating composition Hemoglobin
# ERR creating composition Horseradish peroxidase
# ERR creating composition Horseradish peroxidase
# ERR getting ionic radii NaC7H6NO4; C;
# ERR getting ionic radii NaC6H4NO3; C;
# ERR getting ionic radii NaC6H4NO3; C;
# ERR creating composition AuNPs–SWNTs
# ERR creating composition AuNPs–SWNTs
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii C1; C;
# ERR getting ionic radii C2; C;
# ERR getting ionic radii C3; C;
# ERR getting ionic radii C4; C;
# ERR creating composition ficin
# ERR creating composition Au−Ag/L-Cys-rGO
# ERR creating composition Au−Ag/L-Cys-rGO
# ERR creating composition Au/L-Cys-rGO
# ERR creating composition Au/L-Cys-rGO
# ERR creating composition Ag/L-Cys-rGO
# ERR creating composition Ag/L-Cys-rGO
# ERR getting ionic radii MnP; P;
# ERR getting ionic radii MnP; P;
# ERR getting ionic radii MnP; P;
# ERR getting ionic radii MnP; P;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition Cu-Pt
# ERR creating composition POM-Calix hybrid
# ERR creating composition POM-Calix hybrid
# ERR getting ionic radii NiCo2O4; Ni;
# ERR getting ionic radii NiCo2O4; Ni;
# ERR getting ionic radii NiCo2O4; Ni;
# ERR creating composition Mn-HPyP
# ERR creating composition Mn-HPyP
# ERR creating composition Mn-HPyP
# ERR getting ionic radii C; C;
# ERR creating composition AuNPs@MoS2-QDs
# ERR creating composition AuNPs@MoS2-QDs
# ERR creating composition 15SeP 1
# ERR creating composition 15SeP 1
# ERR creating composition 15SeP
# ERR creating composition 15SeP
# ERR creating composition IgG
# ERR getting ionic radii SiW12@Co3O4; Si;
# ERR getting ionic radii SiW12@Co3O4; Si;
# ERR creating composition Gd-MPO
# ERR creating composition Ni3(OH)2(C8H4O4)2(H2O)4·2H2O
# ERR creating composition Ni3(OH)2(C8H4O4)2(H2O)4·2H2O
# ERR creating composition Au NC micelles
# ERR creating composition NEQC-340
# ERR creating composition oPGHS-1
# ERR getting ionic radii Fe@C; C;
# ERR getting ionic radii Fe@C; C;
# ERR creating composition Por-CeO2
# ERR creating composition Por-CeO2
# ERR creating composition ycc
# ERR getting ionic radii NCNTs@MoS2; N;
# ERR getting ionic radii NCNTs@MoS2; N;
# ERR creating composition MP-8
# ERR creating composition MP-8
# ERR getting ionic radii AuNPTs; Au;
# ERR getting ionic radii AuNPTs; Au;
# ERR creating composition Ceruloplasmin
# ERR creating composition PNIPAM-CD-g-Te
# ERR creating composition PNIPAM-CD-g-Te
# ERR creating composition PNIPAM-CD-g-Te
# ERR creating composition PNIPAM-CD-g-Te
# ERR getting ionic radii C; C;
# ERR getting ionic radii C; C;
# ERR getting ionic radii C6H3Br3O3; C;
# ERR getting ionic radii C6H3Br3O3; C;
# ERR creating composition (25R)-5a-spirostane-2a,3b,5a-triol 3-O-(O-a-L-rhamnopyranosyl-(1 ? 2)-O-(b-D-galactopyranosyl-(1 ? 3))-b-D-glucopyranoside)
# ERR creating composition Fe3(PO4)2·8H2O
# ERR creating composition Fe3(PO4)2·8H2O
# ERR creating composition crystallin aggregate-heme
# ERR creating composition crystallin aggregate-heme
# ERR creating composition crystallin aggregate-heme
# ERR creating composition crystallin aggregate-heme
# ERR creating composition [SVW11O40]3-
# ERR creating composition [SVW11O40]3-
# ERR creating composition [SV2W10O40]4-
# ERR creating composition [SV2W10O40]4-
# ERR creating composition Fe-N-C
# ERR getting ionic radii Rh; Rh;
# ERR getting ionic radii Rh; Rh;
# ERR creating composition Au/Pt
# ERR creating composition Au/Pt
# ERR creating composition Au/Fe3O4/GO
# ERR creating composition Au/Fe3O4/GO
# ERR getting ionic radii MnO2; Mn;
# ERR getting ionic radii MnO2; Mn;
# ERR getting ionic radii MnO2; Mn;
# ERR creating composition Hb
# ERR creating composition FTN_1133
# ERR creating composition FTN_1133
# ERR creating composition MoS2-COOH-MWCNT
# ERR creating composition Fe(por)
# ERR creating composition Fe(por)
# ERR creating composition ficin
# ERR creating composition ficin
# ERR creating composition Tg-HbI
# ERR creating composition Tg-HbII
# ERR creating composition Ti3C2Tx
# ERR creating composition Ti3C2Tx
# ERR creating composition Ti3C2Tx
# ERR creating composition DNA–Pt
# ERR creating composition DNA–Pt
# ERR creating composition g-CN@CuMOF
# ERR creating composition g-CN@CuMOF
# ERR creating composition Fe3C-NC
# ERR getting ionic radii AgAu; Ag;
# ERR getting ionic radii AgPd; Ag;
# ERR getting ionic radii AgPt; Ag;
# ERR creating composition Fe5HO8·4H2O
# ERR creating composition Fe5HO8·4H2O
# ERR creating composition Fe3O4NP@pSiO2
# ERR creating composition Fe3O4NP@pSiO2
# ERR creating composition Fe3O4NP@pSiO2
# ERR creating composition Fe3O4NP@pSiO2
# ERR getting ionic radii MnP; P;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR creating composition HRP/GO-GQDs
# ERR creating composition HRP/GO-GQDs
# ERR creating composition CeO2-Gd
# ERR creating composition CeO2-Gd
# ERR creating composition Co-MGNCs
# ERR creating composition Co-MGNCs
# ERR creating composition TA-Hb
# ERR creating composition TA-Hb
# ERR creating composition Cmcytc
# ERR creating composition Cmcytc
# ERR creating composition Cu,Zn-SOD
# ERR creating composition Cu,Zn-SOD
# ERR creating composition Ce-Fe3O4
# ERR creating composition Ce-Fe3O4
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition MoS2/N-rGO
# ERR creating composition MoS2/N-rGO
# ERR creating composition MoS2/N-rGO
# ERR creating composition MoS2/N-rGO
# ERR creating composition MoS2/N-rGO
# ERR creating composition 2-phenyl-1,2-benzisoselenazol-3(2H)-one
# ERR getting ionic radii Fe; Fe;
# ERR getting ionic radii Fe; Fe;
# ERR getting ionic radii Co; Co;
# ERR getting ionic radii Co; Co;
# ERR getting ionic radii AgPt; Ag;
# ERR getting ionic radii AgPt; Ag;
# ERR creating composition Cyt c
# ERR getting ionic radii Fe SSN; N;
# ERR getting ionic radii Fe SSN; N;
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Co-TCPP(Fe)
# ERR creating composition Cu-TCPP(Fe)
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Cu,Zn-SOD1
# ERR creating composition Cu,Zn-SOD1
# ERR getting ionic radii NiPd; Ni;
# ERR getting ionic radii NiPd; Ni;
# ERR creating composition CoMo hybrids
# ERR creating composition CoMo hybrids
# ERR creating composition CoMo hybrids
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR creating composition Tb-OBBA-Hemin
# ERR creating composition Tb-OBBA-Hemin
# ERR creating composition PS-[VVO(OMe)(hap-iah)]
# ERR creating composition Fe-iCOF
# ERR getting ionic radii Ir@MnFe2O4; Ir;
# ERR getting ionic radii Ir@MnFe2O4; Ir;
# ERR getting ionic radii Ir@MnFe2O4; Ir;
# ERR creating composition S-rGO
# ERR creating composition S-rGO
# ERR getting ionic radii BP; P;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Fe(OH)(BDC); H;
# ERR getting ionic radii Fe3O(H2O)2(BTC)2F; H;
# ERR getting ionic radii Fe(OH)(BDC); H;
# ERR getting ionic radii Fe3O(H2O)2(BTC)2F; H;
# ERR getting ionic radii Fe(OH)(BDC); H;
# ERR getting ionic radii Fe3O(H2O)2(BTC)2F; H;
# ERR creating composition FeP-pSC4-AuNPs
# ERR creating composition FeP-pSC4-AuNPs
# ERR creating composition Ce0.94Fe0.06O2-δ
# ERR creating composition Ce0.94Fe0.06O2-δ
# ERR getting ionic radii Au@Pt; Au;
# ERR getting ionic radii Au@Pt; Au;
# ERR creating composition Fe3O4@MIL-100(Fe)
# ERR creating composition Fe3O4@MIL-100(Fe)
# ERR creating composition SDS-Hemin-Imidazole
# ERR creating composition AuNPs
# ERR creating composition AuNPs
# ERR creating composition CNT/FeNC
# ERR creating composition CNT/FeNC
# ERR getting ionic radii Au@CD; C;
# ERR getting ionic radii Au@CD; C;
# ERR creating composition Au@CD + CeO2
# ERR getting ionic radii Au@CD; C;
# ERR creating composition Au@CD + CeO2
# ERR creating composition Prx4
# ERR getting ionic radii CoPW 11O 39; Co;
# ERR getting ionic radii CoPW 11O 39; Co;
# ERR creating composition AgNPs@Fe3O4
# ERR creating composition AgNPs@Fe3O4
# ERR getting ionic radii Au; Au;
# ERR creating composition g-C3N4
# ERR creating composition g-C3N4
# ERR creating composition Fe-g-C3N4
# ERR creating composition Fe-g-C3N4
# ERR creating composition C44.0%H12.2%O23.3%N16.5%S4.01%
# ERR creating composition C44.0%H12.2%O23.3%N16.5%S4.01%
# ERR getting ionic radii TPO; H;
# ERR getting ionic radii TPO; H;
# ERR getting ionic radii TPO; H;
# ERR creating composition Fe(III)-protoporphyrin IX
# ERR creating composition Fe(III)-protoporphyrin IX
# ERR creating composition Prx2
# ERR creating composition Prx2
# ERR creating composition Prx2
# ERR creating composition Fe(III) protoporphyrin IX chloride
# ERR creating composition FeCu-DA/NC
# ERR creating composition FeCu-DA/NC
# ERR creating composition FeCu-DA/NC
# ERR creating composition ZnFe2O4/ZnO
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Ag; Ag;
# ERR getting ionic radii Ag; Ag;
# ERR creating composition Se-enriched yeast
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition MWNT-SP
# ERR creating composition MWNT-MC
# ERR creating composition CeO2/CoO
# ERR creating composition CeO2/CoO
# ERR creating composition AuPd@UiO-67
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Ag; Ag;
# ERR getting ionic radii Ag; Ag;
# ERR creating composition Co@C-dots
# ERR creating composition Co@C-dots
# ERR getting ionic radii Ru; Ru;
# ERR creating composition CAANSs
# ERR creating composition Fe-PorCOF
# ERR creating composition Fe-PorCOF
# ERR getting ionic radii FeP; P;
# ERR getting ionic radii FeP; P;
# ERR creating composition pTBCB-PEG
# ERR creating composition pTBCB-PEG
# ERR creating composition pTBCB-PEG
# ERR creating composition pTBCB-PEG
# ERR creating composition pTBCB-PEG
# ERR creating composition pTBCB-PEG
# ERR creating composition Fe3O4/MWCNTs
# ERR creating composition Fe3O4/MWCNTs
# ERR getting ionic radii Ti3C2; C;
# ERR getting ionic radii Ti3C2; C;
# ERR getting ionic radii Ti3C2; C;
# ERR getting ionic radii Ti3C2; C;
# ERR creating composition NAD+
# ERR creating composition NAD+
# ERR getting ionic radii Fe3O4@CP; C;
# ERR getting ionic radii Fe3O4@CP; C;
# ERR creating composition HbA0
# ERR creating composition HbA1c
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii MnO2; Mn;
# ERR getting ionic radii MnO2; Mn;
# ERR creating composition Fe3O4@Cu/GMP
# ERR creating composition Fe3O4@Cu/GMP
# ERR creating composition Fe3O4@Cu/GMP-GOx
# ERR creating composition Fe3O4@Cu/GMP-GOx
# ERR creating composition Fe3O4@Cu/GMP-GOx
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Ru; Ru;
# ERR getting ionic radii Eb; Eb0+;
# ERR creating composition EbBz
# ERR creating composition Pt/Fe3O4-DIB-DETA-CNS
# ERR creating composition Pt/Fe3O4-DIB-DETA-CNS
# ERR getting ionic radii MnO2; Mn;
# ERR getting ionic radii MnO2; Mn;
# ERR creating composition Tf-trHb
# ERR creating composition Tf-trHb
# ERR getting ionic radii AgPt; Ag;
# ERR getting ionic radii AgPt; Ag;
# ERR getting ionic radii AgPt; Ag;
# ERR creating composition Cu2-xSe
# ERR creating composition Cu2-xSe
# ERR creating composition Cu2-xSe
# ERR creating composition Cu2-xSe
# ERR creating composition Cu2-xSe
# ERR getting ionic radii MnO2; Mn;
# ERR getting ionic radii MnO2; Mn;
# ERR getting ionic radii MnO2; Mn;
# ERR getting ionic radii MnO2; Mn;
# ERR getting ionic radii MnO2; Mn;
# ERR getting ionic radii NiTe; Ni;
# ERR getting ionic radii H2O2; H;
# ERR getting ionic radii H2O2; H;
# ERR getting ionic radii PtCo; Pt;
# ERR getting ionic radii PtCo; Pt;
# ERR getting ionic radii PtCo; Pt;
# ERR creating composition PtNPs@MnO2
# ERR creating composition Fe3O4-Sch
# ERR creating composition Fe3O4-Sch
# ERR getting ionic radii Fe(C5H4N4)O5Cl; C;
# ERR getting ionic radii Fe(C5H4N4)O5Cl; C;
# ERR getting ionic radii Fe(C5H4N4)O5Cl; C;
# ERR creating composition Pt NC/3D GF
# ERR creating composition Pt NC/3D GF
# ERR creating composition Pt NC/3D GF
# ERR creating composition Pt NC/3D GF
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition ZIF-8/GO
# ERR creating composition ZIF-8/GO
# ERR creating composition ZIF-8/GO
# ERR creating composition ZIF-8/GO
# ERR creating composition ZnFe2O4/rGO
# ERR creating composition ZnFe2O4/rGO
# ERR getting ionic radii CoOOH; H;
# ERR creating composition Fe-N-C
# ERR creating composition PDA/PB
# ERR creating composition PDA/PB
# ERR creating composition Ac-PAL-AMC
# ERR creating composition Cu-MOFs
# ERR creating composition Cu-MOFs
# ERR creating composition Cu3(PO4)2⋅3H2O
# ERR creating composition Cu3(PO4)2⋅3H2O
# ERR creating composition Fe(III) protoporphyrin IX chloride
# ERR creating composition Fe(III) protoporphyrin IX chloride
# ERR creating composition Fe(III) protoporphyrin IX chloride
# ERR creating composition Fe(III) protoporphyrin IX chloride
# ERR getting ionic radii CPO; C;
# ERR getting ionic radii CPO; C;
# ERR getting ionic radii CPO; C;
# ERR getting ionic radii CPO; C;
# ERR getting ionic radii CPO; C;
# ERR creating composition Pt@PCN222-Mn
# ERR creating composition Pt@PCN222-Mn
# ERR creating composition β-CD@AuNPs
# ERR creating composition β-CD@AuNPs
# ERR creating composition β-CD@AuNPs
# ERR creating composition Ohr
# ERR creating composition Ohr
# ERR creating composition Ohr
# ERR creating composition Ohr
# ERR creating composition Ohr
# ERR creating composition c-di-GMP-proflavine-hemin
# ERR creating composition c-di-GMP-proflavine-hemin
# ERR creating composition c-di-GMP-proflavine-hemin
# ERR creating composition c-di-GMP-proflavine-hemin
# ERR getting ionic radii Au; Au;
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR getting ionic radii C4H2N4O4; H;
# ERR creating composition Au@meso-SiO2
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR creating composition CuS-MoS2
# ERR creating composition CuS-MoS2
# ERR creating composition Cyt-c
# ERR creating composition Cyt-c
# ERR creating composition Zn-N-C
# ERR creating composition Zn-N-C
# ERR getting ionic radii C; C;
# ERR getting ionic radii C; C;
# ERR creating composition C60(OH)nOm
# ERR creating composition C60(OH)nOm
# ERR creating composition C60(OH)nOm
# ERR creating composition GO/Au
# ERR creating composition GO/Au
# ERR creating composition Hemin + G-quadruplex
# ERR creating composition Hemin + G-quadruplex
# ERR getting ionic radii CCPK2; C;
# ERR getting ionic radii CCPK2; C;
# ERR getting ionic radii CCPK2; C;
# ERR getting ionic radii CCPK2; C;
# ERR getting ionic radii CCPK2; C;
# ERR getting ionic radii CCPK2; C;
# ERR getting ionic radii CCPK2; C;
# ERR getting ionic radii CCPK2; C;
# ERR creating composition H2O2+TMB
# ERR creating composition H2O2+TMB
# ERR getting ionic radii CCP; C;
# ERR getting ionic radii CCP; C;
# ERR getting ionic radii CCP; C;
# ERR getting ionic radii C; C;
# ERR getting ionic radii C; C;
# ERR creating composition Co3O4-CeO2
# ERR creating composition Co3O4-CeO2
# ERR creating composition GST A1-1
# ERR creating composition GST A1-1
# ERR getting ionic radii PtPd; Pt;
# ERR getting ionic radii PtPd; Pt;
# ERR creating composition Au-Pt
# ERR creating composition Au-Pt
# ERR getting ionic radii CBP; C;
# ERR creating composition CBP–Con A complex
# ERR getting ionic radii Au; Au;
# ERR creating composition Prx1p
# ERR creating composition Prx1p
# ERR creating composition Prx1p
# ERR creating composition Ser38-m-Prx1p
# ERR creating composition Ser38-m-Prx1p
# ERR creating composition Ser38-m-Prx1p
# ERR getting ionic radii FeII(BP1); P;
# ERR creating composition PG endoperoxide synthetase
# ERR creating composition Au@Co-Fe
# ERR creating composition Au@Co-Fe
# ERR creating composition Au@Co-Fe
# ERR creating composition Au@Co-Fe
# ERR getting ionic radii MnO2; Mn;
# ERR getting ionic radii MnO2; Mn;
# ERR creating composition Hb-Hp I-I intermediate complex
# ERR creating composition Hb-Hp I-I intermediate complex
# ERR creating composition Hb-Hp I-I saturated complex
# ERR creating composition Hb-Hp I-I saturated complex
# ERR getting ionic radii Au NP 1; N;
# ERR getting ionic radii Au NP 1; N;
# ERR getting ionic radii Au NP 1; N;
# ERR creating composition Cu-mb
# ERR creating composition PAMTegel
# ERR creating composition PAMTegel
# ERR creating composition PAMTegel
# ERR creating composition PAMTegel
# ERR creating composition d(TTAGGG)4
# ERR creating composition d(TTAGGG)12
# ERR creating composition c-Myc promoter
# ERR creating composition Limlin
# ERR creating composition Ch-Ag
# ERR creating composition Ch-Ag
# ERR creating composition Au-Ft
# ERR creating composition Ag-Au/AgCl
# ERR creating composition Ag-Au/AgCl
# ERR creating composition Fe-SAs/NC
# ERR getting ionic radii Ebselen; Ebselen0+;
# ERR getting ionic radii SBP; B;
# ERR getting ionic radii SBP; B;
# ERR creating composition HRP-C
# ERR creating composition HRP-C
# ERR getting ionic radii SOD1; S;
# ERR creating composition Hb(AcTPOH)12
# ERR creating composition Hb(AcTPOH)12
# ERR creating composition Hb(AcTPOH)12
# ERR creating composition Co xFe 3(cid:2)xO 4
# ERR creating composition Co xFe 3(cid:2)xO 4
# ERR creating composition UiO-66-NH2
# ERR creating composition UiO-66-NH2
# ERR creating composition Fe(ToCPP)
# ERR creating composition Fe(ToCPP)
# ERR creating composition Fe(ToCPP)
# ERR creating composition FePPOPs-SO3H
# ERR creating composition FePPOPs-SO3H
# ERR creating composition D-Trp-OMe@AuNCs
# ERR creating composition D-Trp-OMe@AuNCs
# ERR creating composition D-Trp-OMe@AuNCs-TC
# ERR creating composition D-Trp-OMe@AuNCs-TC
# ERR creating composition FTn-Pt
# ERR creating composition FTn-Rh
# ERR creating composition FTn-Au
# ERR creating composition FTn-Ir
# ERR creating composition FTn-Mn
# ERR creating composition MIL-101(Fe)
# ERR creating composition MIL-101(Fe)
# ERR creating composition Fe{1,2-X2C6H2-4,5-(NCOCMe2NCO)2CR2}(OH2)-
# ERR creating composition Fe{1,2-X2C6H2-4,5-(NCOCMe2NCO)2CR2}(OH2)-
# ERR creating composition ficin
# ERR getting ionic radii PSH; H;
# ERR getting ionic radii PSH; H;
# ERR getting ionic radii PSH; H;
# ERR creating composition Prx6
# ERR creating composition Prx6
# ERR getting ionic radii MnSOD; H;
# ERR creating composition Pt/ZnCo2O4
# ERR creating composition Pt/ZnCo2O4
# ERR creating composition Fe3+
# ERR creating composition Fe3+
# ERR creating composition N-CDs
# ERR creating composition N-CDs
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition H42A hHRP
# ERR creating composition H42A hHRP
# ERR creating composition H42A hHRP
# ERR creating composition H42A hHRP
# ERR getting ionic radii Si; Si;
# ERR getting ionic radii Si; Si;
# ERR creating composition hemin-SWCNT
# ERR creating composition hemin-SWCNT
# ERR creating composition AuNPs/MOGs (Fe)
# ERR creating composition AuNPs/MOGs (Fe)
# ERR creating composition Ag/ZnMOF
# ERR creating composition Hemin/ZIF-8
# ERR creating composition V-substituted tungstosulfate polyoxometalate
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Zn-TCPP(Fe)
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Fe; Fe;
# ERR getting ionic radii Fe; Fe;
# ERR creating composition FeCo-LDH
# ERR creating composition FeCo-LDH
# ERR creating composition FeeHCleNH2-UiO-66
# ERR creating composition FeeHCleNH2-UiO-66
# ERR creating composition FeeHCleNH2-UiO-66
# ERR creating composition FeeHCleNH2-UiO-66
# ERR getting ionic radii C; C;
# ERR getting ionic radii C; C;
# ERR creating composition H2TCPP-ZnS
# ERR creating composition H2TCPP-ZnS
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii PtAu; Pt;
# ERR creating composition VMPxC1
# ERR creating composition VMPxC2
# ERR getting ionic radii NaHSeO3; H;
# ERR getting ionic radii Se; Se;
# ERR getting ionic radii Se; Se;
# ERR getting ionic radii Se; Se;
# ERR getting ionic radii Se; Se;
# ERR getting ionic radii Se; Se;
# ERR creating composition Heme-ficin
# ERR creating composition Heme-ficin
# ERR getting ionic radii Au 21Pd 79; Au;
# ERR getting ionic radii Au 21Pd 79; Au;
# ERR getting ionic radii AgPd; Ag;
# ERR getting ionic radii AgPd; Ag;
# ERR getting ionic radii AgPd; Ag;
# ERR getting ionic radii AgPd; Ag;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition H2TCPP-Fe3O4
# ERR creating composition H2TCPP-Fe3O4
# ERR getting ionic radii Pd; Pd;
# ERR getting ionic radii Pd; Pd;
# ERR creating composition IrOx
# ERR creating composition IrOx
# ERR getting ionic radii Au; Au;
# ERR creating composition Cu2+/GMP
# ERR getting ionic radii TPO; H;
# ERR creating composition Ag3Cit
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition Fe(III) mesoporphyrin
# ERR creating composition Fe(III) mesoporphyrin
# ERR creating composition Fe(III) mesoporphyrin
# ERR creating composition Fe(III) mesoporphyrin
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Cu-CDs
# ERR creating composition CDs@γ-/α-Fe2O3
# ERR creating composition CDs@γ-/α-Fe2O3
# ERR creating composition α-Fe2O3
# ERR creating composition α-Fe2O3
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii CH3HgCl; C;
# ERR getting ionic radii CH3HgCl; C;
# ERR getting ionic radii CH3HgCl; C;
# ERR creating composition TMB + H2O2
# ERR creating composition TMB + H2O2
# ERR creating composition Ag/Pt
# ERR creating composition Ag/Pt
# ERR getting ionic radii H3PW12O40; H;
# ERR getting ionic radii H3PW12O40; H;
# ERR creating composition hematin
# ERR creating composition hematin-methanol complex
# ERR creating composition hematin-pyridine complex
# ERR creating composition hematin-guanidine complex
# ERR creating composition hematin-formamide complex
# ERR creating composition hematin-acetate complex
# ERR creating composition hematin-histidine complex
# ERR creating composition hematin-arginine complex
# ERR creating composition SM-Te
# ERR creating composition SM-Te
# ERR creating composition SM-Te
# ERR creating composition SM-Te
# ERR getting ionic radii PtPdMo; Pt;
# ERR getting ionic radii PtPdMo; Pt;
# ERR getting ionic radii PtPdMo; Pt;
# ERR getting ionic radii PtPdMo; Pt;
# ERR getting ionic radii PtPdMo; Pt;
# ERR creating composition YhjA
# ERR creating composition YhjA
# ERR creating composition YhjA
# ERR creating composition g-C3N4
# ERR creating composition MIP-g-C3N4
# ERR creating composition N-SCSs
# ERR creating composition N-SCSs
# ERR creating composition N-SCSs
# ERR creating composition N-SCSs
# ERR getting ionic radii PtCu; Pt;
# ERR getting ionic radii PtCu; Pt;
# ERR getting ionic radii PtCu; Pt;
# ERR getting ionic radii PtCu; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR creating composition Mn x(PO 4) y
# ERR creating composition Fe-TCPP
# ERR creating composition Mn-TCPP
# ERR creating composition Fe-TCPP
# ERR creating composition Mn-TCPP
# ERR creating composition Fe-TCPP
# ERR creating composition Mn-TCPP
# ERR creating composition Fe-TCPP
# ERR creating composition Mn-TCPP
# ERR getting ionic radii TiO2NTs@MoS2; Ti;
# ERR getting ionic radii TiO2NTs@MoS2; Ti;
# ERR getting ionic radii AuNCs; Au;
# ERR getting ionic radii AuNCs; Au;
# ERR creating composition di-2-(N-cyclohexyl,N-(methylamino)-methyl)phenyl diselenide
# ERR creating composition di-2-(N-cyclohexyl,N-(methylamino)-methyl)phenyl diselenide
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Fe(III)-protoporphyrin IX
# ERR creating composition Fe(III)-protoporphyrin IX
# ERR getting ionic radii Ag2S@Fe2C; C;
# ERR getting ionic radii Ag2S@Fe2C; C;
# ERR getting ionic radii Fe3O4@C; C;
# ERR getting ionic radii Fe3O4@C; C;
# ERR creating composition Carbon shell
# ERR creating composition Carbon shell
# ERR getting ionic radii Au; Au;
# ERR creating composition Carbon
# ERR getting ionic radii Mb; Mb0+;
# ERR getting ionic radii Mb; Mb0+;
# ERR creating composition Hb
# ERR creating composition γ-MnOOH
# ERR getting ionic radii Mn; Mn;
# ERR getting ionic radii Mn; Mn;
# ERR getting ionic radii Mn; Mn;
# ERR getting ionic radii Mn; Mn;
# ERR creating composition Cu,Zn-SOD
# ERR creating composition Cu,Zn-SOD
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Co–Fe@hemin
# ERR creating composition Co–Fe@hemin
# ERR getting ionic radii Au@Pt; Au;
# ERR getting ionic radii Au@Pt; Au;
# ERR creating composition TPhPFe3+OH/Al2O3
# ERR creating composition TPhPFe3+OH/Al2O3
# ERR creating composition TPhPFe3+OH/Al2O3
# ERR creating composition perFTPhPFe3+OH/Al2O3
# ERR creating composition perFTPhPFe3+OH/Al2O3
# ERR creating composition PB-Fe2O3
# ERR creating composition PB-Fe2O3
# ERR creating composition C-dots
# ERR creating composition dSCS-Au NPs
# ERR creating composition GSH-Au NCs
# ERR creating composition dSCS-Au NPs
# ERR creating composition dSCS-Au NPs
# ERR getting ionic radii Fe3O4@C7; C;
# ERR getting ionic radii Fe3O4@C7; C;
# ERR creating composition (Z)-N-(4-methylbenzylidene)-1-(2-((2-(1-((E)-4-methylbenzylideneamino)ethyl)phenyl)diselanyl)phenyl)ethanamine ethyl)phenyl) diselanyl) phenyl) ethylimino) methyl)phenol
# ERR creating composition (PhSe)2
# ERR creating composition (Z)-N-(4-methylbenzylidene)-1-(2-((2-(1-((E)-4-methylbenzylideneamino)ethyl)phenyl)diselanyl)phenyl)ethanamine ethyl)phenyl) diselanyl) phenyl) ethylimino) methyl)phenol
# ERR creating composition (PhSe)2
# ERR creating composition (Z)-N-(4-methylbenzylidene)-1-(2-((2-(1-((E)-4-methylbenzylideneamino)ethyl)phenyl)diselanyl)phenyl)ethanamine ethyl)phenyl) diselanyl) phenyl) ethylimino) methyl)phenol
# ERR creating composition (PhSe)2
# ERR getting ionic radii MnO2; Mn;
# ERR getting ionic radii MnO2; Mn;
# ERR getting ionic radii Au@Pt; Au;
# ERR creating composition hSOD1
# ERR creating composition hSOD1
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au2Pt1; Au;
# ...
# ERR creating composition Mn-TPPS
# ERR creating composition Fe-TMPyP
# ERR creating composition Fe-TMPyP
# ERR creating composition Zn3(MoO4)2(trz)2(H2O)2
# ERR creating composition Zn3(MoO4)2(trz)2(H2O)2
# ERR creating composition cyt-c
# ERR creating composition cyt-c
# ERR creating composition cyt-c
# ERR getting ionic radii Fe3O4@C; C;
# ERR getting ionic radii Fe3O4@C; C;
# ERR creating composition rG4 + hemin
# ERR creating composition rG4 + hemin
# ERR getting ionic radii NiO; Ni;
# ERR getting ionic radii NiO; Ni;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR creating composition 13,16-dicarboxyethyl-2,7-diethyl-3,6,12,17-tetramethylporphycenatoiron(III)
# ERR creating composition 13,16-dicarboxyethyl-2,7-diethyl-3,6,12,17-tetramethylporphycenatoiron(III)
# ERR creating composition 13,16-dicarboxyethyl-2,7-diethyl-3,6,12,17-tetramethylporphycenatoiron(III)
# ERR creating composition 13,16-dicarboxyethyl-2,7-diethyl-3,6,12,17-tetramethylporphycenatoiron(III)
# ERR creating composition CH-Cu
# ERR creating composition CH-Cu
# ERR getting ionic radii TP; H;
# ERR getting ionic radii SOD1; S;
# ERR getting ionic radii SOD1; S;
# ERR creating composition L29H/F43H Mb
# ERR creating composition Cu(II)-L29H/F43H Mb
# ERR creating composition Zn(II)-L29H/F43H Mb
# ERR creating composition L29H/F43H Mb
# ERR creating composition Cu(II)-L29H/F43H Mb
# ERR creating composition Zn(II)-L29H/F43H Mb
# ERR creating composition L29H/F43H Mb
# ERR creating composition Cu(II)-L29H/F43H Mb
# ERR creating composition Zn(II)-L29H/F43H Mb
# ERR getting ionic radii FeN5; N;
# ERR creating composition DhHP-6
# ERR creating composition DhHP-6
# ERR creating composition DhHP-6
# ERR creating composition DhHP-6
# ERR creating composition DhHP-6
# ERR creating composition DhHP-6
# ERR creating composition DhHP-6
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition Fe3+/AMP
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition PLPC-OOH
# ERR creating composition Mn-T(4-TAP)P
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii C7H8N2O2; C;
# ERR getting ionic radii C7H8N2O2; C;
# ERR creating composition Fe(III)-MC6
# ERR creating composition Fe(III)-MC6
# ERR creating composition AuNP/Ag-bipyridine
# ERR creating composition AuNP/Ag-bipyridine
# ERR getting ionic radii Au@Pt; Au;
# ERR getting ionic radii Au@Pt; Au;
# ERR getting ionic radii Au@Pt; Au;
# ERR creating composition Fe-N-CDs
# ERR creating composition Fe-N-CDs
# ERR creating composition Ni(C33H37N4O4S2)·DMF
# ERR creating composition unknown
# ERR creating composition MPS-PPV
# ERR creating composition MPS-PPV
# ERR creating composition Au@Pt 0.25%
# ERR creating composition Au@Pt 2.5%
# ERR creating composition Au@Pt 25%
# ERR creating composition Au@Pt 2.5%
# ERR creating composition Fe3O4-TiO2/rGO
# ERR creating composition Fe3O4-TiO2/rGO
# ERR creating composition DhHP-6-c-ZrMOF
# ERR creating composition DhHP-6-c-ZrMOF
# ERR creating composition DhHP-6
# ERR creating composition DhHP-6
# ERR creating composition Cu/Au
# ERR creating composition Cu/Au
# ERR creating composition CH3CONH2 + HOOC(CH2)3COOH
# ERR creating composition CH3CONH2 + HOOC(CH2)3COOH
# ERR creating composition g-C3N4
# ERR creating composition g-C3N4
# ERR creating composition N-CNTs@Co
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR creating composition PRGI/Pt
# ERR creating composition PRGI/Pt
# ERR creating composition V2O5@pDA@MnO2
# ERR creating composition V2O5@pDA@MnO2
# ERR creating composition PEIeAuNPseMnIIIPPIX
# ERR creating composition Au-Ag-AFT
# ERR creating composition Au-Ag-AFT
# ERR creating composition Au-Ag-AFT
# ERR creating composition Se-DL-Cysteine
# ERR creating composition Se-DL-Cysteine
# ERR creating composition Apt–Au NPs/BiOCl
# ERR creating composition Apt–Au NPs/BiOCl
# ERR creating composition Apt–Au NPs/BiOCl
# ERR creating composition Apt–Au NPs/BiOCl
# ERR creating composition Fe3O4@MoS2-1%Ag
# ERR creating composition Fe3O4@MoS2-1%Ag
# ERR creating composition ADM-Fe3+
# ERR creating composition ADM-Fe3+
# ERR creating composition ADM-Fe3+
# ERR getting ionic radii TCPP Fe(III); H;
# ERR getting ionic radii TCPP Fe(III); H;
# ERR creating composition Cu xO
# ERR creating composition Cu xO
# ERR creating composition Cu xO
# ERR getting ionic radii PdCuFe; Pd;
# ERR getting ionic radii PdCuFe; Pd;
# ERR creating composition seleno-LuGST1-1
# ERR creating composition seleno-LuGST1-1
# ERR creating composition seleno-LuGST1-1
# ERR creating composition seleno-LuGST1-1
# ERR creating composition seleno-LuGST1-1
# ERR creating composition seleno-LuGST1-1
# ERR creating composition Cytc
# ERR creating composition 3,8-DMD(Fe3+)-6-mer/T
# ERR creating composition 3,8-DMD(Fe3+)-6-mer/A
# ERR creating composition 2,8-DPF(Fe3+)-6-mer/T
# ERR creating composition 2,8-DPF(Fe3+)-6-mer/A
# ERR creating composition FeT(4-TAP)P
# ERR creating composition FeT(4-TAP)P
# ERR creating composition MnT(4-TAP)P
# ERR creating composition MnT(4-TAP)P
# ERR getting ionic radii FeTPPS4; H;
# ERR getting ionic radii FeTPPS4; H;
# ERR getting ionic radii MnTPPS4; H;
# ERR getting ionic radii MnTPPS4; H;
# ERR getting ionic radii Cu2Fe(CN)6; C;
# ERR getting ionic radii Cu2Fe(CN)6; C;
# ERR creating composition G4-hpDNA
# ERR creating composition BSA-Au
# ERR creating composition hSOD1
# ERR creating composition hSOD1
# ERR getting ionic radii Au@Pt; Au;
# ERR getting ionic radii Au@Pt; Au;
# ERR creating composition Nak-YCC3.5
# ERR creating composition Nak-YCC3.5
# ERR creating composition Nak-YCC3.5
# ERR creating composition Nak-YCC3.5
# ERR creating composition Nak-YCC3.5
# ERR creating composition Nak-YCC3.5
# ERR creating composition Nak-TMut3.5
# ERR creating composition Nak-TMut3.5
# ERR creating composition FeOxH–rGO
# ERR creating composition FeOxH–rGO
# ERR creating composition I-
# ERR creating composition I-
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition CeO2@MMT(2:8)
# ERR creating composition CeO2@MMT(2:8)
# ERR creating composition CeO2@MMT(2:8)
# ERR creating composition CeO2@MMT(1:9)
# ERR creating composition CeO2@MMT(1:9)
# ERR creating composition CeO2@MMT(1:9)
# ERR creating composition N-CNTs
# ERR creating composition N-CNTs
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR creating composition Au-Pt
# ERR creating composition Au-Pt
# ERR getting ionic radii C8H10Cl2O2Se; C;
# ERR getting ionic radii C8H10Br2O2Se; C;
# ERR creating composition AuNC/GNR
# ERR creating composition AuNC/GNR
# ERR getting ionic radii MoTPPS4; H;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition 1
# ERR creating composition 1
# ERR creating composition 1
# ERR getting ionic radii Cu; Cu;
# ERR getting ionic radii Cu; Cu;
# ERR creating composition HRP-PEG 5000
# ERR creating composition HRP-PEG 20000
# ERR creating composition HRP-PEG 40000
# ERR creating composition HRP-PEG 5000, co-lyophilized
# ERR creating composition HRP-PEG 20000, co-lyophilized
# ERR creating composition HRP-PEG 40000, co-lyophilized
# ERR getting ionic radii Fe3O4@SiO2@Au; Fe;
# ERR getting ionic radii Fe3O4@SiO2@Au; Fe;
# ERR getting ionic radii CIP; C;
# ERR creating composition Arg51Gln
# ERR creating composition Arg51Asn
# ERR creating composition Arg51Leu
# ERR creating composition Arg51Lys
# ERR creating composition TMBDA-MIL-100(Fe)
# ERR creating composition TMBDA-MIL-100(Fe)
# ERR getting ionic radii PdCu; Pd;
# ERR getting ionic radii PdCu; Pd;
# ERR getting ionic radii Pd; Pd;
# ERR getting ionic radii Pd; Pd;
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition metHb
# ERR creating composition metHb
# ERR creating composition myoglobin
# ERR creating composition myoglobin
# ERR creating composition Pt-on-Pd/RGO
# ERR creating composition Pt-on-Pd/RGO
# ERR creating composition NH2-MIL-101(Fe)
# ERR creating composition NH2-MIL-101(Fe)
# ERR creating composition NADPH oxidase
# ERR creating composition NADPH oxidase
# ERR creating composition MoS2/g-C3N4
# ERR creating composition MoS2/g-C3N4
# ERR getting ionic radii Se; Se;
# ERR creating composition [Co(L)(H2O)2]n
# ERR creating composition [Co(L)(H2O)2]n
# ERR creating composition Mo SA–N 3–C
# ERR creating composition Mo SA–N 3–C
# ERR creating composition Fe-N-C
# ERR creating composition Fe-N-C
# ERR creating composition 2-SeCD
# ERR creating composition Pc(OH)8/CoSn(OH)6
# ERR creating composition Pc(OH)8/CoSn(OH)6
# ERR getting ionic radii MnSOD; H;
# ERR creating composition catalase
# ERR getting ionic radii ZnFe2O4@Au; Zn;
# ERR getting ionic radii ZnFe2O4@Au; Zn;
# ERR creating composition Cu(NO3)2·3H2O
# ERR creating composition Cu(NO3)2·3H2O
# ERR creating composition G-quadruplex-Cu2+
# ERR creating composition G-quadruplex-Cu2+
# ERR getting ionic radii SBP; B;
# ERR getting ionic radii SBP; B;
# ERR getting ionic radii WPTP; P;
# ERR getting ionic radii WPTP; P;
# ERR getting ionic radii WPTP; P;
# ERR getting ionic radii WPTP; P;
# ERR creating composition HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating composition HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating composition HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating composition HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating composition HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating composition HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating composition HVA:hemin:ACM:4-Vpy:EGDMA
# ERR getting ionic radii FeS2; S;
# ERR getting ionic radii FeS2; S;
# ERR creating composition SrTiO3/DHB
# ERR creating composition AuPd-PDA
# ERR creating composition AuPd-PDA
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii MnO2; Mn;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition GSH-Px
# ERR creating composition GSH-Px
# ERR creating composition Fe-Ag2S
# ERR creating composition Fe-Ag2S
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR creating composition MbFe(IV)dO
# ERR creating composition MbFe(IV)dO
# ERR creating composition MbFe(IV)dO
# ERR creating composition MbFe(IV)dO
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pd; Pd;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR getting ionic radii Pt; Pt;
# ERR creating composition GO-Cyt c_1 min
# ERR creating composition GO-Cyt c_1 min
# ERR creating composition GO-Cyt c_5 h
# ERR creating composition GO-Cyt c_5 h
# ERR getting ionic radii Ag; Ag;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition metMb
# ERR creating composition metMb
# ERR getting ionic radii PtCu; Pt;
# ERR getting ionic radii PtCu; Pt;
# ERR getting ionic radii PtCu; Pt;
# ERR creating composition Fe3O4-chitosan-tripolyphosphate-calcium
# ERR creating composition Fe3O4-chitosan-tripolyphosphate-calcium-glucose oxidase-concanavalin A
# ERR creating composition Fe3O4-chitosan-tripolyphosphate-calcium-glucose oxidase-concanavalin A
# ERR creating composition Fe3O4-chitosan-tripolyphosphate-calcium-glucose oxidase-concanavalin A
# ERR creating composition Fe3O4-chitosan-tripolyphosphate-calcium-glucose oxidase-concanavalin A
# ERR creating composition Hb
# ERR creating composition Hb
# ERR getting ionic radii Ti3C2; C;
# ERR getting ionic radii Ti3C2; C;
# ERR creating composition His-Ti3C2
# ERR creating composition His-Ti3C2
# ERR creating composition Ala-Ti3C2
# ERR creating composition Ala-Ti3C2
# ERR getting ionic radii AuNCs; Au;
# ERR getting ionic radii AuNCs; Au;
# ERR getting ionic radii AuNCs; Au;
# ERR getting ionic radii AuNCs; Au;
# ERR creating composition HRP/CHIT/CMS
# ERR creating composition ZnO–g-C3N4/MoS2
# ERR creating composition ZnO–g-C3N4/MoS2
# ERR creating composition 6,60-telluro-bis (6-deoxy-b-cyclodextrin)
# ERR creating composition 6,60-telluro-bis (6-deoxy-b-cyclodextrin)
# ERR creating composition 6,60-ditelluro-bis (6-deoxy-b-cyclodextrin)
# ERR creating composition 6,60-ditelluro-bis (6-deoxy-b-cyclodextrin)
# ERR creating composition Fe(III)-porphyrin
# ERR creating composition Fe(III)-porphyrin
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR creating composition Se-SP-1
# ERR creating composition Se-SP-2
# ERR creating composition Fv
# ERR creating composition CoPc-MWCNT
# ERR creating composition CoPc-MWCNT
# ERR creating composition SWNT-3
# ERR creating composition SWNT-3
# ERR creating composition SWNT-4
# ERR creating composition SWNT-4
# ERR creating composition FeTSPc
# ERR creating composition MAP_2744c
# ERR creating composition MAP_2744c
# ERR creating composition MAP_2744c
# ERR creating composition MAP_2744c
# ERR creating composition Fe/C NS
# ERR creating composition Fe/C NS
# ERR creating composition PNPG-PEG
# ERR creating composition PNPG-PEG
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Prdx6
# ERR creating composition Prdx6
# ERR creating composition PPAM–N–CD–Te
# ERR getting ionic radii MnP; P;
# ERR getting ionic radii MnP; P;
# ERR creating composition Co-N-C
# ERR creating composition Co-N-C
# ERR getting ionic radii NiMoO4; Ni;
# ERR getting ionic radii NiMoO4; Ni;
# ERR creating composition CysSeSeCys
# ERR creating composition CysSeSeCys
# ERR creating composition CysSeSeCys
# ERR creating composition CysSeSeCys
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii C; C;
# ERR getting ionic radii C; C;
# ERR getting ionic radii C; C;
# ERR getting ionic radii C; C;
# ERR getting ionic radii C; C;
# ERR getting ionic radii C; C;
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR getting ionic radii FeHCFe; H;
# ERR getting ionic radii FeHCFe@Pd; Fe;
# ERR creating composition BP-IL-SWCNH
# ERR getting ionic radii Au@Pt; Au;
# ERR getting ionic radii Au@Pt; Au;
# ERR getting ionic radii Se; Se;
# ERR creating composition Hb
# ERR creating composition Fe3O4-Au
# ERR creating composition Fe3O4-Au
# ERR creating composition Cu3V2O7(OH)2·2H2O
# ERR creating composition Cu3V2O7(OH)2·2H2O
# ERR creating composition Cu3V2O7(OH)2·2H2O
# ERR creating composition Cu3V2O7(OH)2·2H2O
# ERR creating composition Fe(III)MP-8
# ERR creating composition Fe(III)MP-8
# ERR creating composition Fe(III)MP-8
# ERR creating composition Fe(III)MP-8
# ERR creating composition GMP-Cu
# ERR creating composition GMP-Cu
# ERR creating composition OPD-MoS2
# ERR creating composition OPD-MoS2
# ERR creating composition OPD-MoS2
# ERR creating composition OPD-MoS2
# ERR creating composition H2O2 + o-phenylenediamine
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Au; Au;
# ERR getting ionic radii Os; Os;
# ERR getting ionic radii Os; Os;
# ERR creating composition ficin
# ERR getting ionic radii CH3HgCl; C;
# ERR creating composition H&rGO
# ERR creating composition hemin
# ERR creating composition hemin
# ERR creating composition Pu39WT-hemin
# ERR creating composition HDP-ELP
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Hb(cid:1)Hp
# ERR creating composition Hb(cid:1)Hp
# ERR getting ionic radii H2O2; H;
# ERR creating composition (Et3NH)[Fe(bpb)Cl2]
# ERR creating composition (Et3NH)[Fe(bpb)Cl2]
# ERR creating composition NADH peroxidase
# ERR getting ionic radii Au@Fe3O4; Au;
# ERR creating composition Cyt c
# ERR creating composition Fe2O3/Pt/CNTs
# ERR creating composition Fe2O3/Pt/CNTs
# ERR creating composition Fe2O3/Pt/CNTs
# ERR creating composition HSA + uric acid + Cu
# ERR creating composition HSA + uric acid + Cu
# ERR getting ionic radii PtFe@Fe3O4; Pt;
# ERR getting ionic radii PtFe@Fe3O4; Pt;
# ERR getting ionic radii PtFe@Fe3O4; Pt;
# ERR creating composition CDs@NC-3
# ERR creating composition CDs@NC-3
# ERR creating composition HPtNPs-Fe3O4
# ERR creating composition HbGp
# ERR creating composition HbGp
# ERR creating composition HbGp
# ERR creating composition HbGp
# ERR creating composition HbGp
# ERR creating composition HbGp

# %% [markdown]
# ## pot2

# %%
def createPot2(formula):
    global banned_oxi
    if uf.check_nan(formula) or formula in banned_oxi:
        return np.nan

    try:
        intindex_comp = fu.intindex(formula)
    except:
        print(f"ERR creating intindex {formula}")
        return np.nan

    # print(intindex_comp)
    try:
        os_comp = fu.OS(intindex_comp)
    except:
        print(f"ERR creating os_comp {formula} {intindex_comp}")
        return np.nan

    atom_counts = fu.elfromcomp(fu.Composition(intindex_comp))
    redox_list = []
    for atom, oxi in os_comp.items():

        try:
            elem = fu.Element(atom)
        except:
            print(f"ERR creating element {formula} {atom}")
            return np.nan


        if elem.is_metal:
            # print('is me')
            if oxi <= 0:
                redox_list.append(0)
            else:
                redox_list.append(
                    fu.Redox(
                        atom, 
                        int(round(oxi))
                    ) * atom_counts[atom]
                )
    
    return sum(redox_list)/sum(atom_counts.values())

# %%
res_df["pot2"] = df["formula"].progress_apply(createPot2)
# Out:
#   0%|          | 0/9045 [00:00<?, ?it/s]
# ERR creating intindex N-CQDs
# ERR creating intindex N-CQDs
# ERR creating intindex u-cytc550
# ERR creating intindex u-cytc550
# ERR creating intindex u-cytc550
# ERR creating intindex u-cytc550
# ERR creating intindex BSA-PtAu@CNS
# ERR creating intindex BSA-PtAu@CNS
# ERR creating intindex Cys-AuNCs
# ERR creating intindex CaO2/DOX
# ERR creating intindex CaO2/DOX@SiO2/DOX
# ERR creating intindex CaO2/DOX@SiO2/DOX-MnO2
# ERR creating intindex CaO2/DOX@SiO2/DOX-MnO2
# ERR creating intindex CaO2/DOX@SiO2/DOX-MnO2
# /home/oleg/Programs/.venv/lib/python3.12/site-packages/pymatgen/core/composition.py:372: UserWarning: No Pauling electronegativity for Ds. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   syms = sorted(sym_amt, key=lambda sym: get_el_sp(sym).X)
# ERR creating intindex Fe3O4/Pβ-CD
# ERR creating intindex Fe3O4/Pβ-CD
# ERR creating intindex SeO32-
# ERR creating intindex (CyaSe)2
# ERR creating intindex 3-amino-9-ethylcarbazole
# ERR creating intindex o-tolidine
# ERR creating intindex FeIII–TMPyP
# ERR creating intindex AuNPs/MCA
# ERR creating intindex AuNPs/MCA
# ERR creating intindex Mn3O4/Pd@Pt
# ERR creating intindex Mn3O4/Pd@Pt
# ERR creating intindex P@Pt@P-Au
# ERR creating intindex P@Pt@P-Au
# ERR creating intindex P@Pt@P-Au
# ERR creating intindex Hb
# ERR creating intindex Hb
# ERR creating intindex Hb
# ERR creating intindex AuNPs
# ERR creating intindex AuNPs
# ERR creating intindex cyt c
# ERR creating intindex cyt c
# ERR creating intindex PRT-AuNCs
# ERR creating intindex PRT-AuNCs
# ERR creating intindex 3(cid:11)-H9
# ERR creating intindex 3(cid:11)-H12
# ERR creating intindex Ag-Fe3O4
# ERR creating intindex Ag-Fe3O4
# ERR creating intindex Dex-IONP-GOx
# ERR creating intindex Dex-IONP-GOx
# ERR creating intindex C-dot/NiAl-LDH
# ERR creating intindex C-dot/NiAl-LDH
# ERR creating intindex Au-Ag
# ERR creating intindex Au-Ag
# ERR creating intindex Mn2+
# ERR creating intindex Mn2+
# ERR creating intindex Mn2+
# ERR creating intindex Mn2+
# ERR creating intindex Mn2+
# ERR creating intindex Mn2+
# ERR creating intindex Fe3O4/Au
# ERR creating intindex Fe3O4/Au
# ERR creating intindex Fe3O4/Au
# ERR creating intindex Fe3O4/Au
# ERR creating intindex Cu 1.8S–cgmc
# ERR creating intindex Cu 1.8S–cgmc
# ERR creating intindex ZIF-8@BHb
# ERR creating intindex ZIF-8@BHb
# ERR creating intindex ZIF-8@BHb
# ERR creating intindex G3.0-He
# ERR creating intindex G3.0-He
# ERR creating intindex HRP^SP
# ERR creating intindex 3 MgCO3·9 Mg(OH)2·3 H2O
# ERR creating intindex CH3Se-
# ERR creating element Mb Mb
# ERR creating intindex c-cyts
# ERR creating intindex HRP-OX
# ERR creating intindex YcYfetus
# ERR creating intindex Fe3+
# ERR creating intindex Fe3+
# ERR creating intindex 4c15
# ERR creating intindex 4c15A4
# ERR creating intindex 4c15A12
# ERR creating intindex 4c15A20
# ERR creating intindex Cu2+
# ERR creating intindex Cu2+
# ERR creating intindex Cu2+
# ERR creating intindex Cu2+
# ERR creating intindex Cu2+
# ERR creating intindex Cu2+
# ERR creating intindex Cu2+
# ERR creating intindex Pt-WO3-r-GO
# ERR creating intindex Fe-N-C
# ERR creating intindex Fe-N-C
# ERR creating intindex cyt c
# ERR creating intindex cyt c
# ERR creating intindex Sm-CeO2
# ERR creating intindex GO-CTAB-AuNP-hemin
# ERR creating intindex GO-CTAB-AuNP-hemin
# ERR creating intindex GO-CTAB-AuNP-hemin
# ERR creating intindex GO-CTAB-AuNP-hemin
# ERR creating intindex AuPd-NH2-fMnO2
# ERR creating intindex AuPd-NH2-fMnO2
# ERR creating intindex TfuCat
# ERR creating intindex TfuCat
# /home/oleg/Programs/.venv/lib/python3.12/site-packages/pymatgen/core/composition.py:372: UserWarning: No Pauling electronegativity for Ts. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   syms = sorted(sym_amt, key=lambda sym: get_el_sp(sym).X)
# ERR creating intindex Au-Hg/rGO
# ERR creating intindex Au-Hg/rGO
# ERR creating intindex Prostaglandin H Synthase
# ERR creating intindex Prostaglandin H Synthase
# ERR creating intindex Cyt c
# ERR creating intindex Cyt c
# ERR creating intindex SYI-2074
# ERR creating intindex Cu(Nc)22+
# ERR creating intindex Cu(Nc)22+
# ERR creating intindex Cu2-xSe
# ERR creating intindex Cu2-xSe
# ERR creating intindex Cu2-xSe
# ERR creating intindex Cu2-xSe
# ERR creating intindex BLG-Heme
# ERR creating intindex BLG-T-Heme
# ERR creating intindex BLG-C-Heme
# ERR creating intindex BLG-K-Heme
# ERR creating intindex Crystallin-Heme
# ERR creating intindex CD44 MMSN/AuNPs
# ERR creating intindex CD44 MMSN/AuNPs
# ERR creating intindex Au-Pt/SiO2
# ERR creating intindex Au-Pt/SiO2
# ERR creating intindex cSelS
# ERR creating intindex cSelS
# ERR creating intindex cSelS C174S
# ERR creating intindex AuNWs
# ERR creating intindex PBNPs@AuNWs
# ERR creating intindex Pt-GNRs
# ERR creating intindex Pt-GNRs
# ERR creating intindex TiO2@CeOx
# ERR creating intindex TiO2@CeOx
# ERR creating intindex TiO2@CeOx
# ERR creating intindex TiO2@CeOx
# ERR creating intindex ficin-TN
# ERR creating intindex ficin-TN
# ERR creating intindex cit-PHGPx
# ERR creating intindex ST1Cys
# ERR creating intindex ST2Cys
# ERR creating intindex ST1Sec
# ERR creating intindex ST2Sec
# ERR creating intindex GSH-Px
# ERR creating intindex Cyt c
# ERR creating intindex PPAuMns
# ERR creating intindex PPAuMns
# ERR creating intindex PPAuMns
# ERR creating intindex PPAuMns
# ERR creating intindex PPAuMns
# ERR creating intindex PPAuMns
# ERR creating intindex PPAuMns
# ERR creating intindex PPAuMns
# ERR creating intindex PPAuMns
# ERR creating intindex Co/CuS-MMT
# ERR creating intindex Co/CuS-MMT
# ERR creating intindex g-C3N4-PdNPs
# ERR creating intindex g-C3N4-PdNPs
# ERR creating intindex MnCcP.1
# ERR creating intindex Tyr36Phe-MnCcP.1
# ERR creating intindex Lys179Arg-MnCcP.1
# ERR creating intindex Ile40Gly-MnCcP.1
# ERR creating intindex Tyr36Phe/Lys179Arg-MnCcP.1
# ERR creating intindex Ile40Gly/Lys179Arg-MnCcP.1
# ERR creating intindex Tyr36Phe/Ile40Gly-MnCcP.1
# ERR creating intindex Tyr36Phe/Ile40Gly/Lys179Arg-MnCcP.1
# ERR creating intindex Mn-TCPP
# ERR creating intindex Fe-TCPP
# ERR creating intindex Mn-TCPP
# ERR creating intindex Mn-TCPP
# ERR creating intindex h-Fe3O4@ppy
# ERR creating intindex h-Fe3O4@ppy
# ERR creating intindex ZnPc-GQDs-MnO2@PtNPs
# ERR creating intindex CP 600−6
# ERR creating intindex CP 600−6
# ERR creating intindex HRP-avidin
# ERR creating intindex HRP-avidin
# ERR creating intindex HRP-avidin
# ERR creating intindex HRP-avidin
# ERR creating intindex HRP-avidin
# ERR creating intindex HRP-avidin
# ERR creating intindex Fe3O4@Cu/GMP
# ERR creating intindex PB-Ft
# ERR creating intindex PB-Ft
# ERR creating intindex PB-Ft
# ERR creating intindex PB-Ft
# ERR creating intindex Selenium-enriched yeast
# ERR creating intindex Selenium-enriched alga Chlorella
# ERR creating intindex L4.6k-dG4
# ERR creating intindex L4.6k-dG4
# ERR creating intindex AuNPs@g-C3N4
# ERR creating intindex AuNPs@g-C3N4
# ERR creating intindex g-C3N4
# ERR creating intindex g-C3N4
# ERR creating intindex Prussian Blue
# ERR creating intindex Co/PMCS
# ERR creating intindex Cu−N−C
# ERR creating intindex Zn−N−C
# ERR creating intindex Co−N−C
# ERR creating intindex Fe−N−C
# ERR creating intindex Cu−N−C
# ERR creating intindex Hemin-T 10-EAD2
# ERR creating intindex Hemin-T 10-EAD2
# ERR creating intindex Hemin-T 10-EAD2
# ERR creating intindex Hemin-T 10-EAD2
# ERR creating intindex La3+
# ERR creating intindex La3+
# ERR creating intindex DNA50/hemin
# ERR creating intindex Control1
# ERR creating intindex Control1/hemin
# ERR creating intindex Control2
# ERR creating intindex Control2/hemin
# ERR creating intindex Control3
# ERR creating intindex Control3/hemin
# ERR creating intindex G-PhB
# ERR creating intindex G-PhB
# ERR creating intindex Fe3O4@PDA@Pd/Pt
# ERR creating intindex Fe3O4@PDA@Pd/Pt
# ERR creating intindex PhSe2
# ERR creating intindex Ficin
# ERR creating intindex Ficin
# ERR creating intindex MoS2-Au@Pt
# ERR creating intindex MoS2-Au@Pt
# ERR creating intindex FeIII–mimochrome VI
# ERR creating intindex FeIII–mimochrome VI
# ERR creating intindex FeIII–mimochrome VI
# ERR creating intindex FeIII–mimochrome VI
# ERR creating intindex Se-scFv-B3
# ERR creating intindex H170A hHRP
# ERR creating intindex H170A hHRP
# ERR creating intindex 5Fe2O3•9H2O
# ERR creating intindex Cu2+
# ERR creating intindex Cu2+
# ERR creating intindex NH2-MIL-88B(Fe)
# ERR creating intindex NH2-MIL-88B(Fe)
# ERR creating intindex NMC Tp-TTA
# ERR creating intindex NMC Tp-TTA
# ERR creating intindex AuNPs@POMD-8pep
# ERR creating intindex AuNPs@POMD-8pep
# ERR creating intindex VOx
# ERR creating intindex VOx
# ERR creating intindex Cu-N-C
# ERR creating intindex Cu-N-C
# ERR creating intindex cationic Au NCs
# ERR creating intindex cationic Au NCs
# ERR creating intindex cationic Au NCs
# ERR creating intindex cationic Au NCs
# ERR creating intindex Fc
# ERR creating intindex Fc
# ERR creating intindex PDI/Si-CeO2
# ERR creating intindex PDI/Si-CeO2
# ERR creating intindex Co-MOF
# ERR creating intindex Fe/Al-GNE
# ERR creating intindex Fe/Al-GNE
# ERR creating intindex Fe/Al-GNE
# ERR creating intindex Fe/Al-GNE
# ERR creating intindex SWNT-NH2@hemin
# ERR creating intindex SWNT-NH2@hemin
# ERR creating intindex SWNT@hemin
# ERR creating intindex SWNT@hemin
# ERR creating intindex SWNT-COOH@hemin
# ERR creating intindex SWNT-COOH@hemin
# ERR creating intindex Sepp1UF
# ERR creating intindex Sepp1UF
# ERR creating intindex Sepp1UF
# ERR creating intindex Sepp1UF
# ERR creating intindex NBD-CL
# ERR creating intindex NBD-CL
# ERR creating intindex Pd-WO3-SiO2
# ERR creating intindex Pd-WO3-SiO2-PB
# ERR creating intindex Pd-WO3-SiO2-PB
# ERR creating intindex Pd-WO3-SiO2
# ERR creating intindex Pd-WO3-SiO2-PB
# ERR creating intindex Fe3O4/SiO2/Gr
# ERR creating intindex Fe3O4/SiO2/Gr
# ERR creating intindex Fe3O4/SiO2/Gr
# ERR creating intindex Fe3O4/SiO2/Gr
# ERR creating intindex Co(II) complex 1
# ERR creating intindex Co(II) complex 2
# ERR creating intindex Catalase
# ERR creating intindex Hemoglobin
# ERR creating intindex Cu–hemin
# ERR creating intindex Cu–hemin
# ERR creating intindex Fe-SAs/NC
# ERR creating intindex Fe-SAs/NC
# ERR creating intindex Cu2O/Au
# ERR creating intindex Cu2O/Au
# ERR creating intindex Ni-CuAu
# ERR creating intindex Ni-CuAu
# ERR creating intindex β-CD-hemin
# ERR creating intindex β-CD-hemin
# ERR creating intindex Fe3O4/g-C3N4
# ERR creating intindex Fe3O4/g-C3N4
# ERR creating intindex Fe3O4/g-C3N4
# ERR creating intindex Fe3O4/g-C3N4
# ERR creating intindex Cu,Zn-SOD
# ERR creating intindex Cu,Zn-SOD
# ERR creating intindex [MnIIIMnII(Ldtb)((cid:2)-OAc)2]BPh4
# ERR creating intindex 4c15-s
# ERR creating intindex 4c15
# ERR creating intindex DPPC-PI
# ERR creating intindex DPPC-PI
# ERR creating intindex DPPC-PI
# ERR creating intindex DPPC-PI
# ERR creating intindex DPPC-PI
# ERR creating intindex DPPC-PI
# ERR creating intindex VHb
# ERR creating intindex VHb
# ERR creating intindex VHb
# ERR creating intindex CcpA
# ERR creating intindex FeIII-MC6*
# ERR creating intindex FeIII-MC6*
# ERR creating intindex FeIII-MC6*a
# ERR creating intindex FeIII-MC6*a
# ERR creating intindex T-DMSNs@Au
# ERR creating intindex T-DMSNs@Au
# ERR creating intindex SWNT/Mb
# ERR creating intindex SWNT/HRP
# ERR creating intindex Fe(TpCPP)
# ERR creating intindex Fe(TpCPP)
# ERR creating intindex Fe(TpCPP)-Xln10A
# ERR creating intindex Fe(TpCPP)-Xln10A
# ERR creating intindex N-doped Fe3C
# ERR creating intindex MWCNT@rGONR
# ERR creating intindex MWCNT@rGONR
# ERR creating intindex MoS2-Au
# ERR creating intindex MoS2-Au
# ERR creating intindex Cyt c
# ERR creating intindex Cyt c
# ERR creating intindex Fe(III)Hb
# ERR creating intindex Fe(III)Hb
# ERR creating intindex Cyt c
# ERR creating intindex Cyt c
# ERR creating intindex Prx1
# ERR creating intindex Prx1
# ERR creating intindex Mn-TPPS
# ERR creating intindex GO-UO22+
# ERR creating intindex CS-MoSe2
# ERR creating intindex CS-MoSe2
# ERR creating intindex CS-MoSe2
# ERR creating intindex CS-MoSe2
# ERR creating intindex 2-(benzylselanyl)phenyl)methanamine
# ERR creating intindex Cytc
# ERR creating intindex Hb
# ERR creating intindex Hb
# ERR creating intindex CatG4
# ERR creating intindex Fe@Fe3O4@Cu2-xS
# ERR creating intindex Fe@Fe3O4@Cu2-xS
# ERR creating intindex Au-Cu(II)
# ERR creating intindex Au-Cu(II)
# ERR creating intindex CH3-C(CH3)2CH2C(CH3)2-C6H4-O(C2H4O)9_I0-H
# ERR creating intindex C12H25N(COC(CH3)=CH2)-(C2H40)Is-H
# ERR creating intindex C18H37NH(C2H40)10-H
# ERR creating intindex C18H37NH(C2H40)15-H
# ERR creating intindex ethanol
# ERR creating intindex propanol-2
# ERR creating intindex butanol
# ERR creating intindex CuO-Au
# ERR creating intindex CuO-Au
# ERR creating intindex Ag-Au
# ERR creating intindex Ag-Au
# ERR creating intindex Ag-Au
# ERR creating intindex Ag-Au
# ERR creating intindex metMb
# ERR creating intindex N-(2-nitrophenyl) benzenesulfonamide
# ERR creating intindex NPY–heme
# ERR creating intindex NPY–heme
# ERR creating intindex guaiacol
# ERR creating intindex guaiacol
# ERR creating intindex Kaol-ycc
# ERR creating intindex Kaol-E20-ycc
# ERR creating intindex Kaol-ycc
# ERR creating intindex Kaol-E40-ycc
# ERR creating intindex Hb
# ERR creating intindex Hb
# ERR creating intindex Hb
# ERR creating intindex Hb
# ERR creating intindex Phe68azoAla
# ERR creating intindex Phe179azoAla
# ERR creating intindex PC-OOH
# ERR creating intindex PC-OOH
# ERR creating intindex H2O2 + TMB
# ERR creating intindex H2O2 + OPD
# ERR creating intindex Fe-CNNPs
# ERR creating intindex Fe-CNNPs
# ERR creating intindex Zn-TCPP(Fe)
# ERR creating intindex Zn-TCPP(Fe)
# ERR creating intindex Zn-TCPP(Fe)
# ERR creating intindex Zn-TCPP(Fe)
# ERR creating intindex Zn-TCPP(Fe)
# ERR creating intindex Zn-TCPP(Fe)
# ERR creating intindex Hemoglobin
# ERR creating intindex Hemoglobin
# ERR creating intindex Horseradish peroxidase
# ERR creating intindex Horseradish peroxidase
# ERR creating intindex AuNPs–SWNTs
# ERR creating intindex AuNPs–SWNTs
# ERR creating intindex ficin
# ERR creating intindex Au−Ag/L-Cys-rGO
# ERR creating intindex Au−Ag/L-Cys-rGO
# ERR creating intindex Au/L-Cys-rGO
# ERR creating intindex Au/L-Cys-rGO
# ERR creating intindex Ag/L-Cys-rGO
# ERR creating intindex Ag/L-Cys-rGO
# ERR creating intindex Cu-Pt
# ERR creating intindex POM-Calix hybrid
# ERR creating intindex POM-Calix hybrid
# ERR creating intindex Mn-HPyP
# ERR creating intindex Mn-HPyP
# ERR creating intindex Mn-HPyP
# ERR creating intindex AuNPs@MoS2-QDs
# ERR creating intindex AuNPs@MoS2-QDs
# ERR creating intindex 15SeP 1
# ERR creating intindex 15SeP 1
# ERR creating intindex 15SeP
# ERR creating intindex 15SeP
# ERR creating intindex IgG
# ERR creating intindex Gd-MPO
# ERR creating intindex Ni3(OH)2(C8H4O4)2(H2O)4·2H2O
# ERR creating intindex Ni3(OH)2(C8H4O4)2(H2O)4·2H2O
# ERR creating intindex Au NC micelles
# ERR creating intindex NEQC-340
# ERR creating intindex oPGHS-1
# ERR creating intindex Por-CeO2
# ERR creating intindex Por-CeO2
# ERR creating intindex ycc
# ERR creating intindex MP-8
# ERR creating intindex MP-8
# ERR creating intindex Ceruloplasmin
# ERR creating intindex PNIPAM-CD-g-Te
# ERR creating intindex PNIPAM-CD-g-Te
# ERR creating intindex PNIPAM-CD-g-Te
# ERR creating intindex PNIPAM-CD-g-Te
# ERR creating intindex (25R)-5a-spirostane-2a,3b,5a-triol 3-O-(O-a-L-rhamnopyranosyl-(1 ? 2)-O-(b-D-galactopyranosyl-(1 ? 3))-b-D-glucopyranoside)
# ERR creating intindex Fe3(PO4)2·8H2O
# ERR creating intindex Fe3(PO4)2·8H2O
# ERR creating intindex crystallin aggregate-heme
# ERR creating intindex crystallin aggregate-heme
# ERR creating intindex crystallin aggregate-heme
# ERR creating intindex crystallin aggregate-heme
# ERR creating intindex [SVW11O40]3-
# ERR creating intindex [SVW11O40]3-
# ERR creating intindex [SV2W10O40]4-
# ERR creating intindex [SV2W10O40]4-
# ERR creating intindex Fe-N-C
# ERR creating intindex Au/Pt
# ERR creating intindex Au/Pt
# ERR creating intindex Au/Fe3O4/GO
# ERR creating intindex Au/Fe3O4/GO
# ERR creating intindex Hb
# ERR creating intindex FTN_1133
# ERR creating intindex FTN_1133
# ERR creating intindex MoS2-COOH-MWCNT
# ERR creating intindex Fe(por)
# ERR creating intindex Fe(por)
# ERR creating intindex ficin
# ERR creating intindex ficin
# ERR creating intindex Tg-HbI
# ERR creating intindex Tg-HbII
# ERR creating intindex Ti3C2Tx
# ERR creating intindex Ti3C2Tx
# ERR creating intindex Ti3C2Tx
# ERR creating intindex DNA–Pt
# ERR creating intindex DNA–Pt
# ERR creating intindex g-CN@CuMOF
# ERR creating intindex g-CN@CuMOF
# ERR creating intindex Fe3C-NC
# ERR creating intindex Fe5HO8·4H2O
# ERR creating intindex Fe5HO8·4H2O
# ERR creating intindex Fe3O4NP@pSiO2
# ERR creating intindex Fe3O4NP@pSiO2
# ERR creating intindex Fe3O4NP@pSiO2
# ERR creating intindex Fe3O4NP@pSiO2
# ERR creating intindex HRP/GO-GQDs
# ERR creating intindex HRP/GO-GQDs
# ERR creating intindex CeO2-Gd
# ERR creating intindex CeO2-Gd
# ERR creating intindex Co-MGNCs
# ERR creating intindex Co-MGNCs
# ERR creating intindex TA-Hb
# ERR creating intindex TA-Hb
# ERR creating intindex Cmcytc
# ERR creating intindex Cmcytc
# ERR creating intindex Cu,Zn-SOD
# ERR creating intindex Cu,Zn-SOD
# ERR creating intindex Ce-Fe3O4
# ERR creating intindex Ce-Fe3O4
# ERR creating intindex MoS2/N-rGO
# ERR creating intindex MoS2/N-rGO
# ERR creating intindex MoS2/N-rGO
# ERR creating intindex MoS2/N-rGO
# ERR creating intindex MoS2/N-rGO
# ERR creating intindex 2-phenyl-1,2-benzisoselenazol-3(2H)-one
# ERR creating intindex Cyt c
# ERR creating intindex Zn-TCPP(Fe)
# ERR creating intindex Co-TCPP(Fe)
# ERR creating intindex Cu-TCPP(Fe)
# ERR creating intindex Zn-TCPP(Fe)
# ERR creating intindex Cu,Zn-SOD1
# ERR creating intindex Cu,Zn-SOD1
# ERR creating intindex CoMo hybrids
# ERR creating intindex CoMo hybrids
# ERR creating intindex CoMo hybrids
# ERR creating intindex Tb-OBBA-Hemin
# ERR creating intindex Tb-OBBA-Hemin
# ERR creating intindex PS-[VVO(OMe)(hap-iah)]
# ERR creating intindex Fe-iCOF
# ERR creating intindex S-rGO
# ERR creating intindex S-rGO
# ERR creating intindex FeP-pSC4-AuNPs
# ERR creating intindex FeP-pSC4-AuNPs
# ERR creating intindex Ce0.94Fe0.06O2-δ
# ERR creating intindex Ce0.94Fe0.06O2-δ
# ERR creating intindex Fe3O4@MIL-100(Fe)
# ERR creating intindex Fe3O4@MIL-100(Fe)
# ERR creating intindex SDS-Hemin-Imidazole
# ERR creating intindex AuNPs
# ERR creating intindex AuNPs
# ERR creating intindex CNT/FeNC
# ERR creating intindex CNT/FeNC
# ERR creating intindex Au@CD + CeO2
# ERR creating intindex Au@CD + CeO2
# ERR creating intindex Prx4
# ERR creating intindex AgNPs@Fe3O4
# ERR creating intindex AgNPs@Fe3O4
# ERR creating intindex g-C3N4
# ERR creating intindex g-C3N4
# ERR creating intindex Fe-g-C3N4
# ERR creating intindex Fe-g-C3N4
# ERR creating intindex C44.0%H12.2%O23.3%N16.5%S4.01%
# ERR creating intindex C44.0%H12.2%O23.3%N16.5%S4.01%
# ERR creating intindex Fe(III)-protoporphyrin IX
# ERR creating intindex Fe(III)-protoporphyrin IX
# ERR creating intindex Prx2
# ERR creating intindex Prx2
# ERR creating intindex Prx2
# ERR creating intindex Fe(III) protoporphyrin IX chloride
# ERR creating intindex FeCu-DA/NC
# ERR creating intindex FeCu-DA/NC
# ERR creating intindex FeCu-DA/NC
# ERR creating intindex ZnFe2O4/ZnO
# ERR creating intindex Se-enriched yeast
# ERR creating intindex MWNT-SP
# ERR creating intindex MWNT-MC
# ERR creating intindex CeO2/CoO
# ERR creating intindex CeO2/CoO
# ERR creating intindex AuPd@UiO-67
# ERR creating intindex Co@C-dots
# ERR creating intindex Co@C-dots
# ERR creating intindex CAANSs
# ERR creating intindex Fe-PorCOF
# ERR creating intindex Fe-PorCOF
# ERR creating intindex pTBCB-PEG
# ERR creating intindex pTBCB-PEG
# ERR creating intindex pTBCB-PEG
# ERR creating intindex pTBCB-PEG
# ERR creating intindex pTBCB-PEG
# ERR creating intindex pTBCB-PEG
# ERR creating intindex Fe3O4/MWCNTs
# ERR creating intindex Fe3O4/MWCNTs
# ERR creating intindex NAD+
# ERR creating intindex NAD+
# ERR creating intindex HbA0
# ERR creating intindex HbA1c
# ERR creating intindex Fe3O4@Cu/GMP
# ERR creating intindex Fe3O4@Cu/GMP
# ERR creating intindex Fe3O4@Cu/GMP-GOx
# ERR creating intindex Fe3O4@Cu/GMP-GOx
# ERR creating intindex Fe3O4@Cu/GMP-GOx
# ERR creating element Eb Eb
# ERR creating intindex EbBz
# ERR creating intindex Pt/Fe3O4-DIB-DETA-CNS
# ERR creating intindex Pt/Fe3O4-DIB-DETA-CNS
# ERR creating intindex Tf-trHb
# ERR creating intindex Tf-trHb
# ERR creating intindex Cu2-xSe
# ERR creating intindex Cu2-xSe
# ERR creating intindex Cu2-xSe
# ERR creating intindex Cu2-xSe
# ERR creating intindex Cu2-xSe
# ERR creating intindex PtNPs@MnO2
# ERR creating intindex Fe3O4-Sch
# ERR creating intindex Fe3O4-Sch
# ERR creating intindex Pt NC/3D GF
# ERR creating intindex Pt NC/3D GF
# ERR creating intindex Pt NC/3D GF
# ERR creating intindex Pt NC/3D GF
# ERR creating intindex ZIF-8/GO
# ERR creating intindex ZIF-8/GO
# ERR creating intindex ZIF-8/GO
# ERR creating intindex ZIF-8/GO
# ERR creating intindex ZnFe2O4/rGO
# ERR creating intindex ZnFe2O4/rGO
# ERR creating intindex Fe-N-C
# ERR creating intindex PDA/PB
# ERR creating intindex PDA/PB
# ERR creating intindex Ac-PAL-AMC
# ERR creating intindex Cu-MOFs
# ERR creating intindex Cu-MOFs
# ERR creating intindex Cu3(PO4)2⋅3H2O
# ERR creating intindex Cu3(PO4)2⋅3H2O
# ERR creating intindex Fe(III) protoporphyrin IX chloride
# ERR creating intindex Fe(III) protoporphyrin IX chloride
# ERR creating intindex Fe(III) protoporphyrin IX chloride
# ERR creating intindex Fe(III) protoporphyrin IX chloride
# ERR creating intindex Pt@PCN222-Mn
# ERR creating intindex Pt@PCN222-Mn
# ERR creating intindex β-CD@AuNPs
# ERR creating intindex β-CD@AuNPs
# ERR creating intindex β-CD@AuNPs
# ERR creating intindex Ohr
# ERR creating intindex Ohr
# ERR creating intindex Ohr
# ERR creating intindex Ohr
# ERR creating intindex Ohr
# ERR creating intindex c-di-GMP-proflavine-hemin
# ERR creating intindex c-di-GMP-proflavine-hemin
# ERR creating intindex c-di-GMP-proflavine-hemin
# ERR creating intindex c-di-GMP-proflavine-hemin
# ERR creating intindex Cytc
# ERR creating intindex Cytc
# ERR creating intindex Cytc
# ERR creating intindex Cytc
# ERR creating intindex Cytc
# ERR creating intindex Au@meso-SiO2
# ERR creating intindex CuS-MoS2
# ERR creating intindex CuS-MoS2
# ERR creating intindex Cyt-c
# ERR creating intindex Cyt-c
# ERR creating intindex Zn-N-C
# ERR creating intindex Zn-N-C
# ERR creating intindex C60(OH)nOm
# ERR creating intindex C60(OH)nOm
# ERR creating intindex C60(OH)nOm
# ERR creating intindex GO/Au
# ERR creating intindex GO/Au
# ERR creating intindex Hemin + G-quadruplex
# ERR creating intindex Hemin + G-quadruplex
# ERR creating intindex H2O2+TMB
# ERR creating intindex H2O2+TMB
# ERR creating intindex Co3O4-CeO2
# ERR creating intindex Co3O4-CeO2
# ERR creating intindex GST A1-1
# ERR creating intindex GST A1-1
# ERR creating intindex Au-Pt
# ERR creating intindex Au-Pt
# ERR creating intindex CBP–Con A complex
# ERR creating intindex Prx1p
# ERR creating intindex Prx1p
# ERR creating intindex Prx1p
# ERR creating intindex Ser38-m-Prx1p
# ERR creating intindex Ser38-m-Prx1p
# ERR creating intindex Ser38-m-Prx1p
# ERR creating intindex PG endoperoxide synthetase
# ERR creating intindex Au@Co-Fe
# ERR creating intindex Au@Co-Fe
# ERR creating intindex Au@Co-Fe
# ERR creating intindex Au@Co-Fe
# ERR creating intindex Hb-Hp I-I intermediate complex
# ERR creating intindex Hb-Hp I-I intermediate complex
# ERR creating intindex Hb-Hp I-I saturated complex
# ERR creating intindex Hb-Hp I-I saturated complex
# ERR creating intindex Cu-mb
# ERR creating intindex PAMTegel
# ERR creating intindex PAMTegel
# ERR creating intindex PAMTegel
# ERR creating intindex PAMTegel
# ERR creating intindex d(TTAGGG)4
# ERR creating intindex d(TTAGGG)12
# ERR creating intindex c-Myc promoter
# ERR creating intindex Limlin
# ERR creating intindex Ch-Ag
# ERR creating intindex Ch-Ag
# ERR creating intindex Au-Ft
# ERR creating intindex Ag-Au/AgCl
# ERR creating intindex Ag-Au/AgCl
# ERR creating intindex Fe-SAs/NC
# ERR creating element Ebselen Ebselen
# ERR creating intindex HRP-C
# ERR creating intindex HRP-C
# ERR creating intindex Hb(AcTPOH)12
# ERR creating intindex Hb(AcTPOH)12
# ERR creating intindex Hb(AcTPOH)12
# ERR creating intindex Co xFe 3(cid:2)xO 4
# ERR creating intindex Co xFe 3(cid:2)xO 4
# ERR creating intindex UiO-66-NH2
# ERR creating intindex UiO-66-NH2
# ERR creating intindex Fe(ToCPP)
# ERR creating intindex Fe(ToCPP)
# ERR creating intindex Fe(ToCPP)
# ERR creating intindex FePPOPs-SO3H
# ERR creating intindex FePPOPs-SO3H
# ERR creating intindex D-Trp-OMe@AuNCs
# ERR creating intindex D-Trp-OMe@AuNCs
# ERR creating intindex D-Trp-OMe@AuNCs-TC
# ERR creating intindex D-Trp-OMe@AuNCs-TC
# ERR creating intindex FTn-Pt
# ERR creating intindex FTn-Rh
# ERR creating intindex FTn-Au
# ERR creating intindex FTn-Ir
# ERR creating intindex FTn-Mn
# ERR creating intindex MIL-101(Fe)
# ERR creating intindex MIL-101(Fe)
# ERR creating intindex Fe{1,2-X2C6H2-4,5-(NCOCMe2NCO)2CR2}(OH2)-
# ERR creating intindex Fe{1,2-X2C6H2-4,5-(NCOCMe2NCO)2CR2}(OH2)-
# ERR creating intindex ficin
# ERR creating intindex Prx6
# ERR creating intindex Prx6
# ERR creating intindex Pt/ZnCo2O4
# ERR creating intindex Pt/ZnCo2O4
# ERR creating intindex Fe3+
# ERR creating intindex Fe3+
# ERR creating intindex N-CDs
# ERR creating intindex N-CDs
# ERR creating intindex Cytc
# ERR creating intindex Cytc
# ERR creating intindex Cytc
# ERR creating intindex Cytc
# ERR creating intindex H42A hHRP
# ERR creating intindex H42A hHRP
# ERR creating intindex H42A hHRP
# ERR creating intindex H42A hHRP
# ERR creating intindex hemin-SWCNT
# ERR creating intindex hemin-SWCNT
# ERR creating intindex AuNPs/MOGs (Fe)
# ERR creating intindex AuNPs/MOGs (Fe)
# ERR creating intindex Ag/ZnMOF
# ERR creating intindex Hemin/ZIF-8
# ERR creating intindex V-substituted tungstosulfate polyoxometalate
# ERR creating intindex Zn-TCPP(Fe)
# ERR creating intindex Zn-TCPP(Fe)
# ERR creating intindex FeCo-LDH
# ERR creating intindex FeCo-LDH
# ERR creating intindex FeeHCleNH2-UiO-66
# ERR creating intindex FeeHCleNH2-UiO-66
# ERR creating intindex FeeHCleNH2-UiO-66
# ERR creating intindex FeeHCleNH2-UiO-66
# ERR creating intindex H2TCPP-ZnS
# ERR creating intindex H2TCPP-ZnS
# ERR creating intindex VMPxC1
# ERR creating intindex VMPxC2
# ERR creating intindex Heme-ficin
# ERR creating intindex Heme-ficin
# ERR creating intindex H2TCPP-Fe3O4
# ERR creating intindex H2TCPP-Fe3O4
# ERR creating intindex IrOx
# ERR creating intindex IrOx
# ERR creating intindex Cu2+/GMP
# ERR creating intindex Ag3Cit
# ERR creating intindex Fe(III) mesoporphyrin
# ERR creating intindex Fe(III) mesoporphyrin
# ERR creating intindex Fe(III) mesoporphyrin
# ERR creating intindex Fe(III) mesoporphyrin
# ERR creating intindex Hb
# ERR creating intindex Hb
# ERR creating intindex Cu-CDs
# ERR creating intindex CDs@γ-/α-Fe2O3
# ERR creating intindex CDs@γ-/α-Fe2O3
# ERR creating intindex α-Fe2O3
# ERR creating intindex α-Fe2O3
# ERR creating intindex TMB + H2O2
# ERR creating intindex TMB + H2O2
# ERR creating intindex Ag/Pt
# ERR creating intindex Ag/Pt
# ERR creating intindex hematin
# ERR creating intindex hematin-methanol complex
# ERR creating intindex hematin-pyridine complex
# ERR creating intindex hematin-guanidine complex
# ERR creating intindex hematin-formamide complex
# ERR creating intindex hematin-acetate complex
# ERR creating intindex hematin-histidine complex
# ERR creating intindex hematin-arginine complex
# ERR creating intindex SM-Te
# ERR creating intindex SM-Te
# ERR creating intindex SM-Te
# ERR creating intindex SM-Te
# ERR creating intindex YhjA
# ERR creating intindex YhjA
# ERR creating intindex YhjA
# ERR creating intindex g-C3N4
# ERR creating intindex MIP-g-C3N4
# ERR creating intindex N-SCSs
# ERR creating intindex N-SCSs
# ERR creating intindex N-SCSs
# ERR creating intindex N-SCSs
# ERR creating intindex Mn x(PO 4) y
# ERR creating intindex Fe-TCPP
# ERR creating intindex Mn-TCPP
# ERR creating intindex Fe-TCPP
# ERR creating intindex Mn-TCPP
# ERR creating intindex Fe-TCPP
# ERR creating intindex Mn-TCPP
# ERR creating intindex Fe-TCPP
# ERR creating intindex Mn-TCPP
# ERR creating intindex di-2-(N-cyclohexyl,N-(methylamino)-methyl)phenyl diselenide
# ERR creating intindex di-2-(N-cyclohexyl,N-(methylamino)-methyl)phenyl diselenide
# ERR creating intindex Cyt c
# ERR creating intindex Cyt c
# ERR creating intindex Cyt c
# ERR creating intindex Cyt c
# ERR creating intindex Cyt c
# ERR creating intindex Cyt c
# ERR creating intindex Cyt c
# ERR creating intindex Cyt c
# ERR creating intindex Fe(III)-protoporphyrin IX
# ERR creating intindex Fe(III)-protoporphyrin IX
# ERR creating intindex Carbon shell
# ERR creating intindex Carbon shell
# ERR creating intindex Carbon
# ERR creating element Mb Mb
# ERR creating element Mb Mb
# ERR creating intindex Hb
# ERR creating intindex γ-MnOOH
# ERR creating intindex Cu,Zn-SOD
# ERR creating intindex Cu,Zn-SOD
# ERR creating intindex Cyt c
# ERR creating intindex Cyt c
# ERR creating intindex Cyt c
# ERR creating intindex Cyt c
# ERR creating intindex Co–Fe@hemin
# ERR creating intindex Co–Fe@hemin
# ERR creating intindex TPhPFe3+OH/Al2O3
# ERR creating intindex TPhPFe3+OH/Al2O3
# ERR creating intindex TPhPFe3+OH/Al2O3
# ERR creating intindex perFTPhPFe3+OH/Al2O3
# ERR creating intindex perFTPhPFe3+OH/Al2O3
# ERR creating intindex PB-Fe2O3
# ERR creating intindex PB-Fe2O3
# ERR creating intindex C-dots
# ERR creating intindex dSCS-Au NPs
# ERR creating intindex GSH-Au NCs
# ERR creating intindex dSCS-Au NPs
# ERR creating intindex dSCS-Au NPs
# ERR creating intindex (Z)-N-(4-methylbenzylidene)-1-(2-((2-(1-((E)-4-methylbenzylideneamino)ethyl)phenyl)diselanyl)phenyl)ethanamine ethyl)phenyl) diselanyl) phenyl) ethylimino) methyl)phenol
# ERR creating intindex (PhSe)2
# ERR creating intindex (Z)-N-(4-methylbenzylidene)-1-(2-((2-(1-((E)-4-methylbenzylideneamino)ethyl)phenyl)diselanyl)phenyl)ethanamine ethyl)phenyl) diselanyl) phenyl) ethylimino) methyl)phenol
# ERR creating intindex (PhSe)2
# ERR creating intindex (Z)-N-(4-methylbenzylidene)-1-(2-((2-(1-((E)-4-methylbenzylideneamino)ethyl)phenyl)diselanyl)phenyl)ethanamine ethyl)phenyl) diselanyl) phenyl) ethylimino) methyl)phenol
# ERR creating intindex (PhSe)2
# ERR creating intindex hSOD1
# ERR creating intindex hSOD1
# ERR creating intindex Au-Pt
# ERR creating intindex G20-Cu(II)
# ERR creating intindex G20-Cu(II)
# ERR creating intindex Ovoperoxidase
# ERR creating intindex Ovoperoxidase
# ERR creating intindex AF-SiO2-TiO2NC
# ERR creating intindex Cu-FeHCF
# ERR creating intindex Cu-FeHCF
# ERR creating intindex Mn-FeHCF
# ERR creating intindex Mn-FeHCF
# ERR creating intindex Ni-FeHCF
# ERR creating intindex Ni-FeHCF
# ERR creating intindex cyt c
# ERR creating intindex cyt c
# ERR creating intindex cyt c
# ERR creating intindex cyt c
# ERR creating intindex cyt c
# ERR creating intindex cyt c
# ERR creating intindex AldO-MP
# ERR creating intindex AldO-MP
# ERR creating intindex AldO-HB1
# ERR creating intindex AldO-HB1
# ERR creating intindex 15SeP
# ERR creating intindex 15SeP
# ERR creating intindex MoS2/MWCNTs
# ERR creating intindex Hb
# ERR creating intindex Met Hb
# ERR creating intindex TA@VOx
# ERR creating intindex Co\Fe\TiO2
# ERR creating intindex Co\Fe\TiO2
# ERR creating intindex KatA
# ERR creating intindex KatA
# ERR creating intindex KatB
# ERR creating intindex KatB
# ERR creating intindex Cyt b5
# ERR creating intindex Cyt b5
# ERR creating intindex Ss-HbI
# ERR creating intindex Ss-HbI
# ERR creating intindex Ss-HbII
# ERR creating intindex Ss-HbII
# ERR creating intindex ABTS + H2O2
# ERR creating intindex ABTS + H2O2
# ERR creating intindex hPrx1
# ERR creating intindex Ab 9A5 + mesohemin
# ERR creating intindex Ab 11D1 + mesohemin
# ERR creating intindex Fe-Co-Ni oxide
# ERR creating intindex Fe-Co-Ni oxide
# ERR creating intindex Fe(OH)(O2C(C6H4)CO2)·H2O
# ERR creating intindex Fe(OH)(O2C(C6H4)CO2)·H2O
# ERR creating intindex Se-scFv-WCD1-lessACA
# ERR creating intindex Se-scFv-WCD1-lessACA
# ERR creating intindex Cyt c
# ERR creating intindex Cyt c
# ERR creating intindex Cyt c
# ERR creating intindex CuO-g-C3N4
# ERR creating intindex CuO-g-C3N4
# ERR creating intindex Mb-Cu
# ERR creating intindex Mb2-Cu
# ERR creating intindex Mb4-Cu
# ERR creating intindex Mb2-Cu
# ERR creating intindex Mb2-Cu
# ERR creating intindex PMIDA-Mn0.5Fe0.5Fe2O4
# ERR creating intindex PMIDA-Mn0.5Fe0.5Fe2O4
# ERR creating intindex SV-IV
# ERR creating intindex SV-IV
# ERR creating intindex NH2-MIL-88B(Fe)
# ERR creating intindex NH2-MIL-88B(Fe)
# ERR creating intindex NMC Tp-TTA
# ERR creating intindex NMC Tp-TTA
# ERR creating intindex Mn(II)/CeO2
# ERR creating intindex Mn(II)/CeO2
# ERR creating intindex Fe(III)/CeO2
# ERR creating intindex Fe(III)/CeO2
# ERR creating intindex Co(II)/CeO2
# ERR creating intindex Co(II)/CeO2
# ERR creating intindex Pd NPs/CeO2 NTs
# ERR creating intindex Pd NPs/CeO2 NTs
# ERR creating intindex Pd NPs
# ERR creating intindex Pd NPs
# ERR creating intindex Cu(II)–cysteine/SDS/DTAB
# ERR creating intindex Cu(II)–cysteine/SDS/DTAB
# ERR creating intindex Cu(II)–cysteine/SDS/DTAB
# ERR creating intindex nGO
# ERR creating intindex nGO
# ERR creating intindex Fe-MoS2
# ERR creating intindex Fe-MoS2
# ERR creating intindex PS2.M–hemin
# ERR creating intindex PS2.M–hemin
# ERR creating intindex rPS2.M–hemin
# ERR creating intindex rPS2.M–hemin
# ERR creating intindex OXY4–hemin
# ERR creating intindex OXY4–hemin
# ERR creating intindex C-dots
# ERR creating intindex C-dots
# ERR creating intindex C-dots
# ERR creating intindex C-dots
# ERR creating intindex C-dots
# ERR creating intindex C-dots
# ERR creating intindex C-dots
# ERR creating intindex C-dots
# ERR creating intindex Fe(III)-Mn(II)
# ERR creating intindex CM-HSA
# ERR creating intindex se-scFv-B3
# ERR creating intindex CeO2-CDs
# ERR creating intindex CeO2-CDs
# ERR creating intindex HbFe3+
# ERR creating intindex HbFe3+
# ERR creating intindex TClPP-CuFe2O4/SiO2
# ERR creating intindex TClPP-CuFe2O4/SiO2
# ERR creating intindex Fe3O4@NH2-MIL-101(Fe)
# ERR creating intindex Fe3O4@NH2-MIL-101(Fe)
# ERR creating intindex HRP-GCS
# ERR creating intindex 2-TeCD
# ERR creating intindex 2-TeCD
# ERR creating intindex 2-TeCD
# ERR creating intindex Au/CDs
# ERR creating intindex Au/CDs
# ERR creating intindex H2O2 + TMB
# ERR creating intindex H2O2 + TMB
# ERR creating intindex Co2(OH)2CO3-CeO2
# ERR creating intindex Co2(OH)2CO3-CeO2
# ERR creating intindex Se-g-C3N4
# ERR creating intindex Se-g-C3N4
# ERR creating intindex Pt/C
# ERR creating intindex Pt/C
# ERR creating intindex Pt/C
# ERR creating intindex Pt/C
# ERR creating intindex PtCNPs
# ERR creating intindex PtCNPs
# ERR creating intindex CuCNPs
# ERR creating intindex CuCNPs
# ERR creating intindex NiCNPs
# ERR creating intindex NiCNPs
# ERR creating intindex PdCNPs
# ERR creating intindex PdCNPs
# ERR creating element Mb Mb
# ERR creating element Mb Mb
# ERR creating intindex T67R/S92D Mb
# ERR creating intindex T67R/S92D Mb-H
# ERR creating intindex P-450cam
# ERR creating intindex P-450cam
# ERR creating intindex PB-Ft
# ERR creating intindex PB-Ft
# ERR creating intindex PB-Ft
# ERR creating intindex PB-Ft
# ERR creating intindex CuO/WO3
# ERR creating intindex CuO/WO3
# ERR creating intindex Co3O4@Co-Fe oxide
# ERR creating intindex Co3O4@Co-Fe oxide
# ERR creating intindex ZnO-Pd
# ERR creating intindex ZnO-Pd
# ERR creating intindex Cytochrome c
# ERR creating intindex Cytochrome c
# ERR creating intindex Cu-SBA-15
# ERR creating intindex Cu-SBA-15
# ERR creating intindex Fe-MIL-88NH2
# ERR creating intindex Fe-MIL-88NH2
# ERR creating intindex Cu,Zn-SOD
# ERR creating intindex Cu,Zn-SOD
# ERR creating intindex Au/CeO2
# ERR creating intindex Au/CeO2
# ERR creating intindex TaAPX-6B
# ERR creating intindex Mn-TSPP
# ERR creating intindex Fe-TSPP
# ERR creating intindex Mn-TSPP
# ERR creating intindex Cu2OeAu
# ERR creating intindex Cu2OeAu
# ERR creating intindex ZmANN33/35
# ERR creating intindex Fe-BTC
# ERR creating intindex Cyt c
# ERR creating intindex Cyt c
# ERR creating intindex Cyt c
# ERR creating intindex hemin-Fib
# ERR creating intindex MA-Hem/AueAg
# ERR creating intindex MA-Hem/AueAg
# ERR creating intindex C-dots
# ERR creating intindex C-dots
# ERR creating intindex C-dots
# ERR creating intindex C-dots
# ERR creating intindex Hb
# ERR creating intindex Hb
# ERR creating intindex Se-enriched yeast
# ERR creating intindex Se-enriched yeast
# ERR creating intindex Se-enriched yeast
# ERR creating intindex MoS2@TA/Fe
# ERR creating intindex MoS2@TA/Fe
# ERR creating intindex MoS2@TA/Fe
# ERR creating intindex Cu3(PO4)2·3H2O
# ERR creating intindex Cu3(PO4)2·3H2O
# ERR creating intindex Cu3(PO4)2·3H2O
# ERR creating intindex Cu3(PO4)2·3H2O
# ERR creating intindex Cu3(PO4)2·3H2O
# ERR creating intindex Cu3(PO4)2·3H2O
# ERR creating intindex Cu3(PO4)2·3H2O
# ERR creating intindex Cu3(PO4)2·3H2O
# ERR creating intindex MoS2-MIL-101(Fe)
# ERR creating intindex MoS2-MIL-101(Fe)
# ERR creating intindex AuNS@Ag-5-H-rGO
# ERR creating intindex AuNS@Ag-5-H-rGO
# ERR creating intindex AuNP@Ag-5-H-rGO
# ERR creating intindex AuNP@Ag-5-H-rGO
# ERR creating intindex Zn-N-C
# ERR creating intindex Zn-N-C
# ERR creating intindex Fe3+-TCAS
# ERR creating intindex Fe3+-TCAS
# ERR creating intindex Co-Al ELDH
# ERR creating intindex Co-Al ELDH
# ERR creating intindex Cytochrome bd
# ERR creating intindex Cytochrome bd
# ERR creating intindex GHK/K8[α-SiW11O39]/Co2+
# ERR creating intindex cyt c
# ERR creating intindex cyt c
# ERR creating intindex Na_xH_(2-x)Ti_3O_7
# ERR creating intindex 2,2′-diamino-diphenyldiselenide
# ERR creating intindex 2,2′-diselenopyridin
# ERR creating intindex 2-phenyl-1,2-benzoisoselenazol-3(2H)-one
# ERR creating intindex ethyl-benzo-1,2-selenazine-4-one-3-carboxylate
# ERR creating intindex 2-methylselenobenzoylcyanide
# ERR creating intindex cyt c-SNPs
# ERR creating intindex cyt c-SNPs
# ERR creating intindex iron protoporphyrin IX diglutathione
# ERR creating intindex iron protoporphyrin IX diglutathione
# ERR creating intindex Cyt-c
# ERR creating intindex iron(III)-5-(4-carboxyphenyl)-10,15,20-tritolylporphyrin
# ERR creating intindex iron(III)-5-(4-carboxyphenyl)-10,15,20-tritolylporphyrin
# ERR creating intindex iron(III)-5-(4-carboxyphenyl)-10,15,20-tritolylporphyrin
# ERR creating intindex Au@Ag-Pt
# ERR creating intindex Au@Ag-Pt
# ERR creating intindex GOx@Au@MagSiO2
# ERR creating intindex GOx@Au@MagSiO2
# ERR creating intindex Cu2+-rGO
# ERR creating intindex PEG-GO-Hemin
# ERR creating intindex PEG-GO-Hemin
# ERR creating intindex PEG-GO-Hemin
# ERR creating intindex PEG-GO-Hemin
# ERR creating intindex Au@Pt@mesoporous SiO2
# ERR creating intindex Au@Pt@mesoporous SiO2
# ERR creating intindex FePt-Au
# ERR creating intindex FePt-Au
# ERR creating intindex Fe-MIL-101
# ERR creating intindex Fe-MIL-101
# ERR creating intindex Fe-MIL-101
# ERR creating intindex Fe-MIL-101
# ERR creating intindex Fe-MIL-101-FA
# ERR creating intindex Fe-MIL-101-FA
# ERR creating intindex Fe-MIL-101-FA
# ERR creating intindex Fe-MIL-101-FA
# ERR creating intindex PtNPs/GO
# ERR creating intindex PtNPs/GO
# ERR creating intindex His-AuNCs
# ERR creating intindex His-AuNCs
# ERR creating intindex PtPB-1
# ERR creating intindex PtPB-2
# ERR creating intindex PtPB-3
# ERR creating intindex PtPB-4
# ERR creating intindex IIB-III
# ERR creating intindex IIB-III
# ERR creating intindex Fe@PCN-224
# ERR creating intindex Fe@PCN-224
# ERR creating intindex Fe@PCN-224
# ERR creating intindex PDI-CuO
# ERR creating intindex PDI-CuO
# ERR creating intindex Fe3O4@ZIF-8
# ERR creating intindex Fe3O4@ZIF-8
# ERR creating intindex AuNFs/Fe3O4@ZIF-8-MoS2
# ERR creating intindex AuNFs/Fe3O4@ZIF-8-MoS2
# ERR creating intindex Mn2+
# ERR creating intindex Mn2+
# ERR creating intindex NaYF4:Yb,Er
# ERR creating intindex NaYF4:Yb,Er
# ERR creating intindex Pt@mSiO2
# ERR creating intindex Pt@mSiO2
# ERR creating intindex Hb
# ERR creating intindex Cytochrome c
# ERR creating intindex Cytochrome c
# ERR creating intindex Heme-ZrMOF
# ERR creating intindex Heme-ZrMOF
# ERR creating intindex Heme-ZrMOF
# ERR creating intindex Ca2+-MMT
# ERR creating intindex Ca2+-MMT
# ERR creating intindex MoS2/rGO
# ERR creating intindex MoS2/rGO
# ERR creating intindex MoS2/rGO
# ERR creating intindex MoS2/rGO
# ERR creating intindex NGr-FeTPyP
# ERR creating intindex FeTPyP-NGr
# ERR creating intindex Tellurosubtilisin
# ERR creating intindex Tellurosubtilisin
# ERR creating intindex CYP BM3 21B3
# ERR creating intindex W96A/F405L
# ERR creating intindex Cyt c
# ERR creating intindex Cyt c
# ERR creating intindex Cu2+
# ERR creating intindex Cu2+
# ERR creating intindex Hb
# ERR creating intindex Hb
# ERR creating intindex Hb
# ERR creating intindex Hb
# ERR creating intindex Au-MoS2
# ERR creating intindex Au-MoS2
# ERR creating intindex MnL1(OH2)2⋅H2O
# ERR creating intindex Fe3+
# ERR creating intindex Fe3+
# ERR creating intindex Fe3+
# ERR creating intindex Fe3+
# ERR creating intindex Fe3+
# ERR creating intindex Fe3+
# ERR creating intindex Dz 1Dz 2NPs
# ERR creating intindex Dz 1Dz 2NPs
# ERR creating intindex Dz 1Dz 2NPs
# ERR creating intindex Dz 1Dz 2NPs
# ERR creating intindex Dz 1Dz 2NPs
# ERR creating intindex Dz 1Dz 2NPs
# ERR creating intindex Dz 1Dz 2NPs
# ERR creating intindex Dz 1Dz 2NPs
# ERR creating intindex Mn-TPPS4
# ERR creating intindex Mn-TPPS4
# ERR creating intindex Mn-TPPS4
# ERR creating intindex Cu(II)-coordinated GpG-duplex DNA
# ERR creating intindex Cu(II)-coordinated GpG-duplex DNA
# ERR creating intindex Z-His-NHNH2/Zn2+
# ERR creating intindex FeCPNPs
# ERR creating intindex FeCPNPs
# ERR creating intindex Co/Fe-MOFs-iodide
# ERR creating intindex Co/Fe-MOFs-iodide
# ERR creating intindex Au-C/SiO2
# ERR creating intindex Au-C/SiO2
# ERR creating intindex DAFS-25
# ERR creating intindex DAFS-25
# ERR creating intindex DAFS-25
# ERR creating intindex DAFS-25
# ERR creating intindex Fe3O4@C/Ni
# ERR creating intindex Fe3O4@C/Ni
# ERR creating intindex PNC2-WT
# ERR creating intindex PNC2-WT
# ERR creating intindex PNC2-M
# ERR creating intindex PNC2-M
# ERR creating intindex PtGNs
# ERR creating intindex PtGNs
# ERR creating intindex DypB
# ERR creating intindex D153A/N246A
# ERR creating intindex HAP@MIL-100(Fe)
# ERR creating intindex Cu2+
# ERR creating intindex PhSeZnCl
# ERR creating intindex CuS-BSA-Cu3(PO4)2
# ERR creating intindex CuS-BSA-Cu3(PO4)2
# ERR creating intindex N-GQDs
# ERR creating intindex N-GQDs
# ERR creating intindex N57C/S71C Cyt b5
# ERR creating intindex N57C/S71C Cyt b5
# ERR creating intindex WT Cyt b5
# ERR creating intindex WT Cyt b5
# ERR creating intindex hemin
# ERR creating intindex hemin
# ERR creating intindex HRP-4C
# ERR creating intindex Cu,Zn SOD
# ERR creating intindex Cu,Zn SOD
# ERR creating intindex Cu,Zn SOD
# ERR creating intindex Cu,Zn SOD
# ERR creating intindex CDN1/Au2
# ERR creating intindex CDN1/Au2
# ERR creating intindex CDN/Au1
# ERR creating intindex CDN/Au1
# ERR creating intindex Cu5(pz)6Cl[SiW12O40]
# ERR creating intindex Cu5(pz)6Cl[SiW12O40]
# ERR creating intindex Cu5(pz)6Cl[SiW12O40]
# ERR creating intindex Cu5(pz)6Cl[SiW12O40]
# ERR creating intindex Cu5(pz)6Cl[SiW12O40]
# ERR creating intindex Cu5(pz)6Cl[SiW12O40]
# ERR creating intindex Cu/CuO-rGO
# ERR creating intindex Cu/CuO-rGO
# ERR creating intindex peptide-hGQ
# ERR creating intindex Co3O4 + CoAl2O4 + CeO2
# ERR creating intindex Co3O4 + CoAl2O4 + CeO2
# ERR creating intindex GPx
# ERR creating intindex GPx
# ERR creating intindex C-dots
# ERR creating intindex C-dots
# ERR creating intindex 1a
# ERR creating intindex 1a
# ERR creating intindex Fe-BDC-NH2
# ERR creating intindex Fe-BDC-NH2
# ERR creating intindex GO-Se
# ERR creating intindex GO-Se
# ERR creating intindex Pd/Fe3O4-PEI-RGO
# ERR creating intindex Cu3(PO4)2·3H2O
# ERR creating intindex Cu3(PO4)2·3H2O
# ERR creating intindex PLPC-OOH
# ERR creating intindex AD-100
# ERR creating intindex Cu,ZnSOD
# ERR creating intindex CeO2/NiO
# ERR creating intindex CeO2/NiO
# ERR creating intindex ferritin–heme
# ERR creating intindex ferritin–heme
# ERR creating intindex ferritin–heme
# ERR creating intindex ferritin–heme
# ERR creating intindex ferritin–heme
# ERR creating intindex ferritin–heme
# ERR creating intindex ferritin–heme
# ERR creating intindex ferritin–heme
# ERR creating intindex N, Fe-CDs
# ERR creating intindex N, Fe-CDs
# ERR creating intindex Fe3O4-Au
# ERR creating intindex Fe3O4-Au
# ERR creating intindex Co-N-C
# ERR creating intindex Co-N-C
# ERR creating intindex Fe-Ni LDH-hemin
# ERR creating intindex Fe-Ni LDH-hemin
# ERR creating intindex ATXII-microperoxidase
# ERR creating intindex MoS2/GO
# ERR creating intindex MoS2/GO
# ERR creating intindex Zr-MOF-PVP
# ERR creating intindex Zr-MOF-PVP
# ERR creating intindex SA-PtNPs
# ERR creating intindex Cu/Ag
# ERR creating intindex Cu/Ag
# ERR creating intindex VVO(ap-fah)(OMe)(MeOH)
# ERR creating intindex VVO(ap-bhz)(OMe)(MeOH)
# ERR creating intindex VVO(ap-nah)(OMe)(MeOH)
# ERR creating intindex VVO(ap-inh)(OMe)(MeOH)
# ERR creating intindex H-GNs
# ERR creating intindex H-GNs
# ERR creating intindex Cyt c
# ERR creating intindex Cyt c
# ERR creating intindex Cyt c
# ERR creating intindex seleno-hGPx1-C2/78/115/156/202S
# ERR creating intindex seleno-hGPx1-C2/78/115/156/202S
# ERR creating intindex seleno-hGPx1-C2/78/115/156/202S
# ERR creating intindex seleno-hGPx1-C2/78/115/156/202S
# ERR creating intindex seleno-hGPx1-C2/78/115/156/202S
# ERR creating intindex seleno-hGPx1-C2/78/115/156/202S
# ERR creating intindex seleno-hGPx1-C2/78/115/156/202S
# ERR creating intindex seleno-hGPx1-C2/78/115/156/202S
# ERR creating intindex FeTSPc
# ERR creating intindex FeTSPc
# ERR creating intindex CxOyBrz
# ERR creating intindex CxOyBrz
# ERR creating intindex TPyP-CuS
# ERR creating intindex TPyP-CuS
# ERR creating intindex MIL-101(Cr)
# ERR creating intindex MIL-101(Cr)
# ERR creating intindex Mn2+
# ERR creating intindex Mn2+
# ERR creating intindex Mn2+
# ERR creating intindex Mn2+
# ERR creating intindex Mn2+
# ERR creating intindex Mn2+
# ERR creating intindex Hemoglobin-Haptoglobin Complex
# ERR creating intindex Hemoglobin-Haptoglobin Complex
# ERR creating intindex Hemoglobin-Haptoglobin Complex
# ERR creating intindex Hemoglobin-Haptoglobin Complex
# ERR creating intindex Hemoglobin-Haptoglobin Complex
# ERR creating intindex PtNP/GO
# ERR creating intindex PtNP/GO
# ERR creating intindex CeO2/TiO2
# ERR creating intindex CeO2/TiO2
# ERR creating intindex OgCytAPX1
# ERR creating intindex OgCytAPX1
# ERR creating intindex MoS2@CNNS(30)
# ERR creating intindex MoS2@CNNS(30)
# ERR creating intindex T67R/S92D Mb
# ERR creating intindex T67R/S92D Mb
# ERR creating intindex T67R/S92D Mb
# ERR creating intindex T67R/S92D Mb-H
# ERR creating intindex T67R/S92D Mb-H
# ERR creating intindex T67R/S92D Mb-H
# ERR creating intindex Pd/Fe3O4@C
# ERR creating intindex Pd/Fe3O4@C
# ERR creating intindex Fe-N-C
# ERR creating intindex Fe-N-C
# ERR creating intindex Fe-N-C
# ERR creating intindex CF-H-Au
# ERR creating intindex CF-H-Au
# ERR creating intindex CF-H-Au
# ERR creating intindex PS2.M-MB/hemin
# ERR creating intindex PS2.M-MB/hemin
# ERR creating intindex Fe-N-rGO
# ERR creating intindex Fe-N-rGO
# ERR creating intindex NH2-MWCNT-BP-AgNPs
# ERR creating intindex NH2-MWCNT-BP-AgNPs
# ERR creating intindex NH2-MWCNT-BP-AgNPs
# ERR creating intindex NH2-MWCNT-BP-AgNPs
# ERR creating intindex NH2-MWCNT-BP-AgNPs
# ERR creating intindex NH2-MWCNT-BP-AgNPs
# ERR creating intindex C-Dots
# ERR creating intindex C-Dots
# ERR creating intindex Fe-MIL-88A
# ERR creating intindex Fe-MIL-88A
# ERR creating intindex MIL-53(Fe)
# ERR creating intindex MIL-53(Fe)
# ERR creating intindex Fe-CDs
# ERR creating intindex Fe-CDs
# ERR creating intindex Se@PDA@Bor
# ERR creating intindex Se@PDA@Bor
# ERR creating intindex Cu, Zn SOD
# ERR creating intindex Cu, Zn SOD
# ERR creating intindex Cu, Zn SOD
# ERR creating intindex Cu, Zn SOD
# ERR creating intindex Cu, Zn SOD
# ERR creating intindex Cu, Zn SOD
# ERR creating intindex HRP-PEG 5000
# ERR creating intindex HRP-PEG 20000
# ERR creating intindex HRP-PEG 40000
# ERR creating intindex HRP-PEG 5000, co-lyophilized
# ERR creating intindex HRP-PEG 20000, co-lyophilized
# ERR creating intindex HRP-PEG 40000, co-lyophilized
# ERR creating intindex Hp/Hb
# ERR creating intindex Hp/Hb
# ERR creating intindex HAP@MIL-100(Fe)
# ERR creating intindex HAP@MIL-100(Fe)
# ERR creating intindex HAP@MIL-100(Fe)
# ERR creating intindex HAP@MIL-100(Fe)
# ERR creating intindex PtNPs/CoTPP/rGO
# ERR creating intindex PtNPs/CoTPP/rGO
# ERR creating intindex MIL-53(Fe)
# ERR creating intindex MIL-53(Fe)
# ERR creating intindex Bi-Au
# ERR creating intindex Bi-Au
# ERR creating intindex Fib-Bi-Au
# ERR creating intindex Fib-Bi-Au
# ERR creating intindex Fib-Bi-Au
# ERR creating intindex Fib-Bi-Au
# ERR creating intindex Cu-GGG
# ERR creating intindex Cu-GGG
# ERR creating intindex Cu-HGG
# ERR creating intindex Cu-GGH
# ERR creating intindex rCpTPx
# ERR creating intindex rCpTPx
# ERR creating intindex rCpTPx
# ERR creating intindex rCmTPx
# ERR creating intindex rCmTPx
# ERR creating intindex rCmTPx
# ERR creating intindex Ag-CoO
# ERR creating intindex Ag-CoO
# ERR creating intindex Au NCs-ICG
# ERR creating intindex Cu-MOF
# ERR creating intindex Cu-MOF
# ERR creating intindex Mb-magadiite
# ERR creating intindex Hb-magadiite
# ERR creating intindex TMB+H2O2
# ERR creating intindex TMB+H2O2
# ERR creating intindex Ag/Pt
# ERR creating intindex MnTSPc
# ERR creating intindex Au@PtNP/GO
# ERR creating intindex Au@PtNP/GO
# ERR creating intindex WOx
# ERR creating intindex WOx
# ERR creating intindex 4C15
# ERR creating intindex N-GNMs
# ERR creating intindex N-GNMs
# ERR creating intindex AuNP2-Zn(II)
# ERR creating intindex AuNP2-Eu(III)
# ERR creating intindex AuNP4-Zn(II)
# ERR creating intindex AuNP4-Cu(II)
# ERR creating intindex AuNP4-Eu(III)
# ERR creating intindex SA-Fe/NG
# ERR creating intindex SA-Fe/NG
# ...
# ERR creating intindex Cyt
# ERR creating intindex Cyt
# ERR creating intindex Pt/Fe-MOF
# ERR creating intindex Pt/Fe-MOF
# ERR creating intindex H-GO-CNTs
# ERR creating intindex GTPx-1
# ERR creating intindex GTPx-1
# ERR creating intindex GTPx-1
# ERR creating intindex GTPx-1
# ERR creating intindex GTPx-1
# ERR creating intindex MIL-101(Cr)@PB
# ERR creating intindex MIL-101(Cr)@PB
# ERR creating intindex Mn/PSAE
# ERR creating intindex Mn/PSAE
# ERR creating intindex Mn/PSAE
# ERR creating intindex Mn/PSAE
# ERR creating intindex Au@SeH/NH2
# ERR creating intindex Au@SeH/NH2
# ERR creating intindex Zr6(μ3-O)4(μ3-OH)4(OH)6(H2O)6(BTC)2
# ERR creating intindex Zr6(μ3-O)4(μ3-OH)4(OH)6(H2O)6(BTC)2
# ERR creating intindex P2W18Fe4/PDA
# ERR creating intindex P2W18Fe4/PDA
# ERR creating intindex AuPd-NH2-fMnO2
# ERR creating intindex AuPd-NH2-fMnO2
# ERR creating intindex ZmPrx35
# ERR creating intindex ZmPrx35
# ERR creating intindex Cu-hNs
# ERR creating intindex PMNT-2
# ERR creating intindex PMNT-2
# ERR creating intindex PEI-rGO-Hemin-BSA
# ERR creating intindex PEI-rGO-Hemin-BSA
# ERR creating intindex HCO4-
# ERR creating intindex HCO4-
# ERR creating intindex CuZn-SOD
# ERR creating intindex CuZn-SOD
# ERR creating intindex hemin/MoS2
# ERR creating intindex hemin/MoS2
# ERR creating intindex RGO.npr.NH2/GA@HRP
# ERR creating intindex RGO.npr.NH2/GA@HRP
# ERR creating intindex AHb3
# ERR creating intindex AHb3
# ERR creating intindex Hemin-doped-HKUST-1
# ERR creating intindex Cu(II)-LPQDs
# ERR creating intindex Cu(II)-LPQDs
# ERR creating intindex H2TCPP-TiO2-MMT
# ERR creating intindex H2TCPP-TiO2-MMT
# ERR creating intindex Hemin-GDY
# ERR creating intindex Hemin-GDY
# ERR creating intindex CoFe-LDH/CeO2
# ERR creating intindex CoFe-LDH/CeO2
# ERR creating intindex Gr/Ni@Pd
# ERR creating intindex Gr/Ni@Pd
# ERR creating intindex Fe3O4-DOPA
# ERR creating intindex CoFe2O4-DOPA
# ERR creating intindex CuFe2O4-DOPA
# ERR creating intindex MnFe2O4-DOPA
# ERR creating intindex NiFe2O4-DOPA
# ERR creating intindex PS2.M-hemin
# ERR creating intindex PS2.M-hemin
# ERR creating intindex HbCO
# ERR creating intindex CNMetHb
# ERR creating intindex MOF-Au-Ce
# ERR creating intindex MOF-Au-Ce
# ERR creating intindex MOF-2.5Au
# ERR creating intindex PGP–Con A
# ERR creating intindex DvNgr
# ERR creating intindex Co@NCNTs/NC
# ERR creating intindex DL-selenomethionine
# ERR creating intindex 6A,6B-diseleninic acid-6A*,6B*-selenium bridged b-cyclodextrin
# ERR creating intindex 6A,6B-diseleninic acid-6A*,6B*-selenium bridged b-cyclodextrin
# ERR creating intindex Cyt c-550
# ERR creating intindex Cyt c-550
# ERR creating intindex Fe-MIL-88B-NH2
# ERR creating intindex Fe-MIL-88B-NH2
# ERR creating intindex Sm-TCPP-Pt
# ERR creating intindex Sm-TCPP-Pt
# ERR creating intindex Fe3+P
# ERR creating intindex Fe3+P
# ERR creating intindex Fe3+P
# ERR creating intindex Fe3+P
# ERR creating intindex Fe3+P
# ERR creating intindex Fe3+P
# ERR creating intindex Fe3+P
# ERR creating intindex cytc550
# ERR creating intindex cytc550
# ERR creating intindex cytc550
# ERR creating intindex cytc550
# ERR creating intindex cytc550
# ERR creating intindex cytc550
# ERR creating intindex cytc550
# ERR creating intindex cytc550
# ERR creating intindex H39Q Cyt b5
# ERR creating intindex H39S Cyt b5
# ERR creating intindex Fe-MOF
# ERR creating intindex MLT-7
# ERR creating intindex Fe(III) 5,10,15-tris(4-N-methylpyridiniumyl)-20-(4-phenyl(3-O-amidoxymethylestradiol)) porphyrin
# ERR creating intindex Fe(III) 5,10,15-tris(4-N-methylpyridiniumyl)-20-(4-phenyl(3-O-amidoxymethylestradiol)) porphyrin
# ERR creating intindex Fe(III) 5,10,15-tris(4-N-methylpyridiniumyl)-20-(4-phenyl(3-O-amidoxymethylestradiol)) porphyrin
# ERR creating intindex Fe(III) 5,10,15-tris(4-N-methylpyridiniumyl)-20-(4-phenyl(3-O-amidoxymethylestradiol)) porphyrin
# ERR creating intindex Hb
# ERR creating intindex H2TCPP-CdS
# ERR creating intindex H2TCPP-CdS
# ERR creating intindex Fe-N-C
# ERR creating element Ebs Ebs
# ERR creating element Ebs Ebs
# ERR creating intindex Fe/NC-SAs
# ERR creating intindex Fe/NC-SAs
# ERR creating intindex F-Fe3O4-1
# ERR creating intindex F-Fe3O4-1
# ERR creating intindex F-Fe3O4-1
# ERR creating intindex F-Fe3O4-1
# ERR creating intindex Fe3O4-blank
# ERR creating intindex Fe3O4-blank
# ERR creating intindex Fe3O4-blank
# ERR creating intindex MoOx
# ERR creating intindex Cytochrome b562 (F61I/F65Y/R106L)
# ERR creating intindex Cytochrome b562 (F61A)
# ERR creating intindex Cytochrome b562 (Wild type)
# ERR creating intindex Cytochrome b562 (F61I/F65Y/R106L)
# ERR creating intindex Cytochrome b562 (F61A)
# ERR creating intindex Cytochrome b562 (Wild type)
# ERR creating intindex Cu2-xS
# ERR creating intindex Cu2-xS
# ERR creating intindex Bleomycin-Fe3+
# ERR creating intindex Bleomycin-Fe3+
# ERR creating intindex Bleomycin-Fe3+
# ERR creating intindex Bleomycin-Fe3+
# ERR creating intindex NB-GNRs
# ERR creating intindex NB-GNRs
# ERR creating intindex FeeNeC
# ERR creating intindex FeeNeC
# ERR creating intindex A15/FeeNeC
# ERR creating intindex A15/FeeNeC
# ERR creating intindex 2,2P-diseleno-bis-L-cyclodextrin
# ERR creating intindex 2,2P-diseleno-bis-L-cyclodextrin
# ERR creating intindex Mn3+-octabromo-tetrakis(4-sulfophenyl)porphine
# ERR creating intindex Cu-Ag/g-C3N4/ZIF
# ERR creating intindex Cu-Ag/g-C3N4/ZIF
# ERR creating intindex rHRP(1)
# ERR creating intindex rHRP(2)
# ERR creating intindex rHRP(3)
# ERR creating intindex hemin-EAD2
# ERR creating intindex hemin-EAD2
# ERR creating intindex Tb–HRP
# ERR creating intindex Tb–HRP
# ERR creating intindex Tb–HRP
# ERR creating intindex Mn-TPPS
# ERR creating intindex Mn-TPPS
# ERR creating intindex Fe-TMPyP
# ERR creating intindex Fe-TMPyP
# ERR creating intindex Zn3(MoO4)2(trz)2(H2O)2
# ERR creating intindex Zn3(MoO4)2(trz)2(H2O)2
# ERR creating intindex cyt-c
# ERR creating intindex cyt-c
# ERR creating intindex cyt-c
# ERR creating intindex rG4 + hemin
# ERR creating intindex rG4 + hemin
# ERR creating intindex 13,16-dicarboxyethyl-2,7-diethyl-3,6,12,17-tetramethylporphycenatoiron(III)
# ERR creating intindex 13,16-dicarboxyethyl-2,7-diethyl-3,6,12,17-tetramethylporphycenatoiron(III)
# ERR creating intindex 13,16-dicarboxyethyl-2,7-diethyl-3,6,12,17-tetramethylporphycenatoiron(III)
# ERR creating intindex 13,16-dicarboxyethyl-2,7-diethyl-3,6,12,17-tetramethylporphycenatoiron(III)
# ERR creating intindex CH-Cu
# ERR creating intindex CH-Cu
# ERR creating intindex L29H/F43H Mb
# ERR creating intindex Cu(II)-L29H/F43H Mb
# ERR creating intindex Zn(II)-L29H/F43H Mb
# ERR creating intindex L29H/F43H Mb
# ERR creating intindex Cu(II)-L29H/F43H Mb
# ERR creating intindex Zn(II)-L29H/F43H Mb
# ERR creating intindex L29H/F43H Mb
# ERR creating intindex Cu(II)-L29H/F43H Mb
# ERR creating intindex Zn(II)-L29H/F43H Mb
# ERR creating intindex DhHP-6
# ERR creating intindex DhHP-6
# ERR creating intindex DhHP-6
# ERR creating intindex DhHP-6
# ERR creating intindex DhHP-6
# ERR creating intindex DhHP-6
# ERR creating intindex DhHP-6
# ERR creating intindex Fe3+/AMP
# ERR creating intindex PLPC-OOH
# ERR creating intindex Mn-T(4-TAP)P
# ERR creating intindex Fe(III)-MC6
# ERR creating intindex Fe(III)-MC6
# ERR creating intindex AuNP/Ag-bipyridine
# ERR creating intindex AuNP/Ag-bipyridine
# ERR creating intindex Fe-N-CDs
# ERR creating intindex Fe-N-CDs
# ERR creating intindex Ni(C33H37N4O4S2)·DMF
# ERR creating intindex unknown
# ERR creating intindex MPS-PPV
# ERR creating intindex MPS-PPV
# ERR creating intindex Au@Pt 0.25%
# ERR creating intindex Au@Pt 2.5%
# ERR creating intindex Au@Pt 25%
# ERR creating intindex Au@Pt 2.5%
# ERR creating intindex Fe3O4-TiO2/rGO
# ERR creating intindex Fe3O4-TiO2/rGO
# ERR creating intindex DhHP-6-c-ZrMOF
# ERR creating intindex DhHP-6-c-ZrMOF
# ERR creating intindex DhHP-6
# ERR creating intindex DhHP-6
# ERR creating intindex Cu/Au
# ERR creating intindex Cu/Au
# ERR creating intindex CH3CONH2 + HOOC(CH2)3COOH
# ERR creating intindex CH3CONH2 + HOOC(CH2)3COOH
# ERR creating intindex g-C3N4
# ERR creating intindex g-C3N4
# ERR creating intindex N-CNTs@Co
# ERR creating intindex PRGI/Pt
# ERR creating intindex PRGI/Pt
# ERR creating intindex V2O5@pDA@MnO2
# ERR creating intindex V2O5@pDA@MnO2
# ERR creating intindex PEIeAuNPseMnIIIPPIX
# ERR creating intindex Au-Ag-AFT
# ERR creating intindex Au-Ag-AFT
# ERR creating intindex Au-Ag-AFT
# ERR creating intindex Se-DL-Cysteine
# ERR creating intindex Se-DL-Cysteine
# ERR creating intindex Apt–Au NPs/BiOCl
# ERR creating intindex Apt–Au NPs/BiOCl
# ERR creating intindex Apt–Au NPs/BiOCl
# ERR creating intindex Apt–Au NPs/BiOCl
# ERR creating intindex Fe3O4@MoS2-1%Ag
# ERR creating intindex Fe3O4@MoS2-1%Ag
# ERR creating intindex ADM-Fe3+
# ERR creating intindex ADM-Fe3+
# ERR creating intindex ADM-Fe3+
# ERR creating intindex Cu xO
# ERR creating intindex Cu xO
# ERR creating intindex Cu xO
# ERR creating intindex seleno-LuGST1-1
# ERR creating intindex seleno-LuGST1-1
# ERR creating intindex seleno-LuGST1-1
# ERR creating intindex seleno-LuGST1-1
# ERR creating intindex seleno-LuGST1-1
# ERR creating intindex seleno-LuGST1-1
# ERR creating intindex Cytc
# ERR creating intindex 3,8-DMD(Fe3+)-6-mer/T
# ERR creating intindex 3,8-DMD(Fe3+)-6-mer/A
# ERR creating intindex 2,8-DPF(Fe3+)-6-mer/T
# ERR creating intindex 2,8-DPF(Fe3+)-6-mer/A
# ERR creating intindex FeT(4-TAP)P
# ERR creating intindex FeT(4-TAP)P
# ERR creating intindex MnT(4-TAP)P
# ERR creating intindex MnT(4-TAP)P
# ERR creating intindex G4-hpDNA
# ERR creating intindex BSA-Au
# ERR creating intindex hSOD1
# ERR creating intindex hSOD1
# ERR creating intindex Nak-YCC3.5
# ERR creating intindex Nak-YCC3.5
# ERR creating intindex Nak-YCC3.5
# ERR creating intindex Nak-YCC3.5
# ERR creating intindex Nak-YCC3.5
# ERR creating intindex Nak-YCC3.5
# ERR creating intindex Nak-TMut3.5
# ERR creating intindex Nak-TMut3.5
# ERR creating intindex FeOxH–rGO
# ERR creating intindex FeOxH–rGO
# ERR creating intindex I-
# ERR creating intindex I-
# ERR creating intindex CeO2@MMT(2:8)
# ERR creating intindex CeO2@MMT(2:8)
# ERR creating intindex CeO2@MMT(2:8)
# ERR creating intindex CeO2@MMT(1:9)
# ERR creating intindex CeO2@MMT(1:9)
# ERR creating intindex CeO2@MMT(1:9)
# ERR creating intindex N-CNTs
# ERR creating intindex N-CNTs
# ERR creating intindex Au-Pt
# ERR creating intindex Au-Pt
# ERR creating intindex AuNC/GNR
# ERR creating intindex AuNC/GNR
# ERR creating intindex 1
# ERR creating intindex 1
# ERR creating intindex 1
# ERR creating intindex HRP-PEG 5000
# ERR creating intindex HRP-PEG 20000
# ERR creating intindex HRP-PEG 40000
# ERR creating intindex HRP-PEG 5000, co-lyophilized
# ERR creating intindex HRP-PEG 20000, co-lyophilized
# ERR creating intindex HRP-PEG 40000, co-lyophilized
# ERR creating intindex Arg51Gln
# ERR creating intindex Arg51Asn
# ERR creating intindex Arg51Leu
# ERR creating intindex Arg51Lys
# ERR creating intindex TMBDA-MIL-100(Fe)
# ERR creating intindex TMBDA-MIL-100(Fe)
# ERR creating intindex Hb
# ERR creating intindex Hb
# ERR creating intindex metHb
# ERR creating intindex metHb
# ERR creating intindex myoglobin
# ERR creating intindex myoglobin
# ERR creating intindex Pt-on-Pd/RGO
# ERR creating intindex Pt-on-Pd/RGO
# ERR creating intindex NH2-MIL-101(Fe)
# ERR creating intindex NH2-MIL-101(Fe)
# ERR creating intindex NADPH oxidase
# ERR creating intindex NADPH oxidase
# ERR creating intindex MoS2/g-C3N4
# ERR creating intindex MoS2/g-C3N4
# ERR creating intindex [Co(L)(H2O)2]n
# ERR creating intindex [Co(L)(H2O)2]n
# ERR creating intindex Mo SA–N 3–C
# ERR creating intindex Mo SA–N 3–C
# ERR creating intindex Fe-N-C
# ERR creating intindex Fe-N-C
# ERR creating intindex 2-SeCD
# ERR creating intindex Pc(OH)8/CoSn(OH)6
# ERR creating intindex Pc(OH)8/CoSn(OH)6
# ERR creating intindex catalase
# ERR creating intindex Cu(NO3)2·3H2O
# ERR creating intindex Cu(NO3)2·3H2O
# ERR creating intindex G-quadruplex-Cu2+
# ERR creating intindex G-quadruplex-Cu2+
# ERR creating intindex HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating intindex HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating intindex HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating intindex HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating intindex HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating intindex HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating intindex HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating intindex SrTiO3/DHB
# ERR creating intindex AuPd-PDA
# ERR creating intindex AuPd-PDA
# ERR creating intindex GSH-Px
# ERR creating intindex GSH-Px
# ERR creating intindex Fe-Ag2S
# ERR creating intindex Fe-Ag2S
# ERR creating intindex MbFe(IV)dO
# ERR creating intindex MbFe(IV)dO
# ERR creating intindex MbFe(IV)dO
# ERR creating intindex MbFe(IV)dO
# ERR creating intindex GO-Cyt c_1 min
# ERR creating intindex GO-Cyt c_1 min
# ERR creating intindex GO-Cyt c_5 h
# ERR creating intindex GO-Cyt c_5 h
# ERR creating intindex metMb
# ERR creating intindex metMb
# ERR creating intindex Fe3O4-chitosan-tripolyphosphate-calcium
# ERR creating intindex Fe3O4-chitosan-tripolyphosphate-calcium-glucose oxidase-concanavalin A
# ERR creating intindex Fe3O4-chitosan-tripolyphosphate-calcium-glucose oxidase-concanavalin A
# ERR creating intindex Fe3O4-chitosan-tripolyphosphate-calcium-glucose oxidase-concanavalin A
# ERR creating intindex Fe3O4-chitosan-tripolyphosphate-calcium-glucose oxidase-concanavalin A
# ERR creating intindex Hb
# ERR creating intindex Hb
# ERR creating intindex His-Ti3C2
# ERR creating intindex His-Ti3C2
# ERR creating intindex Ala-Ti3C2
# ERR creating intindex Ala-Ti3C2
# ERR creating intindex HRP/CHIT/CMS
# ERR creating intindex ZnO–g-C3N4/MoS2
# ERR creating intindex ZnO–g-C3N4/MoS2
# ERR creating intindex 6,60-telluro-bis (6-deoxy-b-cyclodextrin)
# ERR creating intindex 6,60-telluro-bis (6-deoxy-b-cyclodextrin)
# ERR creating intindex 6,60-ditelluro-bis (6-deoxy-b-cyclodextrin)
# ERR creating intindex 6,60-ditelluro-bis (6-deoxy-b-cyclodextrin)
# ERR creating intindex Fe(III)-porphyrin
# ERR creating intindex Fe(III)-porphyrin
# ERR creating intindex Se-SP-1
# ERR creating intindex Se-SP-2
# ERR creating intindex Fv
# ERR creating intindex CoPc-MWCNT
# ERR creating intindex CoPc-MWCNT
# ERR creating intindex SWNT-3
# ERR creating intindex SWNT-3
# ERR creating intindex SWNT-4
# ERR creating intindex SWNT-4
# ERR creating intindex FeTSPc
# ERR creating intindex MAP_2744c
# ERR creating intindex MAP_2744c
# ERR creating intindex MAP_2744c
# ERR creating intindex MAP_2744c
# ERR creating intindex Fe/C NS
# ERR creating intindex Fe/C NS
# ERR creating intindex PNPG-PEG
# ERR creating intindex PNPG-PEG
# ERR creating intindex Hb
# ERR creating intindex Hb
# ERR creating intindex Prdx6
# ERR creating intindex Prdx6
# ERR creating intindex PPAM–N–CD–Te
# ERR creating intindex Co-N-C
# ERR creating intindex Co-N-C
# ERR creating intindex CysSeSeCys
# ERR creating intindex CysSeSeCys
# ERR creating intindex CysSeSeCys
# ERR creating intindex CysSeSeCys
# ERR creating intindex Cytc
# ERR creating intindex Cytc
# ERR creating intindex Cytc
# ERR creating intindex Cytc
# ERR creating intindex Cytc
# ERR creating intindex BP-IL-SWCNH
# ERR creating intindex Hb
# ERR creating intindex Fe3O4-Au
# ERR creating intindex Fe3O4-Au
# ERR creating intindex Cu3V2O7(OH)2·2H2O
# ERR creating intindex Cu3V2O7(OH)2·2H2O
# ERR creating intindex Cu3V2O7(OH)2·2H2O
# ERR creating intindex Cu3V2O7(OH)2·2H2O
# ERR creating intindex Fe(III)MP-8
# ERR creating intindex Fe(III)MP-8
# ERR creating intindex Fe(III)MP-8
# ERR creating intindex Fe(III)MP-8
# ERR creating intindex GMP-Cu
# ERR creating intindex GMP-Cu
# ERR creating intindex OPD-MoS2
# ERR creating intindex OPD-MoS2
# ERR creating intindex OPD-MoS2
# ERR creating intindex OPD-MoS2
# ERR creating intindex H2O2 + o-phenylenediamine
# ERR creating intindex ficin
# ERR creating intindex H&rGO
# ERR creating intindex hemin
# ERR creating intindex hemin
# ERR creating intindex Pu39WT-hemin
# ERR creating intindex HDP-ELP
# ERR creating intindex Hb
# ERR creating intindex Hb
# ERR creating intindex Hb(cid:1)Hp
# ERR creating intindex Hb(cid:1)Hp
# ERR creating intindex (Et3NH)[Fe(bpb)Cl2]
# ERR creating intindex (Et3NH)[Fe(bpb)Cl2]
# ERR creating intindex NADH peroxidase
# ERR creating intindex Cyt c
# ERR creating intindex Fe2O3/Pt/CNTs
# ERR creating intindex Fe2O3/Pt/CNTs
# ERR creating intindex Fe2O3/Pt/CNTs
# ERR creating intindex HSA + uric acid + Cu
# ERR creating intindex HSA + uric acid + Cu
# ERR creating intindex CDs@NC-3
# ERR creating intindex CDs@NC-3
# ERR creating intindex HPtNPs-Fe3O4
# ERR creating intindex HbGp
# ERR creating intindex HbGp
# ERR creating intindex HbGp
# ERR creating intindex HbGp
# ERR creating intindex HbGp
# ERR creating intindex HbGp

# %% [markdown]
# ## ph

# %%
res_df["ph"] = df["ph"]

# %% [markdown]
# ## temp

# %%
res_df["temp"] = df["temp, °C"]

# %% [markdown]
# ## dstr

# %%
def createDstr(sizes):
    l, w, d = sizes
    if uf.check_nan(l) or uf.check_nan(w) or uf.check_nan(d):
        return np.nan

    sizes_list = [l, w, d]
    sizes_list.sort(reverse=True)
    l, w, d = sizes_list
    

    big_diff_lw = l/w>6
    big_diff_ld = l/d>6

    if big_diff_lw and big_diff_ld:
        dstr = 1
    elif big_diff_lw or big_diff_ld:
        dstr = 2
    else:
        dstr = 3
    return dstr

# %%
res_df["dstr"] = df[["length, nm", "width, nm", "depth, nm"]].apply(createDstr, axis=1)

# %% [markdown]
# ## C (Cmin, Cmax, lgCmin ...)

# %%
res_df["Cmin"] = df["C min, mM"]
res_df["Cmax"] = df["C max, mM"]
res_df["lgCmin"] = np.log10(res_df["Cmin"])
res_df["lgCmax"] = np.log10(res_df["Cmax"])
# Out:
# /home/oleg/Programs/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /home/oleg/Programs/.venv/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
res_df["Cconst"] = df["C(const), mM"]
res_df["Ccat"] = df["Ccat(mg/mL)"]
res_df["lgCconst"] = np.log10(res_df["Cconst"])
res_df["lgCcat"] = np.log10(res_df["Ccat"])

# %% [markdown]
# ## lgvolume

# %%
def createLgvolume(sizes):
    l, w, d = sizes
    if uf.check_nan(l) or uf.check_nan(w) or uf.check_nan(d):
        return np.nan
    return np.log10(l*w*d)

# %%
res_df["lgvolume"] = df[["length, nm", "width, nm", "depth, nm"]].apply(createLgvolume, axis=1)

# %% [markdown]
# ## Km, Vmax

# %%
res_df["Km"] = df["Km, mM"]
res_df["Vmax"] = df["Vmax, mM/s"]

# %% [markdown]
# ## activity

# %%
res_df["activity"] = df["activity"].apply(uf.map_activity)

# %% [markdown]
# ## polymer, surfactant, reaction_type descriptors

# %%
history = {}
h_prop = {}
h_comp = {}

# %%
def get_gescriptors_by_names(names, use_history=True):
    '''
    names - List of names of chemicals
    '''

    if use_history and (names in history):
        return history[names]

    ### pubchem descriptors
    # mw = 0
    tpsa = 0
    comp = 0
    logp = 0
    for name in names:
        if name in h_prop:
            prop = h_prop[name]
        else:
            prop = fu.pcp.get_properties(
                ['MolecularWeight', 'XLogP','TPSA', 'Complexity'],
                fu.monomer(name), 
                'name'
            )
            h_prop[name] = prop
        
        if len(prop) < 1:
            # if molecue not found then set nan values
            print(f"ERR PCP not found get_properties {name}")
            # mw = np.nan
            tpsa = np.nan
            P = np.nan
            comp = np.nan
            break
        prop = prop[0]
            

        # polym = float(mcoat)*1000/float(mw) ## i don't have mcoat
        # mw += float(prop.get('MolecularWeight', np.nan))
        if len(names) == 1:
            logp = prop.get('XLogP', np.nan)
        tpsa += float(prop.get('TPSA', np.nan))
        comp = float(prop.get('Complexity', np.nan))

    # convert zeros to nan
    # mw = mw if mw else np.nan
    tpsa = tpsa if tpsa else np.nan
    logp = logp if logp else np.nan
    comp = comp if comp else np.nan

    desc_pubchem = {
        # "MolWt": mw,
        "XLogP": logp,
        "TPSA": tpsa,
        "Complexity": comp,
    }

    ### RDKit descriptors
    smiles_list = []
    for name in names:
        if name in h_comp:
            smiles_obj = h_comp[name]
        else:
            smiles_obj = fu.pcp.get_compounds(fu.monomer(name), 'name')
            h_comp[name] = smiles_obj

        if len(smiles_obj) < 1:
            print(f"ERR PCP not found get_compounds {name}")
            desc_rdkit = {
                "MolWt": np.nan,
                "PEOE_VSA7": np.nan,
                "PEOE_VSA9": np.nan,
                "VSA_EState8": np.nan,
                "Kappa2": np.nan,
                "BalabanJ": np.nan,
                "MinAbsEStateIndex": np.nan,
                "MinEStateIndex": np.nan,
                "EState_VSA6": np.nan,
                "VSA_EState4": np.nan,
                "PEOE_VSA8": np.nan,
                "MinPartialCharge": np.nan,
                "EState_VSA4": np.nan,
                "SMR_VSA7": np.nan,
                "BCUT2D_CHGLO": np.nan,
                "MaxEStateIndex": np.nan,
                "MaxPartialCharge": np.nan,
            }
            desc = {**desc_pubchem, **desc_rdkit}
            history[names] = desc
            return desc

        smiles_list.append(smiles_obj[0].isomeric_smiles)

    if len(smiles_list) < 1:
        desc_rdkit = {
                "MolWt": np.nan,
                "PEOE_VSA7": np.nan,
                "PEOE_VSA9": np.nan,
                "VSA_EState8": np.nan,
                "Kappa2": np.nan,
                "BalabanJ": np.nan,
                "MinAbsEStateIndex": np.nan,
                "MinEStateIndex": np.nan,
                "EState_VSA6": np.nan,
                "VSA_EState4": np.nan,
                "PEOE_VSA8": np.nan,
                "MinPartialCharge": np.nan,
                "EState_VSA4": np.nan,
                "SMR_VSA7": np.nan,
                "BCUT2D_CHGLO": np.nan,
                "MaxEStateIndex": np.nan,
                "MaxPartialCharge": np.nan,
            }
    else:
        mol = fu.Chem.MolFromSmiles(".".join(smiles_list))
        # print(smiles_list)
        allDescrs = fu.getMolDescriptors(mol)
        # print(allDescrs.keys())
        desc_rdkit = {
            "MolWt": allDescrs["MolWt"],
            "PEOE_VSA7": allDescrs["PEOE_VSA7"],
            "PEOE_VSA9": allDescrs["PEOE_VSA9"],
            "VSA_EState8": allDescrs["VSA_EState8"],
            "Kappa2": allDescrs["Kappa2"],
            "BalabanJ": allDescrs["BalabanJ"],
            "MinAbsEStateIndex": allDescrs["MinAbsEStateIndex"],
            "MinEStateIndex": allDescrs["MinEStateIndex"],
            "EState_VSA6": allDescrs["EState_VSA6"],
            "VSA_EState4": allDescrs["VSA_EState4"],
            "PEOE_VSA8": allDescrs["PEOE_VSA8"],
            "MinPartialCharge": allDescrs["MinPartialCharge"],
            "EState_VSA4": allDescrs["EState_VSA4"],
            "SMR_VSA7": allDescrs["SMR_VSA7"],
            "BCUT2D_CHGLO": allDescrs["BCUT2D_CHGLO"],
            "MaxEStateIndex": allDescrs["MaxEStateIndex"],
            "MaxPartialCharge": allDescrs["MaxPartialCharge"],
        }

    desc = {**desc_pubchem, **desc_rdkit}
    history[names] = desc
    return desc

# %% [markdown]
# ### Check how well this work

# %%
final_df = pd.read_csv("data/existing_datasets/final_df.csv")
start_df = pd.read_csv("data/existing_datasets/start_df.csv")

# %%
def get_row_descriptors(row, chemicals_columns = ["surface", "pol", "surf"]):
    rd = {}
    
    ### descriptors of surface, pol, surf
    chemicals = [row[col] for col in chemicals_columns]
    chemicals = [ch for ch in chemicals if ch not in ["0", "nan", "naked"] and not uf.check_nan(ch)]
    chemicals = tuple(chemicals)
    # print(chemicals)

    chemicals_descriptors = get_gescriptors_by_names(chemicals)
    # remove descriptors that aren't calculated for (surface, pol, surf)
    chemicals_descriptors = {key: value for key, value in chemicals_descriptors.items() if key not in ["MaxEStateIndex", "MaxPartialCharge", "Complexity"]}
    # print(chemicals_descriptors)
    rd.update(chemicals_descriptors)

    ### descriptors of reaction_type (ex.: TMB + H2O2)
    rd[f"MinPartialCharge.1"] = np.nan
    rd[f"MaxPartialCharge.1"] = np.nan
    rd[f"Complexity1"] = np.nan
    for i in range(2):
        rd[f"TPSA{i+1}"] = np.nan
        rd[f"MaxEStateIndex.{i+1}"] = np.nan


    if uf.check_nan(row["ReactionType"]):
        return rd
        

    chems = row["ReactionType"].replace(" + ", "+").split("+")
    chems = [ch.lstrip().rstrip() for ch in chems if ch not in ["0", "nan", ""] and not uf.check_nan(ch)]
    if len(chems) > 2:
        print("A lot of elements in reaction: ", "id", row["ReactionType"], chems)
        return rd

    for i, chem in enumerate(chems):
        desc = get_gescriptors_by_names((chem,))
        rd[f"TPSA{i+1}"] = desc["TPSA"]
        rd[f"MaxEStateIndex.{i+1}"] = desc["MaxEStateIndex"]
        if i == 0:
            rd[f"Complexity{i+1}"] = desc["Complexity"]
            rd[f"MinPartialCharge.{i+1}"] = desc["MinPartialCharge"]
            rd[f"MaxPartialCharge.{i+1}"] = desc["MaxPartialCharge"]

    return rd

# %%
from collections import defaultdict

# %%
n_of_good_convertions = 0
n_of_errors_by_key = defaultdict(int)
n_of_errors_by_row_id = defaultdict(int)

for i in tqdm(range(1000)):
    row = start_df.loc[i]
    id_ = row["#"]
    
    row_descriptors = get_row_descriptors(row)

    data = final_df[final_df["id"] == id_][[key for key in row_descriptors.keys()]]
    if data.shape[0] < 1:
        continue
        
    for key in row_descriptors.keys():
        eps = 0.01
        if "TPSA" in key:
            eps = 3

        orig = data[key].tolist()[0]
        
        # orig != 0 and descriptor is nan
        if orig > eps and uf.check_nan(row_descriptors[key]):
            if key == "XLogP":
                continue
            n_of_errors_by_key[key] += 1
            n_of_errors_by_row_id[id_] += 1
            print(id_, key, orig, row_descriptors[key])

        if abs(orig - row_descriptors[key])>eps:
            n_of_errors_by_key[key] += 1
            n_of_errors_by_row_id[id_] += 1
            print(id_, key, orig, row_descriptors[key])

    if n_of_errors_by_row_id[id_] == 0:
        n_of_good_convertions += 1

print(n_of_good_convertions)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 23 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 23 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 23 Complexity1 0.0 910.0
# 23 TPSA1 883.0 209.0
# 23 MaxEStateIndex.1 11.3319983 11.447015664231106
# 26 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 26 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 26 Complexity1 0.0 910.0
# 26 TPSA1 883.0 209.0
# 26 MaxEStateIndex.1 11.3319983 11.447015664231106
# 91 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 91 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 91 Complexity1 0.0 910.0
# 91 TPSA1 883.0 209.0
# 91 MaxEStateIndex.1 11.3319983 11.447015664231106
# 97 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 97 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 97 Complexity1 0.0 910.0
# 97 TPSA1 883.0 209.0
# 97 MaxEStateIndex.1 11.3319983 11.447015664231106
# 117 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 117 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 117 Complexity1 0.0 910.0
# 117 TPSA1 883.0 209.0
# 117 MaxEStateIndex.1 11.3319983 11.447015664231106
# 176 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 176 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 176 Complexity1 0.0 910.0
# 176 TPSA1 883.0 209.0
# 176 MaxEStateIndex.1 11.3319983 11.447015664231106
# 184 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 184 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 184 Complexity1 0.0 910.0
# 184 TPSA1 883.0 209.0
# 184 MaxEStateIndex.1 11.3319983 11.447015664231106
# 196 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 196 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 196 Complexity1 0.0 910.0
# 196 TPSA1 883.0 209.0
# 196 MaxEStateIndex.1 11.3319983 11.447015664231106
# 221 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 221 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 221 Complexity1 0.0 910.0
# 221 TPSA1 883.0 209.0
# 221 MaxEStateIndex.1 11.3319983 11.447015664231106
# 223 MinPartialCharge.1 -0.39829863 -0.254557430614467
# 223 MaxPartialCharge.1 0.037337328 -0.254557430614467
# 223 Complexity1 226.0 nan
# 223 TPSA1 52.0 40.5
# 223 TPSA2 40.5 52.0
# 236 MolWt 17.99 nan
# 236 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 236 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 236 Complexity1 0.0 910.0
# 236 TPSA1 883.0 209.0
# 236 MaxEStateIndex.1 11.3319983 11.447015664231106
# 237 MolWt 17.99 nan
# 238 XLogP 0.0 8.5
# 238 TPSA 0.0 207.0
# 238 PEOE_VSA7 0.0 119.35429121566287
# 238 PEOE_VSA9 0.0 45.02951794618183
# 238 Kappa2 0.0 14.70022024837367
# 238 BalabanJ 0.0 1.4314020740974527
# 238 MinAbsEStateIndex 0.0 0.1109455295625903
# 238 MinEStateIndex 0.0 -1.0679502809801995
# 238 EState_VSA6 0.0 48.53093654769288
# 238 VSA_EState4 0.0 10.719094091068374
# 238 PEOE_VSA8 0.0 44.320608837253026
# 238 MinPartialCharge 0.0 -0.47763924658960344
# 238 SMR_VSA7 0.0 166.35685931541406
# 238 BCUT2D_CHGLO 0.0 -2.0764612075323403
# 239 XLogP 0.0 8.5
# 239 TPSA 0.0 207.0
# 239 PEOE_VSA7 0.0 119.35429121566287
# 239 PEOE_VSA9 0.0 45.02951794618183
# 239 Kappa2 0.0 14.70022024837367
# 239 BalabanJ 0.0 1.4314020740974527
# 239 MinAbsEStateIndex 0.0 0.1109455295625903
# 239 MinEStateIndex 0.0 -1.0679502809801995
# 239 EState_VSA6 0.0 48.53093654769288
# 239 VSA_EState4 0.0 10.719094091068374
# 239 PEOE_VSA8 0.0 44.320608837253026
# 239 MinPartialCharge 0.0 -0.47763924658960344
# 239 SMR_VSA7 0.0 166.35685931541406
# 239 BCUT2D_CHGLO 0.0 -2.0764612075323403
# 240 XLogP 0.0 8.5
# 240 TPSA 0.0 207.0
# 240 PEOE_VSA7 0.0 119.35429121566287
# 240 PEOE_VSA9 0.0 45.02951794618183
# 240 Kappa2 0.0 14.70022024837367
# 240 BalabanJ 0.0 1.4314020740974527
# 240 MinAbsEStateIndex 0.0 0.1109455295625903
# 240 MinEStateIndex 0.0 -1.0679502809801995
# 240 EState_VSA6 0.0 48.53093654769288
# 240 VSA_EState4 0.0 10.719094091068374
# 240 PEOE_VSA8 0.0 44.320608837253026
# 240 MinPartialCharge 0.0 -0.47763924658960344
# 240 SMR_VSA7 0.0 166.35685931541406
# 240 BCUT2D_CHGLO 0.0 -2.0764612075323403
# 241 XLogP 0.0 8.5
# 241 TPSA 0.0 207.0
# 241 PEOE_VSA7 0.0 119.35429121566287
# 241 PEOE_VSA9 0.0 45.02951794618183
# 241 Kappa2 0.0 14.70022024837367
# 241 BalabanJ 0.0 1.4314020740974527
# 241 MinAbsEStateIndex 0.0 0.1109455295625903
# 241 MinEStateIndex 0.0 -1.0679502809801995
# 241 EState_VSA6 0.0 48.53093654769288
# 241 VSA_EState4 0.0 10.719094091068374
# 241 PEOE_VSA8 0.0 44.320608837253026
# 241 MinPartialCharge 0.0 -0.47763924658960344
# 241 SMR_VSA7 0.0 166.35685931541406
# 241 BCUT2D_CHGLO 0.0 -2.0764612075323403
# ERR PCP not found get_properties Heparin
# ERR PCP not found get_compounds Heparin
# 246 TPSA 610.49 nan
# 246 MolWt 1134.934 nan
# 246 PEOE_VSA9 13.21376393 nan
# 246 Kappa2 22.78380569 nan
# 246 BalabanJ 1.825883284 nan
# 246 MinAbsEStateIndex 0.840345043 nan
# 246 PEOE_VSA8 6.9237372 nan
# 246 EState_VSA4 6.9237372 nan
# 250 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 250 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 250 Complexity1 0.0 910.0
# 250 TPSA1 883.0 209.0
# 250 MaxEStateIndex.1 11.3319983 11.447015664231106
# 251 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 251 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 251 Complexity1 0.0 910.0
# 251 TPSA1 883.0 209.0
# 251 MaxEStateIndex.1 11.3319983 11.447015664231106
# 253 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 253 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 253 Complexity1 0.0 910.0
# 253 TPSA1 883.0 209.0
# 253 MaxEStateIndex.1 11.3319983 11.447015664231106
# 254 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 254 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 254 Complexity1 0.0 910.0
# 254 TPSA1 883.0 209.0
# 254 MaxEStateIndex.1 11.3319983 11.447015664231106
# 255 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 255 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 255 Complexity1 0.0 910.0
# 255 TPSA1 883.0 209.0
# 255 MaxEStateIndex.1 11.3319983 11.447015664231106
# 267 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 267 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 267 Complexity1 0.0 910.0
# 267 TPSA1 883.0 209.0
# 267 MaxEStateIndex.1 11.3319983 11.447015664231106
# 267 TPSA2 40.5 nan
# 268 TPSA2 40.5 nan
# 269 TPSA2 40.5 nan
# 270 Complexity1 335.0 nan
# 270 TPSA1 70.0 nan
# 270 TPSA2 40.5 nan
# 271 Complexity1 335.0 nan
# 271 TPSA1 70.0 nan
# 271 TPSA2 40.5 nan
# 272 Complexity1 335.0 nan
# 272 TPSA1 70.0 nan
# 272 TPSA2 40.5 nan
# 273 Complexity1 335.0 nan
# 273 TPSA1 70.0 nan
# 273 TPSA2 40.5 nan
# 274 Complexity1 335.0 nan
# 274 TPSA1 70.0 nan
# 274 TPSA2 40.5 nan
# 275 TPSA2 42.8 nan
# 277 TPSA2 42.8 nan
# 278 TPSA2 40.5 nan
# 280 TPSA2 40.5 nan
# 281 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 281 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 281 Complexity1 0.0 910.0
# 281 TPSA1 883.0 209.0
# 281 MaxEStateIndex.1 11.3319983 11.447015664231106
# 281 TPSA2 40.5 nan
# 282 Complexity1 335.0 nan
# 282 TPSA1 70.0 nan
# 282 TPSA2 40.5 nan
# 283 TPSA2 40.5 nan
# 284 TPSA2 40.5 nan
# 285 TPSA2 40.5 nan
# 286 TPSA2 40.5 nan
# 287 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 287 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 287 Complexity1 0.0 910.0
# 287 TPSA1 883.0 209.0
# 287 MaxEStateIndex.1 11.3319983 11.447015664231106
# 287 TPSA2 40.5 nan
# 288 TPSA2 40.5 nan
# 289 TPSA2 40.5 nan
# 290 TPSA2 40.5 nan
# 291 TPSA2 40.5 nan
# 292 TPSA2 40.5 nan
# 294 TPSA2 40.5 nan
# 295 TPSA2 49.7 nan
# 296 TPSA2 49.7 nan
# 297 TPSA2 52.0 nan
# 298 TPSA2 52.0 nan
# 299 TPSA2 52.0 nan
# 300 TPSA2 52.0 nan
# 301 TPSA2 52.0 nan
# 302 TPSA2 52.0 nan
# 303 TPSA2 52.0 nan
# 308 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 308 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 308 Complexity1 0.0 910.0
# 308 TPSA1 883.0 209.0
# 308 MaxEStateIndex.1 11.3319983 11.447015664231106
# 312 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 312 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 312 Complexity1 0.0 910.0
# 312 TPSA1 883.0 209.0
# 312 MaxEStateIndex.1 11.3319983 11.447015664231106
# 366 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 366 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 366 Complexity1 0.0 910.0
# 366 TPSA1 883.0 209.0
# 366 MaxEStateIndex.1 11.3319983 11.447015664231106
# ERR PCP not found get_properties apoferritin
# ERR PCP not found get_compounds apoferritin
# 372 TPSA 477.88 nan
# 372 MolWt 1152.384 nan
# 372 PEOE_VSA7 112.9204435 nan
# 372 PEOE_VSA9 37.5740477 nan
# 372 VSA_EState8 7.307812377 nan
# 372 Kappa2 37.83266664 nan
# 372 BalabanJ 3.312274144 nan
# 372 EState_VSA6 27.6949488 nan
# 372 VSA_EState4 23.25038458 nan
# 372 EState_VSA4 6.9237372 nan
# 372 SMR_VSA7 29.82891977 nan
# 373 TPSA 477.88 nan
# 373 MolWt 1152.384 nan
# 373 PEOE_VSA7 112.9204435 nan
# 373 PEOE_VSA9 37.5740477 nan
# 373 VSA_EState8 7.307812377 nan
# 373 Kappa2 37.83266664 nan
# 373 BalabanJ 3.312274144 nan
# 373 EState_VSA6 27.6949488 nan
# 373 VSA_EState4 23.25038458 nan
# 373 EState_VSA4 6.9237372 nan
# 373 SMR_VSA7 29.82891977 nan
# 385 Complexity1 335.0 nan
# 385 TPSA1 70.0 nan
# 386 TPSA2 70.0 nan
# 419 TPSA 66.43 74.8
# 420 TPSA 66.43 74.8
# 432 XLogP 0.0 1.8
# 432 TPSA 0.0 12.9
# 432 PEOE_VSA7 0.0 24.974377382775238
# 432 VSA_EState8 0.0 4.083333333333333
# 432 Kappa2 0.0 1.94826211591866
# 432 BalabanJ 0.0 3.077660437970554
# 432 MinAbsEStateIndex 0.0 1.226851851851852
# 432 MinEStateIndex 0.0 1.226851851851852
# 432 VSA_EState4 0.0 2.453703703703704
# 432 PEOE_VSA8 0.0 12.393687143226153
# 432 MinPartialCharge 0.0 -0.26418180225198346
# 432 SMR_VSA7 0.0 29.586957195081755
# 432 BCUT2D_CHGLO 0.0 -1.8946239255937454
# 433 XLogP 0.0 1.8
# 433 TPSA 0.0 12.9
# 433 PEOE_VSA7 0.0 24.974377382775238
# 433 VSA_EState8 0.0 4.083333333333333
# 433 Kappa2 0.0 1.94826211591866
# 433 BalabanJ 0.0 3.077660437970554
# 433 MinAbsEStateIndex 0.0 1.226851851851852
# 433 MinEStateIndex 0.0 1.226851851851852
# 433 VSA_EState4 0.0 2.453703703703704
# 433 PEOE_VSA8 0.0 12.393687143226153
# 433 MinPartialCharge 0.0 -0.26418180225198346
# 433 SMR_VSA7 0.0 29.586957195081755
# 433 BCUT2D_CHGLO 0.0 -1.8946239255937454
# 445 Complexity1 335.0 nan
# 445 TPSA1 70.0 nan
# 446 TPSA2 70.0 nan
# 447 Complexity1 335.0 nan
# 447 TPSA1 70.0 nan
# 448 TPSA2 70.0 nan
# 449 Complexity1 335.0 nan
# 449 TPSA1 70.0 nan
# 450 TPSA2 70.0 nan
# 458 TPSA 57.2 65.6
# 459 TPSA 57.2 65.6
# 468 TPSA 66.43 74.8
# 468 TPSA2 40.5 nan
# 491 Complexity1 335.0 nan
# 491 TPSA1 70.0 nan
# 492 TPSA2 70.0 nan
# 493 Complexity1 335.0 nan
# 493 TPSA1 70.0 nan
# 494 TPSA2 70.0 nan
# 517 XLogP 0.0 8.5
# 517 TPSA 0.0 207.0
# 517 MolWt 0.0 790.7880000000004
# 517 PEOE_VSA7 0.0 119.35429121566287
# 517 PEOE_VSA9 0.0 45.02951794618183
# 517 Kappa2 0.0 14.70022024837367
# 517 BalabanJ 0.0 1.4314020740974527
# 517 MinAbsEStateIndex 0.0 0.1109455295625903
# 517 MinEStateIndex 0.0 -1.0679502809801995
# 517 EState_VSA6 0.0 48.53093654769288
# 517 VSA_EState4 0.0 10.719094091068374
# 517 PEOE_VSA8 0.0 44.320608837253026
# 517 MinPartialCharge 0.0 -0.47763924658960344
# 517 SMR_VSA7 0.0 166.35685931541406
# 517 BCUT2D_CHGLO 0.0 -2.0764612075323403
# 518 XLogP 0.0 8.5
# 518 TPSA 0.0 207.0
# 518 MolWt 0.0 790.7880000000004
# 518 PEOE_VSA7 0.0 119.35429121566287
# 518 PEOE_VSA9 0.0 45.02951794618183
# 518 Kappa2 0.0 14.70022024837367
# 518 BalabanJ 0.0 1.4314020740974527
# 518 MinAbsEStateIndex 0.0 0.1109455295625903
# 518 MinEStateIndex 0.0 -1.0679502809801995
# 518 EState_VSA6 0.0 48.53093654769288
# 518 VSA_EState4 0.0 10.719094091068374
# 518 PEOE_VSA8 0.0 44.320608837253026
# 518 MinPartialCharge 0.0 -0.47763924658960344
# 518 SMR_VSA7 0.0 166.35685931541406
# 518 BCUT2D_CHGLO 0.0 -2.0764612075323403
# 521 TPSA 57.2 65.6
# 522 TPSA 57.2 65.6
# 557 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 557 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 557 Complexity1 0.0 910.0
# 557 TPSA1 883.0 209.0
# 557 MaxEStateIndex.1 11.3319983 11.447015664231106
# 558 TPSA2 883.0 209.0
# 558 MaxEStateIndex.2 11.3319983 11.447015664231106
# ERR PCP not found get_properties heparin
# ERR PCP not found get_compounds heparin
# 579 TPSA 610.49 nan
# 579 MolWt 1134.934 nan
# 579 PEOE_VSA9 13.21376393 nan
# 579 Kappa2 22.78380569 nan
# 579 BalabanJ 1.825883284 nan
# 579 MinAbsEStateIndex 0.840345043 nan
# 579 PEOE_VSA8 6.9237372 nan
# 579 EState_VSA4 6.9237372 nan
# 579 TPSA2 45.1 nan
# 580 TPSA2 49.7 nan
# 581 TPSA2 40.5 nan
# 582 TPSA2 42.8 nan
# 583 TPSA2 42.8 nan
# 584 TPSA2 42.8 nan
# 585 TPSA2 42.8 nan
# 586 TPSA2 45.1 nan
# 587 TPSA2 40.5 nan
# 588 TPSA2 40.5 nan
# 589 TPSA2 40.5 nan
# 590 XLogP 89.10180846 -0.1
# 590 TPSA 21.76 12.5
# 590 MolWt 799.366 44.053
# 590 PEOE_VSA7 195.4079804 0.0
# 590 PEOE_VSA9 25.4216967 13.213763929025836
# 590 VSA_EState8 27.8513811 2.0
# 590 Kappa2 17.5196677 0.20616508400292186
# 590 BalabanJ 1.5e-06 2.25
# 590 MinAbsEStateIndex 0.428298933 1.0
# 590 MinEStateIndex 0.428298933 1.0
# 590 VSA_EState4 5.673973868 0.0
# 590 EState_VSA4 84.22863648 13.213763929025836
# 590 SMR_VSA7 23.29824927 0.0
# 590 BCUT2D_CHGLO -2.590745293 -1.2417647574003587
# 590 TPSA2 40.5 nan
# 591 TPSA2 40.5 nan
# 592 TPSA2 40.5 nan
# 593 TPSA2 40.5 nan
# 594 TPSA2 40.5 nan
# 595 TPSA2 40.5 nan
# ERR PCP not found get_properties MBTH/DMAB
# ERR PCP not found get_compounds MBTH/DMAB
# 596 Complexity1 226.0 nan
# 596 TPSA1 52.0 nan
# 596 TPSA2 45.1 nan
# 597 TPSA2 40.5 nan
# 598 TPSA2 40.5 nan
# 599 TPSA2 40.5 nan
# 600 TPSA2 40.5 nan
# 601 Complexity1 226.0 237.0
# 601 TPSA1 52.0 110.0
# 601 TPSA2 45.1 nan
# 602 TPSA2 42.8 nan
# 603 TPSA2 42.8 nan
# 604 TPSA2 42.8 nan
# 605 TPSA2 42.8 nan
# 606 TPSA2 42.8 nan
# 607 TPSA2 40.5 nan
# 608 TPSA2 40.5 nan
# ERR PCP not found get_properties poly(sodium styrene sulfate)
# ERR PCP not found get_compounds poly(sodium styrene sulfate)
# 611 TPSA 66.43 nan
# 611 MolWt 586.653 nan
# 611 PEOE_VSA7 24.48111484 nan
# 611 PEOE_VSA9 27.68777235 nan
# 611 VSA_EState8 3.625283579 nan
# 611 Kappa2 25.74673621 nan
# 611 EState_VSA6 24.26546827 nan
# 611 VSA_EState4 0.755694444 nan
# 611 EState_VSA4 16.3085628 nan
# 611 SMR_VSA7 42.15736728 nan
# 611 TPSA2 40.5 nan
# 612 TPSA 66.43 nan
# 612 MolWt 586.653 nan
# 612 PEOE_VSA7 24.48111484 nan
# 612 PEOE_VSA9 27.68777235 nan
# 612 VSA_EState8 3.625283579 nan
# 612 Kappa2 25.74673621 nan
# 612 EState_VSA6 24.26546827 nan
# 612 VSA_EState4 0.755694444 nan
# 612 EState_VSA4 16.3085628 nan
# 612 SMR_VSA7 42.15736728 nan
# 612 TPSA2 40.5 nan
# 613 TPSA 66.43 nan
# 613 MolWt 586.653 nan
# 613 PEOE_VSA7 24.48111484 nan
# 613 PEOE_VSA9 27.68777235 nan
# 613 VSA_EState8 3.625283579 nan
# 613 Kappa2 25.74673621 nan
# 613 EState_VSA6 24.26546827 nan
# 613 VSA_EState4 0.755694444 nan
# 613 EState_VSA4 16.3085628 nan
# 613 SMR_VSA7 42.15736728 nan
# 614 TPSA 66.43 nan
# 614 MolWt 586.653 nan
# 614 PEOE_VSA7 24.48111484 nan
# 614 PEOE_VSA9 27.68777235 nan
# 614 VSA_EState8 3.625283579 nan
# 614 Kappa2 25.74673621 nan
# 614 EState_VSA6 24.26546827 nan
# 614 VSA_EState4 0.755694444 nan
# 614 EState_VSA4 16.3085628 nan
# 614 SMR_VSA7 42.15736728 nan
# 615 TPSA2 40.5 nan
# 618 TPSA2 49.7 nan
# 619 TPSA2 40.5 nan
# 620 TPSA2 49.7 nan
# 621 Complexity1 164.8 209.0
# 621 TPSA1 51.44 104.0
# 621 TPSA2 47.4 nan
# 622 TPSA2 49.7 nan
# 623 TPSA2 40.5 nan
# 624 TPSA2 52.0 nan
# 626 TPSA2 45.1 nan
# 627 TPSA2 42.8 nan
# 628 TPSA2 42.8 nan
# 629 TPSA2 42.8 nan
# 630 TPSA2 40.5 nan
# 634 TPSA2 45.1 nan
# 635 TPSA2 40.5 nan
# 638 TPSA2 40.5 nan
# 639 TPSA2 40.5 nan
# 640 TPSA2 52.0 74.6
# 641 TPSA2 52.0 74.6
# 642 TPSA2 52.0 74.6
# 646 TPSA2 47.4 28.8
# 647 TPSA 477.88 nan
# 647 MolWt 1152.384 nan
# 647 PEOE_VSA7 112.9204435 nan
# 647 PEOE_VSA9 37.5740477 nan
# 647 VSA_EState8 7.307812377 nan
# 647 Kappa2 37.83266664 nan
# 647 BalabanJ 3.312274144 nan
# 647 EState_VSA6 27.6949488 nan
# 647 VSA_EState4 23.25038458 nan
# 647 EState_VSA4 6.9237372 nan
# 647 SMR_VSA7 29.82891977 nan
# 647 TPSA2 45.1 64.3
# 648 TPSA2 52.0 nan
# 649 TPSA2 52.0 28.8
# 650 TPSA2 52.0 28.8
# 651 TPSA2 52.0 nan
# 672 TPSA2 49.7 nan
# ERR PCP not found get_properties Cetrimonium bromide, sodium laurate
# ERR PCP not found get_compounds Cetrimonium bromide, sodium laurate
# 687 TPSA 40.13 nan
# 687 MolWt 586.76 nan
# 687 PEOE_VSA7 25.68328649 nan
# 687 PEOE_VSA9 27.68777235 nan
# 687 VSA_EState8 5.847442893 nan
# 687 Kappa2 35.91 nan
# 687 PEOE_VSA8 5.969305288 nan
# 687 EState_VSA4 17.3246741 nan
# 688 TPSA 40.13 nan
# 688 MolWt 586.76 nan
# 688 PEOE_VSA7 25.68328649 nan
# 688 PEOE_VSA9 27.68777235 nan
# 688 VSA_EState8 5.847442893 nan
# 688 Kappa2 35.91 nan
# 688 PEOE_VSA8 5.969305288 nan
# 688 EState_VSA4 17.3246741 nan
# 709 Complexity1 12.4 232.0
# 709 TPSA1 42.8 107.0
# 709 TPSA2 49.7 nan
# 713 TPSA2 40.5 nan
# 714 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 714 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 714 Complexity1 0.0 910.0
# 714 TPSA1 883.0 209.0
# 714 MaxEStateIndex.1 11.3319983 11.447015664231106
# 714 TPSA2 40.5 nan
# 718 TPSA2 40.5 nan
# 725 TPSA 0.0 21.6
# 725 MolWt 0.0 203.434
# 725 PEOE_VSA7 0.0 39.28206812208652
# 725 VSA_EState8 0.0 15.136342592592591
# 725 Kappa2 0.0 3.742918213444276
# 725 BalabanJ 0.0 4.226502749346147
# 725 MinAbsEStateIndex 0.0 0.8827160493827162
# 725 MinEStateIndex 0.0 -1.4286265432098764
# 725 PEOE_VSA8 0.0 6.923737199690624
# 725 MinPartialCharge 0.0 -0.5353855627947162
# 725 EState_VSA4 0.0 5.897745344357611
# 725 BCUT2D_CHGLO 0.0 -2.2050484272533053
# 726 TPSA 0.0 21.6
# 726 MolWt 0.0 203.434
# 726 PEOE_VSA7 0.0 39.28206812208652
# 726 VSA_EState8 0.0 15.136342592592591
# 726 Kappa2 0.0 3.742918213444276
# 726 BalabanJ 0.0 4.226502749346147
# 726 MinAbsEStateIndex 0.0 0.8827160493827162
# 726 MinEStateIndex 0.0 -1.4286265432098764
# 726 PEOE_VSA8 0.0 6.923737199690624
# 726 MinPartialCharge 0.0 -0.5353855627947162
# 726 EState_VSA4 0.0 5.897745344357611
# 726 BCUT2D_CHGLO 0.0 -2.2050484272533053
# 747 TPSA 1154.41 1151.0
# 747 TPSA2 42.8 nan
# 750 TPSA2 40.5 nan
# 751 TPSA2 40.5 nan
# 752 TPSA2 40.5 nan
# 753 TPSA2 40.5 nan
# 758 TPSA2 40.5 nan
# 759 TPSA2 45.1 nan
# 760 TPSA2 40.5 nan
# 761 TPSA2 40.5 nan
# 765 TPSA2 40.5 nan
# 766 TPSA2 40.5 nan
# 767 TPSA2 40.5 nan
# 768 TPSA2 40.5 nan
# 769 TPSA2 40.5 nan
# ERR PCP not found get_properties keratin
# ERR PCP not found get_compounds keratin
# 780 TPSA 37.3 nan
# 780 MolWt 173.393 nan
# 780 Kappa2 2.419322814 nan
# 780 BalabanJ 3.257586161 nan
# 780 MinAbsEStateIndex 0.946759259 nan
# 781 TPSA 37.3 nan
# 781 MolWt 173.393 nan
# 781 Kappa2 2.419322814 nan
# 781 BalabanJ 3.257586161 nan
# 781 MinAbsEStateIndex 0.946759259 nan
# 782 TPSA 394.18 282.0
# 783 TPSA 394.18 282.0
# 786 TPSA 128.58 102.0
# 786 MolWt 616.499 651.9520000000003
# 786 Kappa2 12.41439833 13.638911634144643
# 786 MinPartialCharge -0.657364533 -1.0
# 787 TPSA 128.58 102.0
# 787 MolWt 616.499 651.9520000000003
# 787 Kappa2 12.41439833 13.638911634144643
# 787 MinPartialCharge -0.657364533 -1.0
# 792 TPSA 140.62 348.0
# 792 MolWt 258.069 1048.8570000000002
# 792 PEOE_VSA7 0.0 119.35429121566287
# 792 PEOE_VSA9 5.969305288 50.998823234133674
# 792 Kappa2 11.45982806 25.04797187182122
# 792 EState_VSA6 0.0 48.53093654769288
# 792 VSA_EState4 -2.974537037 7.744557054031338
# 792 PEOE_VSA8 24.78025382 69.10086265900874
# 792 SMR_VSA7 0.0 166.35685931541406
# 793 TPSA 140.62 348.0
# 793 MolWt 258.069 1048.8570000000002
# 793 PEOE_VSA7 0.0 119.35429121566287
# 793 PEOE_VSA9 5.969305288 50.998823234133674
# 793 Kappa2 11.45982806 25.04797187182122
# 793 EState_VSA6 0.0 48.53093654769288
# 793 VSA_EState4 -2.974537037 7.744557054031338
# 793 PEOE_VSA8 24.78025382 69.10086265900874
# 793 SMR_VSA7 0.0 166.35685931541406
# 813 TPSA 189.31 12.5
# 813 MolWt 605.81 296.53899999999993
# 813 PEOE_VSA9 31.96645311 13.213763929025836
# 813 VSA_EState8 8.304879772 8.048883378308659
# 813 Kappa2 24.8009289 19.7
# 813 MinAbsEStateIndex 0.598052721 1.0
# 813 MinEStateIndex -2.782531652 1.0
# 813 PEOE_VSA8 13.34455882 0.0
# 813 MinPartialCharge -0.477260862 -0.37666763607345255
# 813 EState_VSA4 20.13750113 13.213763929025836
# 813 BCUT2D_CHGLO -2.441399163 -2.0229710344091805
# 814 TPSA 189.31 12.5
# 814 MolWt 605.81 296.53899999999993
# 814 PEOE_VSA9 31.96645311 13.213763929025836
# 814 VSA_EState8 8.304879772 8.048883378308659
# 814 Kappa2 24.8009289 19.7
# 814 MinAbsEStateIndex 0.598052721 1.0
# 814 MinEStateIndex -2.782531652 1.0
# 814 PEOE_VSA8 13.34455882 0.0
# 814 MinPartialCharge -0.477260862 -0.37666763607345255
# 814 EState_VSA4 20.13750113 13.213763929025836
# 814 BCUT2D_CHGLO -2.441399163 -2.0229710344091805
# 815 TPSA 189.31 12.5
# 815 MolWt 605.81 296.53899999999993
# 815 PEOE_VSA9 31.96645311 13.213763929025836
# 815 VSA_EState8 8.304879772 8.048883378308659
# 815 Kappa2 24.8009289 19.7
# 815 MinAbsEStateIndex 0.598052721 1.0
# 815 MinEStateIndex -2.782531652 1.0
# 815 PEOE_VSA8 13.34455882 0.0
# 815 MinPartialCharge -0.477260862 -0.37666763607345255
# 815 EState_VSA4 20.13750113 13.213763929025836
# 815 BCUT2D_CHGLO -2.441399163 -2.0229710344091805
# 817 TPSA 226.61 49.8
# 817 MolWt 635.792 326.521
# 817 PEOE_VSA9 31.96645311 13.213763929025836
# 817 VSA_EState8 4.514824984 4.258828589684473
# 817 Kappa2 25.10577508 19.21723665564478
# 817 MinEStateIndex -2.782531652 -0.6642338559142937
# 817 PEOE_VSA8 19.76538045 6.4208216229260096
# 817 EState_VSA4 32.97914437 26.055407174877853
# 817 BCUT2D_CHGLO -2.441399186 -1.987595200803079
# 818 TPSA 226.61 49.8
# 818 MolWt 635.792 326.521
# 818 PEOE_VSA9 31.96645311 13.213763929025836
# 818 VSA_EState8 4.514824984 4.258828589684473
# 818 Kappa2 25.10577508 19.21723665564478
# 818 MinEStateIndex -2.782531652 -0.6642338559142937
# 818 PEOE_VSA8 19.76538045 6.4208216229260096
# 818 EState_VSA4 32.97914437 26.055407174877853
# 818 BCUT2D_CHGLO -2.441399186 -1.987595200803079
# 831 TPSA 253.56 141.0
# 832 TPSA 253.56 141.0
# 834 XLogP 0.0 8.5
# 834 TPSA 0.0 207.0
# 834 MolWt 0.0 790.7880000000004
# 834 PEOE_VSA7 0.0 119.35429121566287
# 834 PEOE_VSA9 0.0 45.02951794618183
# 834 Kappa2 0.0 14.70022024837367
# 834 BalabanJ 0.0 1.4314020740974527
# 834 MinAbsEStateIndex 0.0 0.1109455295625903
# 834 MinEStateIndex 0.0 -1.0679502809801995
# 834 EState_VSA6 0.0 48.53093654769288
# 834 VSA_EState4 0.0 10.719094091068374
# 834 PEOE_VSA8 0.0 44.320608837253026
# 834 MinPartialCharge 0.0 -0.47763924658960344
# 834 SMR_VSA7 0.0 166.35685931541406
# 834 BCUT2D_CHGLO 0.0 -2.0764612075323403
# 837 TPSA 253.56 141.0
# 838 TPSA 253.56 141.0
# 845 TPSA 477.88 nan
# 845 MolWt 1152.384 nan
# 845 PEOE_VSA7 112.9204435 nan
# 845 PEOE_VSA9 37.5740477 nan
# 845 VSA_EState8 7.307812377 nan
# 845 Kappa2 37.83266664 nan
# 845 BalabanJ 3.312274144 nan
# 845 EState_VSA6 27.6949488 nan
# 845 VSA_EState4 23.25038458 nan
# 845 EState_VSA4 6.9237372 nan
# 845 SMR_VSA7 29.82891977 nan
# 846 TPSA 477.88 nan
# 846 MolWt 1152.384 nan
# 846 PEOE_VSA7 112.9204435 nan
# 846 PEOE_VSA9 37.5740477 nan
# 846 VSA_EState8 7.307812377 nan
# 846 Kappa2 37.83266664 nan
# 846 BalabanJ 3.312274144 nan
# 846 EState_VSA6 27.6949488 nan
# 846 VSA_EState4 23.25038458 nan
# 846 EState_VSA4 6.9237372 nan
# 846 SMR_VSA7 29.82891977 nan
# ERR PCP not found get_properties Cetrimonium bromide, oleylamine
# ERR PCP not found get_compounds Cetrimonium bromide, oleylamine
# 847 TPSA 63.32 nan
# 847 MolWt 914.425 nan
# 847 PEOE_VSA7 83.59461588 nan
# 847 PEOE_VSA9 27.68777235 nan
# 847 VSA_EState8 9.025129694 nan
# 847 Kappa2 60.439361 nan
# 847 VSA_EState4 5.473640837 nan
# 847 PEOE_VSA8 6.420821623 nan
# 847 EState_VSA4 23.86943051 nan
# 847 SMR_VSA7 24.30408043 nan
# 848 TPSA 63.32 nan
# 848 MolWt 914.425 nan
# 848 PEOE_VSA7 83.59461588 nan
# 848 PEOE_VSA9 27.68777235 nan
# 848 VSA_EState8 9.025129694 nan
# 848 Kappa2 60.439361 nan
# 848 VSA_EState4 5.473640837 nan
# 848 PEOE_VSA8 6.420821623 nan
# 848 EState_VSA4 23.86943051 nan
# 848 SMR_VSA7 24.30408043 nan
# ERR PCP not found get_properties l-ascorbic acid, sodium citrate
# ERR PCP not found get_compounds l-ascorbic acid, sodium citrate
# 849 TPSA 285.14 nan
# 849 MolWt 716.661 nan
# 849 PEOE_VSA7 32.10410811 nan
# 849 PEOE_VSA9 12.57618725 nan
# 849 VSA_EState8 1.587485997 nan
# 849 Kappa2 34.74509195 nan
# 849 PEOE_VSA8 31.20107544 nan
# 849 EState_VSA4 12.84164325 nan
# 849 SMR_VSA7 23.67036996 nan
# 850 TPSA 285.14 nan
# 850 MolWt 716.661 nan
# 850 PEOE_VSA7 32.10410811 nan
# 850 PEOE_VSA9 12.57618725 nan
# 850 VSA_EState8 1.587485997 nan
# 850 Kappa2 34.74509195 nan
# 850 PEOE_VSA8 31.20107544 nan
# 850 EState_VSA4 12.84164325 nan
# 850 SMR_VSA7 23.67036996 nan
# 851 TPSA 285.14 nan
# 851 MolWt 716.661 nan
# 851 PEOE_VSA7 32.10410811 nan
# 851 PEOE_VSA9 12.57618725 nan
# 851 VSA_EState8 1.587485997 nan
# 851 Kappa2 34.74509195 nan
# 851 PEOE_VSA8 31.20107544 nan
# 851 EState_VSA4 12.84164325 nan
# 851 SMR_VSA7 23.67036996 nan
# 852 TPSA 285.14 nan
# 852 MolWt 716.661 nan
# 852 PEOE_VSA7 32.10410811 nan
# 852 PEOE_VSA9 12.57618725 nan
# 852 VSA_EState8 1.587485997 nan
# 852 Kappa2 34.74509195 nan
# 852 PEOE_VSA8 31.20107544 nan
# 852 EState_VSA4 12.84164325 nan
# 852 SMR_VSA7 23.67036996 nan
# 853 TPSA 285.14 nan
# 853 MolWt 716.661 nan
# 853 PEOE_VSA7 32.10410811 nan
# 853 PEOE_VSA9 12.57618725 nan
# 853 VSA_EState8 1.587485997 nan
# 853 Kappa2 34.74509195 nan
# 853 PEOE_VSA8 31.20107544 nan
# 853 EState_VSA4 12.84164325 nan
# 853 SMR_VSA7 23.67036996 nan
# 854 TPSA 285.14 nan
# 854 MolWt 716.661 nan
# 854 PEOE_VSA7 32.10410811 nan
# 854 PEOE_VSA9 12.57618725 nan
# 854 VSA_EState8 1.587485997 nan
# 854 Kappa2 34.74509195 nan
# 854 PEOE_VSA8 31.20107544 nan
# 854 EState_VSA4 12.84164325 nan
# 854 SMR_VSA7 23.67036996 nan
# 879 TPSA2 40.5 nan
# 880 TPSA2 40.5 nan
# 881 TPSA2 42.8 nan
# 882 TPSA2 52.0 nan
# 883 TPSA2 52.0 nan
# 884 TPSA2 52.0 nan
# 885 TPSA2 52.0 nan
# 886 TPSA2 52.0 nan
# 887 TPSA2 52.0 nan
# 896 TPSA2 52.0 nan
# 897 TPSA2 52.0 nan
# 898 TPSA2 52.0 nan
# 899 TPSA2 52.0 nan
# 900 TPSA2 52.0 nan
# 901 TPSA2 52.0 nan
# ERR PCP not found get_properties citric acid, ascorbic acid
# ERR PCP not found get_compounds citric acid, ascorbic acid
# 931 TPSA 259.66 nan
# 931 MolWt 479.391 nan
# 931 PEOE_VSA7 12.62077651 nan
# 931 PEOE_VSA9 19.44852521 nan
# 931 VSA_EState8 3.690277778 nan
# 931 Kappa2 12.99444315 nan
# 931 MinAbsEStateIndex 0.208333333 nan
# 931 EState_VSA6 11.09986462 nan
# 931 PEOE_VSA8 12.96557803 nan
# 931 EState_VSA4 12.96557803 nan
# 931 SMR_VSA7 24.29722032 nan
# 932 TPSA 259.66 nan
# 932 MolWt 479.391 nan
# 932 PEOE_VSA7 12.62077651 nan
# 932 PEOE_VSA9 19.44852521 nan
# 932 VSA_EState8 3.690277778 nan
# 932 Kappa2 12.99444315 nan
# 932 MinAbsEStateIndex 0.208333333 nan
# 932 EState_VSA6 11.09986462 nan
# 932 PEOE_VSA8 12.96557803 nan
# 932 EState_VSA4 12.96557803 nan
# 932 SMR_VSA7 24.29722032 nan
# 933 TPSA 259.66 nan
# 933 MolWt 479.391 nan
# 933 PEOE_VSA7 12.62077651 nan
# 933 PEOE_VSA9 19.44852521 nan
# 933 VSA_EState8 3.690277778 nan
# 933 Kappa2 12.99444315 nan
# 933 MinAbsEStateIndex 0.208333333 nan
# 933 EState_VSA6 11.09986462 nan
# 933 PEOE_VSA8 12.96557803 nan
# 933 EState_VSA4 12.96557803 nan
# 933 SMR_VSA7 24.29722032 nan
# 934 TPSA 259.66 nan
# 934 MolWt 479.391 nan
# 934 PEOE_VSA7 12.62077651 nan
# 934 PEOE_VSA9 19.44852521 nan
# 934 VSA_EState8 3.690277778 nan
# 934 Kappa2 12.99444315 nan
# 934 MinAbsEStateIndex 0.208333333 nan
# 934 EState_VSA6 11.09986462 nan
# 934 PEOE_VSA8 12.96557803 nan
# 934 EState_VSA4 12.96557803 nan
# 934 SMR_VSA7 24.29722032 nan
# 935 TPSA 259.66 nan
# 935 MolWt 479.391 nan
# 935 PEOE_VSA7 12.62077651 nan
# 935 PEOE_VSA9 19.44852521 nan
# 935 VSA_EState8 3.690277778 nan
# 935 Kappa2 12.99444315 nan
# 935 MinAbsEStateIndex 0.208333333 nan
# 935 EState_VSA6 11.09986462 nan
# 935 PEOE_VSA8 12.96557803 nan
# 935 EState_VSA4 12.96557803 nan
# 935 SMR_VSA7 24.29722032 nan
# 936 TPSA 259.66 nan
# 936 MolWt 479.391 nan
# 936 PEOE_VSA7 12.62077651 nan
# 936 PEOE_VSA9 19.44852521 nan
# 936 VSA_EState8 3.690277778 nan
# 936 Kappa2 12.99444315 nan
# 936 MinAbsEStateIndex 0.208333333 nan
# 936 EState_VSA6 11.09986462 nan
# 936 PEOE_VSA8 12.96557803 nan
# 936 EState_VSA4 12.96557803 nan
# 936 SMR_VSA7 24.29722032 nan
# 939 TPSA2 64.4 nan
# 940 TPSA2 64.4 nan
# 946 TPSA2 40.5 nan
# 947 TPSA2 40.5 nan
# 948 TPSA2 40.5 nan
# 955 TPSA2 45.1 nan
# 958 TPSA2 40.5 nan
# 961 TPSA 20.31 132.3
# 961 MolWt 111.144 321.28500000000014
# 961 PEOE_VSA7 12.62077651 30.81987771813129
# 961 PEOE_VSA9 0.0 16.690354475090988
# 961 Kappa2 1.987228406 7.736279231074118
# 961 BalabanJ 2.536681979 2.769583235484909e-07
# 961 MinEStateIndex 0.208333333 -1.3744444444444441
# 961 VSA_EState4 0.0 -1.104722222222222
# 961 MinPartialCharge -0.319671229 -0.4776386873038457
# 961 EState_VSA4 12.96557803 31.164679234223417
# 961 SMR_VSA7 12.77889057 47.66834625389476
# 961 TPSA2 45.1 nan
# 962 TPSA2 45.1 nan
# 963 TPSA2 40.5 nan
# 964 TPSA2 40.5 nan
# 965 TPSA2 40.5 nan
# 966 TPSA2 40.5 nan
# 967 TPSA2 40.5 nan
# 968 TPSA2 40.5 nan
# 973 TPSA2 40.5 nan
# 981 TPSA2 40.5 nan
# 982 TPSA2 40.5 nan
# 987 TPSA2 42.8 nan
# 988 TPSA 86.74 95.1
# 988 TPSA 86.74 95.1
# 988 MinPartialCharge.1 -0.39829863 -0.254557430614467
# 988 MaxPartialCharge.1 0.037337328 -0.254557430614467
# 988 Complexity1 226.0 nan
# 988 TPSA1 52.0 40.5
# 988 TPSA2 40.5 52.0
# 990 TPSA 146.05 119.5
# 990 MolWt 320.294 220.177
# 990 PEOE_VSA7 6.9237372 0.0
# 990 PEOE_VSA9 26.93044343 19.820645893538753
# 990 VSA_EState8 6.283009259 1.3286574074074071
# 990 Kappa2 9.767179562 4.964460295417243
# 990 MinAbsEStateIndex 0.347222222 0.6713425925925929
# 990 EState_VSA6 6.9237372 0.0
# 990 VSA_EState4 0.43287037 0.0
# 990 PEOE_VSA8 5.57310453 0.0
# 990 SMR_VSA7 23.67036996 11.518329743312352
# 991 TPSA 146.05 119.5
# 991 MolWt 320.294 220.177
# 991 PEOE_VSA7 6.9237372 0.0
# 991 PEOE_VSA9 26.93044343 19.820645893538753
# 991 VSA_EState8 6.283009259 1.3286574074074071
# 991 Kappa2 9.767179562 4.964460295417243
# 991 MinAbsEStateIndex 0.347222222 0.6713425925925929
# 991 EState_VSA6 6.9237372 0.0
# 991 VSA_EState4 0.43287037 0.0
# 991 PEOE_VSA8 5.57310453 0.0
# 991 SMR_VSA7 23.67036996 11.518329743312352
# 992 TPSA 146.05 119.5
# 992 MolWt 320.294 220.177
# 992 PEOE_VSA7 6.9237372 0.0
# 992 PEOE_VSA9 26.93044343 19.820645893538753
# 992 VSA_EState8 6.283009259 1.3286574074074071
# 992 Kappa2 9.767179562 4.964460295417243
# 992 MinAbsEStateIndex 0.347222222 0.6713425925925929
# 992 EState_VSA6 6.9237372 0.0
# 992 VSA_EState4 0.43287037 0.0
# 992 PEOE_VSA8 5.57310453 0.0
# 992 SMR_VSA7 23.67036996 11.518329743312352
# ERR PCP not found get_properties Cetrimonium bromide, ascorbic acid
# ERR PCP not found get_compounds Cetrimonium bromide, ascorbic acid
# 993 TPSA 107.22 nan
# 993 MolWt 540.58 nan
# 993 PEOE_VSA7 12.84164325 nan
# 993 PEOE_VSA9 34.29465432 nan
# 993 VSA_EState8 2.953940986 nan
# 993 Kappa2 20.53535904 nan
# 993 EState_VSA4 4.483030858 nan
# 993 SMR_VSA7 11.51832974 nan
# 994 TPSA 107.22 nan
# 994 MolWt 540.58 nan
# 994 PEOE_VSA7 12.84164325 nan
# 994 PEOE_VSA9 34.29465432 nan
# 994 VSA_EState8 2.953940986 nan
# 994 Kappa2 20.53535904 nan
# 994 EState_VSA4 4.483030858 nan
# 994 SMR_VSA7 11.51832974 nan
# 995 TPSA 107.22 nan
# 995 MolWt 540.58 nan
# 995 PEOE_VSA7 12.84164325 nan
# 995 PEOE_VSA9 34.29465432 nan
# 995 VSA_EState8 2.953940986 nan
# 995 Kappa2 20.53535904 nan
# 995 EState_VSA4 4.483030858 nan
# 995 SMR_VSA7 11.51832974 nan
# ERR PCP not found get_properties Cetrimonium bromide, ascorbic acid
# ERR PCP not found get_compounds Cetrimonium bromide, ascorbic acid
# 996 TPSA 164.42 nan
# 996 MolWt 746.778 nan
# 996 PEOE_VSA7 30.53782887 nan
# 996 PEOE_VSA9 39.19013779 nan
# 996 VSA_EState8 6.449143178 nan
# 996 Kappa2 27.93580271 nan
# 996 EState_VSA6 6.076020107 nan
# 996 VSA_EState4 0.78 nan
# 996 EState_VSA4 10.04648235 nan
# 996 SMR_VSA7 47.92618519 nan
# ERR PCP not found get_properties Cetrimonium bromide, ascorbic acid
# ERR PCP not found get_compounds Cetrimonium bromide, ascorbic acid
# ERR PCP not found get_properties Cetrimonium bromide, ascorbic acid
# ERR PCP not found get_compounds Cetrimonium bromide, ascorbic acid
# 998 TPSA 164.42 nan
# 998 MolWt 746.778 nan
# 998 PEOE_VSA7 30.53782887 nan
# 998 PEOE_VSA9 39.19013779 nan
# 998 VSA_EState8 6.449143178 nan
# 998 Kappa2 27.93580271 nan
# 998 EState_VSA6 6.076020107 nan
# 998 VSA_EState4 0.78 nan
# 998 EState_VSA4 10.04648235 nan
# 998 SMR_VSA7 47.92618519 nan
# 998 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 998 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 998 Complexity1 0.0 910.0
# 998 TPSA1 883.0 209.0
# 998 MaxEStateIndex.1 11.3319983 11.447015664231106
# 999 TPSA 107.22 nan
# 999 MolWt 702.256 nan
# 999 PEOE_VSA7 24.99368346 nan
# 999 PEOE_VSA9 61.4795111 nan
# 999 VSA_EState8 12.32227432 nan
# 999 Kappa2 29.60216084 nan
# 999 EState_VSA4 22.05557453 nan
# 999 SMR_VSA7 36.82824132 nan
# 999 MinPartialCharge.1 -0.744035145 -0.34392573610777344
# 999 MaxPartialCharge.1 0.211204803 0.29406472784425514
# 999 Complexity1 0.0 910.0
# 999 TPSA1 883.0 209.0
# 999 MaxEStateIndex.1 11.3319983 11.447015664231106
# 710

# %% [markdown]
# ### apply to my data

# %%
new_rows = []
for row in tqdm(df.iloc, total=len(df)):
    new_rows.append(get_row_descriptors(row, ['pol', 'surf']))
new_df = pd.DataFrame(new_rows)
# Out:
#   0%|          | 0/9045 [00:00<?, ?it/s]
# ERR PCP not found get_properties LDCF
# ERR PCP not found get_compounds LDCF
# ERR PCP not found get_properties MR
# ERR PCP not found get_compounds MR
# ERR PCP not found get_properties β-cyclodextrin
# ERR PCP not found get_compounds β-cyclodextrin
# ERR PCP not found get_properties O2•−
# ERR PCP not found get_compounds O2•−
# ERR PCP not found get_properties TCP
# ERR PCP not found get_compounds TCP
# ERR PCP not found get_properties Protamine
# ERR PCP not found get_compounds Protamine
# ERR PCP not found get_properties o-MP
# ERR PCP not found get_compounds o-MP
# ERR PCP not found get_properties Chitin
# ERR PCP not found get_compounds Chitin
# ERR PCP not found get_properties NaI
# ERR PCP not found get_compounds NaI
# ERR PCP not found get_properties substrate
# ERR PCP not found get_compounds substrate
# ERR PCP not found get_properties gelatin
# ERR PCP not found get_compounds gelatin
# ERR PCP not found get_properties Nylon
# ERR PCP not found get_compounds Nylon
# ERR PCP not found get_properties DTTred
# ERR PCP not found get_compounds DTTred
# ERR PCP not found get_properties 1-chloro-2.4-dinitro-benzene
# ERR PCP not found get_compounds 1-chloro-2.4-dinitro-benzene
# ERR PCP not found get_properties Poly(thienylethyloxy butylsulfonate)
# ERR PCP not found get_compounds Poly(thienylethyloxy butylsulfonate)
# ERR PCP not found get_properties Poly(amidoamine)
# ERR PCP not found get_compounds Poly(amidoamine)
# ERR PCP not found get_properties Poly(styrene-co-acrolein)
# ERR PCP not found get_compounds Poly(styrene-co-acrolein)
# ERR PCP not found get_properties Polyadenine
# ERR PCP not found get_compounds Polyadenine
# A lot of elements in reaction:  id O2^- + O2^- + 2H+ -> H2O2 + O2 ['O2^-', 'O2^-', '2H', '-> H2O2', 'O2']
# A lot of elements in reaction:  id O2^- + O2^- + 2H+ -> H2O2 + O2 ['O2^-', 'O2^-', '2H', '-> H2O2', 'O2']
# A lot of elements in reaction:  id O2^- + O2^- + 2H+ -> H2O2 + O2 ['O2^-', 'O2^-', '2H', '-> H2O2', 'O2']
# A lot of elements in reaction:  id O2^- + O2^- + 2H+ -> H2O2 + O2 ['O2^-', 'O2^-', '2H', '-> H2O2', 'O2']
# A lot of elements in reaction:  id O2^- + O2^- + 2H+ -> H2O2 + O2 ['O2^-', 'O2^-', '2H', '-> H2O2', 'O2']
# A lot of elements in reaction:  id O2^- + O2^- + 2H+ -> H2O2 + O2 ['O2^-', 'O2^-', '2H', '-> H2O2', 'O2']
# A lot of elements in reaction:  id O2^- + O2^- + 2H+ -> H2O2 + O2 ['O2^-', 'O2^-', '2H', '-> H2O2', 'O2']
# ERR PCP not found get_properties MBTH/o-phenylenediamine
# ERR PCP not found get_compounds MBTH/o-phenylenediamine
# ERR PCP not found get_properties MP
# ERR PCP not found get_compounds MP
# ERR PCP not found get_properties coumaric acid
# ERR PCP not found get_compounds coumaric acid
# ERR PCP not found get_properties 4-MN
# ERR PCP not found get_compounds 4-MN
# A lot of elements in reaction:  id Ag+ + TMB+H2O2 ['Ag', 'TMB', 'H2O2']
# ERR PCP not found get_properties poly(styrene sulfonate)
# ERR PCP not found get_compounds poly(styrene sulfonate)
# ERR PCP not found get_properties hyaluronic acid
# ERR PCP not found get_compounds hyaluronic acid
# ERR PCP not found get_properties NMBA
# ERR PCP not found get_compounds NMBA
# ERR PCP not found get_properties phosphatidylcholine hydroperoxide
# ERR PCP not found get_compounds phosphatidylcholine hydroperoxide
# ERR PCP not found get_properties Choline dioctylsulfosuccinate
# ERR PCP not found get_compounds Choline dioctylsulfosuccinate
# ERR PCP not found get_properties Polypyrrole
# ERR PCP not found get_compounds Polypyrrole
# ERR PCP not found get_properties Poly-L-lysine
# ERR PCP not found get_compounds Poly-L-lysine
# ERR PCP not found get_properties p-HPPA
# ERR PCP not found get_compounds p-HPPA
# ERR PCP not found get_properties DA
# ERR PCP not found get_compounds DA
# ERR PCP not found get_properties Poly(methacrylic acid-co-ethylene glycol dimethacrylate)
# ERR PCP not found get_compounds Poly(methacrylic acid-co-ethylene glycol dimethacrylate)
# ERR PCP not found get_properties Poly(allyloxyethylcyanoacrylate)
# ERR PCP not found get_compounds Poly(allyloxyethylcyanoacrylate)
# ERR PCP not found get_properties FMA
# ERR PCP not found get_compounds FMA
# ERR PCP not found get_properties O2−
# ERR PCP not found get_compounds O2−
# ERR PCP not found get_properties ArS3
# ERR PCP not found get_compounds ArS3
# ERR PCP not found get_properties CuOOH
# ERR PCP not found get_compounds CuOOH
# ERR PCP not found get_properties SOD assay
# ERR PCP not found get_compounds SOD assay
# ERR PCP not found get_properties MB
# ERR PCP not found get_compounds MB
# ERR PCP not found get_properties Citrus polysaccharide
# ERR PCP not found get_compounds Citrus polysaccharide
# ERR PCP not found get_properties a-keto-γ-methylthiobutyrate
# ERR PCP not found get_compounds a-keto-γ-methylthiobutyrate
# ERR PCP not found get_properties p-NPP
# ERR PCP not found get_compounds p-NPP
# ERR PCP not found get_properties PBZ
# ERR PCP not found get_compounds PBZ
# ERR PCP not found get_properties Amplex Ultra Red
# ERR PCP not found get_compounds Amplex Ultra Red
# ERR PCP not found get_properties Nafion
# ERR PCP not found get_compounds Nafion
# A lot of elements in reaction:  id H2O2 + a-naphthol + p-phenylenediamine ['H2O2', 'a-naphthol', 'p-phenylenediamine']
# ERR PCP not found get_properties Gum olibanum
# ERR PCP not found get_compounds Gum olibanum
# ERR PCP not found get_properties 4-methoxy-a-naphtol
# ERR PCP not found get_compounds 4-methoxy-a-naphtol
# ERR PCP not found get_properties KO2
# ERR PCP not found get_compounds KO2
# ERR PCP not found get_properties acetylated ferricytochrome c
# ERR PCP not found get_compounds acetylated ferricytochrome c
# ERR PCP not found get_properties 4-chloro-naphthol
# ERR PCP not found get_compounds 4-chloro-naphthol
# ERR PCP not found get_properties BHPx
# ERR PCP not found get_compounds BHPx
# ERR PCP not found get_properties PC-OOH
# ERR PCP not found get_compounds PC-OOH
# ERR PCP not found get_properties Gellan gum
# ERR PCP not found get_compounds Gellan gum
# ERR PCP not found get_properties BTC
# ERR PCP not found get_compounds BTC
# ERR PCP not found get_properties Tween 80
# ERR PCP not found get_compounds Tween 80
# ERR PCP not found get_properties Mn2
# ERR PCP not found get_compounds Mn2
# ERR PCP not found get_properties ChEO 15
# ERR PCP not found get_compounds ChEO 15
# ERR PCP not found get_properties O2-
# ERR PCP not found get_compounds O2-
# ERR PCP not found get_properties phenol red dye
# ERR PCP not found get_compounds phenol red dye
# ERR PCP not found get_properties HPNP
# ERR PCP not found get_compounds HPNP
# ERR PCP not found get_properties CUOOH
# ERR PCP not found get_compounds CUOOH
# ERR PCP not found get_properties tetrabutylhydroperoxide
# ERR PCP not found get_compounds tetrabutylhydroperoxide
# ERR PCP not found get_properties TMP
# ERR PCP not found get_compounds TMP
# ERR PCP not found get_properties 5-NG
# ERR PCP not found get_compounds 5-NG
# ERR PCP not found get_properties CMN
# ERR PCP not found get_compounds CMN
# ERR PCP not found get_properties phenol/AAP
# ERR PCP not found get_compounds phenol/AAP
# ERR PCP not found get_properties T[SH]2
# ERR PCP not found get_compounds T[SH]2
# ERR PCP not found get_properties O2•-
# ERR PCP not found get_compounds O2•-
# ERR PCP not found get_properties Sodium bis(2-ethylhexyl)sulfosuccinate
# ERR PCP not found get_compounds Sodium bis(2-ethylhexyl)sulfosuccinate
# ERR PCP not found get_properties PDMS-block-PMOXA
# ERR PCP not found get_compounds PDMS-block-PMOXA
# ERR PCP not found get_properties Beta-casein
# ERR PCP not found get_compounds Beta-casein
# ERR PCP not found get_properties Tween 80
# ERR PCP not found get_compounds Tween 80
# ERR PCP not found get_properties chloromethylated polystyrene
# ERR PCP not found get_compounds chloromethylated polystyrene
# ERR PCP not found get_properties poly(styrene sulfonate)
# ERR PCP not found get_compounds poly(styrene sulfonate)
# ERR PCP not found get_properties Phosphatidyl choline hydroperoxides
# ERR PCP not found get_compounds Phosphatidyl choline hydroperoxides
# ERR PCP not found get_properties Polypyrrole
# ERR PCP not found get_compounds Polypyrrole
# ERR PCP not found get_properties orto-dianizidine
# ERR PCP not found get_compounds orto-dianizidine
# ERR PCP not found get_properties hTrx
# ERR PCP not found get_compounds hTrx
# ERR PCP not found get_properties ONOOH
# ERR PCP not found get_compounds ONOOH
# ERR PCP not found get_properties electron donor dye
# ERR PCP not found get_compounds electron donor dye
# ERR PCP not found get_properties 0-dianisidine
# ERR PCP not found get_compounds 0-dianisidine
# ERR PCP not found get_properties PPD
# ERR PCP not found get_compounds PPD
# ERR PCP not found get_properties PG
# ERR PCP not found get_compounds PG
# ERR PCP not found get_properties HDMB-butanolide
# ERR PCP not found get_compounds HDMB-butanolide
# ERR PCP not found get_properties Hanker and Yate's reagent
# ERR PCP not found get_compounds Hanker and Yate's reagent
# ERR PCP not found get_properties r-coumaric acid
# ERR PCP not found get_compounds r-coumaric acid
# ERR PCP not found get_properties oxidized glutathione
# ERR PCP not found get_compounds oxidized glutathione
# ERR PCP not found get_properties pirogalol
# ERR PCP not found get_compounds pirogalol
# ERR PCP not found get_properties TMPD
# ERR PCP not found get_compounds TMPD
# ERR PCP not found get_properties Polyvinylpyrrolidone
# ERR PCP not found get_compounds Polyvinylpyrrolidone
# ERR PCP not found get_properties carbobenzoxy-Ile-Glu-Gly-Arg p-nitroanilide
# ERR PCP not found get_compounds carbobenzoxy-Ile-Glu-Gly-Arg p-nitroanilide
# ERR PCP not found get_properties t-butyloxycarbonyl-Ile-Glu-Gly-Arg methylcoumarinamide
# ERR PCP not found get_compounds t-butyloxycarbonyl-Ile-Glu-Gly-Arg methylcoumarinamide
# ERR PCP not found get_properties DNA
# ERR PCP not found get_compounds DNA
# ERR PCP not found get_properties PDHB
# ERR PCP not found get_compounds PDHB
# ERR PCP not found get_properties SucB
# ERR PCP not found get_compounds SucB
# ERR PCP not found get_properties ferrocyt c
# ERR PCP not found get_compounds ferrocyt c
# ERR PCP not found get_properties Polyethylenimine
# ERR PCP not found get_compounds Polyethylenimine
# ERR PCP not found get_properties PLPC-OOH
# ERR PCP not found get_compounds PLPC-OOH
# ERR PCP not found get_properties Polythymine
# ERR PCP not found get_compounds Polythymine
# ERR PCP not found get_properties Calcium alginate-pectin
# ERR PCP not found get_compounds Calcium alginate-pectin
# ERR PCP not found get_properties phospholipid hydroperoxide
# ERR PCP not found get_compounds phospholipid hydroperoxide
# ERR PCP not found get_properties Trx3p
# ERR PCP not found get_compounds Trx3p
# ERR PCP not found get_properties HPNPP
# ERR PCP not found get_compounds HPNPP
# ERR PCP not found get_properties cis-2
# ERR PCP not found get_compounds cis-2
# ERR PCP not found get_properties trans-2
# ERR PCP not found get_compounds trans-2
# ERR PCP not found get_properties Chl a
# ERR PCP not found get_compounds Chl a
# ERR PCP not found get_properties PEG-block-poly(aspartate diethyltriamine)
# ERR PCP not found get_compounds PEG-block-poly(aspartate diethyltriamine)
# A lot of elements in reaction:  id H2O2 + phenol + 4-aminoantipyrine ['H2O2', 'phenol', '4-aminoantipyrine']
# ERR PCP not found get_properties Ferrocytochrome c
# ERR PCP not found get_compounds Ferrocytochrome c
# ERR PCP not found get_properties Cytc
# ERR PCP not found get_compounds Cytc
# ERR PCP not found get_properties ABTS2−
# ERR PCP not found get_compounds ABTS2−
# ERR PCP not found get_properties O 2•−
# ERR PCP not found get_compounds O 2•−
# ERR PCP not found get_properties UO22
# ERR PCP not found get_compounds UO22
# ERR PCP not found get_properties DSPE-PEG
# ERR PCP not found get_compounds DSPE-PEG
# ERR PCP not found get_properties DMOP
# ERR PCP not found get_compounds DMOP
# ERR PCP not found get_properties p-HPA
# ERR PCP not found get_compounds p-HPA
# ERR PCP not found get_properties 13-S-HPODE
# ERR PCP not found get_compounds 13-S-HPODE
# ERR PCP not found get_properties 5-S-HPETE
# ERR PCP not found get_compounds 5-S-HPETE
# ERR PCP not found get_properties 15-S-HPETE
# ERR PCP not found get_compounds 15-S-HPETE
# ERR PCP not found get_properties DPPH
# ERR PCP not found get_compounds DPPH
# ERR PCP not found get_properties dna
# ERR PCP not found get_compounds dna
# ERR PCP not found get_properties O2^-
# ERR PCP not found get_compounds O2^-
# ERR PCP not found get_properties AY 42
# ERR PCP not found get_compounds AY 42
# ERR PCP not found get_properties Py
# ERR PCP not found get_compounds Py
# ERR PCP not found get_properties DMB
# ERR PCP not found get_compounds DMB
# ERR PCP not found get_properties Ionic liquid
# ERR PCP not found get_compounds Ionic liquid
# ERR PCP not found get_properties resorufin-β-D-glucuronide
# ERR PCP not found get_compounds resorufin-β-D-glucuronide
# ERR PCP not found get_properties salicylic acid acyl glucuronide
# ERR PCP not found get_compounds salicylic acid acyl glucuronide
# ERR PCP not found get_properties ciprofloxacin glucuronide
# ERR PCP not found get_compounds ciprofloxacin glucuronide
# ERR PCP not found get_properties 3-Amino-9-ethyl-carbazol
# ERR PCP not found get_compounds 3-Amino-9-ethyl-carbazol
# ERR PCP not found get_properties t-BOOH
# ERR PCP not found get_compounds t-BOOH
# A lot of elements in reaction:  id {'TMB+H2O2': 'TMB + H2O2', 'H2O2+TMB': 'H2O2 + TMB'} ["{'TMB", "H2O2': 'TMB", "H2O2', 'H2O2", "TMB': 'H2O2", "TMB'}"]
# ERR PCP not found get_properties Sodium dodecyl sulfate / Dodecyltrimethylammonium bromide
# ERR PCP not found get_compounds Sodium dodecyl sulfate / Dodecyltrimethylammonium bromide
# ERR PCP not found get_properties pVIII
# ERR PCP not found get_compounds pVIII
# ERR PCP not found get_properties a-napthyl acetate
# ERR PCP not found get_compounds a-napthyl acetate
# ERR PCP not found get_properties LOOA
# ERR PCP not found get_compounds LOOA
# ERR PCP not found get_properties Trx
# ERR PCP not found get_compounds Trx
# A lot of elements in reaction:  id phenol + 4-AAP + H2O2 ['phenol', '4-AAP', 'H2O2']
# ERR PCP not found get_properties ArSH
# ERR PCP not found get_compounds ArSH
# ERR PCP not found get_properties C18-PEG
# ERR PCP not found get_compounds C18-PEG
# ERR PCP not found get_properties tert. butyl hydroperoxide
# ERR PCP not found get_compounds tert. butyl hydroperoxide
# ERR PCP not found get_properties DPD
# ERR PCP not found get_compounds DPD
# ERR PCP not found get_properties BuOOH
# ERR PCP not found get_compounds BuOOH
# A lot of elements in reaction:  id {'TMB+H2O2': 'TMB+H2O2', 'H2O2+TMB': 'H2O2+TMB'} ["{'TMB", "H2O2': 'TMB", "H2O2', 'H2O2", "TMB': 'H2O2", "TMB'}"]
# ERR PCP not found get_properties p-NP
# ERR PCP not found get_compounds p-NP
# ERR PCP not found get_properties DNDPC
# ERR PCP not found get_compounds DNDPC
# ERR PCP not found get_properties LPO
# ERR PCP not found get_compounds LPO
# ERR PCP not found get_properties LAOOH
# ERR PCP not found get_compounds LAOOH
# ERR PCP not found get_properties Polydispersity index
# ERR PCP not found get_compounds Polydispersity index
# ERR PCP not found get_properties Triton CF-54
# ERR PCP not found get_compounds Triton CF-54
# ERR PCP not found get_properties Silk fibroin
# ERR PCP not found get_compounds Silk fibroin
# ERR PCP not found get_properties o-PD
# ERR PCP not found get_compounds o-PD
# ERR PCP not found get_properties Gum kondagogu
# ERR PCP not found get_compounds Gum kondagogu
# ERR PCP not found get_properties Phosphorylated PEG
# ERR PCP not found get_compounds Phosphorylated PEG
# ERR PCP not found get_properties Hyperbranched polyglycidol
# ERR PCP not found get_compounds Hyperbranched polyglycidol
# ERR PCP not found get_properties co-substrates
# ERR PCP not found get_compounds co-substrates
# A lot of elements in reaction:  id 4-AAP + PSA + H2O2 ['4-AAP', 'PSA', 'H2O2']
# A lot of elements in reaction:  id H2O2+DMAB+MBTH ['H2O2', 'DMAB', 'MBTH']
# A lot of elements in reaction:  id H2O2+DMAB+MBTH ['H2O2', 'DMAB', 'MBTH']
# ERR PCP not found get_properties ARS
# ERR PCP not found get_compounds ARS
# ERR PCP not found get_properties 4-amino antipyrine
# ERR PCP not found get_compounds 4-amino antipyrine
# ERR PCP not found get_properties Cationic cellulose nanofibrils
# ERR PCP not found get_compounds Cationic cellulose nanofibrils
# ERR PCP not found get_properties p-nitrophenyl-β-D-glucuronide
# ERR PCP not found get_compounds p-nitrophenyl-β-D-glucuronide
# ERR PCP not found get_properties HPF
# ERR PCP not found get_compounds HPF
# ERR PCP not found get_properties poly(styrene sulfonate)
# ERR PCP not found get_compounds poly(styrene sulfonate)
# ERR PCP not found get_properties polyvinylpoly-pyrolidone
# ERR PCP not found get_compounds polyvinylpoly-pyrolidone
# ERR PCP not found get_properties Maltose-binding protein
# ERR PCP not found get_compounds Maltose-binding protein
# A lot of elements in reaction:  id NADH + H+ + O2 → NAD+ + H2O2 ['NADH', 'H', 'O2 → NAD', 'H2O2']
# A lot of elements in reaction:  id NADH + 2O2 → NAD+ + 2O2- + H+ ['NADH', '2O2 → NAD', '2O2-', 'H']
# ERR PCP not found get_properties H2O2 → H2O
# ERR PCP not found get_compounds H2O2 → H2O
# A lot of elements in reaction:  id ABTS + H2O2 → ABTS+ + H2O ['ABTS', 'H2O2 → ABTS', 'H2O']
# ERR PCP not found get_properties pro-Res
# ERR PCP not found get_compounds pro-Res
# ERR PCP not found get_properties HPA
# ERR PCP not found get_compounds HPA
# ERR PCP not found get_properties o-dionisidine
# ERR PCP not found get_compounds o-dionisidine
# ERR PCP not found get_properties Fe3
# ERR PCP not found get_compounds Fe3
# ERR PCP not found get_properties Nafion
# ERR PCP not found get_compounds Nafion
# ERR PCP not found get_properties H₂O₂
# ERR PCP not found get_compounds H₂O₂
# ERR PCP not found get_properties pyrogalol
# ERR PCP not found get_compounds pyrogalol
# ERR PCP not found get_properties Poly(D,L-lactic-co-glycolic acid) (PLGA)
# ERR PCP not found get_compounds Poly(D,L-lactic-co-glycolic acid) (PLGA)
# ERR PCP not found get_properties BAFA
# ERR PCP not found get_compounds BAFA
# ERR PCP not found get_properties Hcy-SH
# ERR PCP not found get_compounds Hcy-SH
# ERR PCP not found get_properties TB-OOH
# ERR PCP not found get_compounds TB-OOH
# ERR PCP not found get_properties phosphatidylcholine-hydroperoxide
# ERR PCP not found get_compounds phosphatidylcholine-hydroperoxide
# ERR PCP not found get_properties P-HPAA
# ERR PCP not found get_compounds P-HPAA
# ERR PCP not found get_properties Poly(methyl methacrylate-co-glycidyl methacrylate)
# ERR PCP not found get_compounds Poly(methyl methacrylate-co-glycidyl methacrylate)
# ERR PCP not found get_properties 3,3’-diaminobenzidine tetrahydrochloride
# ERR PCP not found get_compounds 3,3’-diaminobenzidine tetrahydrochloride
# ERR PCP not found get_properties cytochrome c
# ERR PCP not found get_compounds cytochrome c
# ERR PCP not found get_properties dQH2
# ERR PCP not found get_compounds dQH2
# ERR PCP not found get_properties BSA–FITC
# ERR PCP not found get_compounds BSA–FITC
# ERR PCP not found get_properties MBP
# ERR PCP not found get_compounds MBP
# ERR PCP not found get_properties ter-butyl-hydroperoxide
# ERR PCP not found get_compounds ter-butyl-hydroperoxide
# ERR PCP not found get_properties 4-NPA
# ERR PCP not found get_compounds 4-NPA
# ERR PCP not found get_properties PGR
# ERR PCP not found get_compounds PGR
# ERR PCP not found get_properties Poly-L-lysine-grafted dextran
# ERR PCP not found get_compounds Poly-L-lysine-grafted dextran
# ERR PCP not found get_properties cyt. c
# ERR PCP not found get_compounds cyt. c
# ERR PCP not found get_properties PEG-PAMA
# ERR PCP not found get_compounds PEG-PAMA
# ERR PCP not found get_properties Poly(vinylidene)fluoride
# ERR PCP not found get_compounds Poly(vinylidene)fluoride
# ERR PCP not found get_properties t-BH
# ERR PCP not found get_compounds t-BH
# ERR PCP not found get_properties methylaminophenol
# ERR PCP not found get_compounds methylaminophenol
# ERR PCP not found get_properties cumene hydro-peroxide
# ERR PCP not found get_compounds cumene hydro-peroxide
# ERR PCP not found get_properties Hf18
# ERR PCP not found get_compounds Hf18
# ERR PCP not found get_properties ChOx
# ERR PCP not found get_compounds ChOx
# ERR PCP not found get_properties LOOH
# ERR PCP not found get_compounds LOOH
# ERR PCP not found get_properties Poly[(2-methacryloyloxyethyl)trimethyl ammonium chloride]
# ERR PCP not found get_compounds Poly[(2-methacryloyloxyethyl)trimethyl ammonium chloride]
# ERR PCP not found get_properties 4-NTP
# ERR PCP not found get_compounds 4-NTP
# ERR PCP not found get_properties DIT
# ERR PCP not found get_compounds DIT
# ERR PCP not found get_properties thyroglobulin
# ERR PCP not found get_compounds thyroglobulin
# A lot of elements in reaction:  id 17 beta estradiol + DPNH + H2O2 ['17 beta estradiol', 'DPNH', 'H2O2']
# A lot of elements in reaction:  id 17 beta estradiol + DPNH + H2O2 ['17 beta estradiol', 'DPNH', 'H2O2']
# ERR PCP not found get_properties starch
# ERR PCP not found get_compounds starch
# ERR PCP not found get_properties Polyoxometalates
# ERR PCP not found get_compounds Polyoxometalates
# ERR PCP not found get_properties hyaluronic acid
# ERR PCP not found get_compounds hyaluronic acid
# ERR PCP not found get_properties t-Bu-OOH
# ERR PCP not found get_compounds t-Bu-OOH
# ERR PCP not found get_properties peroxidized linolenic acid
# ERR PCP not found get_compounds peroxidized linolenic acid
# ERR PCP not found get_properties Am-NH/phenol
# ERR PCP not found get_compounds Am-NH/phenol
# ERR PCP not found get_properties Cum-OOH
# ERR PCP not found get_compounds Cum-OOH
# ERR PCP not found get_properties AAHPO
# ERR PCP not found get_compounds AAHPO
# ERR PCP not found get_properties LAHPO
# ERR PCP not found get_compounds LAHPO
# ERR PCP not found get_properties Beta-cyclodextrin polymer
# ERR PCP not found get_compounds Beta-cyclodextrin polymer
# ERR PCP not found get_properties UPNP
# ERR PCP not found get_compounds UPNP
# ERR PCP not found get_properties Sodium polyacrylate
# ERR PCP not found get_compounds Sodium polyacrylate
# A lot of elements in reaction:  id AAP + DEA + H2O2 ['AAP', 'DEA', 'H2O2']
# A lot of elements in reaction:  id AAP + DEA + H2O2 ['AAP', 'DEA', 'H2O2']
# A lot of elements in reaction:  id AAP + DEA + H2O2 ['AAP', 'DEA', 'H2O2']
# ERR PCP not found get_properties Fmoc-Gly Alko-PEG resin
# ERR PCP not found get_compounds Fmoc-Gly Alko-PEG resin
# ERR PCP not found get_properties Monoethanolamide
# ERR PCP not found get_compounds Monoethanolamide
# ERR PCP not found get_properties Nbs-SCN
# ERR PCP not found get_compounds Nbs-SCN
# ERR PCP not found get_properties Carboxymethyl guar gum
# ERR PCP not found get_compounds Carboxymethyl guar gum
# ERR PCP not found get_properties 13S-HPOTE
# ERR PCP not found get_compounds 13S-HPOTE
# ERR PCP not found get_properties DMAB
# ERR PCP not found get_compounds DMAB
# ERR PCP not found get_properties 3-IP
# ERR PCP not found get_compounds 3-IP
# ERR PCP not found get_properties ACP
# ERR PCP not found get_compounds ACP
# ERR PCP not found get_properties PCOOH
# ERR PCP not found get_compounds PCOOH
# ERR PCP not found get_properties I131
# ERR PCP not found get_compounds I131
# ERR PCP not found get_properties ONOO3
# ERR PCP not found get_compounds ONOO3
# ERR PCP not found get_properties Oligo-N-isopropylacrylamide
# ERR PCP not found get_compounds Oligo-N-isopropylacrylamide
# ERR PCP not found get_properties SOSG
# ERR PCP not found get_compounds SOSG
# ERR PCP not found get_properties CPA
# ERR PCP not found get_compounds CPA
# ERR PCP not found get_properties APS
# ERR PCP not found get_compounds APS
# ERR PCP not found get_properties Terc-butil hydroperoxide
# ERR PCP not found get_compounds Terc-butil hydroperoxide
# A lot of elements in reaction:  id H2O2+DEA+AAP ['H2O2', 'DEA', 'AAP']
# ERR PCP not found get_properties Silica-PEG-Silica
# ERR PCP not found get_compounds Silica-PEG-Silica
# ERR PCP not found get_properties Tween 80
# ERR PCP not found get_compounds Tween 80
# ERR PCP not found get_properties p-nitroanisole-O-demethylation
# ERR PCP not found get_compounds p-nitroanisole-O-demethylation
# ERR PCP not found get_properties 13-OOH-182
# ERR PCP not found get_compounds 13-OOH-182
# ERR PCP not found get_properties 15-OOH-204
# ERR PCP not found get_compounds 15-OOH-204
# ERR PCP not found get_properties guaiacol-H2O2
# ERR PCP not found get_compounds guaiacol-H2O2
# ERR PCP not found get_properties 6-phenylenediamine hydrochloride
# ERR PCP not found get_compounds 6-phenylenediamine hydrochloride
# ERR PCP not found get_properties Micrococcus lysodeikticus
# ERR PCP not found get_compounds Micrococcus lysodeikticus
# ERR PCP not found get_properties Polyadenine-containing diblock DNA
# ERR PCP not found get_compounds Polyadenine-containing diblock DNA
# ERR PCP not found get_properties Poly(methacrylic acid-co-ethylene glycol dimethacrylate)
# ERR PCP not found get_compounds Poly(methacrylic acid-co-ethylene glycol dimethacrylate)
# A lot of elements in reaction:  id CH4 + 1/4 O2 → 1/2 C2H6 + 1/2 H2O ['CH4', '1/4 O2 → 1/2 C2H6', '1/2 H2O']
# A lot of elements in reaction:  id H2O2+4-AAP+Phenol ['H2O2', '4-AAP', 'Phenol']
# ERR PCP not found get_properties PS
# ERR PCP not found get_compounds PS
# ERR PCP not found get_properties RhB
# ERR PCP not found get_compounds RhB
# ERR PCP not found get_properties CDP-star
# ERR PCP not found get_compounds CDP-star
# A lot of elements in reaction:  id H2O2 + 4-AAP + phenol ['H2O2', '4-AAP', 'phenol']
# ERR PCP not found get_properties Lipopolysaccharide
# ERR PCP not found get_compounds Lipopolysaccharide
# ERR PCP not found get_properties p-NPh
# ERR PCP not found get_compounds p-NPh
# ERR PCP not found get_properties ROOH
# ERR PCP not found get_compounds ROOH
# ERR PCP not found get_properties Polyvinylpolypyrrolidone
# ERR PCP not found get_compounds Polyvinylpolypyrrolidone
# ERR PCP not found get_properties ICI
# ERR PCP not found get_compounds ICI
# ERR PCP not found get_properties Triton X-405
# ERR PCP not found get_compounds Triton X-405
# ERR PCP not found get_properties Poly(benzyl methacrylate-co-glycidyl methacrylate)
# ERR PCP not found get_compounds Poly(benzyl methacrylate-co-glycidyl methacrylate)
# ERR PCP not found get_properties LMG
# ERR PCP not found get_compounds LMG
# ERR PCP not found get_properties Cytochrome c
# ERR PCP not found get_compounds Cytochrome c
# ERR PCP not found get_properties Polyamidoamine dendrimer
# ERR PCP not found get_compounds Polyamidoamine dendrimer
# ERR PCP not found get_properties p-naphthyl acetate
# ERR PCP not found get_compounds p-naphthyl acetate
# ERR PCP not found get_properties DmTrx-2
# ERR PCP not found get_compounds DmTrx-2
# ERR PCP not found get_properties DmTrx-1
# ERR PCP not found get_compounds DmTrx-1
# ERR PCP not found get_properties Poly Bed 812
# ERR PCP not found get_compounds Poly Bed 812
# ERR PCP not found get_properties 15a
# ERR PCP not found get_compounds 15a
# ERR PCP not found get_properties pNPP-Na
# ERR PCP not found get_compounds pNPP-Na
# ERR PCP not found get_properties QA
# ERR PCP not found get_compounds QA
# ERR PCP not found get_properties EA
# ERR PCP not found get_compounds EA
# ERR PCP not found get_properties eumene hydroperoxide
# ERR PCP not found get_compounds eumene hydroperoxide
# ERR PCP not found get_properties f-butyl hydroperoxide
# ERR PCP not found get_compounds f-butyl hydroperoxide
# ERR PCP not found get_properties PMNT
# ERR PCP not found get_compounds PMNT
# ERR PCP not found get_properties 4NPA
# ERR PCP not found get_compounds 4NPA
# ERR PCP not found get_properties ABTS2-
# ERR PCP not found get_compounds ABTS2-
# A lot of elements in reaction:  id H2O2+TOPS+4-AAP ['H2O2', 'TOPS', '4-AAP']
# ERR PCP not found get_properties AmplexRed
# ERR PCP not found get_compounds AmplexRed
# ERR PCP not found get_properties sodium perborate
# ERR PCP not found get_compounds sodium perborate
# ERR PCP not found get_properties Phytagel
# ERR PCP not found get_compounds Phytagel
# ERR PCP not found get_properties O 2(cid:129)−
# ERR PCP not found get_compounds O 2(cid:129)−
# ERR PCP not found get_properties Starch
# ERR PCP not found get_compounds Starch
# ERR PCP not found get_properties Polyethylenimine
# ERR PCP not found get_compounds Polyethylenimine
# ERR PCP not found get_properties Apoferritin
# ERR PCP not found get_compounds Apoferritin
# ERR PCP not found get_properties DOPA-PIMA-PEG
# ERR PCP not found get_compounds DOPA-PIMA-PEG
# ERR PCP not found get_properties DEA
# ERR PCP not found get_compounds DEA
# A lot of elements in reaction:  id phenol+4-AAP+H2O2 ['phenol', '4-AAP', 'H2O2']
# A lot of elements in reaction:  id H2O2+phenol+4-AAP ['H2O2', 'phenol', '4-AAP']
# A lot of elements in reaction:  id H2O2+4-AAP+p-chlorophenol ['H2O2', '4-AAP', 'p-chlorophenol']
# ERR PCP not found get_properties Cotton fabric
# ERR PCP not found get_compounds Cotton fabric
# ERR PCP not found get_properties 13-hydroperoxy-linoleic acid
# ERR PCP not found get_compounds 13-hydroperoxy-linoleic acid
# ERR PCP not found get_properties o’dianisidine
# ERR PCP not found get_compounds o’dianisidine
# ERR PCP not found get_properties o’phenylenediamine
# ERR PCP not found get_compounds o’phenylenediamine
# ERR PCP not found get_properties 4-aminonaphthalene-1-yl acetate
# ERR PCP not found get_compounds 4-aminonaphthalene-1-yl acetate
# ERR PCP not found get_properties Ammonia–Borane
# ERR PCP not found get_compounds Ammonia–Borane
# ERR PCP not found get_properties ferric cytochrome c
# ERR PCP not found get_compounds ferric cytochrome c
# ERR PCP not found get_properties Triton-X
# ERR PCP not found get_compounds Triton-X
# ERR PCP not found get_properties RB19
# ERR PCP not found get_compounds RB19
# ERR PCP not found get_properties DrB38
# ERR PCP not found get_compounds DrB38
# ERR PCP not found get_properties RB5
# ERR PCP not found get_compounds RB5
# ERR PCP not found get_properties L012
# ERR PCP not found get_compounds L012
# ERR PCP not found get_properties o-DA
# ERR PCP not found get_compounds o-DA
# ERR PCP not found get_properties h-CA
# ERR PCP not found get_compounds h-CA
# ERR PCP not found get_properties PAA
# ERR PCP not found get_compounds PAA
# ERR PCP not found get_properties Elastin-like polypeptide
# ERR PCP not found get_compounds Elastin-like polypeptide
# ERR PCP not found get_properties cholesteryl linoleate hydroperoxide
# ERR PCP not found get_compounds cholesteryl linoleate hydroperoxide

# %%
new_df
# Out:
#       XLogP  TPSA    MolWt  PEOE_VSA7  PEOE_VSA9  VSA_EState8    Kappa2  \
# 0       NaN   NaN      NaN        NaN        NaN          NaN       NaN
# 1       0.4  20.3  111.144  12.620777        0.0      4.36162  1.987228
# 2       NaN   NaN      NaN        NaN        NaN          NaN       NaN
# 3       NaN   NaN      NaN        NaN        NaN          NaN       NaN
# 4       NaN   NaN      NaN        NaN        NaN          NaN       NaN
# ...     ...   ...      ...        ...        ...          ...       ...
# 9040    NaN   NaN      NaN        NaN        NaN          NaN       NaN
# 9041    NaN   NaN      NaN        NaN        NaN          NaN       NaN
# 9042    NaN   NaN      NaN        NaN        NaN          NaN       NaN
# 9043    NaN   NaN      NaN        NaN        NaN          NaN       NaN
# 9044    NaN   NaN      NaN        NaN        NaN          NaN       NaN
#
#       BalabanJ  MinAbsEStateIndex  MinEStateIndex  ...  EState_VSA4  \
# 0          NaN                NaN             NaN  ...          NaN
# 1     2.536682           0.208333        0.208333  ...    12.965578
# 2          NaN                NaN             NaN  ...          NaN
# 3          NaN                NaN             NaN  ...          NaN
# 4          NaN                NaN             NaN  ...          NaN
# ...        ...                ...             ...  ...          ...
# 9040       NaN                NaN             NaN  ...          NaN
# 9041       NaN                NaN             NaN  ...          NaN
# 9042       NaN                NaN             NaN  ...          NaN
# 9043       NaN                NaN             NaN  ...          NaN
# 9044       NaN                NaN             NaN  ...          NaN
#
#        SMR_VSA7  BCUT2D_CHGLO  MinPartialCharge.1  MaxPartialCharge.1  \
# 0           NaN           NaN           -0.398299            0.037337
# 1     12.778891     -2.048433           -0.254557           -0.254557
# 2           NaN           NaN           -0.254557           -0.254557
# 3           NaN           NaN           -0.254557           -0.254557
# 4           NaN           NaN           -0.254557           -0.254557
# ...         ...           ...                 ...                 ...
# 9040        NaN           NaN           -0.254557           -0.254557
# 9041        NaN           NaN           -0.254557           -0.254557
# 9042        NaN           NaN           -0.254557           -0.254557
# 9043        NaN           NaN           -0.254557           -0.254557
# 9044        NaN           NaN                 NaN                 NaN
#
#       Complexity1  TPSA1  MaxEStateIndex.1  TPSA2  MaxEStateIndex.2
# 0           226.0   52.0          5.992739   40.5          6.000000
# 1             NaN   40.5          6.000000   29.5          8.985509
# 2             NaN   40.5          6.000000   29.5          8.985509
# 3             NaN   40.5          6.000000   29.5          8.985509
# 4             NaN   40.5          6.000000   52.0          5.992739
# ...           ...    ...               ...    ...               ...
# 9040          NaN   40.5          6.000000   29.5          8.985509
# 9041          NaN   40.5          6.000000   29.5          8.985509
# 9042          NaN   40.5          6.000000   29.5          8.985509
# 9043          NaN   40.5          6.000000   29.5          8.985509
# 9044          NaN    NaN               NaN    NaN               NaN
#
# [9045 rows x 24 columns]

# %%
final_columns = final_df.drop(columns=['id', 'cryst', 'Mcoat', 'Sufrace', 'polym', 'Complexity']).columns.tolist()
new_final_df = pd.concat([res_df, new_df], axis=1)[final_columns]

# %%
new_final_df["id"] = pd.Series(np.arange(10000, 10000+len(new_final_df))+1)

# %%
new_final_df.to_csv("final_p2.csv", index=False)

# %%
start_columns = start_df.drop(
    columns=['#', 'type', 'Syngony', 'Sufrace', 'surface', 'Mw(coat), g/mol',
             'Subtype', 'Vsub_min(mL)', 'Vsub_max(mL)', 'Vsub_const(mL)',
             'Vcat(mL)', 'Ccat(mkM)', 'Vbuffer(mL)', 'Dstr', 'mX',
             'mROx', 'mCD', 'volume', 'Mr, g/mol', 'link']
).columns.tolist()
new_start_df = df.rename(columns={"SurfaceArea, m^2/g": "SurfaceArea, m^2/g "})[start_columns]
new_start_df["id"] = pd.Series(np.arange(10000, 10000+len(new_final_df))+1)

# %%
new_start_df.to_csv("start_p2.csv", index=False)
