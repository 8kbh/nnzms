# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import functions.unifyer as uf
from tqdm.notebook import tqdm
tqdm.pandas()

# %%
from importlib import reload
reload(uf);

# %%
df = pd.read_csv("data/LLM_unif.csv") # dataset generated by LLM with units

# %% [markdown]
# # Prepare LLM Dataset

# %% [markdown]
# ## Rename synonyms

# %% [markdown]
# For example:
# ```
# 'sheet-like': 'sheet',
# 'nanosheets': 'sheet',
# 'Nanosheets': 'sheet',
# ```

# %%
df["shape_unif"] = df["shape"].apply(uf.unify_shape)

# %%
df["activity_unif"] = df["activity"].apply(uf.unify_activity)

# %%
df["polymer_unif"] = df["polymer_used_in_synthesis"].apply(uf.unify_polymer)

# %%
df["surfactant_unif"] = df["surfactant"].apply(uf.unify_surfactant)

# %% [markdown]
# ## Rename dataset columns according to 'start_df.csv'

# %%
usefull_columns_and_rename = {
    'formula': 'formula',
    # no type
    'activity_unif': 'activity',
    # no Syngony
    'shape_unif': 'shape',
    'length_mean': 'length, nm',
    'width_mean': 'width, nm',
    'depth_mean': 'depth, nm',
    'size_mean': 'size, nm', # only in my dataset
    # no Sufrace
    # no surface
    'polymer_unif': 'pol',
    'surfactant_unif': 'surf',
    # no Mw(coat), g/mol
    'km_unif': 'Km, mM',
    'vmax_unif': 'Vmax, mM/s',
    'reaction_type': 'ReactionType',
    # no Subtype
    'c_min_unif': 'C min, mM',
    # no Vsub_min(mL)
    'c_max_unif': 'C max, mM',
    # no Vsub_max(mL)
    'concentration_of_co_substrate_unif': 'C(const), mM',  #  C(const)
    # no Vsub_const(mL)
    'concentration_of_nanoparticles_unif': 'Ccat(mg/mL)', #  C(cat)
    # no Vcat(mL)
    # no Ccat(mkM)
    'p_h': 'ph',
    'temperature': 'temp, °C',
    # no 'Vbuffer(mL)', 'Dstr', 'mX', 'mROx', 'mCD', 'volume', 'Mr, g/mol'
    'zeta_potential_unif': 'Zpotential',
    'surface_area_unif': 'SurfaceArea, m^2/g',
}

# %%
df = df[list(usefull_columns_and_rename.keys())].rename(columns=usefull_columns_and_rename)

# %% [markdown]
# ## Fill length, width, depth with sizse if Nan

# %%
cols_to_fill = ['length, nm', 'width, nm', 'depth, nm']
for col in cols_to_fill:
    df[col] = df[col].fillna(df['size, nm'])

# %% [markdown]
# ## Remove temperature units

# %%
import re
def convert_temp(temp_str):
    
    if uf.check_nan(temp_str):
        return np.nan
    temp_str = temp_str.replace("~", "").lower().replace("_", " ")
    
    match = re.match(r"(\d+(?:\.\d+)?)\s*\-\s*(\d+(?:\.\d+)?)\s*(?:°c|degrees celsius|c|degree celsius)", temp_str)
    if match:
        mn, mx = match.groups()
        return (float(mn)+float(mx))/2

    match = re.match(r"(\d+(?:\.\d+)?)\s*(?:°c|degrees celsius|c|degree celsius)", temp_str)
    if match:
        return float(match.groups()[0])

    match = re.match(r"(\d+(?:\.\d+)?)\s*±\s*(\d+(?:\.\d+)?)\s*(?:°c|degrees celsius|c|degree celsius)", temp_str)
    if match:
        return float(match.groups()[0])

    print(temp_str)
    return np.nan
df["temp, °C"] = df["temp, °C"].apply(convert_temp)
# Out:
# 298 k
# 298 k
# 298 k
# 298 k
# 298 k
# 298 k
# 298 k
# 298 k
# 298.15 k
# 298.1 k
# 298.1 k
# 298.1 k
# 298.1 k
# 298.1 k
# 298.1 k
# 298.1 k
# 300 k
# 300 k
# 300 k
# 300 k
# 298.15 k
# 293 k
# 293 k
# 293 k
# 293 k
# 295 k
# 295 k
# 293 k
# 293 k
# 293 k
# 293 k
# 293 k
# 5 min
# 5 min
# 298 k
# 298 k
# 303.1 k
# 303.1 k
# ambient
# 303 k
# 303 k
# ambient
# 298 k
# 278-328 k
# 310.00 k
# 310.00 k
# 20 - -30 °c
# 20 - -30 °c
# 25 degree c
# 25 degree c
# 298 k
# 298 k
# 298 k
# 298 k
# 310 k
# 4 degrees centigrade
# 4 degrees centigrade
# 8 k
# 8 k
# ambient
# 295 k
# 300 k
# 300 k
# 300 k
# 298 k
# 298 k
# 298 k
# 298 k
# 298 k
# 298 k
# 25 degrees c
# 25 degrees c
# 307 k
# 298 k
# 298 k
# 298 k
# 50 # einsteins/m2/s
# 365 millidegree
# 83-88 f
# 85-88 f
# 79-90 f
# 85-88 f
# 79-90 f
# 79-90 f
# 363 k
# 298 k
# 298 k
# 303 k
# 303 k
# 303 k
# 310 k
# 298 k
# 310 k
# 310 k
# 310 k
# 298 k
# 298 k
# 298 k
# 343 k
# 305 k
# 293 k
# 293 k
# 293 k
# 293 k
# 293 k
# 293 k
# 293 k
# 293 k
# 293 k
# 293 k
# room temperature
# room temperature
# room temperature
# room temperature
# 300 k
# 300 k
# 298.15 k
# 298.15 k
# 298.15 k
# 298 k
# 298 k
# 298 k
# 298 k
# 140 f

# %% [markdown]
# # Make descriptors

# %%
import functions.functions_a as fu

# %%
reload(fu);

# %%
res_df = pd.DataFrame()

# %% [markdown]
# ## X

# %%
def createX(formula):
    if uf.check_nan(formula):
        return np.nan
    try:
        composition = fu.Composition(formula)
    except:
        print(f"ERR creating composition {formula}")
        return np.nan

    X = composition.average_electroneg
    return X

# %%
df["formula"].apply(createX)
# Out:
# ERR creating composition N-CQDs
# ERR creating composition N-CQDs
# ERR creating composition u-cytc550
# ERR creating composition u-cytc550
# ERR creating composition u-cytc550
# ERR creating composition u-cytc550
# ERR creating composition BSA-PtAu@CNS
# ERR creating composition BSA-PtAu@CNS
# ERR creating composition Cys-AuNCs
# ERR creating composition CaO2/DOX
# ERR creating composition CaO2/DOX@SiO2/DOX
# ERR creating composition CaO2/DOX@SiO2/DOX-MnO2
# ERR creating composition CaO2/DOX@SiO2/DOX-MnO2
# ERR creating composition CaO2/DOX@SiO2/DOX-MnO2
# ERR creating composition Fe3O4/Pβ-CD
# ERR creating composition Fe3O4/Pβ-CD
# ERR creating composition SeO32-
# ERR creating composition (CyaSe)2
# ERR creating composition 3-amino-9-ethylcarbazole
# ERR creating composition o-tolidine
# ERR creating composition FeIII–TMPyP
# ERR creating composition AuNPs/MCA
# ERR creating composition AuNPs/MCA
# ERR creating composition Mn3O4/Pd@Pt
# ERR creating composition Mn3O4/Pd@Pt
# ERR creating composition P@Pt@P-Au
# ERR creating composition P@Pt@P-Au
# ERR creating composition P@Pt@P-Au
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition AuNPs
# ERR creating composition AuNPs
# ERR creating composition cyt c
# ERR creating composition cyt c
# ERR creating composition PRT-AuNCs
# ERR creating composition PRT-AuNCs
# ERR creating composition 3(cid:11)-H9
# ERR creating composition 3(cid:11)-H12
# ERR creating composition Ag-Fe3O4
# ERR creating composition Ag-Fe3O4
# ERR creating composition Dex-IONP-GOx
# ERR creating composition Dex-IONP-GOx
# ERR creating composition C-dot/NiAl-LDH
# ERR creating composition C-dot/NiAl-LDH
# ERR creating composition Au-Ag
# ERR creating composition Au-Ag
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Fe3O4/Au
# ERR creating composition Fe3O4/Au
# ERR creating composition Fe3O4/Au
# ERR creating composition Fe3O4/Au
# ERR creating composition Cu 1.8S–cgmc
# ERR creating composition Cu 1.8S–cgmc
# ERR creating composition ZIF-8@BHb
# ERR creating composition ZIF-8@BHb
# ERR creating composition ZIF-8@BHb
# ERR creating composition G3.0-He
# ERR creating composition G3.0-He
# ERR creating composition HRP^SP
# ERR creating composition 3 MgCO3·9 Mg(OH)2·3 H2O
# ERR creating composition CH3Se-
# ERR creating composition c-cyts
# ERR creating composition HRP-OX
# ERR creating composition YcYfetus
# ERR creating composition Fe3+
# ERR creating composition Fe3+
# ERR creating composition 4c15
# ERR creating composition 4c15A4
# ERR creating composition 4c15A12
# ERR creating composition 4c15A20
# ERR creating composition Cu2+
# ERR creating composition Cu2+
# ERR creating composition Cu2+
# ERR creating composition Cu2+
# ERR creating composition Cu2+
# ERR creating composition Cu2+
# ERR creating composition Cu2+
# ERR creating composition Pt-WO3-r-GO
# ERR creating composition Fe-N-C
# ERR creating composition Fe-N-C
# ERR creating composition cyt c
# ERR creating composition cyt c
# ERR creating composition Sm-CeO2
# ERR creating composition GO-CTAB-AuNP-hemin
# ERR creating composition GO-CTAB-AuNP-hemin
# ERR creating composition GO-CTAB-AuNP-hemin
# ERR creating composition GO-CTAB-AuNP-hemin
# ERR creating composition AuPd-NH2-fMnO2
# ERR creating composition AuPd-NH2-fMnO2
# ERR creating composition TfuCat
# ERR creating composition TfuCat
# ERR creating composition Au-Hg/rGO
# ERR creating composition Au-Hg/rGO
# ERR creating composition Prostaglandin H Synthase
# ERR creating composition Prostaglandin H Synthase
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition SYI-2074
# ERR creating composition Cu(Nc)22+
# ERR creating composition Cu(Nc)22+
# ERR creating composition Cu2-xSe
# ERR creating composition Cu2-xSe
# ERR creating composition Cu2-xSe
# ERR creating composition Cu2-xSe
# ERR creating composition BLG-Heme
# ERR creating composition BLG-T-Heme
# ERR creating composition BLG-C-Heme
# ERR creating composition BLG-K-Heme
# ERR creating composition Crystallin-Heme
# ERR creating composition CD44 MMSN/AuNPs
# ERR creating composition CD44 MMSN/AuNPs
# ERR creating composition Au-Pt/SiO2
# ERR creating composition Au-Pt/SiO2
# ERR creating composition cSelS
# ERR creating composition cSelS
# ERR creating composition cSelS C174S
# ERR creating composition AuNWs
# ERR creating composition PBNPs@AuNWs
# ERR creating composition Pt-GNRs
# ERR creating composition Pt-GNRs
# ERR creating composition TiO2@CeOx
# ERR creating composition TiO2@CeOx
# ERR creating composition TiO2@CeOx
# ERR creating composition TiO2@CeOx
# ERR creating composition ficin-TN
# ERR creating composition ficin-TN
# ERR creating composition cit-PHGPx
# ERR creating composition ST1Cys
# ERR creating composition ST2Cys
# ERR creating composition ST1Sec
# ERR creating composition ST2Sec
# ERR creating composition GSH-Px
# ERR creating composition Cyt c
# ERR creating composition PPAuMns
# ERR creating composition PPAuMns
# ERR creating composition PPAuMns
# ERR creating composition PPAuMns
# ERR creating composition PPAuMns
# ERR creating composition PPAuMns
# ERR creating composition PPAuMns
# ERR creating composition PPAuMns
# ERR creating composition PPAuMns
# ERR creating composition Co/CuS-MMT
# ERR creating composition Co/CuS-MMT
# ERR creating composition g-C3N4-PdNPs
# ERR creating composition g-C3N4-PdNPs
# ERR creating composition MnCcP.1
# ERR creating composition Tyr36Phe-MnCcP.1
# ERR creating composition Lys179Arg-MnCcP.1
# ERR creating composition Ile40Gly-MnCcP.1
# ERR creating composition Tyr36Phe/Lys179Arg-MnCcP.1
# ERR creating composition Ile40Gly/Lys179Arg-MnCcP.1
# ERR creating composition Tyr36Phe/Ile40Gly-MnCcP.1
# ERR creating composition Tyr36Phe/Ile40Gly/Lys179Arg-MnCcP.1
# ERR creating composition Mn-TCPP
# ERR creating composition Fe-TCPP
# ERR creating composition Mn-TCPP
# ERR creating composition Mn-TCPP
# ERR creating composition h-Fe3O4@ppy
# ERR creating composition h-Fe3O4@ppy
# ERR creating composition ZnPc-GQDs-MnO2@PtNPs
# ERR creating composition CP 600−6
# ERR creating composition CP 600−6
# ERR creating composition HRP-avidin
# ERR creating composition HRP-avidin
# ERR creating composition HRP-avidin
# ERR creating composition HRP-avidin
# ERR creating composition HRP-avidin
# ERR creating composition HRP-avidin
# ERR creating composition Fe3O4@Cu/GMP
# ERR creating composition PB-Ft
# ERR creating composition PB-Ft
# ERR creating composition PB-Ft
# ERR creating composition PB-Ft
# ERR creating composition Selenium-enriched yeast
# ERR creating composition Selenium-enriched alga Chlorella
# ERR creating composition L4.6k-dG4
# ERR creating composition L4.6k-dG4
# ERR creating composition AuNPs@g-C3N4
# ERR creating composition AuNPs@g-C3N4
# ERR creating composition g-C3N4
# ERR creating composition g-C3N4
# ERR creating composition Prussian Blue
# ERR creating composition Co/PMCS
# ERR creating composition Cu−N−C
# ERR creating composition Zn−N−C
# ERR creating composition Co−N−C
# ERR creating composition Fe−N−C
# ERR creating composition Cu−N−C
# ERR creating composition Hemin-T 10-EAD2
# ERR creating composition Hemin-T 10-EAD2
# ERR creating composition Hemin-T 10-EAD2
# ERR creating composition Hemin-T 10-EAD2
# ERR creating composition La3+
# ERR creating composition La3+
# ERR creating composition DNA50/hemin
# ERR creating composition Control1
# ERR creating composition Control1/hemin
# ERR creating composition Control2
# ERR creating composition Control2/hemin
# ERR creating composition Control3
# ERR creating composition Control3/hemin
# ERR creating composition G-PhB
# ERR creating composition G-PhB
# ERR creating composition Fe3O4@PDA@Pd/Pt
# ERR creating composition Fe3O4@PDA@Pd/Pt
# ERR creating composition PhSe2
# ERR creating composition Ficin
# ERR creating composition Ficin
# ERR creating composition MoS2-Au@Pt
# ERR creating composition MoS2-Au@Pt
# ERR creating composition FeIII–mimochrome VI
# ERR creating composition FeIII–mimochrome VI
# ERR creating composition FeIII–mimochrome VI
# ERR creating composition FeIII–mimochrome VI
# ERR creating composition Se-scFv-B3
# ERR creating composition H170A hHRP
# ERR creating composition H170A hHRP
# ERR creating composition 5Fe2O3•9H2O
# ERR creating composition Cu2+
# ERR creating composition Cu2+
# ERR creating composition NH2-MIL-88B(Fe)
# ERR creating composition NH2-MIL-88B(Fe)
# ERR creating composition NMC Tp-TTA
# ERR creating composition NMC Tp-TTA
# ERR creating composition AuNPs@POMD-8pep
# ERR creating composition AuNPs@POMD-8pep
# ERR creating composition VOx
# ERR creating composition VOx
# ERR creating composition Cu-N-C
# ERR creating composition Cu-N-C
# ERR creating composition cationic Au NCs
# ERR creating composition cationic Au NCs
# ERR creating composition cationic Au NCs
# ERR creating composition cationic Au NCs
# ERR creating composition Fc
# ERR creating composition Fc
# ERR creating composition PDI/Si-CeO2
# ERR creating composition PDI/Si-CeO2
# ERR creating composition Co-MOF
# ERR creating composition Fe/Al-GNE
# ERR creating composition Fe/Al-GNE
# ERR creating composition Fe/Al-GNE
# ERR creating composition Fe/Al-GNE
# ERR creating composition SWNT-NH2@hemin
# ERR creating composition SWNT-NH2@hemin
# ERR creating composition SWNT@hemin
# ERR creating composition SWNT@hemin
# ERR creating composition SWNT-COOH@hemin
# ERR creating composition SWNT-COOH@hemin
# ERR creating composition Sepp1UF
# ERR creating composition Sepp1UF
# ERR creating composition Sepp1UF
# ERR creating composition Sepp1UF
# ERR creating composition NBD-CL
# ERR creating composition NBD-CL
# ERR creating composition Pd-WO3-SiO2
# ERR creating composition Pd-WO3-SiO2-PB
# ERR creating composition Pd-WO3-SiO2-PB
# ERR creating composition Pd-WO3-SiO2
# ERR creating composition Pd-WO3-SiO2-PB
# ERR creating composition Fe3O4/SiO2/Gr
# ERR creating composition Fe3O4/SiO2/Gr
# ERR creating composition Fe3O4/SiO2/Gr
# ERR creating composition Fe3O4/SiO2/Gr
# ERR creating composition Co(II) complex 1
# ERR creating composition Co(II) complex 2
# ERR creating composition Catalase
# ERR creating composition Hemoglobin
# ERR creating composition Cu–hemin
# ERR creating composition Cu–hemin
# ERR creating composition Fe-SAs/NC
# ERR creating composition Fe-SAs/NC
# ERR creating composition Cu2O/Au
# ERR creating composition Cu2O/Au
# ERR creating composition Ni-CuAu
# ERR creating composition Ni-CuAu
# ERR creating composition β-CD-hemin
# ERR creating composition β-CD-hemin
# ERR creating composition Fe3O4/g-C3N4
# ERR creating composition Fe3O4/g-C3N4
# ERR creating composition Fe3O4/g-C3N4
# ERR creating composition Fe3O4/g-C3N4
# ERR creating composition Cu,Zn-SOD
# ERR creating composition Cu,Zn-SOD
# ERR creating composition [MnIIIMnII(Ldtb)((cid:2)-OAc)2]BPh4
# ERR creating composition 4c15-s
# ERR creating composition 4c15
# ERR creating composition DPPC-PI
# ERR creating composition DPPC-PI
# ERR creating composition DPPC-PI
# ERR creating composition DPPC-PI
# ERR creating composition DPPC-PI
# ERR creating composition DPPC-PI
# ERR creating composition VHb
# ERR creating composition VHb
# ERR creating composition VHb
# ERR creating composition CcpA
# ERR creating composition FeIII-MC6*
# ERR creating composition FeIII-MC6*
# ERR creating composition FeIII-MC6*a
# ERR creating composition FeIII-MC6*a
# ERR creating composition T-DMSNs@Au
# ERR creating composition T-DMSNs@Au
# ERR creating composition SWNT/Mb
# ERR creating composition SWNT/HRP
# ERR creating composition Fe(TpCPP)
# ERR creating composition Fe(TpCPP)
# ERR creating composition Fe(TpCPP)-Xln10A
# ERR creating composition Fe(TpCPP)-Xln10A
# ERR creating composition N-doped Fe3C
# ERR creating composition MWCNT@rGONR
# ERR creating composition MWCNT@rGONR
# ERR creating composition MoS2-Au
# ERR creating composition MoS2-Au
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Fe(III)Hb
# ERR creating composition Fe(III)Hb
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Prx1
# ERR creating composition Prx1
# ERR creating composition Mn-TPPS
# ERR creating composition GO-UO22+
# ERR creating composition CS-MoSe2
# ERR creating composition CS-MoSe2
# ERR creating composition CS-MoSe2
# ERR creating composition CS-MoSe2
# ERR creating composition 2-(benzylselanyl)phenyl)methanamine
# ERR creating composition Cytc
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition CatG4
# ERR creating composition Fe@Fe3O4@Cu2-xS
# ERR creating composition Fe@Fe3O4@Cu2-xS
# ERR creating composition Au-Cu(II)
# ERR creating composition Au-Cu(II)
# ERR creating composition CH3-C(CH3)2CH2C(CH3)2-C6H4-O(C2H4O)9_I0-H
# ERR creating composition C12H25N(COC(CH3)=CH2)-(C2H40)Is-H
# ERR creating composition C18H37NH(C2H40)10-H
# ERR creating composition C18H37NH(C2H40)15-H
# ERR creating composition ethanol
# ERR creating composition propanol-2
# ERR creating composition butanol
# ERR creating composition CuO-Au
# ERR creating composition CuO-Au
# ERR creating composition Ag-Au
# ERR creating composition Ag-Au
# ERR creating composition Ag-Au
# ERR creating composition Ag-Au
# ERR creating composition metMb
# ERR creating composition N-(2-nitrophenyl) benzenesulfonamide
# ERR creating composition NPY–heme
# ERR creating composition NPY–heme
# ERR creating composition guaiacol
# ERR creating composition guaiacol
# ERR creating composition Kaol-ycc
# ERR creating composition Kaol-E20-ycc
# ERR creating composition Kaol-ycc
# ERR creating composition Kaol-E40-ycc
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Phe68azoAla
# ERR creating composition Phe179azoAla
# ERR creating composition PC-OOH
# ERR creating composition PC-OOH
# ERR creating composition H2O2 + TMB
# ERR creating composition H2O2 + OPD
# ERR creating composition Fe-CNNPs
# ERR creating composition Fe-CNNPs
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Hemoglobin
# ERR creating composition Hemoglobin
# ERR creating composition Horseradish peroxidase
# ERR creating composition Horseradish peroxidase
# ERR creating composition AuNPs–SWNTs
# ERR creating composition AuNPs–SWNTs
# ERR creating composition ficin
# ERR creating composition Au−Ag/L-Cys-rGO
# ERR creating composition Au−Ag/L-Cys-rGO
# ERR creating composition Au/L-Cys-rGO
# ERR creating composition Au/L-Cys-rGO
# ERR creating composition Ag/L-Cys-rGO
# ERR creating composition Ag/L-Cys-rGO
# ERR creating composition Cu-Pt
# ERR creating composition POM-Calix hybrid
# ERR creating composition POM-Calix hybrid
# ERR creating composition Mn-HPyP
# ERR creating composition Mn-HPyP
# ERR creating composition Mn-HPyP
# ERR creating composition AuNPs@MoS2-QDs
# ERR creating composition AuNPs@MoS2-QDs
# ERR creating composition 15SeP 1
# ERR creating composition 15SeP 1
# ERR creating composition 15SeP
# ERR creating composition 15SeP
# ERR creating composition IgG
# ERR creating composition Gd-MPO
# ERR creating composition Ni3(OH)2(C8H4O4)2(H2O)4·2H2O
# ERR creating composition Ni3(OH)2(C8H4O4)2(H2O)4·2H2O
# ERR creating composition Au NC micelles
# ERR creating composition NEQC-340
# ERR creating composition oPGHS-1
# ERR creating composition Por-CeO2
# ERR creating composition Por-CeO2
# ERR creating composition ycc
# ERR creating composition MP-8
# ERR creating composition MP-8
# ERR creating composition Ceruloplasmin
# ERR creating composition PNIPAM-CD-g-Te
# ERR creating composition PNIPAM-CD-g-Te
# ERR creating composition PNIPAM-CD-g-Te
# ERR creating composition PNIPAM-CD-g-Te
# ERR creating composition (25R)-5a-spirostane-2a,3b,5a-triol 3-O-(O-a-L-rhamnopyranosyl-(1 ? 2)-O-(b-D-galactopyranosyl-(1 ? 3))-b-D-glucopyranoside)
# ERR creating composition Fe3(PO4)2·8H2O
# ERR creating composition Fe3(PO4)2·8H2O
# ERR creating composition crystallin aggregate-heme
# ERR creating composition crystallin aggregate-heme
# ERR creating composition crystallin aggregate-heme
# ERR creating composition crystallin aggregate-heme
# ERR creating composition [SVW11O40]3-
# ERR creating composition [SVW11O40]3-
# ERR creating composition [SV2W10O40]4-
# ERR creating composition [SV2W10O40]4-
# ERR creating composition Fe-N-C
# ERR creating composition Au/Pt
# ERR creating composition Au/Pt
# ERR creating composition Au/Fe3O4/GO
# ERR creating composition Au/Fe3O4/GO
# ERR creating composition Hb
# ERR creating composition FTN_1133
# ERR creating composition FTN_1133
# ERR creating composition MoS2-COOH-MWCNT
# ERR creating composition Fe(por)
# ERR creating composition Fe(por)
# ERR creating composition ficin
# ERR creating composition ficin
# ERR creating composition Tg-HbI
# ERR creating composition Tg-HbII
# ERR creating composition Ti3C2Tx
# ERR creating composition Ti3C2Tx
# ERR creating composition Ti3C2Tx
# ERR creating composition DNA–Pt
# ERR creating composition DNA–Pt
# ERR creating composition g-CN@CuMOF
# ERR creating composition g-CN@CuMOF
# ERR creating composition Fe3C-NC
# ERR creating composition Fe5HO8·4H2O
# ERR creating composition Fe5HO8·4H2O
# ERR creating composition Fe3O4NP@pSiO2
# ERR creating composition Fe3O4NP@pSiO2
# ERR creating composition Fe3O4NP@pSiO2
# ERR creating composition Fe3O4NP@pSiO2
# ERR creating composition HRP/GO-GQDs
# ERR creating composition HRP/GO-GQDs
# ERR creating composition CeO2-Gd
# ERR creating composition CeO2-Gd
# ERR creating composition Co-MGNCs
# ERR creating composition Co-MGNCs
# ERR creating composition TA-Hb
# ERR creating composition TA-Hb
# ERR creating composition Cmcytc
# ERR creating composition Cmcytc
# ERR creating composition Cu,Zn-SOD
# ERR creating composition Cu,Zn-SOD
# ERR creating composition Ce-Fe3O4
# ERR creating composition Ce-Fe3O4
# ERR creating composition MoS2/N-rGO
# ERR creating composition MoS2/N-rGO
# ERR creating composition MoS2/N-rGO
# ERR creating composition MoS2/N-rGO
# ERR creating composition MoS2/N-rGO
# ERR creating composition 2-phenyl-1,2-benzisoselenazol-3(2H)-one
# ERR creating composition Cyt c
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Co-TCPP(Fe)
# ERR creating composition Cu-TCPP(Fe)
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Cu,Zn-SOD1
# ERR creating composition Cu,Zn-SOD1
# ERR creating composition CoMo hybrids
# ERR creating composition CoMo hybrids
# ERR creating composition CoMo hybrids
# ERR creating composition Tb-OBBA-Hemin
# ERR creating composition Tb-OBBA-Hemin
# ERR creating composition PS-[VVO(OMe)(hap-iah)]
# ERR creating composition Fe-iCOF
# ERR creating composition S-rGO
# ERR creating composition S-rGO
# ERR creating composition FeP-pSC4-AuNPs
# ERR creating composition FeP-pSC4-AuNPs
# ERR creating composition Ce0.94Fe0.06O2-δ
# ERR creating composition Ce0.94Fe0.06O2-δ
# ERR creating composition Fe3O4@MIL-100(Fe)
# ERR creating composition Fe3O4@MIL-100(Fe)
# ERR creating composition SDS-Hemin-Imidazole
# ERR creating composition AuNPs
# ERR creating composition AuNPs
# ERR creating composition CNT/FeNC
# ERR creating composition CNT/FeNC
# ERR creating composition Au@CD + CeO2
# ERR creating composition Au@CD + CeO2
# ERR creating composition Prx4
# ERR creating composition AgNPs@Fe3O4
# ERR creating composition AgNPs@Fe3O4
# ERR creating composition g-C3N4
# ERR creating composition g-C3N4
# ERR creating composition Fe-g-C3N4
# ERR creating composition Fe-g-C3N4
# ERR creating composition C44.0%H12.2%O23.3%N16.5%S4.01%
# ERR creating composition C44.0%H12.2%O23.3%N16.5%S4.01%
# ERR creating composition Fe(III)-protoporphyrin IX
# ERR creating composition Fe(III)-protoporphyrin IX
# ERR creating composition Prx2
# ERR creating composition Prx2
# ERR creating composition Prx2
# ERR creating composition Fe(III) protoporphyrin IX chloride
# ERR creating composition FeCu-DA/NC
# ERR creating composition FeCu-DA/NC
# ERR creating composition FeCu-DA/NC
# ERR creating composition ZnFe2O4/ZnO
# ERR creating composition Se-enriched yeast
# ERR creating composition MWNT-SP
# ERR creating composition MWNT-MC
# ERR creating composition CeO2/CoO
# ERR creating composition CeO2/CoO
# ERR creating composition AuPd@UiO-67
# ERR creating composition Co@C-dots
# ERR creating composition Co@C-dots
# ERR creating composition CAANSs
# ERR creating composition Fe-PorCOF
# ERR creating composition Fe-PorCOF
# ERR creating composition pTBCB-PEG
# ERR creating composition pTBCB-PEG
# ERR creating composition pTBCB-PEG
# ERR creating composition pTBCB-PEG
# ERR creating composition pTBCB-PEG
# ERR creating composition pTBCB-PEG
# ERR creating composition Fe3O4/MWCNTs
# ERR creating composition Fe3O4/MWCNTs
# ERR creating composition NAD+
# ERR creating composition NAD+
# ERR creating composition HbA0
# ERR creating composition HbA1c
# ERR creating composition Fe3O4@Cu/GMP
# ERR creating composition Fe3O4@Cu/GMP
# ERR creating composition Fe3O4@Cu/GMP-GOx
# ERR creating composition Fe3O4@Cu/GMP-GOx
# ERR creating composition Fe3O4@Cu/GMP-GOx
# ERR creating composition EbBz
# ERR creating composition Pt/Fe3O4-DIB-DETA-CNS
# ERR creating composition Pt/Fe3O4-DIB-DETA-CNS
# ERR creating composition Tf-trHb
# ERR creating composition Tf-trHb
# ERR creating composition Cu2-xSe
# ERR creating composition Cu2-xSe
# ERR creating composition Cu2-xSe
# ERR creating composition Cu2-xSe
# ERR creating composition Cu2-xSe
# ERR creating composition PtNPs@MnO2
# ERR creating composition Fe3O4-Sch
# ERR creating composition Fe3O4-Sch
# ERR creating composition Pt NC/3D GF
# ERR creating composition Pt NC/3D GF
# ERR creating composition Pt NC/3D GF
# ERR creating composition Pt NC/3D GF
# ERR creating composition ZIF-8/GO
# ERR creating composition ZIF-8/GO
# ERR creating composition ZIF-8/GO
# ERR creating composition ZIF-8/GO
# ERR creating composition ZnFe2O4/rGO
# ERR creating composition ZnFe2O4/rGO
# ERR creating composition Fe-N-C
# ERR creating composition PDA/PB
# ERR creating composition PDA/PB
# ERR creating composition Ac-PAL-AMC
# ERR creating composition Cu-MOFs
# ERR creating composition Cu-MOFs
# ERR creating composition Cu3(PO4)2⋅3H2O
# ERR creating composition Cu3(PO4)2⋅3H2O
# ERR creating composition Fe(III) protoporphyrin IX chloride
# ERR creating composition Fe(III) protoporphyrin IX chloride
# ERR creating composition Fe(III) protoporphyrin IX chloride
# ERR creating composition Fe(III) protoporphyrin IX chloride
# ERR creating composition Pt@PCN222-Mn
# ERR creating composition Pt@PCN222-Mn
# ERR creating composition β-CD@AuNPs
# ERR creating composition β-CD@AuNPs
# ERR creating composition β-CD@AuNPs
# ERR creating composition Ohr
# ERR creating composition Ohr
# ERR creating composition Ohr
# ERR creating composition Ohr
# ERR creating composition Ohr
# ERR creating composition c-di-GMP-proflavine-hemin
# ERR creating composition c-di-GMP-proflavine-hemin
# ERR creating composition c-di-GMP-proflavine-hemin
# ERR creating composition c-di-GMP-proflavine-hemin
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Au@meso-SiO2
# ERR creating composition CuS-MoS2
# ERR creating composition CuS-MoS2
# ERR creating composition Cyt-c
# ERR creating composition Cyt-c
# ERR creating composition Zn-N-C
# ERR creating composition Zn-N-C
# ERR creating composition C60(OH)nOm
# ERR creating composition C60(OH)nOm
# ERR creating composition C60(OH)nOm
# ERR creating composition GO/Au
# ERR creating composition GO/Au
# ERR creating composition Hemin + G-quadruplex
# ERR creating composition Hemin + G-quadruplex
# ERR creating composition H2O2+TMB
# ERR creating composition H2O2+TMB
# ERR creating composition Co3O4-CeO2
# ERR creating composition Co3O4-CeO2
# ERR creating composition GST A1-1
# ERR creating composition GST A1-1
# ERR creating composition Au-Pt
# ERR creating composition Au-Pt
# ERR creating composition CBP–Con A complex
# ERR creating composition Prx1p
# ERR creating composition Prx1p
# ERR creating composition Prx1p
# ERR creating composition Ser38-m-Prx1p
# ERR creating composition Ser38-m-Prx1p
# ERR creating composition Ser38-m-Prx1p
# ERR creating composition PG endoperoxide synthetase
# ERR creating composition Au@Co-Fe
# ERR creating composition Au@Co-Fe
# ERR creating composition Au@Co-Fe
# ERR creating composition Au@Co-Fe
# ERR creating composition Hb-Hp I-I intermediate complex
# ERR creating composition Hb-Hp I-I intermediate complex
# ERR creating composition Hb-Hp I-I saturated complex
# ERR creating composition Hb-Hp I-I saturated complex
# ERR creating composition Cu-mb
# ERR creating composition PAMTegel
# ERR creating composition PAMTegel
# ERR creating composition PAMTegel
# ERR creating composition PAMTegel
# ERR creating composition d(TTAGGG)4
# ERR creating composition d(TTAGGG)12
# ERR creating composition c-Myc promoter
# ERR creating composition Limlin
# ERR creating composition Ch-Ag
# ERR creating composition Ch-Ag
# ERR creating composition Au-Ft
# ERR creating composition Ag-Au/AgCl
# ERR creating composition Ag-Au/AgCl
# ERR creating composition Fe-SAs/NC
# ERR creating composition HRP-C
# ERR creating composition HRP-C
# ERR creating composition Hb(AcTPOH)12
# ERR creating composition Hb(AcTPOH)12
# ERR creating composition Hb(AcTPOH)12
# ERR creating composition Co xFe 3(cid:2)xO 4
# ERR creating composition Co xFe 3(cid:2)xO 4
# ERR creating composition UiO-66-NH2
# ERR creating composition UiO-66-NH2
# ERR creating composition Fe(ToCPP)
# ERR creating composition Fe(ToCPP)
# ERR creating composition Fe(ToCPP)
# ERR creating composition FePPOPs-SO3H
# ERR creating composition FePPOPs-SO3H
# ERR creating composition D-Trp-OMe@AuNCs
# ERR creating composition D-Trp-OMe@AuNCs
# ERR creating composition D-Trp-OMe@AuNCs-TC
# ERR creating composition D-Trp-OMe@AuNCs-TC
# ERR creating composition FTn-Pt
# ERR creating composition FTn-Rh
# ERR creating composition FTn-Au
# ERR creating composition FTn-Ir
# ERR creating composition FTn-Mn
# ERR creating composition MIL-101(Fe)
# ERR creating composition MIL-101(Fe)
# ERR creating composition Fe{1,2-X2C6H2-4,5-(NCOCMe2NCO)2CR2}(OH2)-
# ERR creating composition Fe{1,2-X2C6H2-4,5-(NCOCMe2NCO)2CR2}(OH2)-
# ERR creating composition ficin
# ERR creating composition Prx6
# ERR creating composition Prx6
# ERR creating composition Pt/ZnCo2O4
# ERR creating composition Pt/ZnCo2O4
# ERR creating composition Fe3+
# ERR creating composition Fe3+
# ERR creating composition N-CDs
# ERR creating composition N-CDs
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition H42A hHRP
# ERR creating composition H42A hHRP
# ERR creating composition H42A hHRP
# ERR creating composition H42A hHRP
# ERR creating composition hemin-SWCNT
# ERR creating composition hemin-SWCNT
# ERR creating composition AuNPs/MOGs (Fe)
# ERR creating composition AuNPs/MOGs (Fe)
# ERR creating composition Ag/ZnMOF
# ERR creating composition Hemin/ZIF-8
# ERR creating composition V-substituted tungstosulfate polyoxometalate
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition Zn-TCPP(Fe)
# ERR creating composition FeCo-LDH
# ERR creating composition FeCo-LDH
# ERR creating composition FeeHCleNH2-UiO-66
# ERR creating composition FeeHCleNH2-UiO-66
# ERR creating composition FeeHCleNH2-UiO-66
# ERR creating composition FeeHCleNH2-UiO-66
# ERR creating composition H2TCPP-ZnS
# ERR creating composition H2TCPP-ZnS
# ERR creating composition VMPxC1
# ERR creating composition VMPxC2
# ERR creating composition Heme-ficin
# ERR creating composition Heme-ficin
# ERR creating composition H2TCPP-Fe3O4
# ERR creating composition H2TCPP-Fe3O4
# ERR creating composition IrOx
# ERR creating composition IrOx
# ERR creating composition Cu2+/GMP
# ERR creating composition Ag3Cit
# ERR creating composition Fe(III) mesoporphyrin
# ERR creating composition Fe(III) mesoporphyrin
# ERR creating composition Fe(III) mesoporphyrin
# ERR creating composition Fe(III) mesoporphyrin
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Cu-CDs
# ERR creating composition CDs@γ-/α-Fe2O3
# ERR creating composition CDs@γ-/α-Fe2O3
# ERR creating composition α-Fe2O3
# ERR creating composition α-Fe2O3
# ERR creating composition TMB + H2O2
# ERR creating composition TMB + H2O2
# ERR creating composition Ag/Pt
# ERR creating composition Ag/Pt
# ERR creating composition hematin
# ERR creating composition hematin-methanol complex
# ERR creating composition hematin-pyridine complex
# ERR creating composition hematin-guanidine complex
# ERR creating composition hematin-formamide complex
# ERR creating composition hematin-acetate complex
# ERR creating composition hematin-histidine complex
# ERR creating composition hematin-arginine complex
# ERR creating composition SM-Te
# ERR creating composition SM-Te
# ERR creating composition SM-Te
# ERR creating composition SM-Te
# ERR creating composition YhjA
# ERR creating composition YhjA
# ERR creating composition YhjA
# ERR creating composition g-C3N4
# ERR creating composition MIP-g-C3N4
# ERR creating composition N-SCSs
# ERR creating composition N-SCSs
# ERR creating composition N-SCSs
# ERR creating composition N-SCSs
# ERR creating composition Mn x(PO 4) y
# ERR creating composition Fe-TCPP
# ERR creating composition Mn-TCPP
# ERR creating composition Fe-TCPP
# ERR creating composition Mn-TCPP
# ERR creating composition Fe-TCPP
# ERR creating composition Mn-TCPP
# ERR creating composition Fe-TCPP
# ERR creating composition Mn-TCPP
# ERR creating composition di-2-(N-cyclohexyl,N-(methylamino)-methyl)phenyl diselenide
# ERR creating composition di-2-(N-cyclohexyl,N-(methylamino)-methyl)phenyl diselenide
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Fe(III)-protoporphyrin IX
# ERR creating composition Fe(III)-protoporphyrin IX
# ERR creating composition Carbon shell
# ERR creating composition Carbon shell
# ERR creating composition Carbon
# ERR creating composition Hb
# ERR creating composition γ-MnOOH
# ERR creating composition Cu,Zn-SOD
# ERR creating composition Cu,Zn-SOD
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Co–Fe@hemin
# ERR creating composition Co–Fe@hemin
# ERR creating composition TPhPFe3+OH/Al2O3
# ERR creating composition TPhPFe3+OH/Al2O3
# ERR creating composition TPhPFe3+OH/Al2O3
# ERR creating composition perFTPhPFe3+OH/Al2O3
# ERR creating composition perFTPhPFe3+OH/Al2O3
# ERR creating composition PB-Fe2O3
# ERR creating composition PB-Fe2O3
# ERR creating composition C-dots
# ERR creating composition dSCS-Au NPs
# ERR creating composition GSH-Au NCs
# ERR creating composition dSCS-Au NPs
# ERR creating composition dSCS-Au NPs
# ERR creating composition (Z)-N-(4-methylbenzylidene)-1-(2-((2-(1-((E)-4-methylbenzylideneamino)ethyl)phenyl)diselanyl)phenyl)ethanamine ethyl)phenyl) diselanyl) phenyl) ethylimino) methyl)phenol
# ERR creating composition (PhSe)2
# ERR creating composition (Z)-N-(4-methylbenzylidene)-1-(2-((2-(1-((E)-4-methylbenzylideneamino)ethyl)phenyl)diselanyl)phenyl)ethanamine ethyl)phenyl) diselanyl) phenyl) ethylimino) methyl)phenol
# ERR creating composition (PhSe)2
# ERR creating composition (Z)-N-(4-methylbenzylidene)-1-(2-((2-(1-((E)-4-methylbenzylideneamino)ethyl)phenyl)diselanyl)phenyl)ethanamine ethyl)phenyl) diselanyl) phenyl) ethylimino) methyl)phenol
# ERR creating composition (PhSe)2
# ERR creating composition hSOD1
# ERR creating composition hSOD1
# ERR creating composition Au-Pt
# ERR creating composition G20-Cu(II)
# ERR creating composition G20-Cu(II)
# ERR creating composition Ovoperoxidase
# ERR creating composition Ovoperoxidase
# ERR creating composition AF-SiO2-TiO2NC
# ERR creating composition Cu-FeHCF
# ERR creating composition Cu-FeHCF
# ERR creating composition Mn-FeHCF
# ERR creating composition Mn-FeHCF
# ERR creating composition Ni-FeHCF
# ERR creating composition Ni-FeHCF
# ERR creating composition cyt c
# ERR creating composition cyt c
# ERR creating composition cyt c
# ERR creating composition cyt c
# ERR creating composition cyt c
# ERR creating composition cyt c
# ERR creating composition AldO-MP
# ERR creating composition AldO-MP
# ERR creating composition AldO-HB1
# ERR creating composition AldO-HB1
# ERR creating composition 15SeP
# ERR creating composition 15SeP
# ERR creating composition MoS2/MWCNTs
# ERR creating composition Hb
# ERR creating composition Met Hb
# ERR creating composition TA@VOx
# ERR creating composition Co\Fe\TiO2
# ERR creating composition Co\Fe\TiO2
# ERR creating composition KatA
# ERR creating composition KatA
# ERR creating composition KatB
# ERR creating composition KatB
# ERR creating composition Cyt b5
# ERR creating composition Cyt b5
# ERR creating composition Ss-HbI
# ERR creating composition Ss-HbI
# ERR creating composition Ss-HbII
# ERR creating composition Ss-HbII
# ERR creating composition ABTS + H2O2
# ERR creating composition ABTS + H2O2
# ERR creating composition hPrx1
# ERR creating composition Ab 9A5 + mesohemin
# ERR creating composition Ab 11D1 + mesohemin
# ERR creating composition Fe-Co-Ni oxide
# ERR creating composition Fe-Co-Ni oxide
# ERR creating composition Fe(OH)(O2C(C6H4)CO2)·H2O
# ERR creating composition Fe(OH)(O2C(C6H4)CO2)·H2O
# ERR creating composition Se-scFv-WCD1-lessACA
# ERR creating composition Se-scFv-WCD1-lessACA
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition CuO-g-C3N4
# ERR creating composition CuO-g-C3N4
# ERR creating composition Mb-Cu
# ERR creating composition Mb2-Cu
# ERR creating composition Mb4-Cu
# ERR creating composition Mb2-Cu
# ERR creating composition Mb2-Cu
# ERR creating composition PMIDA-Mn0.5Fe0.5Fe2O4
# ERR creating composition PMIDA-Mn0.5Fe0.5Fe2O4
# ERR creating composition SV-IV
# ERR creating composition SV-IV
# ERR creating composition NH2-MIL-88B(Fe)
# ERR creating composition NH2-MIL-88B(Fe)
# ERR creating composition NMC Tp-TTA
# ERR creating composition NMC Tp-TTA
# ERR creating composition Mn(II)/CeO2
# ERR creating composition Mn(II)/CeO2
# ERR creating composition Fe(III)/CeO2
# ERR creating composition Fe(III)/CeO2
# ERR creating composition Co(II)/CeO2
# ERR creating composition Co(II)/CeO2
# ERR creating composition Pd NPs/CeO2 NTs
# ERR creating composition Pd NPs/CeO2 NTs
# ERR creating composition Pd NPs
# ERR creating composition Pd NPs
# ERR creating composition Cu(II)–cysteine/SDS/DTAB
# ERR creating composition Cu(II)–cysteine/SDS/DTAB
# ERR creating composition Cu(II)–cysteine/SDS/DTAB
# ERR creating composition nGO
# ERR creating composition nGO
# ERR creating composition Fe-MoS2
# ERR creating composition Fe-MoS2
# ERR creating composition PS2.M–hemin
# ERR creating composition PS2.M–hemin
# ERR creating composition rPS2.M–hemin
# ERR creating composition rPS2.M–hemin
# ERR creating composition OXY4–hemin
# ERR creating composition OXY4–hemin
# ERR creating composition C-dots
# ERR creating composition C-dots
# ERR creating composition C-dots
# ERR creating composition C-dots
# ERR creating composition C-dots
# ERR creating composition C-dots
# ERR creating composition C-dots
# ERR creating composition C-dots
# ERR creating composition Fe(III)-Mn(II)
# ERR creating composition CM-HSA
# ERR creating composition se-scFv-B3
# ERR creating composition CeO2-CDs
# ERR creating composition CeO2-CDs
# ERR creating composition HbFe3+
# ERR creating composition HbFe3+
# ERR creating composition TClPP-CuFe2O4/SiO2
# ERR creating composition TClPP-CuFe2O4/SiO2
# ERR creating composition Fe3O4@NH2-MIL-101(Fe)
# ERR creating composition Fe3O4@NH2-MIL-101(Fe)
# ERR creating composition HRP-GCS
# ERR creating composition 2-TeCD
# ERR creating composition 2-TeCD
# ERR creating composition 2-TeCD
# ERR creating composition Au/CDs
# ERR creating composition Au/CDs
# ERR creating composition H2O2 + TMB
# ERR creating composition H2O2 + TMB
# ERR creating composition Co2(OH)2CO3-CeO2
# ERR creating composition Co2(OH)2CO3-CeO2
# ERR creating composition Se-g-C3N4
# ERR creating composition Se-g-C3N4
# ERR creating composition Pt/C
# ERR creating composition Pt/C
# ERR creating composition Pt/C
# ERR creating composition Pt/C
# ERR creating composition PtCNPs
# ERR creating composition PtCNPs
# ERR creating composition CuCNPs
# ERR creating composition CuCNPs
# ERR creating composition NiCNPs
# ERR creating composition NiCNPs
# ERR creating composition PdCNPs
# ERR creating composition PdCNPs
# ERR creating composition T67R/S92D Mb
# ERR creating composition T67R/S92D Mb-H
# ERR creating composition P-450cam
# ERR creating composition P-450cam
# ERR creating composition PB-Ft
# ERR creating composition PB-Ft
# ERR creating composition PB-Ft
# ERR creating composition PB-Ft
# ERR creating composition CuO/WO3
# ERR creating composition CuO/WO3
# ERR creating composition Co3O4@Co-Fe oxide
# ERR creating composition Co3O4@Co-Fe oxide
# ERR creating composition ZnO-Pd
# ERR creating composition ZnO-Pd
# ERR creating composition Cytochrome c
# ERR creating composition Cytochrome c
# ERR creating composition Cu-SBA-15
# ERR creating composition Cu-SBA-15
# ERR creating composition Fe-MIL-88NH2
# ERR creating composition Fe-MIL-88NH2
# ERR creating composition Cu,Zn-SOD
# ERR creating composition Cu,Zn-SOD
# ERR creating composition Au/CeO2
# ERR creating composition Au/CeO2
# ERR creating composition TaAPX-6B
# ERR creating composition Mn-TSPP
# ERR creating composition Fe-TSPP
# ERR creating composition Mn-TSPP
# ERR creating composition Cu2OeAu
# ERR creating composition Cu2OeAu
# ERR creating composition ZmANN33/35
# ERR creating composition Fe-BTC
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition hemin-Fib
# ERR creating composition MA-Hem/AueAg
# ERR creating composition MA-Hem/AueAg
# ERR creating composition C-dots
# ERR creating composition C-dots
# ERR creating composition C-dots
# ERR creating composition C-dots
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Se-enriched yeast
# ERR creating composition Se-enriched yeast
# ERR creating composition Se-enriched yeast
# ERR creating composition MoS2@TA/Fe
# ERR creating composition MoS2@TA/Fe
# ERR creating composition MoS2@TA/Fe
# ERR creating composition Cu3(PO4)2·3H2O
# ERR creating composition Cu3(PO4)2·3H2O
# ERR creating composition Cu3(PO4)2·3H2O
# ERR creating composition Cu3(PO4)2·3H2O
# ERR creating composition Cu3(PO4)2·3H2O
# ERR creating composition Cu3(PO4)2·3H2O
# ERR creating composition Cu3(PO4)2·3H2O
# ERR creating composition Cu3(PO4)2·3H2O
# ERR creating composition MoS2-MIL-101(Fe)
# ERR creating composition MoS2-MIL-101(Fe)
# ERR creating composition AuNS@Ag-5-H-rGO
# ERR creating composition AuNS@Ag-5-H-rGO
# ERR creating composition AuNP@Ag-5-H-rGO
# ERR creating composition AuNP@Ag-5-H-rGO
# ERR creating composition Zn-N-C
# ERR creating composition Zn-N-C
# ERR creating composition Fe3+-TCAS
# ERR creating composition Fe3+-TCAS
# ERR creating composition Co-Al ELDH
# ERR creating composition Co-Al ELDH
# ERR creating composition Cytochrome bd
# ERR creating composition Cytochrome bd
# ERR creating composition GHK/K8[α-SiW11O39]/Co2+
# ERR creating composition cyt c
# ERR creating composition cyt c
# ERR creating composition Na_xH_(2-x)Ti_3O_7
# ERR creating composition 2,2′-diamino-diphenyldiselenide
# ERR creating composition 2,2′-diselenopyridin
# ERR creating composition 2-phenyl-1,2-benzoisoselenazol-3(2H)-one
# ERR creating composition ethyl-benzo-1,2-selenazine-4-one-3-carboxylate
# ERR creating composition 2-methylselenobenzoylcyanide
# ERR creating composition cyt c-SNPs
# ERR creating composition cyt c-SNPs
# ERR creating composition iron protoporphyrin IX diglutathione
# ERR creating composition iron protoporphyrin IX diglutathione
# ERR creating composition Cyt-c
# ERR creating composition iron(III)-5-(4-carboxyphenyl)-10,15,20-tritolylporphyrin
# ERR creating composition iron(III)-5-(4-carboxyphenyl)-10,15,20-tritolylporphyrin
# ERR creating composition iron(III)-5-(4-carboxyphenyl)-10,15,20-tritolylporphyrin
# ERR creating composition Au@Ag-Pt
# ERR creating composition Au@Ag-Pt
# ERR creating composition GOx@Au@MagSiO2
# ERR creating composition GOx@Au@MagSiO2
# ERR creating composition Cu2+-rGO
# ERR creating composition PEG-GO-Hemin
# ERR creating composition PEG-GO-Hemin
# ERR creating composition PEG-GO-Hemin
# ERR creating composition PEG-GO-Hemin
# ERR creating composition Au@Pt@mesoporous SiO2
# ERR creating composition Au@Pt@mesoporous SiO2
# ERR creating composition FePt-Au
# ERR creating composition FePt-Au
# ERR creating composition Fe-MIL-101
# ERR creating composition Fe-MIL-101
# ERR creating composition Fe-MIL-101
# ERR creating composition Fe-MIL-101
# ERR creating composition Fe-MIL-101-FA
# ERR creating composition Fe-MIL-101-FA
# ERR creating composition Fe-MIL-101-FA
# ERR creating composition Fe-MIL-101-FA
# ERR creating composition PtNPs/GO
# ERR creating composition PtNPs/GO
# ERR creating composition His-AuNCs
# ERR creating composition His-AuNCs
# ERR creating composition PtPB-1
# ERR creating composition PtPB-2
# ERR creating composition PtPB-3
# ERR creating composition PtPB-4
# ERR creating composition IIB-III
# ERR creating composition IIB-III
# ERR creating composition Fe@PCN-224
# ERR creating composition Fe@PCN-224
# ERR creating composition Fe@PCN-224
# ERR creating composition PDI-CuO
# ERR creating composition PDI-CuO
# ERR creating composition Fe3O4@ZIF-8
# ERR creating composition Fe3O4@ZIF-8
# ERR creating composition AuNFs/Fe3O4@ZIF-8-MoS2
# ERR creating composition AuNFs/Fe3O4@ZIF-8-MoS2
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition NaYF4:Yb,Er
# ERR creating composition NaYF4:Yb,Er
# ERR creating composition Pt@mSiO2
# ERR creating composition Pt@mSiO2
# ERR creating composition Hb
# ERR creating composition Cytochrome c
# ERR creating composition Cytochrome c
# ERR creating composition Heme-ZrMOF
# ERR creating composition Heme-ZrMOF
# ERR creating composition Heme-ZrMOF
# ERR creating composition Ca2+-MMT
# ERR creating composition Ca2+-MMT
# ERR creating composition MoS2/rGO
# ERR creating composition MoS2/rGO
# ERR creating composition MoS2/rGO
# ERR creating composition MoS2/rGO
# ERR creating composition NGr-FeTPyP
# ERR creating composition FeTPyP-NGr
# ERR creating composition Tellurosubtilisin
# ERR creating composition Tellurosubtilisin
# ERR creating composition CYP BM3 21B3
# ERR creating composition W96A/F405L
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cu2+
# ERR creating composition Cu2+
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Au-MoS2
# ERR creating composition Au-MoS2
# ERR creating composition MnL1(OH2)2⋅H2O
# ERR creating composition Fe3+
# ERR creating composition Fe3+
# ERR creating composition Fe3+
# ERR creating composition Fe3+
# ERR creating composition Fe3+
# ERR creating composition Fe3+
# ERR creating composition Dz 1Dz 2NPs
# ERR creating composition Dz 1Dz 2NPs
# ERR creating composition Dz 1Dz 2NPs
# ERR creating composition Dz 1Dz 2NPs
# ERR creating composition Dz 1Dz 2NPs
# ERR creating composition Dz 1Dz 2NPs
# ERR creating composition Dz 1Dz 2NPs
# ERR creating composition Dz 1Dz 2NPs
# ERR creating composition Mn-TPPS4
# ERR creating composition Mn-TPPS4
# ERR creating composition Mn-TPPS4
# ERR creating composition Cu(II)-coordinated GpG-duplex DNA
# ERR creating composition Cu(II)-coordinated GpG-duplex DNA
# ERR creating composition Z-His-NHNH2/Zn2+
# ERR creating composition FeCPNPs
# ERR creating composition FeCPNPs
# ERR creating composition Co/Fe-MOFs-iodide
# ERR creating composition Co/Fe-MOFs-iodide
# ERR creating composition Au-C/SiO2
# ERR creating composition Au-C/SiO2
# ERR creating composition DAFS-25
# ERR creating composition DAFS-25
# ERR creating composition DAFS-25
# ERR creating composition DAFS-25
# ERR creating composition Fe3O4@C/Ni
# ERR creating composition Fe3O4@C/Ni
# ERR creating composition PNC2-WT
# ERR creating composition PNC2-WT
# ERR creating composition PNC2-M
# ERR creating composition PNC2-M
# ERR creating composition PtGNs
# ERR creating composition PtGNs
# ERR creating composition DypB
# ERR creating composition D153A/N246A
# ERR creating composition HAP@MIL-100(Fe)
# ERR creating composition Cu2+
# ERR creating composition PhSeZnCl
# ERR creating composition CuS-BSA-Cu3(PO4)2
# ERR creating composition CuS-BSA-Cu3(PO4)2
# ERR creating composition N-GQDs
# ERR creating composition N-GQDs
# ERR creating composition N57C/S71C Cyt b5
# ERR creating composition N57C/S71C Cyt b5
# ERR creating composition WT Cyt b5
# ERR creating composition WT Cyt b5
# ERR creating composition hemin
# ERR creating composition hemin
# ERR creating composition HRP-4C
# ERR creating composition Cu,Zn SOD
# ERR creating composition Cu,Zn SOD
# ERR creating composition Cu,Zn SOD
# ERR creating composition Cu,Zn SOD
# ERR creating composition CDN1/Au2
# ERR creating composition CDN1/Au2
# ERR creating composition CDN/Au1
# ERR creating composition CDN/Au1
# ERR creating composition Cu5(pz)6Cl[SiW12O40]
# ERR creating composition Cu5(pz)6Cl[SiW12O40]
# ERR creating composition Cu5(pz)6Cl[SiW12O40]
# ERR creating composition Cu5(pz)6Cl[SiW12O40]
# ERR creating composition Cu5(pz)6Cl[SiW12O40]
# ERR creating composition Cu5(pz)6Cl[SiW12O40]
# ERR creating composition Cu/CuO-rGO
# ERR creating composition Cu/CuO-rGO
# ERR creating composition peptide-hGQ
# ERR creating composition Co3O4 + CoAl2O4 + CeO2
# ERR creating composition Co3O4 + CoAl2O4 + CeO2
# ERR creating composition GPx
# ERR creating composition GPx
# ERR creating composition C-dots
# ERR creating composition C-dots
# ERR creating composition 1a
# ERR creating composition 1a
# ERR creating composition Fe-BDC-NH2
# ERR creating composition Fe-BDC-NH2
# ERR creating composition GO-Se
# ERR creating composition GO-Se
# ERR creating composition Pd/Fe3O4-PEI-RGO
# ERR creating composition Cu3(PO4)2·3H2O
# ERR creating composition Cu3(PO4)2·3H2O
# ERR creating composition PLPC-OOH
# ERR creating composition AD-100
# ERR creating composition Cu,ZnSOD
# ERR creating composition CeO2/NiO
# ERR creating composition CeO2/NiO
# ERR creating composition ferritin–heme
# ERR creating composition ferritin–heme
# ERR creating composition ferritin–heme
# ERR creating composition ferritin–heme
# ERR creating composition ferritin–heme
# ERR creating composition ferritin–heme
# ERR creating composition ferritin–heme
# ERR creating composition ferritin–heme
# ERR creating composition N, Fe-CDs
# ERR creating composition N, Fe-CDs
# ERR creating composition Fe3O4-Au
# ERR creating composition Fe3O4-Au
# ERR creating composition Co-N-C
# ERR creating composition Co-N-C
# ERR creating composition Fe-Ni LDH-hemin
# ERR creating composition Fe-Ni LDH-hemin
# ERR creating composition ATXII-microperoxidase
# ERR creating composition MoS2/GO
# ERR creating composition MoS2/GO
# ERR creating composition Zr-MOF-PVP
# ERR creating composition Zr-MOF-PVP
# ERR creating composition SA-PtNPs
# ERR creating composition Cu/Ag
# ERR creating composition Cu/Ag
# ERR creating composition VVO(ap-fah)(OMe)(MeOH)
# ERR creating composition VVO(ap-bhz)(OMe)(MeOH)
# ERR creating composition VVO(ap-nah)(OMe)(MeOH)
# ERR creating composition VVO(ap-inh)(OMe)(MeOH)
# ERR creating composition H-GNs
# ERR creating composition H-GNs
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition Cyt c
# ERR creating composition seleno-hGPx1-C2/78/115/156/202S
# ERR creating composition seleno-hGPx1-C2/78/115/156/202S
# ERR creating composition seleno-hGPx1-C2/78/115/156/202S
# ERR creating composition seleno-hGPx1-C2/78/115/156/202S
# ERR creating composition seleno-hGPx1-C2/78/115/156/202S
# ERR creating composition seleno-hGPx1-C2/78/115/156/202S
# ERR creating composition seleno-hGPx1-C2/78/115/156/202S
# ERR creating composition seleno-hGPx1-C2/78/115/156/202S
# ERR creating composition FeTSPc
# ERR creating composition FeTSPc
# ERR creating composition CxOyBrz
# ERR creating composition CxOyBrz
# ERR creating composition TPyP-CuS
# ERR creating composition TPyP-CuS
# ERR creating composition MIL-101(Cr)
# ERR creating composition MIL-101(Cr)
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Mn2+
# ERR creating composition Hemoglobin-Haptoglobin Complex
# ERR creating composition Hemoglobin-Haptoglobin Complex
# ERR creating composition Hemoglobin-Haptoglobin Complex
# ERR creating composition Hemoglobin-Haptoglobin Complex
# ERR creating composition Hemoglobin-Haptoglobin Complex
# ERR creating composition PtNP/GO
# ERR creating composition PtNP/GO
# ERR creating composition CeO2/TiO2
# ERR creating composition CeO2/TiO2
# ERR creating composition OgCytAPX1
# ERR creating composition OgCytAPX1
# ERR creating composition MoS2@CNNS(30)
# ERR creating composition MoS2@CNNS(30)
# ERR creating composition T67R/S92D Mb
# ERR creating composition T67R/S92D Mb
# ERR creating composition T67R/S92D Mb
# ERR creating composition T67R/S92D Mb-H
# ERR creating composition T67R/S92D Mb-H
# ERR creating composition T67R/S92D Mb-H
# ...
# ERR creating composition DL-selenomethionine
# ERR creating composition 6A,6B-diseleninic acid-6A*,6B*-selenium bridged b-cyclodextrin
# ERR creating composition 6A,6B-diseleninic acid-6A*,6B*-selenium bridged b-cyclodextrin
# ERR creating composition Cyt c-550
# ERR creating composition Cyt c-550
# ERR creating composition Fe-MIL-88B-NH2
# ERR creating composition Fe-MIL-88B-NH2
# ERR creating composition Sm-TCPP-Pt
# ERR creating composition Sm-TCPP-Pt
# ERR creating composition Fe3+P
# ERR creating composition Fe3+P
# ERR creating composition Fe3+P
# ERR creating composition Fe3+P
# ERR creating composition Fe3+P
# ERR creating composition Fe3+P
# ERR creating composition Fe3+P
# ERR creating composition cytc550
# ERR creating composition cytc550
# ERR creating composition cytc550
# ERR creating composition cytc550
# ERR creating composition cytc550
# ERR creating composition cytc550
# ERR creating composition cytc550
# ERR creating composition cytc550
# ERR creating composition H39Q Cyt b5
# ERR creating composition H39S Cyt b5
# ERR creating composition Fe-MOF
# ERR creating composition MLT-7
# ERR creating composition Fe(III) 5,10,15-tris(4-N-methylpyridiniumyl)-20-(4-phenyl(3-O-amidoxymethylestradiol)) porphyrin
# ERR creating composition Fe(III) 5,10,15-tris(4-N-methylpyridiniumyl)-20-(4-phenyl(3-O-amidoxymethylestradiol)) porphyrin
# ERR creating composition Fe(III) 5,10,15-tris(4-N-methylpyridiniumyl)-20-(4-phenyl(3-O-amidoxymethylestradiol)) porphyrin
# ERR creating composition Fe(III) 5,10,15-tris(4-N-methylpyridiniumyl)-20-(4-phenyl(3-O-amidoxymethylestradiol)) porphyrin
# ERR creating composition Hb
# ERR creating composition H2TCPP-CdS
# ERR creating composition H2TCPP-CdS
# ERR creating composition Fe-N-C
# ERR creating composition Fe/NC-SAs
# ERR creating composition Fe/NC-SAs
# ERR creating composition F-Fe3O4-1
# ERR creating composition F-Fe3O4-1
# ERR creating composition F-Fe3O4-1
# ERR creating composition F-Fe3O4-1
# ERR creating composition Fe3O4-blank
# ERR creating composition Fe3O4-blank
# ERR creating composition Fe3O4-blank
# ERR creating composition MoOx
# ERR creating composition Cytochrome b562 (F61I/F65Y/R106L)
# ERR creating composition Cytochrome b562 (F61A)
# ERR creating composition Cytochrome b562 (Wild type)
# ERR creating composition Cytochrome b562 (F61I/F65Y/R106L)
# ERR creating composition Cytochrome b562 (F61A)
# ERR creating composition Cytochrome b562 (Wild type)
# ERR creating composition Cu2-xS
# ERR creating composition Cu2-xS
# ERR creating composition Bleomycin-Fe3+
# ERR creating composition Bleomycin-Fe3+
# ERR creating composition Bleomycin-Fe3+
# ERR creating composition Bleomycin-Fe3+
# ERR creating composition NB-GNRs
# ERR creating composition NB-GNRs
# ERR creating composition FeeNeC
# ERR creating composition FeeNeC
# ERR creating composition A15/FeeNeC
# ERR creating composition A15/FeeNeC
# ERR creating composition 2,2P-diseleno-bis-L-cyclodextrin
# ERR creating composition 2,2P-diseleno-bis-L-cyclodextrin
# ERR creating composition Mn3+-octabromo-tetrakis(4-sulfophenyl)porphine
# ERR creating composition Cu-Ag/g-C3N4/ZIF
# ERR creating composition Cu-Ag/g-C3N4/ZIF
# ERR creating composition rHRP(1)
# ERR creating composition rHRP(2)
# ERR creating composition rHRP(3)
# ERR creating composition hemin-EAD2
# ERR creating composition hemin-EAD2
# ERR creating composition Tb–HRP
# ERR creating composition Tb–HRP
# ERR creating composition Tb–HRP
# ERR creating composition Mn-TPPS
# ERR creating composition Mn-TPPS
# ERR creating composition Fe-TMPyP
# ERR creating composition Fe-TMPyP
# ERR creating composition Zn3(MoO4)2(trz)2(H2O)2
# ERR creating composition Zn3(MoO4)2(trz)2(H2O)2
# ERR creating composition cyt-c
# ERR creating composition cyt-c
# ERR creating composition cyt-c
# ERR creating composition rG4 + hemin
# ERR creating composition rG4 + hemin
# ERR creating composition 13,16-dicarboxyethyl-2,7-diethyl-3,6,12,17-tetramethylporphycenatoiron(III)
# ERR creating composition 13,16-dicarboxyethyl-2,7-diethyl-3,6,12,17-tetramethylporphycenatoiron(III)
# ERR creating composition 13,16-dicarboxyethyl-2,7-diethyl-3,6,12,17-tetramethylporphycenatoiron(III)
# ERR creating composition 13,16-dicarboxyethyl-2,7-diethyl-3,6,12,17-tetramethylporphycenatoiron(III)
# ERR creating composition CH-Cu
# ERR creating composition CH-Cu
# ERR creating composition L29H/F43H Mb
# ERR creating composition Cu(II)-L29H/F43H Mb
# ERR creating composition Zn(II)-L29H/F43H Mb
# ERR creating composition L29H/F43H Mb
# ERR creating composition Cu(II)-L29H/F43H Mb
# ERR creating composition Zn(II)-L29H/F43H Mb
# ERR creating composition L29H/F43H Mb
# ERR creating composition Cu(II)-L29H/F43H Mb
# ERR creating composition Zn(II)-L29H/F43H Mb
# ERR creating composition DhHP-6
# ERR creating composition DhHP-6
# ERR creating composition DhHP-6
# ERR creating composition DhHP-6
# ERR creating composition DhHP-6
# ERR creating composition DhHP-6
# ERR creating composition DhHP-6
# ERR creating composition Fe3+/AMP
# ERR creating composition PLPC-OOH
# ERR creating composition Mn-T(4-TAP)P
# ERR creating composition Fe(III)-MC6
# ERR creating composition Fe(III)-MC6
# ERR creating composition AuNP/Ag-bipyridine
# ERR creating composition AuNP/Ag-bipyridine
# ERR creating composition Fe-N-CDs
# ERR creating composition Fe-N-CDs
# ERR creating composition Ni(C33H37N4O4S2)·DMF
# ERR creating composition unknown
# ERR creating composition MPS-PPV
# ERR creating composition MPS-PPV
# ERR creating composition Au@Pt 0.25%
# ERR creating composition Au@Pt 2.5%
# ERR creating composition Au@Pt 25%
# ERR creating composition Au@Pt 2.5%
# ERR creating composition Fe3O4-TiO2/rGO
# ERR creating composition Fe3O4-TiO2/rGO
# ERR creating composition DhHP-6-c-ZrMOF
# ERR creating composition DhHP-6-c-ZrMOF
# ERR creating composition DhHP-6
# ERR creating composition DhHP-6
# ERR creating composition Cu/Au
# ERR creating composition Cu/Au
# ERR creating composition CH3CONH2 + HOOC(CH2)3COOH
# ERR creating composition CH3CONH2 + HOOC(CH2)3COOH
# ERR creating composition g-C3N4
# ERR creating composition g-C3N4
# ERR creating composition N-CNTs@Co
# ERR creating composition PRGI/Pt
# ERR creating composition PRGI/Pt
# ERR creating composition V2O5@pDA@MnO2
# ERR creating composition V2O5@pDA@MnO2
# ERR creating composition PEIeAuNPseMnIIIPPIX
# ERR creating composition Au-Ag-AFT
# ERR creating composition Au-Ag-AFT
# ERR creating composition Au-Ag-AFT
# ERR creating composition Se-DL-Cysteine
# ERR creating composition Se-DL-Cysteine
# ERR creating composition Apt–Au NPs/BiOCl
# ERR creating composition Apt–Au NPs/BiOCl
# ERR creating composition Apt–Au NPs/BiOCl
# ERR creating composition Apt–Au NPs/BiOCl
# ERR creating composition Fe3O4@MoS2-1%Ag
# ERR creating composition Fe3O4@MoS2-1%Ag
# ERR creating composition ADM-Fe3+
# ERR creating composition ADM-Fe3+
# ERR creating composition ADM-Fe3+
# ERR creating composition Cu xO
# ERR creating composition Cu xO
# ERR creating composition Cu xO
# ERR creating composition seleno-LuGST1-1
# ERR creating composition seleno-LuGST1-1
# ERR creating composition seleno-LuGST1-1
# ERR creating composition seleno-LuGST1-1
# ERR creating composition seleno-LuGST1-1
# ERR creating composition seleno-LuGST1-1
# ERR creating composition Cytc
# ERR creating composition 3,8-DMD(Fe3+)-6-mer/T
# ERR creating composition 3,8-DMD(Fe3+)-6-mer/A
# ERR creating composition 2,8-DPF(Fe3+)-6-mer/T
# ERR creating composition 2,8-DPF(Fe3+)-6-mer/A
# ERR creating composition FeT(4-TAP)P
# ERR creating composition FeT(4-TAP)P
# ERR creating composition MnT(4-TAP)P
# ERR creating composition MnT(4-TAP)P
# ERR creating composition G4-hpDNA
# ERR creating composition BSA-Au
# ERR creating composition hSOD1
# ERR creating composition hSOD1
# ERR creating composition Nak-YCC3.5
# ERR creating composition Nak-YCC3.5
# ERR creating composition Nak-YCC3.5
# ERR creating composition Nak-YCC3.5
# ERR creating composition Nak-YCC3.5
# ERR creating composition Nak-YCC3.5
# ERR creating composition Nak-TMut3.5
# ERR creating composition Nak-TMut3.5
# ERR creating composition FeOxH–rGO
# ERR creating composition FeOxH–rGO
# ERR creating composition I-
# ERR creating composition I-
# ERR creating composition CeO2@MMT(2:8)
# ERR creating composition CeO2@MMT(2:8)
# ERR creating composition CeO2@MMT(2:8)
# ERR creating composition CeO2@MMT(1:9)
# ERR creating composition CeO2@MMT(1:9)
# ERR creating composition CeO2@MMT(1:9)
# ERR creating composition N-CNTs
# ERR creating composition N-CNTs
# ERR creating composition Au-Pt
# ERR creating composition Au-Pt
# ERR creating composition AuNC/GNR
# ERR creating composition AuNC/GNR
# ERR creating composition 1
# ERR creating composition 1
# ERR creating composition 1
# ERR creating composition HRP-PEG 5000
# ERR creating composition HRP-PEG 20000
# ERR creating composition HRP-PEG 40000
# ERR creating composition HRP-PEG 5000, co-lyophilized
# ERR creating composition HRP-PEG 20000, co-lyophilized
# ERR creating composition HRP-PEG 40000, co-lyophilized
# ERR creating composition Arg51Gln
# ERR creating composition Arg51Asn
# ERR creating composition Arg51Leu
# ERR creating composition Arg51Lys
# ERR creating composition TMBDA-MIL-100(Fe)
# ERR creating composition TMBDA-MIL-100(Fe)
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition metHb
# ERR creating composition metHb
# ERR creating composition myoglobin
# ERR creating composition myoglobin
# ERR creating composition Pt-on-Pd/RGO
# ERR creating composition Pt-on-Pd/RGO
# ERR creating composition NH2-MIL-101(Fe)
# ERR creating composition NH2-MIL-101(Fe)
# ERR creating composition NADPH oxidase
# ERR creating composition NADPH oxidase
# ERR creating composition MoS2/g-C3N4
# ERR creating composition MoS2/g-C3N4
# ERR creating composition [Co(L)(H2O)2]n
# ERR creating composition [Co(L)(H2O)2]n
# ERR creating composition Mo SA–N 3–C
# ERR creating composition Mo SA–N 3–C
# ERR creating composition Fe-N-C
# ERR creating composition Fe-N-C
# ERR creating composition 2-SeCD
# ERR creating composition Pc(OH)8/CoSn(OH)6
# ERR creating composition Pc(OH)8/CoSn(OH)6
# ERR creating composition catalase
# ERR creating composition Cu(NO3)2·3H2O
# ERR creating composition Cu(NO3)2·3H2O
# ERR creating composition G-quadruplex-Cu2+
# ERR creating composition G-quadruplex-Cu2+
# ERR creating composition HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating composition HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating composition HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating composition HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating composition HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating composition HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating composition HVA:hemin:ACM:4-Vpy:EGDMA
# ERR creating composition SrTiO3/DHB
# ERR creating composition AuPd-PDA
# ERR creating composition AuPd-PDA
# ERR creating composition GSH-Px
# ERR creating composition GSH-Px
# ERR creating composition Fe-Ag2S
# ERR creating composition Fe-Ag2S
# ERR creating composition MbFe(IV)dO
# ERR creating composition MbFe(IV)dO
# ERR creating composition MbFe(IV)dO
# ERR creating composition MbFe(IV)dO
# ERR creating composition GO-Cyt c_1 min
# ERR creating composition GO-Cyt c_1 min
# ERR creating composition GO-Cyt c_5 h
# ERR creating composition GO-Cyt c_5 h
# ERR creating composition metMb
# ERR creating composition metMb
# ERR creating composition Fe3O4-chitosan-tripolyphosphate-calcium
# ERR creating composition Fe3O4-chitosan-tripolyphosphate-calcium-glucose oxidase-concanavalin A
# ERR creating composition Fe3O4-chitosan-tripolyphosphate-calcium-glucose oxidase-concanavalin A
# ERR creating composition Fe3O4-chitosan-tripolyphosphate-calcium-glucose oxidase-concanavalin A
# ERR creating composition Fe3O4-chitosan-tripolyphosphate-calcium-glucose oxidase-concanavalin A
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition His-Ti3C2
# ERR creating composition His-Ti3C2
# ERR creating composition Ala-Ti3C2
# ERR creating composition Ala-Ti3C2
# ERR creating composition HRP/CHIT/CMS
# ERR creating composition ZnO–g-C3N4/MoS2
# ERR creating composition ZnO–g-C3N4/MoS2
# ERR creating composition 6,60-telluro-bis (6-deoxy-b-cyclodextrin)
# ERR creating composition 6,60-telluro-bis (6-deoxy-b-cyclodextrin)
# ERR creating composition 6,60-ditelluro-bis (6-deoxy-b-cyclodextrin)
# ERR creating composition 6,60-ditelluro-bis (6-deoxy-b-cyclodextrin)
# ERR creating composition Fe(III)-porphyrin
# ERR creating composition Fe(III)-porphyrin
# ERR creating composition Se-SP-1
# ERR creating composition Se-SP-2
# ERR creating composition Fv
# ERR creating composition CoPc-MWCNT
# ERR creating composition CoPc-MWCNT
# ERR creating composition SWNT-3
# ERR creating composition SWNT-3
# ERR creating composition SWNT-4
# ERR creating composition SWNT-4
# ERR creating composition FeTSPc
# ERR creating composition MAP_2744c
# ERR creating composition MAP_2744c
# ERR creating composition MAP_2744c
# ERR creating composition MAP_2744c
# ERR creating composition Fe/C NS
# ERR creating composition Fe/C NS
# ERR creating composition PNPG-PEG
# ERR creating composition PNPG-PEG
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Prdx6
# ERR creating composition Prdx6
# ERR creating composition PPAM–N–CD–Te
# ERR creating composition Co-N-C
# ERR creating composition Co-N-C
# ERR creating composition CysSeSeCys
# ERR creating composition CysSeSeCys
# ERR creating composition CysSeSeCys
# ERR creating composition CysSeSeCys
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition Cytc
# ERR creating composition BP-IL-SWCNH
# ERR creating composition Hb
# ERR creating composition Fe3O4-Au
# ERR creating composition Fe3O4-Au
# ERR creating composition Cu3V2O7(OH)2·2H2O
# ERR creating composition Cu3V2O7(OH)2·2H2O
# ERR creating composition Cu3V2O7(OH)2·2H2O
# ERR creating composition Cu3V2O7(OH)2·2H2O
# ERR creating composition Fe(III)MP-8
# ERR creating composition Fe(III)MP-8
# ERR creating composition Fe(III)MP-8
# ERR creating composition Fe(III)MP-8
# ERR creating composition GMP-Cu
# ERR creating composition GMP-Cu
# ERR creating composition OPD-MoS2
# ERR creating composition OPD-MoS2
# ERR creating composition OPD-MoS2
# ERR creating composition OPD-MoS2
# ERR creating composition H2O2 + o-phenylenediamine
# ERR creating composition ficin
# ERR creating composition H&rGO
# ERR creating composition hemin
# ERR creating composition hemin
# ERR creating composition Pu39WT-hemin
# ERR creating composition HDP-ELP
# ERR creating composition Hb
# ERR creating composition Hb
# ERR creating composition Hb(cid:1)Hp
# ERR creating composition Hb(cid:1)Hp
# ERR creating composition (Et3NH)[Fe(bpb)Cl2]
# ERR creating composition (Et3NH)[Fe(bpb)Cl2]
# ERR creating composition NADH peroxidase
# ERR creating composition Cyt c
# ERR creating composition Fe2O3/Pt/CNTs
# ERR creating composition Fe2O3/Pt/CNTs
# ERR creating composition Fe2O3/Pt/CNTs
# ERR creating composition HSA + uric acid + Cu
# ERR creating composition HSA + uric acid + Cu
# ERR creating composition CDs@NC-3
# ERR creating composition CDs@NC-3
# ERR creating composition HPtNPs-Fe3O4
# ERR creating composition HbGp
# ERR creating composition HbGp
# ERR creating composition HbGp
# ERR creating composition HbGp
# ERR creating composition HbGp
# ERR creating composition HbGp
# /home/oleg/Programs/.venv/lib/python3.12/site-packages/pymatgen/core/composition.py:328: UserWarning: No Pauling electronegativity for Ds. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   return sum((el.X * abs(amt) for el, amt in self.items())) / self.num_atoms
# /home/oleg/Programs/.venv/lib/python3.12/site-packages/pymatgen/core/composition.py:328: UserWarning: No Pauling electronegativity for Ts. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   return sum((el.X * abs(amt) for el, amt in self.items())) / self.num_atoms
# /home/oleg/Programs/.venv/lib/python3.12/site-packages/pymatgen/core/composition.py:328: UserWarning: No Pauling electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   return sum((el.X * abs(amt) for el, amt in self.items())) / self.num_atoms
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 9040   NaN
# 9041   NaN
# 9042   NaN
# 9043   NaN
# 9044   NaN
# Name: formula, Length: 9045, dtype: float64

# %%
res_df["X"] = df["formula"].apply(createX)

# %%
st = pd.read_csv("./data/existing_datasets/start_df.csv")

# %%
fin = pd.read_csv("./data/existing_datasets/final_df.csv")

# %%
fin[fin["id"].isin(st[st["formula"].apply(createX).isna()]["#"])]
# Out:
# ERR creating composition (CeO2)0.10/CoO
# ERR creating composition (CeO2)0.10/CoO
# ERR creating composition CoO/CeO2
# ERR creating composition CoO/CeO2
# ERR creating composition Co3O4/CeO2
# ERR creating composition Co3O4/CeO2
# ERR creating composition Pd/CeO2
# ERR creating composition Pd/CeO2
# ERR creating composition Ce-Fe3O4
# ERR creating composition Ce-Fe3O4
# ERR creating composition Fe3O4-MnO2
# ERR creating composition Fe3O4-MnO2
# ERR creating composition Pt-WO2.72
# ERR creating composition Pt-WO2.72
# ERR creating composition Co3O4/CeO2
# ERR creating composition Co3O4/CeO2
# ERR creating composition Au-Cu2O
# ERR creating composition Au-Cu2O
# ERR creating composition Au-CeO2
# ERR creating composition Au-CeO2
# ERR creating composition CuO/Pt
# ERR creating composition CuO/Pt
# ERR creating composition Cu-CuFe2O4
# ERR creating composition Cu-CuFe2O4
# ERR creating composition Ru/C
# ERR creating composition Ru/C
# ERR creating composition Fe/CeO2
# ERR creating composition Fe/CeO2
# ERR creating composition TiO2/TiN
# ERR creating composition TiO2/TiN
# ERR creating composition Cu-Fe4(Fe(CN)6)3
# ERR creating composition Cu-Fe4(Fe(CN)6)3
# ERR creating composition Co3O4/MoO3
# ERR creating composition Co3O4/MoO3
# ERR creating composition Fe2O3-Fe4(Fe(CN)6)3
# ERR creating composition Fe2O3-Fe4(Fe(CN)6)4
# ERR creating composition Pt0.1-CdS
# ERR creating composition Pt0.1-CdS
# ERR creating composition Ru0.1-V2O4
# ERR creating composition Ru0.1-V2O4
# ERR creating composition Ru0.1-V2O4
# ERR creating composition Au-Pt
# ERR creating composition Mo0.02-Co3O4
# ERR creating composition Mo0.02-Co3O4
# ERR creating composition Fe3O4-Pt0.15
# ERR creating composition Fe3O4-Pt0.15
# ERR creating composition Si-Fe3O4
# ERR creating composition Si-Fe3O4
# ERR creating composition (FeS2)0.3-SiO2
# ERR creating composition (FeS2)0.3-SiO2
# ERR creating composition FeS2-C
# ERR creating composition FeS2-C
# ERR creating composition Pt0.5-MoO3
# ERR creating composition Pt0.5-MoO3
# ERR creating composition Pt0.5-MoO3
# ERR creating composition Pt0.5-MoO3
# ERR creating composition N0.1-MoS2
# ERR creating composition N0.1-MoS2
# ERR creating composition Pd0.2-Fe3O4
# ERR creating composition Pd0.2-Fe3O4
# ERR creating composition Pd0.2-Fe3O4
# ERR creating composition Pd0.2-Fe3O4
# ERR creating composition Pd0.2-Fe3O4
# ERR creating composition Pd0.2-Fe3O4
# ERR creating composition Pt0.48Pd0.52-Fe3O4
# ERR creating composition Pt0.48Pd0.52-Fe3O4
# ERR creating composition Pd@Pt3-Ru
# ERR creating composition Pd@Pt3-Ru
# ERR creating composition Pd@Pt-Ru
# ERR creating composition Pd@Pt-Ru
# ERR creating composition Pd@Pt-Ru3
# ERR creating composition Pd@Pt-Ru3
# ERR creating composition Pd@Pt-Ru
# ERR creating composition Pd@Pt-Ru
# ERR creating composition Pd@Pt-Ru
# ERR creating composition Pd@Pt-Ru
# ERR creating composition Ag0.26-Au0.3@CeO2
# ERR creating composition Ag0.26-Au0.3@CeO2
# ERR creating composition Au0.1/Co3O4-CeO2
# ERR creating composition Au0.1/Co3O4-CeO2
# ERR creating composition Co3O4/CuO
# ERR creating composition (Co,Mn)3O4
# ERR creating composition Au0.02/Fe2O3
# ERR creating composition Au0.02/Fe2O3
# ERR creating composition Pt/ZnCo2O4
# ERR creating composition Pt/ZnCo2O4
# ERR creating composition Pt/CeO2
# ERR creating composition Pt/CeO2
# ERR creating composition CoMn2O4/Mn2O3
# ERR creating composition Pr0.05-CeO2
# ERR creating composition Pr0.1-CeO2
# ERR creating composition Pr0.15-CeO2
# ERR creating composition Pr0.2-CeO2
# ERR creating composition Fe2O3/Fe4(Fe(CN)6)4
# ERR creating composition Fe2O3/Fe4(Fe(CN)6)4
# ERR creating composition Ni/CoMoO4
# ERR creating composition Ni/CoMoO4
# ERR creating composition Ni/CoMoO4
# ERR creating composition NiCo2O4-Au0.44
# ERR creating composition NiCo2O4-Au0.44
# ERR creating composition NiCo2O4-Au0.44
# ERR creating composition Au-Pt0.25
# ERR creating composition Au-Pt0.17
# ERR creating composition Au-Pt0.10
# ERR creating composition Au-Pt0.25
# ERR creating composition Au-Pt0.25
# ERR creating composition Au-Pt0.25
# ERR creating composition Au-Pt0.25
# ERR creating composition NiMoO4-Cu
# ERR creating composition NiMoO4-Cu
# ERR creating composition CoMoO4-Cu
# ERR creating composition CoMoO4-Cu
# ERR creating composition LaNiO3-H2
# ERR creating composition Co3O4/Rh0.125
# ERR creating composition (Fe3O4)0.1/CuO1.5
# ERR creating composition (Fe3O4)0.1/CuO1.5
# ERR creating composition (CeO2)0.10/Co3O4
# ERR creating composition (CeO2)0.10/Co3O4
# ERR creating composition Cu2(OH)3Cl-CeO2
# ERR creating composition Cu2(OH)3Cl-CeO2
# ERR creating composition Ag/Ag3PO4
# ERR creating composition Ag/Ag3PO4
# ERR creating composition (CeO2)0.1/TiO2
# ERR creating composition (CeO2)0.1/TiO2
# ERR creating composition Fe0.15-CoO
# ERR creating composition Fe0.15-CoO
# ERR creating composition Co0.5-Fe3O4
# ERR creating composition Co0.5-Fe3O4
# ERR creating composition Fe3O4-Cu-Cu2O
# ERR creating composition Fe3O4-Cu-Cu2O
# ERR creating composition Fe3O4-Cu-Cu2O
# ERR creating composition Fe3O4-Cu-Cu2O
# ERR creating composition Fe3O4-Cu-Cu2O
# ERR creating composition Fe3O4-Cu-Cu2O
# ERR creating composition Fe2O3/Fe4(Fe(CN)6)4
# ERR creating composition Fe2O3/Fe4(Fe(CN)6)4
# ERR creating composition Si-CoO
# ERR creating composition Si-CoO
# ERR creating composition Cu-CuFe2O4
# ERR creating composition Cu-CuFe2O4
# ERR creating composition Fe2O3/CoNi
# ERR creating composition Fe2O3/CoNi
# ERR creating composition MoS2/Fe3O4
# ERR creating composition MoS2/Fe3O4
# ERR creating composition MoS2–Pt0.74Ag0.26
# ERR creating composition MoS2–Pt0.74Ag0.26
# ERR creating composition Fe-Ag2S
# ERR creating composition Fe-Ag2S
# ERR creating composition 4N-TiO2
# ERR creating composition 4N-TiO2
# ERR creating composition 4N-TiO2
# ERR creating composition 4N-TiO2
# ERR creating composition Pd/C
# ERR creating composition Pd/C
# ERR creating composition Pd-As0.01
# ERR creating composition Pd3.5-Ir
# ERR creating composition Pd3.5-Ir
# ERR creating composition Pd3.5-Ir
# ERR creating composition Pd3.5-Ir
# ERR creating composition Pd/C3N4
# ERR creating composition Fe–Mn
# ERR creating composition MnO2/C
# ERR creating composition Cu/Cu2O
# ERR creating composition Cu/Cu2O
# ERR creating composition H-MnO2
#          Km       Vmax    id  activity       X      IR    pot2   ph  temp  \
# 56    0.245  0.0001478    58         1  2.8696  1.1562 -0.2150  5.0  25.0
# 57    0.133   0.001101    59         1  2.8828  1.1208 -0.2150  5.0  25.0
# 58     1.81   2.70E-05    60         1  2.8206  1.1762 -0.2150  3.6  25.0
# 59    0.021   2.80E-05    61         1  2.7826  1.1878 -0.2150  3.6  25.0
# 60     0.36  0.0001666    62         1  2.7966  1.1608 -0.2900  6.0  30.0
# ...     ...        ...   ...       ...     ...     ...     ...  ...   ...
# 1104    0.2  0.0001025  1175         2  2.7432  1.0962  0.3222  3.0  25.0
# 1109   0.11   0.000244  1181         2  2.7452  1.1496  0.3222  4.0  25.0
# 1110  0.356       0.64  1182         2  2.7486  1.1434  0.0784  7.4  28.0
# 1111  0.189      0.907  1183         2  2.3700  1.1686  0.5208  7.4  35.0
# 1119  0.781   0.000668  1191         2  2.2800  1.3500  1.2000  4.0  41.4
#
#       dstr  ...  TPSA2    TPSA  XLogP  MaxEStateIndex.1  MaxEStateIndex.2  \
# 56       3  ...  52.00    0.00    0.0          6.000000          5.992739
# 57       3  ...  40.50    0.00    0.0          5.992739          6.000000
# 58       1  ...  40.50    0.00    0.0          5.992739          6.000000
# 59       1  ...  52.00    0.00    0.0          6.000000          5.992739
# 60       1  ...  40.50   20.31    0.4          5.992739          6.000000
# ...    ...  ...    ...     ...    ...               ...               ...
# 1104     3  ...  40.50    0.00    0.0          5.992739          0.000000
# 1109     1  ...  40.50    0.00    0.0          5.992739          0.000000
# 1110     3  ...  47.40    0.00    0.0         10.532445          0.000000
# 1111     3  ...  50.38  158.82   -4.5         10.532445          0.000000
# 1119     3  ...  45.78  132.13   -1.7          5.992739          0.000000
#
#       MinPartialCharge.1  MaxPartialCharge.1  BCUT2D_CHGLO     polym  \
# 56             -0.254557           -0.254557      0.000000  0.000000
# 57             -0.398299            0.037337      0.000000  0.000000
# 58             -0.398299            0.037337      0.000000  0.000000
# 59             -0.254557           -0.254557      0.000000  0.000000
# 60             -0.398299            0.037337     -2.048433  0.000000
# ...                  ...                 ...           ...       ...
# 1104           -0.398299            0.037337      0.000000  0.000000
# 1109           -0.398299            0.037337      0.000000  0.000000
# 1110           -0.505047            0.377497      0.000000  0.000000
# 1111           -0.505047            0.377497     -2.157158  1.000007
# 1119           -0.398299            0.037337     -2.178395  0.999984
#
#       Complexity
# 56           0.0
# 57           0.0
# 58           0.0
# 59           0.0
# 60           0.0
# ...          ...
# 1104         0.0
# 1109         0.0
# 1110         0.0
# 1111       389.0
# 1119         0.0
#
# [156 rows x 48 columns]

# %%
createX("CoO")
# Out:
# 2.66

# %%
createX("SeO2")
# Out:
# 3.143333333333333

# %% [markdown]
# ## IR

# %%
banned_oxi = ['HRP', 'H10Q', 'H10A', 'GSH', 'GrdB', 'Cu 1.8S', 'K12[Ga4L6]', 'C14H24N2O2Se',
              'C30H24N2O2Se', 'C30H48N2O2Se', 'C16H24N2O2Se', 'FeMP', 'C15H21NOSe',
              'C16H21NOSe', 'C24H32N2O2Se2', 'C20H20N2O2Se2', 'K0.8Fe0.8Ti1.2O4', 'PTEBS',
              'C22H24N2O2Se2', '[Gly64]Mb', 'PS2.MA4', 'PS2.MA20', 'RBCm@Ru@MnO2', 'GNRs',
              'BSA', 'OsAPX', 'MPO', 'PANI', 'COX', 'Fe4[Fe(CN)6]3', 'POX 1B', 'C96H160O66N2Se2',
              'DNA50', 'C22H22Br2N2O10Se2', 'C22H24N2O6Se2', 'C18H22N2O6Se', 'C20H26N2O6Se', 'C20H20N2O6Se2',
              'PZ51', 'GAPDH', 'GQDs', 'C14H11NO3Se', 'C18H14OSe', 'C15H14O2Se', 'C3N4@NMF', 'C20H24N2O6Se2',
              'C34H28Fe2N2O2Se2', 'C30H36Fe2N2O2Se2', 'C38H38Fe2N2O2Se2', 'C26H28N2Se2', 'C12H6N4O8Se2',
              'P450CLA', 'C23H34N4O8SSe', 'Fe(III)Mb', 'G34C', 'A50C', 'DAB', 'GNR', 'STAP', 'C15H10O2',
              'C14H11NO2Se', 'PRDX1', 'K79A', 'K73A', 'K72AK73A', 'K72AK73AK79A', 'C13H9NOSe', 'PRX1',
              'Fe0.5Co0.5', 'TMB', 'TcGPXI', 'GFeF', 'CQDs', 'GO', 'C28H22O8', 'C29H24O8', 'C30H24O9',
              'C32H26O10', 'C19H24N3O3Se', 'C21H21N2O2Se', 'C20H31N4O', 'C16H19N2O2Se', 'C14H19N2O',
              'C27H33N4O2Se', 'C18H23N2O4Se', 'C16H21N2O2Se', 'EbMe', 'EbTe2', 'Ag2S@GO', 'GDYO', 'NADPH',
              'NADH', 'C12H14N4', 'Au140RS60', 'APX1', 'GGGTGGGAnGGGTGGG', 'GGGTGGGTGGGTGGG',
              'GGGTGGGTGGGTGGGAnGGGTGGGTGGG', 'GGGTGGGTGGGTGGGA7GGGTGGGTGGG', 'GST M208A', 'GST R15K',
              'C34H32N4O4FeCl', 'C15H10O7', 'C20H28N2O2Se2', 'PS2.M', 'Fe SAzyme', 'Zn SAzyme', 'C20H14N2O3Se',
              'HRP 5000', 'FeAC', 'Au 9.8Pd 90.2', 'CuI 4L 4', 'Ce0.5Zr0.5O2', 'CeGONRs', 'Fe3[Fe(CN)6]2', 'RNP',
              '[H2N(CH2)3]8Si8Co6O12(OH)4', 'HSA', 'MnP S168W', 'DMOP', 'CAPOA1', 'CAPOT1', 'CAPO1', 'C19H14BrN3O2Se',
              'C18H19BrN2O2Se', 'C17H17BrN2O2Se', 'C12H13O2.50Se', 'L29H Mb', 'Mn0.15Fe0.85Fe2O4', 'Mn0.5Fe0.5Fe2O4',
              'GHZ', 'CYP25', 'CuNiAl LDH', 'SAA', 'C20H29NO2SSe', 'PtCo@G', 'ATP A2', 'HRP A2', 'BiSA@Au', 'T67R Mb',
              'T67K Mb', 'BSA@AuNCs', 'PZ 51', 'TMPD', 'LPO', 'LspPOX', 'Fe(III)HRP', 'Mn(III)HRP', 'FeTBAP', 'C9H11NOSe',
              'C11H16NOSe', 'SAG', 'C8H18O2Se2', 'AF', 'W96A', 'F405L', 'F393A', 'M237V',
              'KFe(III)[Fe(CN) 6]Fe 2(III)(OH)(DMF)O(BDC) 3', 'C12H10O2Se2', 'C12H10O3Se2', 'D153A', 'N246A',
              'C13H8Cl2N2O2Se', 'C13H8Br2N2O2Se', 'C13H9Br3N2O2Se', 'C14H14O3Se', 'C18H12N2O2', 'FCG', 'AtGLB1',
              'AtGLB2', 'AtGLB3', 'TSA', 'AhpC', 'LmPP', 'V90H', 'Cu 0.3Co 2.7O 4', 'C1H0.677O0.586N0.015Na0.069',
              'C34H32ClFeN4O4', 'ESeSAr', 'C26H20N2O2Se', 'C26H20N2O2Te', 'C27H20Cl2N2O2Se', 'C28H18N2O2.5Te',
              'C26H18N2O2Te', 'BAFA', 'MbFeIII', 'C14H18N2Se2', 'C22H26N2Se2', 'C14H17NSe', 'C18H21NSe', 'ETP',
              'WT Mb', 'Fe 1.44O 0.32 (OH) 3.86', 'C34H32FeN4O4', 'ABTS', 'PdCu@HRP', 'C62(COOH)4', 'AnnAt1',
              'C60[C(COOH)2]2', 'Y103F Mb', 'VO(DAC)2', 'D138V', 'C16H18O4Se', 'C18H22O6Se', 'C20H26O8Se', 'CAT',
              'CNA', 'FePPIX', 'C26H40N2Se2', 'C16H20N2Se2', 'C18H24N2Se2', 'C20H28N2Se2', 'H39Q', 'GSeSeG',
              'C18H15N2O11Se2', 'C18H16N2O8Se', 'C18H15N2O8Se2', 'DOPA', 'C44H81O10NP', 'CYP119A1', 'BMP',
              'CYP152A1', 'CYP101A1', 'Cu 3.2(PO 4) 2@GOD', 'Cu 0.89Zn 0.11O', 'EPO', 'CPZ', 'CCP(M1)', 'W51F',
              'W191F', 'HRPC', 'Fe3O4@MOF', 'GIM', 'DMP', 'C15H10O5', 'C15H10O6', 'FeCPNGs', 'BSA@Au', 'Pd@PEDOT',
              'H404A', 'D292A', 'H496A', 'R490A', 'R360A', 'K353A', 'Au127SR51', 'Au127SR65', 'OsGrx', 'B(C6F5)3',
              'C25H14O7', '(T 3G 2) 4', 'T 2G 3', 'H48Q', 'Ce61Zr39O4(OH)4(BDC)6', 'Ce28Zr72O4(OH)4(BDC)6',
              'Ce43Zr57O4(OH)4(BDC)6', 'Ce87Zr13O4(OH)4(BDC)6', 'MMb', 'C282H432N80O80S4Fe', 'C4H10N130Te', 'C5H12N130Te',
              'CuC19H14N4O2', 'PGP', 'PMNT', 'MnTBAP', 'AuMS', 'C100H180N20O24', 'DMSN@AuPtCo', 'CYP119', 'GCDSA', 'MTP',
              'C20H10F2O5', 'Ni(C30H28N4O4S2)', 'Ni(C31H30N4O4S2)', 'AuAMP', 'C18H20N2O2Se2', 'C22H28N2O2Se2', 'C26H36N2O2Se2',
              'C26H40N2O2Se2', 'PMGO', 'CYP175A1', 'L80H', 'L80Q', 'Cu2Ag0.53Fe0.465(CN)6', 'Pd12L6', 'BM3', 'HRPR', 'GFH',
              'GPX1', 'WPTP E254G', 'BPQDs', 'Co1.5Mn1.5O4', 'Ru@G', 'PEDOT', 'ZPOA', 'HRPA', 'DMA', 'DNAzyme']

# %%
def createIR(formula):
    global banned_oxi
    if uf.check_nan(formula) or formula in banned_oxi:
        return np.nan

    try:
        composition = fu.Composition(formula)
    except:
        print(f"ERR creating composition {formula}")
        return np.nan

    element_counts = fu.elfromcomp(composition)
    sum_atoms = 0
    res = []

    try:
        oxi_state = fu.OS(formula)
    except:
        banned_oxi += [formula]
        print(f"ERR creating OS {formula}")
        return np.nan

    for atom, _ in composition.items():
        try:
            ir = atom.ionic_radii[int(oxi_state[str(atom)])]
            # print(atom, oxi_state[str(atom)], ir, element_counts[str(atom)])
        except:
            print(f"ERR getting ionic radii {formula}; {atom};")#{atom.ionic_radii}; {oxi_state[str(atom)]};")
            return np.nan
        sum_atoms += element_counts[str(atom)]
        res.append(element_counts[str(atom)] * ir)
        
    IR = sum(res)/sum_atoms
    return IR

# %%
res_df["IR"] = df["formula"].apply(createIR)

# %% [markdown]
# ## pot2

# %%
def createPot2(formula):
    global banned_oxi
    if uf.check_nan(formula) or formula in banned_oxi:
        return np.nan

    try:
        intindex_comp = fu.intindex(formula)
    except:
        print(f"ERR creating intindex {formula}")
        return np.nan

    # print(intindex_comp)
    try:
        os_comp = fu.OS(intindex_comp)
    except:
        print(f"ERR creating os_comp {formula} {intindex_comp}")
        return np.nan

    atom_counts = fu.elfromcomp(fu.Composition(intindex_comp))
    redox_list = []
    for atom, oxi in os_comp.items():

        try:
            elem = fu.Element(atom)
        except:
            print(f"ERR creating element {formula} {atom}")
            return np.nan


        if elem.is_metal:
            # print('is me')
            if oxi <= 0:
                redox_list.append(0)
            else:
                redox_list.append(
                    fu.Redox(
                        atom, 
                        int(round(oxi))
                    ) * atom_counts[atom]
                )
    
    return sum(redox_list)/sum(atom_counts.values())

# %%
res_df["pot2"] = df["formula"].progress_apply(createPot2)

# %% [markdown]
# ## ph

# %%
res_df["ph"] = df["ph"]

# %% [markdown]
# ## temp

# %%
res_df["temp"] = df["temp, °C"]

# %% [markdown]
# ## dstr

# %%
def createDstr(sizes):
    l, w, d = sizes
    if uf.check_nan(l) or uf.check_nan(w) or uf.check_nan(d):
        return np.nan

    sizes_list = [l, w, d]
    sizes_list.sort(reverse=True)
    l, w, d = sizes_list
    

    big_diff_lw = l/w>6
    big_diff_ld = l/d>6

    if big_diff_lw and big_diff_ld:
        dstr = 1
    elif big_diff_lw or big_diff_ld:
        dstr = 2
    else:
        dstr = 3
    return dstr

# %%
res_df["dstr"] = df[["length, nm", "width, nm", "depth, nm"]].apply(createDstr, axis=1)

# %% [markdown]
# ## C (Cmin, Cmax, lgCmin ...)

# %%
res_df["Cmin"] = df["C min, mM"]
res_df["Cmax"] = df["C max, mM"]
res_df["lgCmin"] = np.log10(res_df["Cmin"])
res_df["lgCmax"] = np.log10(res_df["Cmax"])

# %%
res_df["Cconst"] = df["C(const), mM"]
res_df["Ccat"] = df["Ccat(mg/mL)"]
res_df["lgCconst"] = np.log10(res_df["Cconst"])
res_df["lgCcat"] = np.log10(res_df["Ccat"])

# %% [markdown]
# ## lgvolume

# %%
def createLgvolume(sizes):
    l, w, d = sizes
    if uf.check_nan(l) or uf.check_nan(w) or uf.check_nan(d):
        return np.nan
    return np.log10(l*w*d)

# %%
res_df["lgvolume"] = df[["length, nm", "width, nm", "depth, nm"]].apply(createLgvolume, axis=1)

# %% [markdown]
# ## Km, Vmax

# %%
res_df["Km"] = df["Km, mM"]
res_df["Vmax"] = df["Vmax, mM/s"]

# %% [markdown]
# ## activity

# %%
res_df["activity"] = df["activity"].apply(uf.map_activity)

# %% [markdown]
# ## polymer, surfactant, reaction_type descriptors

# %%
history = {}
h_prop = {}
h_comp = {}

# %%
def get_gescriptors_by_names(names, use_history=True):
    '''
    names - List of names of chemicals
    '''

    if use_history and (names in history):
        return history[names]

    ### pubchem descriptors
    # mw = 0
    tpsa = 0
    comp = 0
    logp = 0
    for name in names:
        if name in h_prop:
            prop = h_prop[name]
        else:
            prop = fu.pcp.get_properties(
                ['MolecularWeight', 'XLogP','TPSA', 'Complexity'],
                fu.monomer(name), 
                'name'
            )
            h_prop[name] = prop
        
        if len(prop) < 1:
            # if molecue not found then set nan values
            print(f"ERR PCP not found get_properties {name}")
            # mw = np.nan
            tpsa = np.nan
            P = np.nan
            comp = np.nan
            break
        prop = prop[0]
            

        # polym = float(mcoat)*1000/float(mw) ## i don't have mcoat
        # mw += float(prop.get('MolecularWeight', np.nan))
        if len(names) == 1:
            logp = prop.get('XLogP', np.nan)
        tpsa += float(prop.get('TPSA', np.nan))
        comp = float(prop.get('Complexity', np.nan))

    # convert zeros to nan
    # mw = mw if mw else np.nan
    tpsa = tpsa if tpsa else np.nan
    logp = logp if logp else np.nan
    comp = comp if comp else np.nan

    desc_pubchem = {
        # "MolWt": mw,
        "XLogP": logp,
        "TPSA": tpsa,
        "Complexity": comp,
    }

    ### RDKit descriptors
    smiles_list = []
    for name in names:
        if name in h_comp:
            smiles_obj = h_comp[name]
        else:
            smiles_obj = fu.pcp.get_compounds(fu.monomer(name), 'name')
            h_comp[name] = smiles_obj

        if len(smiles_obj) < 1:
            print(f"ERR PCP not found get_compounds {name}")
            desc_rdkit = {
                "MolWt": np.nan,
                "PEOE_VSA7": np.nan,
                "PEOE_VSA9": np.nan,
                "VSA_EState8": np.nan,
                "Kappa2": np.nan,
                "BalabanJ": np.nan,
                "MinAbsEStateIndex": np.nan,
                "MinEStateIndex": np.nan,
                "EState_VSA6": np.nan,
                "VSA_EState4": np.nan,
                "PEOE_VSA8": np.nan,
                "MinPartialCharge": np.nan,
                "EState_VSA4": np.nan,
                "SMR_VSA7": np.nan,
                "BCUT2D_CHGLO": np.nan,
                "MaxEStateIndex": np.nan,
                "MaxPartialCharge": np.nan,
            }
            desc = {**desc_pubchem, **desc_rdkit}
            history[names] = desc
            return desc

        smiles_list.append(smiles_obj[0].isomeric_smiles)

    if len(smiles_list) < 1:
        desc_rdkit = {
                "MolWt": np.nan,
                "PEOE_VSA7": np.nan,
                "PEOE_VSA9": np.nan,
                "VSA_EState8": np.nan,
                "Kappa2": np.nan,
                "BalabanJ": np.nan,
                "MinAbsEStateIndex": np.nan,
                "MinEStateIndex": np.nan,
                "EState_VSA6": np.nan,
                "VSA_EState4": np.nan,
                "PEOE_VSA8": np.nan,
                "MinPartialCharge": np.nan,
                "EState_VSA4": np.nan,
                "SMR_VSA7": np.nan,
                "BCUT2D_CHGLO": np.nan,
                "MaxEStateIndex": np.nan,
                "MaxPartialCharge": np.nan,
            }
    else:
        mol = fu.Chem.MolFromSmiles(".".join(smiles_list))
        # print(smiles_list)
        allDescrs = fu.getMolDescriptors(mol)
        # print(allDescrs.keys())
        desc_rdkit = {
            "MolWt": allDescrs["MolWt"],
            "PEOE_VSA7": allDescrs["PEOE_VSA7"],
            "PEOE_VSA9": allDescrs["PEOE_VSA9"],
            "VSA_EState8": allDescrs["VSA_EState8"],
            "Kappa2": allDescrs["Kappa2"],
            "BalabanJ": allDescrs["BalabanJ"],
            "MinAbsEStateIndex": allDescrs["MinAbsEStateIndex"],
            "MinEStateIndex": allDescrs["MinEStateIndex"],
            "EState_VSA6": allDescrs["EState_VSA6"],
            "VSA_EState4": allDescrs["VSA_EState4"],
            "PEOE_VSA8": allDescrs["PEOE_VSA8"],
            "MinPartialCharge": allDescrs["MinPartialCharge"],
            "EState_VSA4": allDescrs["EState_VSA4"],
            "SMR_VSA7": allDescrs["SMR_VSA7"],
            "BCUT2D_CHGLO": allDescrs["BCUT2D_CHGLO"],
            "MaxEStateIndex": allDescrs["MaxEStateIndex"],
            "MaxPartialCharge": allDescrs["MaxPartialCharge"],
        }

    desc = {**desc_pubchem, **desc_rdkit}
    history[names] = desc
    return desc

# %% [markdown]
# ### Check how well this work

# %%
final_df = pd.read_csv("data/existing_datasets/final_df.csv")
start_df = pd.read_csv("data/existing_datasets/start_df.csv")

# %%
def get_row_descriptors(row, chemicals_columns = ["surface", "pol", "surf"]):
    rd = {}
    
    ### descriptors of surface, pol, surf
    chemicals = [row[col] for col in chemicals_columns]
    chemicals = [ch for ch in chemicals if ch not in ["0", "nan", "naked"] and not uf.check_nan(ch)]
    chemicals = tuple(chemicals)
    # print(chemicals)

    chemicals_descriptors = get_gescriptors_by_names(chemicals)
    # remove descriptors that aren't calculated for (surface, pol, surf)
    chemicals_descriptors = {key: value for key, value in chemicals_descriptors.items() if key not in ["MaxEStateIndex", "MaxPartialCharge", "Complexity"]}
    # print(chemicals_descriptors)
    rd.update(chemicals_descriptors)

    ### descriptors of reaction_type (ex.: TMB + H2O2)
    rd[f"MinPartialCharge.1"] = np.nan
    rd[f"MaxPartialCharge.1"] = np.nan
    rd[f"Complexity1"] = np.nan
    for i in range(2):
        rd[f"TPSA{i+1}"] = np.nan
        rd[f"MaxEStateIndex.{i+1}"] = np.nan


    if uf.check_nan(row["ReactionType"]):
        return rd
        

    chems = row["ReactionType"].replace(" + ", "+").split("+")
    chems = [ch.lstrip().rstrip() for ch in chems if ch not in ["0", "nan", ""] and not uf.check_nan(ch)]
    if len(chems) > 2:
        print("A lot of elements in reaction: ", "id", row["ReactionType"], chems)
        return rd

    for i, chem in enumerate(chems):
        desc = get_gescriptors_by_names((chem,))
        rd[f"TPSA{i+1}"] = desc["TPSA"]
        rd[f"MaxEStateIndex.{i+1}"] = desc["MaxEStateIndex"]
        if i == 0:
            rd[f"Complexity{i+1}"] = desc["Complexity"]
            rd[f"MinPartialCharge.{i+1}"] = desc["MinPartialCharge"]
            rd[f"MaxPartialCharge.{i+1}"] = desc["MaxPartialCharge"]

    return rd

# %%
from collections import defaultdict

# %%
n_of_good_convertions = 0
n_of_errors_by_key = defaultdict(int)
n_of_errors_by_row_id = defaultdict(int)

for i in tqdm(range(1000)):
    row = start_df.loc[i]
    id_ = row["#"]
    
    row_descriptors = get_row_descriptors(row)

    data = final_df[final_df["id"] == id_][[key for key in row_descriptors.keys()]]
    if data.shape[0] < 1:
        continue
        
    for key in row_descriptors.keys():
        eps = 0.01
        if "TPSA" in key:
            eps = 3

        orig = data[key].tolist()[0]
        
        # orig != 0 and descriptor is nan
        if orig > eps and uf.check_nan(row_descriptors[key]):
            if key == "XLogP":
                continue
            n_of_errors_by_key[key] += 1
            n_of_errors_by_row_id[id_] += 1
            print(id_, key, orig, row_descriptors[key])

        if abs(orig - row_descriptors[key])>eps:
            n_of_errors_by_key[key] += 1
            n_of_errors_by_row_id[id_] += 1
            print(id_, key, orig, row_descriptors[key])

    if n_of_errors_by_row_id[id_] == 0:
        n_of_good_convertions += 1

print(n_of_good_convertions)

# %% [markdown]
# ### apply to my data

# %%
new_rows = []
for row in tqdm(df.iloc, total=len(df)):
    new_rows.append(get_row_descriptors(row, ['pol', 'surf']))
new_df = pd.DataFrame(new_rows)

# %%
new_df

# %%
final_columns = final_df.drop(columns=['id', 'cryst', 'Mcoat', 'Sufrace', 'polym', 'Complexity']).columns.tolist()
new_final_df = pd.concat([res_df, new_df], axis=1)[final_columns]

# %%
new_final_df["id"] = pd.Series(np.arange(10000, 10000+len(new_final_df))+1)

# %%
new_final_df.to_csv("final_p2.csv", index=False)

# %%
start_columns = start_df.drop(
    columns=['#', 'type', 'Syngony', 'Sufrace', 'surface', 'Mw(coat), g/mol',
             'Subtype', 'Vsub_min(mL)', 'Vsub_max(mL)', 'Vsub_const(mL)',
             'Vcat(mL)', 'Ccat(mkM)', 'Vbuffer(mL)', 'Dstr', 'mX',
             'mROx', 'mCD', 'volume', 'Mr, g/mol', 'link']
).columns.tolist()
new_start_df = df.rename(columns={"SurfaceArea, m^2/g": "SurfaceArea, m^2/g "})[start_columns]
new_start_df["id"] = pd.Series(np.arange(10000, 10000+len(new_final_df))+1)

# %%
new_start_df.to_csv("start_p2.csv", index=False)
